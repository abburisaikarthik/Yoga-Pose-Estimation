#   inflating: dataset/train/warrior2/00000419.jpg
#   inflating: dataset/train/warrior2/00000420.jpg
#   inflating: dataset/train/warrior2/00000421.jpg
#   inflating: dataset/train/warrior2/00000423.jpg
#   inflating: dataset/train/warrior2/00000425.jpg
#   inflating: dataset/train/warrior2/00000426.jpg
#   inflating: dataset/train/warrior2/00000427.jpg
#   inflating: dataset/train/warrior2/00000428.jpg
#   inflating: dataset/train/warrior2/00000429.jpg
#   inflating: dataset/train/warrior2/00000430.jpg
#   inflating: dataset/train/warrior2/00000431.jpg
#  extracting: dataset/train/warrior2/00000432.png
#   inflating: dataset/train/warrior2/00000433.jpg
#   inflating: dataset/train/warrior2/00000434.jpg
#   inflating: dataset/train/warrior2/00000436.jpg
#   inflating: dataset/train/warrior2/00000437.jpg
#   inflating: dataset/train/warrior2/00000438.jpg

# %%
# !pip install mediapipe
# !pip install ultralytics
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.8/34.8 MB 40.9 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.23)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.25.2)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.8.0.76)
# Requirement already satisfied: protobuf<4,>=3.11 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.20.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.10 sounddevice-0.4.6
# Collecting ultralytics
#   Downloading ultralytics-8.1.20-py3-none-any.whl (716 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.3/716.3 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.1.20

# %%
import numpy as np
import pandas as pd
import os
import cv2
import csv
import itertools
import sys
import tempfile
import tqdm
import zipfile
import pickle
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import seaborn as sns
import mediapipe as mp
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
from pydantic import BaseModel
from PIL import Image
import glob

# %%
dataset_name = 'Kaggle Dataset'
train_dir = '/content/dataset/train'
test_dir = '/content/dataset/test'

# %% [markdown]
# # Xception Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)  # Automatically detects image format
        img = tf.image.resize(img, (299, 299))  # Resize image to match Xception input shape
        img = tf.keras.applications.xception.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue

    return df

def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df

# %%
train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)
# Out:
# Error loading image /content/dataset/train/tree/00000114.jpg: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} jpeg::Uncompress failed. Invalid JPEG data or crop window. [Op:DecodeImage] name:

# %%
X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1080, 299, 299, 3)
# (470, 299, 299, 3)
# (1080, 5)
# (470, 5)

# %%
xception_model = tf.keras.applications.Xception(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
xception_model.trainable = False

model = tf.keras.Sequential([
    xception_model,
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.6),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.6),
    keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer= keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  flatten_6 (Flatten)         (None, 204800)            0
#
#  dense_25 (Dense)            (None, 256)               52429056
#
#  batch_normalization_221 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_26 (Dense)            (None, 64)                16448
#
#  batch_normalization_222 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_27 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 73308589 (279.65 MB)
# Trainable params: 52446469 (200.07 MB)
# Non-trainable params: 20862120 (79.58 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_Xception.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 34/34 [==============================] - ETA: 0s - loss: 1.7523 - accuracy: 0.4287
# Epoch 1: val_accuracy improved from -inf to 0.64468, saving model to weights_Xception.keras
# 34/34 [==============================] - 29s 701ms/step - loss: 1.7523 - accuracy: 0.4287 - val_loss: 1.4367 - val_accuracy: 0.6447
# Epoch 2/50
# 34/34 [==============================] - ETA: 0s - loss: 1.0520 - accuracy: 0.6111
# Epoch 2: val_accuracy improved from 0.64468 to 0.86170, saving model to weights_Xception.keras
# 34/34 [==============================] - 15s 439ms/step - loss: 1.0520 - accuracy: 0.6111 - val_loss: 0.4331 - val_accuracy: 0.8617
# Epoch 13/50
# 34/34 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.9556
# Epoch 13: val_accuracy did not improve from 0.95957
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1383 - accuracy: 0.9556 - val_loss: 0.1763 - val_accuracy: 0.9426
# Epoch 14/50
# 34/34 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9750
# Epoch 14: val_accuracy did not improve from 0.95957
# 34/34 [==============================] - 12s 345ms/step - loss: 0.1128 - accuracy: 0.9750 - val_loss: 0.1679 - val_accuracy: 0.9532
# Epoch 15/50
# 34/34 [==============================] - ETA: 0s - loss: 0.1138 - accuracy: 0.9676
# Epoch 15: val_accuracy did not improve from 0.95957
# 34/34 [==============================] - 12s 345ms/step - loss: 0.1138 - accuracy: 0.9676 - val_loss: 0.1661 - val_accuracy: 0.9532
# Epoch 16/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0983 - accuracy: 0.9750
# Epoch 16: val_accuracy did not improve from 0.95957
# 34/34 [==============================] - 12s 346ms/step - loss: 0.0983 - accuracy: 0.9750 - val_loss: 0.1631 - val_accuracy: 0.9489
# Epoch 17/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9741
# Epoch 17: val_accuracy did not improve from 0.95957
# 34/34 [==============================] - 12s 347ms/step - loss: 0.0892 - accuracy: 0.9741 - val_loss: 0.1554 - val_accuracy: 0.9468
# Epoch 18/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9833
# Epoch 18: val_accuracy did not improve from 0.95957
# 34/34 [==============================] - 12s 346ms/step - loss: 0.0760 - accuracy: 0.9833 - val_loss: 0.1600 - val_accuracy: 0.9511

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of Xception with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_Xception.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of Xception with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_Xception.png')
plt.show()

# %%
model = tf.keras.models.load_model("weights_Xception.keras")
model.evaluate(X_test, y_test)
# Out:
# 15/15 [==============================] - 5s 219ms/step - loss: 0.1814 - accuracy: 0.9596
# [0.18135420978069305, 0.9595744609832764]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of Xception with {dataset_name}')
plt.savefig('Confusion_Matrix_Xception.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 15/15 [==============================] - 4s 224ms/step
#               precision    recall  f1-score   support
#
#      downdog       0.98      0.96      0.97        97
#      goddess       0.95      0.91      0.93        80
#        plank       0.95      0.97      0.96       115
#         tree       0.97      0.99      0.98        69
#     warrior2       0.95      0.96      0.96       109
#
#     accuracy                           0.96       470
#    macro avg       0.96      0.96      0.96       470
# weighted avg       0.96      0.96      0.96       470

# %%
import zipfile
import os
import pickle

with open('history_for_Xception.pkl', 'wb') as f:
    pickle.dump(history, f)

def create_zip(files_to_zip, zip_filename):
    with zipfile.ZipFile(zip_filename, 'w') as zipf:
        for file in files_to_zip:
            # Add the file to the zip archive
            zipf.write(file, os.path.basename(file))

# Example: List of files to be included in the zip
files_to_zip = ['Accuracy_Graph_Xception.png', 'Loss_Graph_Xception.png', 'history_for_Xception.pkl', 'weights_Xception.keras', 'Confusion_Matrix_Xception.png']

# Specify the name of the zip file
zip_filename = 'results_Xception.zip'

# Create the zip file
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/

# %% [markdown]
# # EfficientNetB0 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)  # Automatically detects image format
        img = tf.image.resize(img, (224, 224))  # Resize image to match Xception input shape
        img = tf.keras.applications.efficientnet.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df

def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Error loading image /content/dataset/train/tree/00000114.jpg: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} jpeg::Uncompress failed. Invalid JPEG data or crop window. [Op:DecodeImage] name:
# (1080, 224, 224, 3)
# (470, 224, 224, 3)
# (1080, 5)
# (470, 5)

# %%
efficient_net_model = tf.keras.applications.EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
efficient_net_model.trainable = False

model = tf.keras.Sequential([
    efficient_net_model,
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer= keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 7, 7, 1280)        4049571
#  )
#
#  flatten_7 (Flatten)         (None, 62720)             0
#
#  dense_28 (Dense)            (None, 256)               16056576
#
#  batch_normalization_223 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 64)                16448
#
#  batch_normalization_224 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_16 (Dropout)        (None, 64)                0
#
#  dense_30 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 20124200 (76.77 MB)
# Trainable params: 16073989 (61.32 MB)
# Non-trainable params: 4050211 (15.45 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_EfficientNetB0.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 34/34 [==============================] - ETA: 0s - loss: 1.2479 - accuracy: 0.5843
# Epoch 1: val_accuracy improved from -inf to 0.92553, saving model to weights_EfficientNetB0.keras
# 34/34 [==============================] - 17s 243ms/step - loss: 1.2479 - accuracy: 0.5843 - val_loss: 0.2645 - val_accuracy: 0.9255
# Epoch 2/50
# 34/34 [==============================] - ETA: 0s - loss: 0.5398 - accuracy: 0.8315
# Epoch 2: val_accuracy improved from 0.92553 to 0.95532, saving model to weights_EfficientNetB0.keras
# 34/34 [==============================] - 5s 149ms/step - loss: 0.5398 - accuracy: 0.8315 - val_loss: 0.1471 - val_accuracy: 0.9553
# Epoch 3/50
# 34/34 [==============================] - ETA: 0s - loss: 0.3829 - accuracy: 0.8759
# Epoch 3: val_accuracy improved from 0.95532 to 0.96809, saving model to weights_EfficientNetB0.keras
# 34/34 [==============================] - 5s 142ms/step - loss: 0.3829 - accuracy: 0.8759 - val_loss: 0.1285 - val_accuracy: 0.9681
# Epoch 4/50
# 34/34 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.9278
# Epoch 4: val_accuracy did not improve from 0.96809
# 34/34 [==============================] - 3s 93ms/step - loss: 0.2641 - accuracy: 0.9278 - val_loss: 0.1286 - val_accuracy: 0.9681
# Epoch 5/50
# 34/34 [==============================] - ETA: 0s - loss: 0.1944 - accuracy: 0.9407
# Epoch 5: val_accuracy did not improve from 0.96809
# 34/34 [==============================] - 3s 94ms/step - loss: 0.1944 - accuracy: 0.9407 - val_loss: 0.1329 - val_accuracy: 0.9660
# Epoch 6/50
# 34/34 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9583
# Epoch 6: val_accuracy did not improve from 0.96809
# 34/34 [==============================] - 3s 94ms/step - loss: 0.1407 - accuracy: 0.9583 - val_loss: 0.1182 - val_accuracy: 0.9681
# Epoch 7/50
# 34/34 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9759
# Epoch 7: val_accuracy improved from 0.96809 to 0.97234, saving model to weights_EfficientNetB0.keras
# 34/34 [==============================] - 5s 141ms/step - loss: 0.1081 - accuracy: 0.9759 - val_loss: 0.1097 - val_accuracy: 0.9723
# Epoch 8/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9787
# Epoch 8: val_accuracy improved from 0.97234 to 0.97447, saving model to weights_EfficientNetB0.keras
# 34/34 [==============================] - 5s 144ms/step - loss: 0.0917 - accuracy: 0.9787 - val_loss: 0.1028 - val_accuracy: 0.9745
# Epoch 9/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9778
# Epoch 9: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 3s 94ms/step - loss: 0.0822 - accuracy: 0.9778 - val_loss: 0.1084 - val_accuracy: 0.9681
# Epoch 10/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9880
# Epoch 10: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 3s 93ms/step - loss: 0.0598 - accuracy: 0.9880 - val_loss: 0.1113 - val_accuracy: 0.9702
# Epoch 11/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9861
# Epoch 11: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 3s 94ms/step - loss: 0.0565 - accuracy: 0.9861 - val_loss: 0.1108 - val_accuracy: 0.9723
# Epoch 12/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9852
# Epoch 12: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 3s 94ms/step - loss: 0.0512 - accuracy: 0.9852 - val_loss: 0.1066 - val_accuracy: 0.9723
# Epoch 13/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9861
# Epoch 13: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 3s 94ms/step - loss: 0.0540 - accuracy: 0.9861 - val_loss: 0.1164 - val_accuracy: 0.9745
# Epoch 14/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9935
# Epoch 14: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 3s 95ms/step - loss: 0.0442 - accuracy: 0.9935 - val_loss: 0.1160 - val_accuracy: 0.9702
# Epoch 15/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9889
# Epoch 15: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 3s 94ms/step - loss: 0.0519 - accuracy: 0.9889 - val_loss: 0.1172 - val_accuracy: 0.9660
# Epoch 16/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9917
# Epoch 16: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 3s 95ms/step - loss: 0.0325 - accuracy: 0.9917 - val_loss: 0.1076 - val_accuracy: 0.9745
# Epoch 17/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9944
# Epoch 17: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 3s 94ms/step - loss: 0.0355 - accuracy: 0.9944 - val_loss: 0.1019 - val_accuracy: 0.9702
# Epoch 18/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9944
# Epoch 18: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 3s 94ms/step - loss: 0.0291 - accuracy: 0.9944 - val_loss: 0.1081 - val_accuracy: 0.9702

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of EfficientNetB0 with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_EfficientNetB0.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of EfficientNetB0 with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_EfficientNetB0.png')
plt.show()

# %%
model = tf.keras.models.load_model('weights_EfficientNetB0.keras')
model.evaluate(X_test, y_test)
# Out:
# 15/15 [==============================] - 4s 61ms/step - loss: 0.1028 - accuracy: 0.9745
# [0.10277395695447922, 0.9744681119918823]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of EfficientNetB0 with {dataset_name}')
plt.savefig('Confusion_Matrix_EfficientNetB0.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 15/15 [==============================] - 2s 62ms/step
#               precision    recall  f1-score   support
#
#      downdog       0.98      1.00      0.99        97
#      goddess       0.97      0.95      0.96        80
#        plank       0.98      0.97      0.97       115
#         tree       0.97      0.99      0.98        69
#     warrior2       0.96      0.97      0.97       109
#
#     accuracy                           0.97       470
#    macro avg       0.97      0.97      0.97       470
# weighted avg       0.97      0.97      0.97       470

# %%
with open('history_for_EfficientNetB0.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_EfficientNetB0.keras', 'history_for_EfficientNetB0.pkl', 'Confusion_Matrix_EfficientNetB0.png', 'Loss_Graph_EfficientNetB0.png', 'Accuracy_Graph_EfficientNetB0.png']
zip_filename = 'results_EfficientNetB0.zip'

create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/

# %% [markdown]
# # Inception V3 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)  # Automatically detects image format
        img = tf.image.resize(img, (224, 224))  # Resize image to match Xception input shape
        img = tf.keras.applications.inception_v3.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df


def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Error loading image /content/dataset/train/tree/00000114.jpg: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} jpeg::Uncompress failed. Invalid JPEG data or crop window. [Op:DecodeImage] name:
# (1080, 224, 224, 3)
# (470, 224, 224, 3)
# (1080, 5)
# (470, 5)

# %%
inception_model = tf.keras.applications.InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
inception_model.trainable = False

model = tf.keras.Sequential([
    inception_model,
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer= keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten_8 (Flatten)         (None, 51200)             0
#
#  dense_31 (Dense)            (None, 256)               13107456
#
#  batch_normalization_319 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  dense_32 (Dense)            (None, 64)                16448
#
#  batch_normalization_320 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  dense_33 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 34928293 (133.24 MB)
# Trainable params: 13124869 (50.07 MB)
# Non-trainable params: 21803424 (83.17 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_InceptionV3.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 34/34 [==============================] - ETA: 0s - loss: 1.2615 - accuracy: 0.5917
# Epoch 1: val_accuracy improved from -inf to 0.84255, saving model to weights_InceptionV3.keras
# 34/34 [==============================] - 18s 362ms/step - loss: 1.2615 - accuracy: 0.5917 - val_loss: 0.5943 - val_accuracy: 0.8426
# Epoch 2/50
# 34/34 [==============================] - ETA: 0s - loss: 0.6295 - accuracy: 0.7824
# Epoch 2: val_accuracy improved from 0.84255 to 0.91702, saving model to weights_InceptionV3.keras
# 34/34 [==============================] - 6s 169ms/step - loss: 0.6295 - accuracy: 0.7824 - val_loss: 0.2706 - val_accuracy: 0.9170
# Epoch 3/50
# 34/34 [==============================] - ETA: 0s - loss: 0.4438 - accuracy: 0.8537
# Epoch 3: val_accuracy improved from 0.91702 to 0.93191, saving model to weights_InceptionV3.keras
# 34/34 [==============================] - 6s 165ms/step - loss: 0.4438 - accuracy: 0.8537 - val_loss: 0.2410 - val_accuracy: 0.9319
# Epoch 4/50
# 34/34 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.9065
# Epoch 4: val_accuracy improved from 0.93191 to 0.93617, saving model to weights_InceptionV3.keras
# 34/34 [==============================] - 6s 165ms/step - loss: 0.2693 - accuracy: 0.9065 - val_loss: 0.1810 - val_accuracy: 0.9362
# Epoch 5/50
# 34/34 [==============================] - ETA: 0s - loss: 0.2411 - accuracy: 0.9287
# Epoch 5: val_accuracy improved from 0.93617 to 0.94255, saving model to weights_InceptionV3.keras
# 34/34 [==============================] - 6s 166ms/step - loss: 0.2411 - accuracy: 0.9287 - val_loss: 0.1705 - val_accuracy: 0.9426
# Epoch 6/50
# 34/34 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9389
# Epoch 6: val_accuracy did not improve from 0.94255
# 34/34 [==============================] - 4s 106ms/step - loss: 0.1897 - accuracy: 0.9389 - val_loss: 0.2488 - val_accuracy: 0.9319
# Epoch 7/50
# 34/34 [==============================] - ETA: 0s - loss: 0.1536 - accuracy: 0.9463
# Epoch 7: val_accuracy did not improve from 0.94255
# 34/34 [==============================] - 4s 106ms/step - loss: 0.1536 - accuracy: 0.9463 - val_loss: 0.1758 - val_accuracy: 0.9426
# Epoch 8/50
# Epoch 18: val_accuracy did not improve from 0.95319
# 34/34 [==============================] - 4s 105ms/step - loss: 0.0352 - accuracy: 0.9944 - val_loss: 0.2023 - val_accuracy: 0.9447
# Epoch 19/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9935
# Epoch 19: val_accuracy did not improve from 0.95319
# 34/34 [==============================] - 4s 105ms/step - loss: 0.0339 - accuracy: 0.9935 - val_loss: 0.2022 - val_accuracy: 0.9447
# Epoch 20/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9889
# Epoch 20: val_accuracy did not improve from 0.95319
# 34/34 [==============================] - 4s 104ms/step - loss: 0.0392 - accuracy: 0.9889 - val_loss: 0.1856 - val_accuracy: 0.9468
# Epoch 21/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9972
# Epoch 21: val_accuracy did not improve from 0.95319
# 34/34 [==============================] - 4s 105ms/step - loss: 0.0265 - accuracy: 0.9972 - val_loss: 0.1848 - val_accuracy: 0.9468
# Epoch 22/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9963
# Epoch 22: val_accuracy did not improve from 0.95319
# 34/34 [==============================] - 4s 104ms/step - loss: 0.0220 - accuracy: 0.9963 - val_loss: 0.2185 - val_accuracy: 0.9426

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of InceptionV3 with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_InceptionV3.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of InceptionV3 with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_InceptionV3.png')
plt.show()

# %%
model = tf.keras.models.load_model('weights_InceptionV3.keras')
model.evaluate(X_test, y_test)
# Out:
# 15/15 [==============================] - 3s 70ms/step - loss: 0.1753 - accuracy: 0.9532
# [0.17528648674488068, 0.9531915187835693]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of Inception-V3 with {dataset_name}')
plt.savefig('Confusion_Matrix_InceptionV3.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 15/15 [==============================] - 2s 71ms/step
#               precision    recall  f1-score   support
#
#      downdog       0.98      0.95      0.96        97
#      goddess       0.86      1.00      0.92        80
#        plank       0.96      0.98      0.97       115
#         tree       1.00      0.99      0.99        69
#     warrior2       0.98      0.87      0.92       109
#
#     accuracy                           0.95       470
#    macro avg       0.96      0.96      0.95       470
# weighted avg       0.96      0.95      0.95       470

# %%
with open('history_InceptionV3.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['Accuracy_Graph_InceptionV3.png', 'Loss_Graph_InceptionV3.png', 'Confusion_Matrix_InceptionV3.png', 'history_InceptionV3.pkl', 'weights_InceptionV3.keras']
zip_filename = "results_InceptionV3.zip"
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/

# %% [markdown]
# # MobileNet V2 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)  # Automatically detects image format
        img = tf.image.resize(img, (224, 224))  # Resize image to match Xception input shape
        img = tf.keras.applications.mobilenet_v2.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df


def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Error loading image /content/dataset/train/tree/00000114.jpg: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} jpeg::Uncompress failed. Invalid JPEG data or crop window. [Op:DecodeImage] name:
# (1080, 224, 224, 3)
# (470, 224, 224, 3)
# (1080, 5)
# (470, 5)

# %%
mobile_net = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
mobile_net.trainable = False

model = tf.keras.Sequential([
    mobile_net,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  flatten_9 (Flatten)         (None, 62720)             0
#
#  dense_34 (Dense)            (None, 256)               16056576
#
#  batch_normalization_321 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  dense_35 (Dense)            (None, 64)                16448
#
#  batch_normalization_322 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_20 (Dropout)        (None, 64)                0
#
#  dense_36 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 18332613 (69.93 MB)
# Trainable params: 16073989 (61.32 MB)
# Non-trainable params: 2258624 (8.62 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_MobileNetV2.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 34/34 [==============================] - ETA: 0s - loss: 1.1066 - accuracy: 0.5981
# Epoch 1: val_accuracy improved from -inf to 0.81064, saving model to weights_MobileNetV2.keras
# 34/34 [==============================] - 10s 177ms/step - loss: 1.1066 - accuracy: 0.5981 - val_loss: 0.9305 - val_accuracy: 0.8106
# Epoch 2/50
# 33/34 [============================>.] - ETA: 0s - loss: 0.5007 - accuracy: 0.8258
# Epoch 2: val_accuracy improved from 0.81064 to 0.91277, saving model to weights_MobileNetV2.keras
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0382 - accuracy: 0.9935 - val_loss: 0.0976 - val_accuracy: 0.9723
# Epoch 13/50
# 33/34 [============================>.] - ETA: 0s - loss: 0.0436 - accuracy: 0.9915
# Epoch 13: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0433 - accuracy: 0.9917 - val_loss: 0.1113 - val_accuracy: 0.9681
# Epoch 14/50
# 33/34 [============================>.] - ETA: 0s - loss: 0.0346 - accuracy: 0.9915
# Epoch 14: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 2s 64ms/step - loss: 0.0395 - accuracy: 0.9907 - val_loss: 0.0973 - val_accuracy: 0.9660
# Epoch 15/50
# 33/34 [============================>.] - ETA: 0s - loss: 0.0392 - accuracy: 0.9924
# Epoch 15: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0386 - accuracy: 0.9926 - val_loss: 0.1306 - val_accuracy: 0.9596
# Epoch 16/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9963
# Epoch 16: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0271 - accuracy: 0.9963 - val_loss: 0.1069 - val_accuracy: 0.9702
# Epoch 17/50
# 33/34 [============================>.] - ETA: 0s - loss: 0.0287 - accuracy: 0.9943
# Epoch 17: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0286 - accuracy: 0.9944 - val_loss: 0.1059 - val_accuracy: 0.9681
# Epoch 18/50
# 33/34 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9953
# Epoch 18: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 2s 64ms/step - loss: 0.0317 - accuracy: 0.9954 - val_loss: 0.1135 - val_accuracy: 0.9681
# Epoch 19/50
# 33/34 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 0.9943
# Epoch 19: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0217 - accuracy: 0.9944 - val_loss: 0.1017 - val_accuracy: 0.9723
# Epoch 20/50
# 33/34 [============================>.] - ETA: 0s - loss: 0.0167 - accuracy: 0.9981
# Epoch 20: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 2s 64ms/step - loss: 0.0165 - accuracy: 0.9981 - val_loss: 0.1084 - val_accuracy: 0.9617
# Epoch 21/50
# 33/34 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 0.9962
# Epoch 21: val_accuracy did not improve from 0.97447
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0221 - accuracy: 0.9963 - val_loss: 0.1114 - val_accuracy: 0.9617

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of MobileNetV2 with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_MobileNetV2.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of MobileNetV2 with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_MobileNetV2.png')
plt.show()

# %%
model = tf.keras.models.load_model("weights_MobileNetV2.keras")
model.evaluate(X_test, y_test)
# Out:
# 15/15 [==============================] - 2s 44ms/step - loss: 0.0998 - accuracy: 0.9745
# [0.09975477308034897, 0.9744681119918823]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of MobileNetV2 with {dataset_name}')
plt.savefig('Confusion_Matrix_MobileNetV2.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 15/15 [==============================] - 1s 42ms/step
#               precision    recall  f1-score   support
#
#      downdog       0.99      1.00      0.99        97
#      goddess       0.99      0.93      0.95        80
#        plank       0.97      0.99      0.98       115
#         tree       0.97      0.96      0.96        69
#     warrior2       0.96      0.98      0.97       109
#
#     accuracy                           0.97       470
#    macro avg       0.98      0.97      0.97       470
# weighted avg       0.97      0.97      0.97       470

# %%
with open('history_for_MoblieNetV2.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_MobileNetV2.keras', 'history_for_MoblieNetV2.pkl', 'Loss_Graph_MobileNetV2.png', 'Accuracy_Graph_MobileNetV2.png', 'Confusion_Matrix_MobileNetV2.png']
zip_filename = 'results_MobileNetV2.zip'
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/

# %% [markdown]
# # ResNet50 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)  # Automatically detects image format
        img = tf.image.resize(img, (224, 224))  # Resize image to match Xception input shape
        img = tf.keras.applications.resnet50.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df


def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Error loading image /content/dataset/train/tree/00000114.jpg: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} jpeg::Uncompress failed. Invalid JPEG data or crop window. [Op:DecodeImage] name:
# (1080, 224, 224, 3)
# (470, 224, 224, 3)
# (1080, 5)
# (470, 5)

# %%
resnet_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
resnet_model.trainable = False

model = tf.keras.Sequential([
    resnet_model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 4s 0us/step
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_10 (Flatten)        (None, 100352)            0
#
#  dense_37 (Dense)            (None, 256)               25690368
#
#  batch_normalization_323 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_21 (Dropout)        (None, 256)               0
#
#  dense_38 (Dense)            (None, 64)                16448
#
#  batch_normalization_324 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_22 (Dropout)        (None, 64)                0
#
#  dense_39 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 49296133 (188.05 MB)
# Trainable params: 25707781 (98.07 MB)
# Non-trainable params: 23588352 (89.98 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_ResNet50.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 34/34 [==============================] - ETA: 0s - loss: 1.1737 - accuracy: 0.5880
# Epoch 1: val_accuracy improved from -inf to 0.91915, saving model to weights_ResNet50.keras
# 34/34 [==============================] - 18s 346ms/step - loss: 1.1737 - accuracy: 0.5880 - val_loss: 0.3077 - val_accuracy: 0.9191
# Epoch 2/50
# 34/34 [==============================] - ETA: 0s - loss: 0.5461 - accuracy: 0.8148
# Epoch 2: val_accuracy improved from 0.91915 to 0.93830, saving model to weights_ResNet50.keras
# 34/34 [==============================] - 7s 215ms/step - loss: 0.5461 - accuracy: 0.8148 - val_loss: 0.1789 - val_accuracy: 0.9383
# Epoch 3/50
# 34/34 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.8898
# Epoch 3: val_accuracy improved from 0.93830 to 0.95106, saving model to weights_ResNet50.keras
# 34/34 [==============================] - 7s 215ms/step - loss: 0.3137 - accuracy: 0.8898 - val_loss: 0.1492 - val_accuracy: 0.9511
# Epoch 4/50
# 34/34 [==============================] - ETA: 0s - loss: 0.2427 - accuracy: 0.9250
# Epoch 4: val_accuracy improved from 0.95106 to 0.95319, saving model to weights_ResNet50.keras
# 34/34 [==============================] - 7s 214ms/step - loss: 0.2427 - accuracy: 0.9250 - val_loss: 0.1582 - val_accuracy: 0.9532
# Epoch 5/50
# 34/34 [==============================] - ETA: 0s - loss: 0.1814 - accuracy: 0.9398
# Epoch 5: val_accuracy improved from 0.95319 to 0.96596, saving model to weights_ResNet50.keras
# 34/34 [==============================] - 7s 213ms/step - loss: 0.1814 - accuracy: 0.9398 - val_loss: 0.1353 - val_accuracy: 0.9660
# Epoch 6/50
# 34/34 [==============================] - ETA: 0s - loss: 0.1328 - accuracy: 0.9667
# Epoch 6: val_accuracy improved from 0.96596 to 0.97234, saving model to weights_ResNet50.keras
# 34/34 [==============================] - 7s 217ms/step - loss: 0.1328 - accuracy: 0.9667 - val_loss: 0.1230 - val_accuracy: 0.9723
# Epoch 7/50
# 34/34 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9630
# Epoch 7: val_accuracy improved from 0.97234 to 0.97660, saving model to weights_ResNet50.keras
# Epoch 18/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9963
# Epoch 18: val_accuracy did not improve from 0.97872
# 34/34 [==============================] - 5s 146ms/step - loss: 0.0187 - accuracy: 0.9963 - val_loss: 0.1196 - val_accuracy: 0.9660
# Epoch 19/50
# 34/34 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9954
# Epoch 19: val_accuracy did not improve from 0.97872
# 34/34 [==============================] - 5s 145ms/step - loss: 0.0245 - accuracy: 0.9954 - val_loss: 0.1199 - val_accuracy: 0.9681

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of ResNet50 with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_ResNet50.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of ResNet50 with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_ResNet50.png')
plt.show()

# %%
model = keras.models.load_model('weights_ResNet50.keras')
model.evaluate(X_test, y_test)
# Out:
# 15/15 [==============================] - 3s 95ms/step - loss: 0.1138 - accuracy: 0.9787
# [0.11378848552703857, 0.978723406791687]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of ResNet50 with {dataset_name}')
plt.savefig('Confusion_Matrix_ResNet50.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 15/15 [==============================] - 2s 92ms/step
#               precision    recall  f1-score   support
#
#      downdog       0.98      0.97      0.97        97
#      goddess       0.98      0.99      0.98        80
#        plank       0.97      0.97      0.97       115
#         tree       0.97      1.00      0.99        69
#     warrior2       0.99      0.97      0.98       109
#
#     accuracy                           0.98       470
#    macro avg       0.98      0.98      0.98       470
# weighted avg       0.98      0.98      0.98       470

# %%
with open('history_for_ResNet50.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['history_for_ResNet50.pkl', 'weights_ResNet50.keras', 'Loss_Graph_ResNet50.png', 'Accuracy_Graph_ResNet50.png', 'Confusion_Matrix_ResNet50.png']
zip_filename = 'results_ResNet50.zip'

create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/

# %% [markdown]
# # Vgg 16 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)  # Automatically detects image format
        img = tf.image.resize(img, (224, 224))  # Resize image to match Xception input shape
        img = tf.keras.applications.vgg16.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df


def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Error loading image /content/dataset/train/tree/00000114.jpg: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} jpeg::Uncompress failed. Invalid JPEG data or crop window. [Op:DecodeImage] name:
# (1080, 224, 224, 3)
# (470, 224, 224, 3)
# (1080, 5)
# (470, 5)

# %%
vgg_model = keras.applications.vgg16.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
vgg_model.trainable = False

model = tf.keras.Sequential([
    vgg_model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_11 (Flatten)        (None, 25088)             0
#
#  dense_40 (Dense)            (None, 256)               6422784
#
#  batch_normalization_325 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_23 (Dropout)        (None, 256)               0
#
#  dense_41 (Dense)            (None, 64)                16448
#
#  batch_normalization_326 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_24 (Dropout)        (None, 64)                0
#
#  dense_42 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 21155525 (80.70 MB)
# Trainable params: 6440197 (24.57 MB)
# Non-trainable params: 14715328 (56.13 MB)
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = 'weights_Vgg16.keras'
checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/100
# 34/34 [==============================] - ETA: 0s - loss: 1.2230 - accuracy: 0.5815
# Epoch 1: val_accuracy improved from -inf to 0.90000, saving model to weights_Vgg16.keras
# 34/34 [==============================] - 28s 571ms/step - loss: 1.2230 - accuracy: 0.5815 - val_loss: 0.3388 - val_accuracy: 0.9000
# Epoch 2/100
# 34/34 [==============================] - ETA: 0s - loss: 0.5389 - accuracy: 0.8250
# Epoch 2: val_accuracy improved from 0.90000 to 0.95106, saving model to weights_Vgg16.keras
# 34/34 [==============================] - 7s 207ms/step - loss: 0.5389 - accuracy: 0.8250 - val_loss: 0.1996 - val_accuracy: 0.9511
# Epoch 3/100
# 34/34 [==============================] - ETA: 0s - loss: 0.3176 - accuracy: 0.9028
# Epoch 3: val_accuracy improved from 0.95106 to 0.96809, saving model to weights_Vgg16.keras
# 34/34 [==============================] - 7s 209ms/step - loss: 0.3176 - accuracy: 0.9028 - val_loss: 0.1302 - val_accuracy: 0.9681
# Epoch 4/100
# 34/34 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9269
# Epoch 4: val_accuracy did not improve from 0.96809
# 34/34 [==============================] - 6s 191ms/step - loss: 0.2429 - accuracy: 0.9269 - val_loss: 0.1275 - val_accuracy: 0.9660
# Epoch 5/100
# 34/34 [==============================] - ETA: 0s - loss: 0.1666 - accuracy: 0.9519
# 34/34 [==============================] - 6s 188ms/step - loss: 0.0345 - accuracy: 0.9954 - val_loss: 0.1297 - val_accuracy: 0.9766
# Epoch 16/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9972
# Epoch 16: val_accuracy did not improve from 0.97660
# 34/34 [==============================] - 6s 188ms/step - loss: 0.0213 - accuracy: 0.9972 - val_loss: 0.1240 - val_accuracy: 0.9766
# Epoch 17/100
# 34/34 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9917
# Epoch 17: val_accuracy did not improve from 0.97660
# 34/34 [==============================] - 6s 189ms/step - loss: 0.0315 - accuracy: 0.9917 - val_loss: 0.1291 - val_accuracy: 0.9702

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of Vgg16 with {dataset_name}')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_Vgg16.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of Vgg16 with {dataset_name}')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_Vgg16.png')
plt.show()

# %%
model = keras.models.load_model('weights_Vgg16.keras')
model.evaluate(X_test, y_test)
# Out:
# 15/15 [==============================] - 2s 123ms/step - loss: 0.1155 - accuracy: 0.9766
# [0.11554409563541412, 0.9765957593917847]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of Vgg16 with {dataset_name}')
plt.savefig('Confusion_Matrix_Vgg16.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 15/15 [==============================] - 2s 126ms/step
#               precision    recall  f1-score   support
#
#      downdog       0.99      0.99      0.99        97
#      goddess       1.00      0.95      0.97        80
#        plank       0.97      0.97      0.97       115
#         tree       0.97      1.00      0.99        69
#     warrior2       0.96      0.97      0.97       109
#
#     accuracy                           0.98       470
#    macro avg       0.98      0.98      0.98       470
# weighted avg       0.98      0.98      0.98       470

# %%
with open('history_for_Vgg16.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_Vgg16.keras', 'history_for_Vgg16.pkl', 'Confusion_Matrix_Vgg16.png', 'Accuracy_Graph_Vgg16.png', 'Loss_Graph_Vgg16.png']
zip_filename = 'results_Vgg16.zip'

create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/

# %% [markdown]
# # MoveNet Model

# %% [markdown]
# ## Downloading MoveNet Model from TF Hub

# %%
# Download model from TF Hub and check out inference code from GitHub
# !wget -q -O movenet_thunder.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# !git clone https://github.com/tensorflow/examples.git
pose_sample_rpi_path = os.path.join(os.getcwd(), 'examples/lite/examples/pose_estimation/raspberry_pi')
sys.path.append(pose_sample_rpi_path)

# Load MoveNet Thunder model
import utils
from data import BodyPart
from ml import Movenet
movenet = Movenet('movenet_thunder')

# Define function to run pose estimation using MoveNet Thunder.
# You'll apply MoveNet's cropping algorithm and run inference multiple times on
# the input image to improve pose estimation accuracy.
def detect(input_tensor, inference_count=3):
  """Runs detection on an input image.

  Args:
    input_tensor: A [height, width, 3] Tensor of type tf.float32.
      Note that height and width can be anything since the image will be
      immediately resized according to the needs of the model within this
      function.
    inference_count: Number of times the model should run repeatly on the
      same input image to improve detection accuracy.

  Returns:
    A Person entity detected by the MoveNet.SinglePose.
  """
  image_height, image_width, channel = input_tensor.shape

  # Detect pose using the full input image
  movenet.detect(input_tensor.numpy(), reset_crop_region=True)

  # Repeatedly using previous detection result to identify the region of
  # interest and only croping that region to improve detection accuracy
  for _ in range(inference_count - 1):
    person = movenet.detect(input_tensor.numpy(),
                            reset_crop_region=False)

  return person
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 23737, done.
# remote: Counting objects: 100% (701/701), done.
# remote: Compressing objects: 100% (428/428), done.
# remote: Total 23737 (delta 230), reused 559 (delta 185), pack-reused 23036
# Receiving objects: 100% (23737/23737), 44.19 MiB | 21.28 MiB/s, done.
# Resolving deltas: 100% (12878/12878), done.

# %%
def draw_prediction_on_image(
    image, person, crop_region=None, close_figure=True,
    keep_input_size=False):
  """Draws the keypoint predictions on image.

  Args:
    image: An numpy array with shape [height, width, channel] representing the
      pixel values of the input image.
    person: A person entity returned from the MoveNet.SinglePose model.
    close_figure: Whether to close the plt figure after the function returns.
    keep_input_size: Whether to keep the size of the input image.

  Returns:
    An numpy array with shape [out_height, out_width, channel] representing the
    image overlaid with keypoint predictions.
  """
  # Draw the detection result on top of the image.
  image_np = utils.visualize(image, [person])

  # Plot the image with detection results.
  height, width, channel = image.shape
  aspect_ratio = float(width) / height
  fig, ax = plt.subplots(figsize=(12 * aspect_ratio, 12))
  im = ax.imshow(image_np)

  if close_figure:
    plt.close(fig)

  if not keep_input_size:
    image_np = utils.keep_aspect_ratio_resizer(image_np, (512, 512))

  return image_np

# %%
class MoveNetPreprocessor(object):
  """Helper class to preprocess pose sample images for classification."""

  def __init__(self,
               images_in_folder,
               images_out_folder,
               csvs_out_path):
    """Creates a preprocessor to detection pose from images and save as CSV.

    Args:
      images_in_folder: Path to the folder with the input images. It should
        follow this structure:
        yoga_poses
        |__ downdog
            |______ 00000128.jpg
            |______ 00000181.bmp
            |______ ...
        |__ goddess
            |______ 00000243.jpg
            |______ 00000306.jpg
            |______ ...
        ...
      images_out_folder: Path to write the images overlay with detected
        landmarks. These images are useful when you need to debug accuracy
        issues.
      csvs_out_path: Path to write the CSV containing the detected landmark
        coordinates and label of each image that can be used to train a pose
        classification model.
    """
    self._images_in_folder = images_in_folder
    self._images_out_folder = images_out_folder
    self._csvs_out_path = csvs_out_path
    self._messages = []

    # Create a temp dir to store the pose CSVs per class
    self._csvs_out_folder_per_class = tempfile.mkdtemp()

    # Get list of pose classes and print image statistics
    self._pose_class_names = sorted(
        [n for n in os.listdir(self._images_in_folder) if not n.startswith('.')]
        )

  def process(self, per_pose_class_limit=None, detection_threshold=0.1):
    """Preprocesses images in the given folder.
    Args:
      per_pose_class_limit: Number of images to load. As preprocessing usually
        takes time, this parameter can be specified to make the reduce of the
        dataset for testing.
      detection_threshold: Only keep images with all landmark confidence score
        above this threshold.
    """
    # Loop through the classes and preprocess its images
    for pose_class_name in self._pose_class_names:
      print('Preprocessing', pose_class_name, file=sys.stderr)

      # Paths for the pose class.
      images_in_folder = os.path.join(self._images_in_folder, pose_class_name)
      images_out_folder = os.path.join(self._images_out_folder, pose_class_name)
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  pose_class_name + '.csv')
      if not os.path.exists(images_out_folder):
        os.makedirs(images_out_folder)

      # Detect landmarks in each image and write it to a CSV file
      with open(csv_out_path, 'w') as csv_out_file:
        csv_out_writer = csv.writer(csv_out_file,
                                    delimiter=',',
                                    quoting=csv.QUOTE_MINIMAL)
        # Get list of images
        image_names = sorted(
            [n for n in os.listdir(images_in_folder) if not n.startswith('.')])
        if per_pose_class_limit is not None:
          image_names = image_names[:per_pose_class_limit]

        valid_image_count = 0

        # Detect pose landmarks from each image
        for image_name in tqdm.tqdm(image_names):
          image_path = os.path.join(images_in_folder, image_name)

          try:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
          except:
            self._messages.append('Skipped ' + image_path + '. Invalid image.')
            continue
          else:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
            image_height, image_width, channel = image.shape

          # Skip images that isn't RGB because Movenet requires RGB images
          if channel != 3:
            self._messages.append('Skipped ' + image_path +
                                  '. Image isn\'t in RGB format.')
            continue
          person = detect(image)

          # Save landmarks if all landmarks were detected
          min_landmark_score = min(
              [keypoint.score for keypoint in person.keypoints])
          should_keep_image = min_landmark_score >= detection_threshold
          if not should_keep_image:
            self._messages.append('Skipped ' + image_path +
                                  '. No pose was confidentlly detected.')
            continue

          valid_image_count += 1

          # Draw the prediction result on top of the image for debugging later
          output_overlay = draw_prediction_on_image(
              image.numpy().astype(np.uint8), person,
              close_figure=True, keep_input_size=True)

          # Write detection result into an image file
          output_frame = cv2.cvtColor(output_overlay, cv2.COLOR_RGB2BGR)
          cv2.imwrite(os.path.join(images_out_folder, image_name), output_frame)

          # Get landmarks and scale it to the same size as the input image
          pose_landmarks = np.array(
              [[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score]
                for keypoint in person.keypoints],
              dtype=np.float32)

          # Write the landmark coordinates to its per-class CSV file
          coordinates = pose_landmarks.flatten().astype(str).tolist()
          csv_out_writer.writerow([image_name] + coordinates)

        if not valid_image_count:
          raise RuntimeError(
              'No valid images found for the "{}" class.'
              .format(pose_class_name))

    # Print the error message collected during preprocessing.
    print('\n'.join(self._messages))

    # Combine all per-class CSVs into a single output file
    all_landmarks_df = self._all_landmarks_as_dataframe()
    all_landmarks_df.to_csv(self._csvs_out_path, index=False)

  def class_names(self):
    """List of classes found in the training dataset."""
    return self._pose_class_names

  def _all_landmarks_as_dataframe(self):
    """Merge all per-class CSVs into a single dataframe."""
    total_df = None
    for class_index, class_name in enumerate(self._pose_class_names):
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  class_name + '.csv')
      per_class_df = pd.read_csv(csv_out_path, header=None)

      # Add the labels
      per_class_df['class_no'] = [class_index]*len(per_class_df)
      per_class_df['class_name'] = [class_name]*len(per_class_df)

      # Append the folder name to the filename column (first column)
      per_class_df[per_class_df.columns[0]] = (os.path.join(class_name, '')
        + per_class_df[per_class_df.columns[0]].astype(str))

      if total_df is None:
        # For the first class, assign its data to the total dataframe
        total_df = per_class_df
      else:
        # Concatenate each class's data into the total dataframe
        total_df = pd.concat([total_df, per_class_df], axis=0)

    list_name = [[bodypart.name + '_x', bodypart.name + '_y',
                  bodypart.name + '_score'] for bodypart in BodyPart]
    header_name = []
    for columns_name in list_name:
      header_name += columns_name
    header_name = ['file_name'] + header_name
    header_map = {total_df.columns[i]: header_name[i]
                  for i in range(len(header_name))}

    total_df.rename(header_map, axis=1, inplace=True)

    return total_df

# %% [markdown]
# #Testing MoveNet Model

# %%
image = tf.io.read_file('/content/dataset/test/downdog/00000000.jpg')
image = tf.io.decode_jpeg(image)
person = detect(image)
_ = draw_prediction_on_image(image.numpy(), person, crop_region=None,
                            close_figure=False, keep_input_size=True)

# %%
dataset_in = '/content/dataset/'

# %%
images_in_train_folder = os.path.join(dataset_in, 'train')
images_out_train_folder = 'poses_images_out_train'
csvs_out_train_path = 'train_data_MoveNet.csv'

preprocessor = MoveNetPreprocessor(
    images_in_folder=images_in_train_folder,
    images_out_folder=images_out_train_folder,
    csvs_out_path=csvs_out_train_path,
)

preprocessor.process(per_pose_class_limit=None)
# Out:
# Preprocessing downdog
# 100%|██████████| 223/223 [00:22<00:00,  9.86it/s]
# Preprocessing goddess
#  69%|██████▉   | 125/180 [00:13<00:04, 11.92it/s]/usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 180/180 [00:20<00:00,  8.65it/s]
# Preprocessing plank
# 100%|██████████| 266/266 [00:26<00:00, 10.15it/s]
# Preprocessing tree
# 100%|██████████| 160/160 [00:21<00:00,  7.28it/s]
# Preprocessing warrior2
# 100%|██████████| 252/252 [00:27<00:00,  9.16it/s]
# Skipped /content/dataset/train/downdog/00000147.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000168.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000188.png. Image isn't in RGB format.
# Skipped /content/dataset/train/downdog/00000194.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000212.png. Image isn't in RGB format.
# Skipped /content/dataset/train/downdog/00000218.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000220.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000221.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000223.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000224.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000232.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000234.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000235.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000239.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000245.png. Image isn't in RGB format.
# Skipped /content/dataset/train/downdog/00000274.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000283.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000287.png. Image isn't in RGB format.
# Skipped /content/dataset/train/downdog/00000300.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000333.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000340.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000345.png. Image isn't in RGB format.
# Skipped /content/dataset/train/downdog/00000349.png. Image isn't in RGB format.
# Skipped /content/dataset/train/downdog/00000350.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000351.png. Image isn't in RGB format.
# Skipped /content/dataset/train/downdog/00000352.png. Image isn't in RGB format.
# Skipped /content/dataset/train/downdog/00000361.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000367.png. Image isn't in RGB format.
# Skipped /content/dataset/train/downdog/00000379.png. Image isn't in RGB format.
# Skipped /content/dataset/train/downdog/00000381.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000385.png. Image isn't in RGB format.
# Skipped /content/dataset/train/downdog/00000387.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/00000388.png. Image isn't in RGB format.
# Skipped /content/dataset/train/downdog/00000391.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/goddess/00000110.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/goddess/00000127.png. Image isn't in RGB format.
# Skipped /content/dataset/train/goddess/00000149.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/goddess/00000165.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/goddess/00000169.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/goddess/00000190.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/goddess/00000193.png. Image isn't in RGB format.
# Skipped /content/dataset/train/goddess/00000261.png. Image isn't in RGB format.
# Skipped /content/dataset/train/goddess/00000263.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/goddess/00000272.png. Image isn't in RGB format.
# Skipped /content/dataset/train/goddess/00000282.png. Image isn't in RGB format.
# Skipped /content/dataset/train/goddess/00000299.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/goddess/00000301.JPG. No pose was confidentlly detected.
# Skipped /content/dataset/train/goddess/00000307.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/goddess/00000316.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/goddess/00000376.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/goddess/00000377.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/plank/00000136.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000146.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000167.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/plank/00000170.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000179.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000187.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000204.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000236.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000263.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000266.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/plank/00000267.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/plank/00000285.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/plank/00000290.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000294.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000307.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000309.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/plank/00000327.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/plank/00000330.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000348.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/plank/00000378.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/plank/00000388.png. Image isn't in RGB format.
# Skipped /content/dataset/train/plank/00000413.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/plank/00000431.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/tree/00000090.png. Image isn't in RGB format.
# Skipped /content/dataset/train/tree/00000106.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/tree/00000114.jpg. Invalid image.
# Skipped /content/dataset/train/tree/00000119.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/tree/00000131.png. Image isn't in RGB format.
# Skipped /content/dataset/train/tree/00000134.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/tree/00000140.png. Image isn't in RGB format.
# Skipped /content/dataset/train/tree/00000145.png. Image isn't in RGB format.
# Skipped /content/dataset/train/tree/00000153.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/tree/00000154.png. Image isn't in RGB format.
# Skipped /content/dataset/train/tree/00000157.png. Image isn't in RGB format.
# Skipped /content/dataset/train/tree/00000159.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/tree/00000182.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/tree/00000187.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/tree/00000193.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/tree/00000200.png. Image isn't in RGB format.
# Skipped /content/dataset/train/tree/00000203.png. Image isn't in RGB format.
# Skipped /content/dataset/train/warrior2/00000123.png. Image isn't in RGB format.
# Skipped /content/dataset/train/warrior2/00000130.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000137.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000182.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000184.png. Image isn't in RGB format.
# Skipped /content/dataset/train/warrior2/00000186.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000198.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000250.png. Image isn't in RGB format.
# Skipped /content/dataset/train/warrior2/00000272.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000273.jpg. Image isn't in RGB format.
# Skipped /content/dataset/train/warrior2/00000275.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000278.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000279.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000281.PNG. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000287.png. Image isn't in RGB format.
# Skipped /content/dataset/train/warrior2/00000331.png. Image isn't in RGB format.
# Skipped /content/dataset/train/warrior2/00000343.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000361.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000370.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000377.png. Image isn't in RGB format.
# Skipped /content/dataset/train/warrior2/00000397.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000402.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000416.png. Image isn't in RGB format.
# Skipped /content/dataset/train/warrior2/00000423.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000430.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/00000432.png. Image isn't in RGB format.

# %%
images_in_test_folder = os.path.join(dataset_in, 'test')
images_out_test_folder = 'poses_images_out_test'
csvs_out_test_path = 'test_data_MoveNet.csv'

preprocessor = MoveNetPreprocessor(
    images_in_folder=images_in_test_folder,
    images_out_folder=images_out_test_folder,
    csvs_out_path=csvs_out_test_path,
)

preprocessor.process(per_pose_class_limit=None)
# Out:
# Preprocessing downdog
# 100%|██████████| 97/97 [00:14<00:00,  6.50it/s]
# Preprocessing goddess
# 100%|██████████| 80/80 [00:08<00:00,  9.34it/s]
# Preprocessing plank
# 100%|██████████| 115/115 [00:17<00:00,  6.40it/s]
# Preprocessing tree
#  84%|████████▍ | 58/69 [00:10<00:01,  9.61it/s]/usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 69/69 [00:11<00:00,  6.04it/s]
# Preprocessing warrior2
# 100%|██████████| 109/109 [00:13<00:00,  8.27it/s]
# Skipped /content/dataset/test/downdog/00000010.png. Image isn't in RGB format.
# Skipped /content/dataset/test/downdog/00000017.png. Image isn't in RGB format.
# Skipped /content/dataset/test/downdog/00000035.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/downdog/00000041.png. Image isn't in RGB format.
# Skipped /content/dataset/test/downdog/00000042.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/downdog/00000075.png. Image isn't in RGB format.
# Skipped /content/dataset/test/downdog/00000080.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/downdog/00000102.png. Image isn't in RGB format.
# Skipped /content/dataset/test/downdog/00000120.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/downdog/00000127.png. Image isn't in RGB format.
# Skipped /content/dataset/test/goddess/00000006.png. Image isn't in RGB format.
# Skipped /content/dataset/test/goddess/00000038.png. Image isn't in RGB format.
# Skipped /content/dataset/test/goddess/00000092.png. Image isn't in RGB format.
# Skipped /content/dataset/test/plank/00000050.png. Image isn't in RGB format.
# Skipped /content/dataset/test/plank/00000054.png. Image isn't in RGB format.
# Skipped /content/dataset/test/plank/00000058.png. Image isn't in RGB format.
# Skipped /content/dataset/test/plank/00000079.png. Image isn't in RGB format.
# Skipped /content/dataset/test/plank/00000105.png. Image isn't in RGB format.
# Skipped /content/dataset/test/plank/00000114.png. Image isn't in RGB format.
# Skipped /content/dataset/test/plank/00000115.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/plank/00000116.png. Image isn't in RGB format.
# Skipped /content/dataset/test/tree/00000019.png. Image isn't in RGB format.
# Skipped /content/dataset/test/tree/00000036.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/tree/00000047.png. Image isn't in RGB format.
# Skipped /content/dataset/test/tree/00000059.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/tree/00000068.png. Image isn't in RGB format.
# Skipped /content/dataset/test/warrior2/00000006.png. Image isn't in RGB format.
# Skipped /content/dataset/test/warrior2/00000025.png. Image isn't in RGB format.
# Skipped /content/dataset/test/warrior2/00000039.png. Image isn't in RGB format.
# Skipped /content/dataset/test/warrior2/00000045.png. Image isn't in RGB format.
# Skipped /content/dataset/test/warrior2/00000101.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior2/00000115.png. Image isn't in RGB format.

# %%
# !cp {csvs_out_train_path} /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/
# !cp {csvs_out_test_path} /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/

# %%
def load_pose_landmarks(csv_path):
  """Loads a CSV created by MoveNetPreprocessor.

  Returns:
    X: Detected landmark coordinates and scores of shape (N, 17 * 3)
    y: Ground truth labels of shape (N, label_count)
    classes: The list of all class names found in the dataset
    dataframe: The CSV loaded as a Pandas dataframe features (X) and ground
      truth labels (y) to use later to train a pose classification model.
  """

  # Load the CSV file
  dataframe = pd.read_csv(csv_path)
  df_to_process = dataframe.copy()

  # Drop the file_name columns as you don't need it during training.
  df_to_process.drop(columns=['file_name'], inplace=True)

  # Extract the list of class names
  classes = df_to_process.pop('class_name').unique()

  # Extract the labels
  y = df_to_process.pop('class_no')

  # Convert the input features and labels into the correct format for training.
  X = df_to_process.astype('float64')
  y = keras.utils.to_categorical(y)

  return X, y, classes, dataframe

# %%
# Load the train data
X, y, class_names, _ = load_pose_landmarks(csvs_out_train_path)

X_train = X
y_train = y
# Load the test data
X_test, y_test, _, df_test = load_pose_landmarks(csvs_out_test_path)

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
  """Calculates the center point of the two given landmarks."""

  left = tf.gather(landmarks, left_bodypart.value, axis=1)
  right = tf.gather(landmarks, right_bodypart.value, axis=1)
  center = left * 0.5 + right * 0.5
  return center


def get_pose_size(landmarks, torso_size_multiplier=2.5):
  """Calculates pose size.

  It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
  """
  # Hips center
  hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)

  # Shoulders center
  shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

  # Torso size as the minimum body size
  torso_size = tf.linalg.norm(shoulders_center - hips_center)

  # Pose center
  pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                     BodyPart.RIGHT_HIP)
  pose_center_new = tf.expand_dims(pose_center_new, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to
  # perform substraction
  pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

  # Dist to pose center
  d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
  # Max dist to pose center
  max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

  # Normalize scale
  pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)

  return pose_size


def normalize_pose_landmarks(landmarks):
  """Normalizes the landmarks translation by moving the pose center to (0,0) and
  scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
  pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)
  pose_center = tf.expand_dims(pose_center, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to perform
  # substraction
  pose_center = tf.broadcast_to(pose_center,
                                [tf.size(landmarks) // (17*2), 17, 2])
  landmarks = landmarks - pose_center

  # Scale the landmarks to a constant pose size
  pose_size = get_pose_size(landmarks)
  landmarks /= pose_size

  return landmarks


def landmarks_to_embedding(landmarks_and_scores):
  """Converts the input landmarks into a pose embedding."""
  # Reshape the flat input into a matrix with shape=(17, 3)
  reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

  # Normalize landmarks 2D
  landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])

  # Flatten the normalized landmark coordinates into a vector
  embedding = keras.layers.Flatten()(landmarks)

  return embedding

# %%
# Define the model
inputs = tf.keras.Input(shape=(51))
embedding = landmarks_to_embedding(inputs)

layer = keras.layers.Dense(128, activation=tf.nn.relu6)(embedding)
layer = keras.layers.Dropout(0.5)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.5)(layer)
outputs = keras.layers.Dense(len(class_names), activation="softmax")(layer)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_16 (InputLayer)       [(None, 51)]                 0         []
#
#  reshape (Reshape)           (None, 17, 3)                0         ['input_16[0][0]']
#
#  tf.__operators__.getitem (  (None, 17, 2)                0         ['reshape[0][0]']
#  SlicingOpLambda)
#
#  tf.compat.v1.gather (TFOpL  (None, 2)                    0         ['tf.__operators__.getitem[0][
#  ambda)                                                             0]']
#
#  tf.compat.v1.gather_1 (TFO  (None, 2)                    0         ['tf.__operators__.getitem[0][
#  pLambda)                                                           0]']
#
#  tf.math.multiply (TFOpLamb  (None, 2)                    0         ['tf.compat.v1.gather[0][0]']
#  da)
#
#  tf.math.multiply_1 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_1[0][0]'
#  mbda)                                                              ]
#
#  tf.__operators__.add (TFOp  (None, 2)                    0         ['tf.math.multiply[0][0]',
#  Lambda)                                                             'tf.math.multiply_1[0][0]']
#
#  tf.compat.v1.size (TFOpLam  ()                           0         ['tf.__operators__.getitem[0][
#  bda)                                                               0]']
#
#  tf.expand_dims (TFOpLambda  (None, 1, 2)                 0         ['tf.__operators__.add[0][0]']
#  )
#
#  tf.compat.v1.floor_div (TF  ()                           0         ['tf.compat.v1.size[0][0]']
#  OpLambda)
#
#  tf.broadcast_to (TFOpLambd  (None, 17, 2)                0         ['tf.expand_dims[0][0]',
#  a)                                                                  'tf.compat.v1.floor_div[0][0]
#                                                                     ']
#
#  tf.math.subtract (TFOpLamb  (None, 17, 2)                0         ['tf.__operators__.getitem[0][
#  da)                                                                0]',
#                                                                      'tf.broadcast_to[0][0]']
#
#  tf.compat.v1.gather_6 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.compat.v1.gather_7 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.math.multiply_6 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_6[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_7 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_7[0][0]'
#  mbda)                                                              ]
#
#  tf.__operators__.add_3 (TF  (None, 2)                    0         ['tf.math.multiply_6[0][0]',
#  OpLambda)                                                           'tf.math.multiply_7[0][0]']
#
#  tf.compat.v1.size_1 (TFOpL  ()                           0         ['tf.math.subtract[0][0]']
#  ambda)
#
#  tf.compat.v1.gather_4 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.compat.v1.gather_5 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.compat.v1.gather_2 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.compat.v1.gather_3 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.expand_dims_1 (TFOpLamb  (None, 1, 2)                 0         ['tf.__operators__.add_3[0][0]
#  da)                                                                ']
#
#  tf.compat.v1.floor_div_1 (  ()                           0         ['tf.compat.v1.size_1[0][0]']
#  TFOpLambda)
#
#  tf.math.multiply_4 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_4[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_5 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_5[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_2 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_2[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_3 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_3[0][0]'
#  mbda)                                                              ]
#
#  tf.broadcast_to_1 (TFOpLam  (None, 17, 2)                0         ['tf.expand_dims_1[0][0]',
#  bda)                                                                'tf.compat.v1.floor_div_1[0][
#                                                                     0]']
#
#  tf.__operators__.add_2 (TF  (None, 2)                    0         ['tf.math.multiply_4[0][0]',
#  OpLambda)                                                           'tf.math.multiply_5[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 2)                    0         ['tf.math.multiply_2[0][0]',
#  OpLambda)                                                           'tf.math.multiply_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLa  (None, 17, 2)                0         ['tf.math.subtract[0][0]',
#  mbda)                                                               'tf.broadcast_to_1[0][0]']
#
#  tf.math.subtract_1 (TFOpLa  (None, 2)                    0         ['tf.__operators__.add_2[0][0]
#  mbda)                                                              ',
#                                                                      'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  tf.compat.v1.gather_8 (TFO  (17, 2)                      0         ['tf.math.subtract_2[0][0]']
#  pLambda)
#
#  tf.compat.v1.norm (TFOpLam  ()                           0         ['tf.math.subtract_1[0][0]']
#  bda)
#
#  tf.compat.v1.norm_1 (TFOpL  (2,)                         0         ['tf.compat.v1.gather_8[0][0]'
#  ambda)                                                             ]
#
#  tf.math.multiply_8 (TFOpLa  ()                           0         ['tf.compat.v1.norm[0][0]']
#  mbda)
#
#  tf.math.reduce_max (TFOpLa  ()                           0         ['tf.compat.v1.norm_1[0][0]']
#  mbda)
#
#  tf.math.maximum (TFOpLambd  ()                           0         ['tf.math.multiply_8[0][0]',
#  a)                                                                  'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv (TFOpLambd  (None, 17, 2)                0         ['tf.math.subtract[0][0]',
#  a)                                                                  'tf.math.maximum[0][0]']
#
#  flatten_12 (Flatten)        (None, 34)                   0         ['tf.math.truediv[0][0]']
#
#  dense_43 (Dense)            (None, 128)                  4480      ['flatten_12[0][0]']
#
#  dropout_25 (Dropout)        (None, 128)                  0         ['dense_43[0][0]']
#
#  dense_44 (Dense)            (None, 64)                   8256      ['dropout_25[0][0]']
#
#  dropout_26 (Dropout)        (None, 64)                   0         ['dense_44[0][0]']
#
#  dense_45 (Dense)            (None, 5)                    325       ['dropout_26[0][0]']
#
# ==================================================================================================
# Total params: 13061 (51.02 KB)
# Trainable params: 13061 (51.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Add a checkpoint callback to store the checkpoint that has the highest
# validation accuracy.
checkpoint_path = "weights_MoveNet.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='max')
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                              patience=20)

# Start training
history = model.fit(X_train, y_train,
                    epochs=200,
                    batch_size=16,
                    validation_data=(X_test,y_test),
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/200
# 60/61 [============================>.] - ETA: 0s - loss: 1.5182 - accuracy: 0.4594
# Epoch 1: val_accuracy improved from -inf to 0.60731, saving model to weights_MoveNet.keras
# 61/61 [==============================] - 2s 11ms/step - loss: 1.5164 - accuracy: 0.4595 - val_loss: 1.3519 - val_accuracy: 0.6073
# Epoch 2/200
# 61/61 [==============================] - ETA: 0s - loss: 1.2011 - accuracy: 0.5902
# Epoch 2: val_accuracy improved from 0.60731 to 0.66438, saving model to weights_MoveNet.keras
# 61/61 [==============================] - 0s 6ms/step - loss: 1.2011 - accuracy: 0.5902 - val_loss: 0.9627 - val_accuracy: 0.6644
# Epoch 3/200
# 61/61 [==============================] - ETA: 0s - loss: 0.9479 - accuracy: 0.6255
# Epoch 3: val_accuracy did not improve from 0.66438
# 61/61 [==============================] - 0s 5ms/step - loss: 0.9479 - accuracy: 0.6255 - val_loss: 0.7704 - val_accuracy: 0.6484
# Epoch 4/200
# 46/61 [=====================>........] - ETA: 0s - loss: 0.8379 - accuracy: 0.6454
# Epoch 4: val_accuracy improved from 0.66438 to 0.68950, saving model to weights_MoveNet.keras
# 61/61 [==============================] - 0s 6ms/step - loss: 0.8336 - accuracy: 0.6400 - val_loss: 0.6904 - val_accuracy: 0.6895
# Epoch 5/200
# 48/61 [======================>.......] - ETA: 0s - loss: 0.8098 - accuracy: 0.6758
# Epoch 5: val_accuracy improved from 0.68950 to 0.73059, saving model to weights_MoveNet.keras
# 61/61 [==============================] - 0s 6ms/step - loss: 0.8050 - accuracy: 0.6753 - val_loss: 0.6401 - val_accuracy: 0.7306
# Epoch 6/200
# 47/61 [======================>.......] - ETA: 0s - loss: 0.7163 - accuracy: 0.6915
# Epoch 6: val_accuracy improved from 0.73059 to 0.74429, saving model to weights_MoveNet.keras
# 61/61 [==============================] - 0s 6ms/step - loss: 0.7357 - accuracy: 0.6857 - val_loss: 0.5978 - val_accuracy: 0.7443
# Epoch 7/200
# 60/61 [============================>.] - ETA: 0s - loss: 0.7004 - accuracy: 0.7156
# Epoch 7: val_accuracy improved from 0.74429 to 0.74886, saving model to weights_MoveNet.keras
# 61/61 [==============================] - 0s 6ms/step - loss: 0.7017 - accuracy: 0.7147 - val_loss: 0.5635 - val_accuracy: 0.7489
# Epoch 8/200
# 61/61 [==============================] - ETA: 0s - loss: 0.6783 - accuracy: 0.7137
# Epoch 8: val_accuracy did not improve from 0.74886
# 61/61 [==============================] - 0s 5ms/step - loss: 0.6783 - accuracy: 0.7137 - val_loss: 0.5419 - val_accuracy: 0.7466
# Epoch 9/200
# 47/61 [======================>.......] - ETA: 0s - loss: 0.6778 - accuracy: 0.7221
# Epoch 9: val_accuracy improved from 0.74886 to 0.78767, saving model to weights_MoveNet.keras
# 61/61 [==============================] - 0s 6ms/step - loss: 0.6548 - accuracy: 0.7344 - val_loss: 0.5128 - val_accuracy: 0.7877
# Epoch 10/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2838 - accuracy: 0.9295 - val_loss: 0.1419 - val_accuracy: 0.9680
# Epoch 61/200
# 47/61 [======================>.......] - ETA: 0s - loss: 0.2660 - accuracy: 0.9149
# Epoch 61: val_accuracy did not improve from 0.97032
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2618 - accuracy: 0.9232 - val_loss: 0.1382 - val_accuracy: 0.9703
# Epoch 62/200
# 61/61 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.9243
# Epoch 62: val_accuracy did not improve from 0.97032
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2646 - accuracy: 0.9243 - val_loss: 0.1429 - val_accuracy: 0.9680
# Epoch 63/200
# 61/61 [==============================] - ETA: 0s - loss: 0.2541 - accuracy: 0.9263
# Epoch 63: val_accuracy did not improve from 0.97032
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2541 - accuracy: 0.9263 - val_loss: 0.1373 - val_accuracy: 0.9680
# Epoch 64/200
# 61/61 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.9263
# Epoch 64: val_accuracy did not improve from 0.97032
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2593 - accuracy: 0.9263 - val_loss: 0.1349 - val_accuracy: 0.9680
# Epoch 65/200
# 47/61 [======================>.......] - ETA: 0s - loss: 0.2487 - accuracy: 0.9335
# Epoch 65: val_accuracy did not improve from 0.97032
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2683 - accuracy: 0.9284 - val_loss: 0.1315 - val_accuracy: 0.9703

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of MoveNet for {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.savefig("Accuracy_Graph_MoveNet.png")
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of MoveNet for {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.savefig("Loss_Graph_MoveNet.png")
plt.show()

# %%
# Evaluate the model using the TEST dataset
model = keras.models.load_model('weights_MoveNet.keras')
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2270 - accuracy: 0.9658

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of MoveNet for {dataset_name}')
plt.savefig("Confusion_Matrix_MoveNet.png")
plt.show()

class_report = classification_report(y_true, y_pred, target_names=class_names)
print(class_report)
# Out:
# 14/14 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#      downdog       1.00      0.99      0.99        87
#      goddess       0.99      0.86      0.92        77
#        plank       0.98      0.99      0.99       107
#         tree       0.96      1.00      0.98        64
#     warrior2       0.92      0.98      0.95       103
#
#     accuracy                           0.97       438
#    macro avg       0.97      0.96      0.96       438
# weighted avg       0.97      0.97      0.97       438

# %%
with open('history_for_MoveNet.pkl', 'wb') as f:
    pickle.dump(history, f)

files_to_zip = ['weights_MoveNet.keras', 'history_for_MoveNet.pkl', 'Confusion_Matrix_MoveNet.png','Accuracy_Graph_MoveNet.png','Loss_Graph_MoveNet.png' ]
zip_filename = 'results_MoveNet.zip'
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/

# %% [markdown]
# # MediaPipe Model

# %%
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.3, model_complexity=2)
mp_drawing = mp.solutions.drawing_utils
# Out:
# Downloading model to /usr/local/lib/python3.10/dist-packages/mediapipe/modules/pose_landmark/pose_landmark_heavy.tflite

# %%
# Read an image from the specified path.
sample_img = cv2.imread('/content/dataset/test/downdog/00000000.jpg')
sample_img = cv2.cvtColor(sample_img, cv2.COLOR_BGR2RGB)
# Specify a size of the figure.
plt.figure(figsize = [10, 10])
results = pose.process(sample_img)
img_copy = sample_img.copy()

# Check if any landmarks are found.
if results.pose_landmarks:

    # Draw Pose landmarks on the sample image.
    mp_drawing.draw_landmarks(image=img_copy, landmark_list=results.pose_landmarks, connections=mp_pose.POSE_CONNECTIONS)

    # Specify a size of the figure.
    fig = plt.figure(figsize = [10, 10])

    # Display the output image with the landmarks drawn, also convert BGR to RGB for display.
    plt.title("Output");plt.axis('off');plt.imshow(img_copy);plt.show()

# %%
def detectPose(image, pose, display=True):
    '''
    This function performs pose detection on an image.
    Args:
        image: The input image with a prominent person whose pose landmarks needs to be detected.
        pose: The pose setup function required to perform the pose detection.
        display: A boolean value that is if set to true the function displays the original input image, the resultant image,
                 and the pose landmarks in 3D plot and returns nothing.
    Returns:
        output_image: The input image with the detected pose landmarks drawn.
        landmarks: A list of dictionaries representing the detected landmarks with name, x, y, and score.
    '''

    # Create a copy of the input image.
    output_image = image.copy()

    # Convert the image from BGR into RGB format.
    imageRGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Perform the Pose Detection.
    results = pose.process(imageRGB)

    # Retrieve the height and width of the input image.
    height, width, _ = image.shape

    # Initialize a list to store the detected landmarks.
    landmarks = []

    # Check if any landmarks are detected.
    if results.pose_landmarks:
        # Draw Pose landmarks on the output image.
        mp_drawing.draw_landmarks(image=output_image, landmark_list=results.pose_landmarks, connections=mp_pose.POSE_CONNECTIONS)

        # Iterate over the detected landmarks.
        for idx, landmark in enumerate(results.pose_landmarks.landmark):
            # Append the landmark into the list as a dictionary with name, x, y, and score.
            landmarks.append({
                'name': mp_pose.PoseLandmark(idx).name,
                'x': landmark.x * width,
                'y': landmark.y * height,
                'score': landmark.visibility
            })

    # Check if the original input image and the resultant image are specified to be displayed.
    if display:
        # Display the original input image and the resultant image.
        plt.figure(figsize=[22, 22])
        plt.subplot(121);plt.imshow(image[:,:,::-1]);plt.title("Original Image");plt.axis('off');
        plt.subplot(122);plt.imshow(output_image[:,:,::-1]);plt.title("Output Image");plt.axis('off');

        # Also Plot the Pose landmarks in 3D.
        mp_drawing.plot_landmarks(results.pose_world_landmarks, mp_pose.POSE_CONNECTIONS)

    # Otherwise
    else:
        # Return the output image and the found landmarks.
        return output_image, landmarks

def landmarks_list_to_df(landmarks):
    # Convert the list of dictionaries to a DataFrame
    landmarks_df = pd.DataFrame(landmarks)

    # Initialize an empty list to store the transformed data
    transformed_data = []

    # Loop through each row of the DataFrame
    for index, row in landmarks_df.iterrows():
        transformed_row = dict()
        for landmark in row:
            if landmark is not None:
                name_x = landmark['name']+"_x"
                name_y = landmark['name']+'_y'
                name_score = landmark['name']+'_score'
                transformed_row[name_x] = landmark['x']
                transformed_row[name_y] = landmark['y']
                transformed_row[name_score] = landmark['score']
        transformed_data.append(transformed_row)

        # print()
    # Convert the transformed data list to a DataFrame
    landmarks_df_transformed = pd.DataFrame(transformed_data)
    return landmarks_df_transformed

def create_landmarks_dataframe(dataset_dir, pose):
    image_paths_train = []
    image_paths_test = []
    landmarks_train = []
    landmarks_test = []
    pose_name_train = []
    pose_name_test = []
    class_labels = {}
    class_label_counter = 0
    for root, _, files in os.walk(dataset_dir):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
                image_path = os.path.join(root, file)
                img = cv2.imread(image_path)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                istrain = root.split(os.path.sep)[-2]
                o_img, landmark = detectPose(img, pose, display=False)
                if len(landmark)==0:
                    print(image_path)
                    print(landmark)
                    print()

                if landmark:
                    if istrain == 'train':
                        image_paths_train.append(image_path)
                        landmarks_train.append(landmark)
                        folder_name = root.split(os.path.sep)[-1]
                        pose_name_train.append(folder_name)
                        if folder_name not in class_labels:
                            class_labels[folder_name] = class_label_counter
                            class_label_counter += 1
                    else:
                        image_paths_test.append(image_path)
                        landmarks_test.append(landmark)
                        folder_name = root.split(os.path.sep)[-1]
                        pose_name_test.append(folder_name)
                        if folder_name not in class_labels:
                            class_labels[folder_name] = class_label_counter
                            class_label_counter += 1

    landmarks_train_df = landmarks_list_to_df(landmarks_train)
    landmarks_test_df = landmarks_list_to_df(landmarks_test)

    train_df = pd.DataFrame({'path': image_paths_train, 'pose_name': pose_name_train})
    test_df = pd.DataFrame({'path': image_paths_test, 'pose_name': pose_name_test})

    train_df['label'] = train_df['pose_name'].map(class_labels)
    test_df['label'] = test_df['pose_name'].map(class_labels)

    # # Combine the DataFrames horizontally
    train_combined_df = pd.concat([train_df, landmarks_train_df], axis=1)
    test_combined_df = pd.concat([test_df, landmarks_test_df], axis=1)

    return train_combined_df, test_combined_df

# %%
train_df, test_df = create_landmarks_dataframe('/content/dataset', pose)
# Out:
# /content/dataset/test/downdog/00000043.jpg
# []
#
# /content/dataset/test/downdog/00000120.jpg
# []
#
# /content/dataset/test/downdog/00000041.png
# []
#
# /content/dataset/test/downdog/00000084.jpg
# []
#
# /content/dataset/test/downdog/00000080.jpg
# []
#
# /content/dataset/test/downdog/00000075.png
# []
#
# /content/dataset/test/downdog/00000025.jpg
# []
#
# /content/dataset/test/downdog/00000060.jpg
# []
#
# /content/dataset/test/warrior2/00000025.png
# []
#
# /content/dataset/test/warrior2/00000039.png
# []
#
# /content/dataset/test/tree/00000034.jpg
# []
#
# /content/dataset/train/plank/00000285.jpg
# []
#
# /content/dataset/train/plank/00000378.jpg
# []
#
# /content/dataset/train/plank/00000294.png
# []
#
# /content/dataset/train/plank/00000178.jpg
# []
#
# /content/dataset/train/plank/00000413.jpg
# []
#
# /content/dataset/train/plank/00000236.png
# []
#
# /content/dataset/train/downdog/00000212.png
# []
#
# /content/dataset/train/downdog/00000168.jpg
# []
#
# /content/dataset/train/downdog/00000287.png
# []
#
# /content/dataset/train/downdog/00000147.jpg
# []
#
# /content/dataset/train/downdog/00000239.jpg
# []
#
# /content/dataset/train/downdog/00000235.jpg
# []
#
# /content/dataset/train/downdog/00000188.png
# []
#
# /content/dataset/train/downdog/00000224.jpg
# []
#
# /content/dataset/train/downdog/00000367.png
# []
#
# /content/dataset/train/downdog/00000350.jpg
# []
#
# /content/dataset/train/downdog/00000361.jpg
# []
#
# /content/dataset/train/downdog/00000340.jpg
# []
#
# /content/dataset/train/downdog/00000300.jpg
# []
#
# /content/dataset/train/downdog/00000221.jpg
# []
#
# /content/dataset/train/downdog/00000234.jpg
# []
#
# /content/dataset/train/downdog/00000394.jpg
# []
#
# /content/dataset/train/downdog/00000352.png
# []
#
# /content/dataset/train/downdog/00000297.jpg
# []
#
# /content/dataset/train/downdog/00000223.jpg
# []
#
# /content/dataset/train/downdog/00000200.jpg
# []
#
# /content/dataset/train/goddess/00000285.jpg
# []
#
# /content/dataset/train/goddess/00000127.png
# []
#
# /content/dataset/train/goddess/00000110.jpg
# []
#
# /content/dataset/train/goddess/00000299.jpg
# []
#
# /content/dataset/train/goddess/00000272.png
# []
#
# /content/dataset/train/goddess/00000190.jpg
# []
#
# /content/dataset/train/goddess/00000329.jpg
# []
#
# /content/dataset/train/goddess/00000282.png
# []
#
# /content/dataset/train/goddess/00000165.jpg
# []
#
# /content/dataset/train/goddess/00000146.jpg
# []
#
# /content/dataset/train/goddess/00000271.jpg
# []
#
# /content/dataset/train/goddess/00000228.jpg
# []
#
# /content/dataset/train/goddess/00000149.jpg
# []
#
# /content/dataset/train/goddess/00000242.jpg
# []
#
# /content/dataset/train/warrior2/00000349.jpg
# []
#
# /content/dataset/train/warrior2/00000326.jpg
# []
#
# /content/dataset/train/warrior2/00000137.jpg
# []
#
# /content/dataset/train/tree/00000198.jpg
# []
#
# /content/dataset/train/tree/00000140.png
# []
#
# /content/dataset/train/tree/00000137.jpg
# []
#
# /content/dataset/train/tree/00000204.jpg
# []

# %%
train_df.to_csv('train_data_MediaPipe.csv', index=False)
test_df.to_csv('test_data_MediaPipe.csv', index=False)

# %%
# !cp train_data_MediaPipe.csv /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset
# !cp test_data_MediaPipe.csv /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset

# %%
def load_pose_landmarks(dataframe):
  """Loads a CSV created by MoveNetPreprocessor.

  Returns:
    X: Detected landmark coordinates and scores of shape (N, 17 * 3)
    y: Ground truth labels of shape (N, label_count)
    classes: The list of all class names found in the dataset
    dataframe: The CSV loaded as a Pandas dataframe features (X) and ground
      truth labels (y) to use later to train a pose classification model.
  """

  df_to_process = dataframe.copy()

  # Drop the file_name columns as you don't need it during training.
  df_to_process.drop(columns=['path'], inplace=True)

  # Extract the list of class names
  classes = df_to_process.pop('pose_name').unique()

  # Extract the labels
  y = df_to_process.pop('label')

  # Convert the input features and labels into the correct format for training.
  X = df_to_process.astype('float64')
  y = keras.utils.to_categorical(y)

  return X, y, classes, dataframe

# %%
X_train, y_train, class_names_train, _ = load_pose_landmarks(train_df)
X_test, y_test, class_names_test, _ = load_pose_landmarks(test_df)
# Combine the train and test class names to ensure consistency
class_names = np.unique(np.concatenate((class_names_train, class_names_test), axis=0))

# Build the neural network model
input_shape = X_train.shape[1:]
num_classes = len(class_names)

# %%
model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=input_shape),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(num_classes, activation='softmax')
])

# Compile the model with learning rate
learning_rate = 0.001
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_56 (Dense)            (None, 256)               25600
#
#  dense_57 (Dense)            (None, 128)               32896
#
#  dense_58 (Dense)            (None, 64)                8256
#
#  dense_59 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 67077 (262.02 KB)
# Trainable params: 67077 (262.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)
checkpoint_pth = 'weights_MediaPipe.keras'
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, verbose = 1)
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/100
# 17/33 [==============>...............] - ETA: 0s - loss: 49.4350 - accuracy: 0.4136
# Epoch 1: val_accuracy improved from -inf to 0.71678, saving model to weights_MediaPipe.keras
# 33/33 [==============================] - 2s 11ms/step - loss: 31.7914 - accuracy: 0.4971 - val_loss: 8.4113 - val_accuracy: 0.7168
# Epoch 2/100
# 18/33 [===============>..............] - ETA: 0s - loss: 6.4514 - accuracy: 0.7465
# Epoch 2: val_accuracy improved from 0.71678 to 0.76688, saving model to weights_MediaPipe.keras
# 33/33 [==============================] - 0s 6ms/step - loss: 8.8203 - accuracy: 0.7060 - val_loss: 8.9230 - val_accuracy: 0.7669
# Epoch 3/100
# 17/33 [==============>...............] - ETA: 0s - loss: 8.7133 - accuracy: 0.6949
# Epoch 3: val_accuracy improved from 0.76688 to 0.83442, saving model to weights_MediaPipe.keras
# 33/33 [==============================] - 0s 6ms/step - loss: 8.0625 - accuracy: 0.6983 - val_loss: 4.7194 - val_accuracy: 0.8344
# Epoch 4/100
# 17/33 [==============>...............] - ETA: 0s - loss: 7.2549 - accuracy: 0.7206
# Epoch 4: val_accuracy did not improve from 0.83442
# 33/33 [==============================] - 0s 5ms/step - loss: 6.6367 - accuracy: 0.7360 - val_loss: 3.3443 - val_accuracy: 0.8017
# Epoch 5/100
# 18/33 [===============>..............] - ETA: 0s - loss: 3.4893 - accuracy: 0.7639
# Epoch 5: val_accuracy did not improve from 0.83442
# 33/33 [==============================] - 0s 5ms/step - loss: 2.9875 - accuracy: 0.7805 - val_loss: 5.3408 - val_accuracy: 0.6754
# Epoch 6/100
# 18/33 [===============>..............] - ETA: 0s - loss: 3.8545 - accuracy: 0.7569
# Epoch 37/100
# 18/33 [===============>..............] - ETA: 0s - loss: 0.3691 - accuracy: 0.9375
# Epoch 37: val_accuracy did not improve from 0.96296
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3298 - accuracy: 0.9381 - val_loss: 0.4577 - val_accuracy: 0.9542
# Epoch 38/100
# 18/33 [===============>..............] - ETA: 0s - loss: 0.2449 - accuracy: 0.9462
# Epoch 38: val_accuracy did not improve from 0.96296
# 33/33 [==============================] - 0s 5ms/step - loss: 0.4369 - accuracy: 0.9197 - val_loss: 0.8839 - val_accuracy: 0.9172
# Epoch 39/100
# 33/33 [==============================] - ETA: 0s - loss: 0.6332 - accuracy: 0.9130
# Epoch 39: val_accuracy did not improve from 0.96296
# 33/33 [==============================] - 0s 5ms/step - loss: 0.6332 - accuracy: 0.9130 - val_loss: 0.5980 - val_accuracy: 0.9281

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of MediaPipe for {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.savefig("Accuracy_Graph_MediaPipe.png")
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of MediaPipe for {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.savefig("Loss_Graph_MediaPipe.png")
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3262 - accuracy: 0.9630
# [0.32619401812553406, 0.9629629850387573]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize = (6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of MediaPipe for {dataset_name}')
plt.savefig("Confusion_Matrix_MediaPipe.png")
plt.show()

class_report = classification_report(y_true, y_pred, target_names=class_names)
print(class_report)
# Out:
# 15/15 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#      downdog       0.98      0.97      0.98       115
#      goddess       0.99      0.99      0.99        89
#        plank       0.94      0.91      0.92        80
#         tree       0.94      0.95      0.94       107
#     warrior2       0.97      0.99      0.98        68
#
#     accuracy                           0.96       459
#    macro avg       0.96      0.96      0.96       459
# weighted avg       0.96      0.96      0.96       459

# %%
with open('history_MediaPipe.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_MediaPipe.keras', 'history_MediaPipe.pkl', 'Confusion_Matrix_MediaPipe.png', 'Accuracy_Graph_MediaPipe.png', 'Loss_Graph_MediaPipe.png']
zip_filename = 'results_MediaPipe.zip'
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/

# %% [markdown]
# # YoloV8 Model

# %%
model = YOLO(model='yolov8x-pose-p6.pt')
image = cv2.imread('/content/dataset/test/downdog/00000000.jpg')
result = model.predict(image, save=False)[0]
result_keypoint = result.keypoints.xyn.cpu().numpy()[0]
Image.fromarray(cv2.cvtColor(result.plot(), cv2.COLOR_BGR2RGB))
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8x-pose-p6.pt to 'yolov8x-pose-p6.pt'...
# 100%|██████████| 190M/190M [00:02<00:00, 84.0MB/s]
# 0: 768x1280 1 person, 132.4ms
# Speed: 4.3ms preprocess, 132.4ms inference, 768.8ms postprocess per image at shape (1, 3, 768, 1280)
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
class GetKeypoint(BaseModel):
    NOSE:           int = 0
    LEFT_EYE:       int = 1
    RIGHT_EYE:      int = 2
    LEFT_EAR:       int = 3
    RIGHT_EAR:      int = 4
    LEFT_SHOULDER:  int = 5
    RIGHT_SHOULDER: int = 6
    LEFT_ELBOW:     int = 7
    RIGHT_ELBOW:    int = 8
    LEFT_WRIST:     int = 9
    RIGHT_WRIST:    int = 10
    LEFT_HIP:       int = 11
    RIGHT_HIP:      int = 12
    LEFT_KNEE:      int = 13
    RIGHT_KNEE:     int = 14
    LEFT_ANKLE:     int = 15
    RIGHT_ANKLE:    int = 16

get_keypoint = GetKeypoint()

# %%
dataset_root_train = '/content/dataset/train'
dataset_root_test = '/content/dataset/test'
pose_list = sorted(os.listdir(dataset_root_train))
pose_list
# Out:
# ['downdog', 'goddess', 'plank', 'tree', 'warrior2']

# %%
def extract_keypoint(keypoint):
    # nose
    nose_x, nose_y = keypoint[get_keypoint.NOSE]
    # eye
    left_eye_x, left_eye_y = keypoint[get_keypoint.LEFT_EYE]
    right_eye_x, right_eye_y = keypoint[get_keypoint.RIGHT_EYE]
    # ear
    left_ear_x, left_ear_y = keypoint[get_keypoint.LEFT_EAR]
    right_ear_x, right_ear_y = keypoint[get_keypoint.RIGHT_EAR]
    # shoulder
    left_shoulder_x, left_shoulder_y = keypoint[get_keypoint.LEFT_SHOULDER]
    right_shoulder_x, right_shoulder_y = keypoint[get_keypoint.RIGHT_SHOULDER]
    # elbow
    left_elbow_x, left_elbow_y = keypoint[get_keypoint.LEFT_ELBOW]
    right_elbow_x, right_elbow_y = keypoint[get_keypoint.RIGHT_ELBOW]
    # wrist
    left_wrist_x, left_wrist_y = keypoint[get_keypoint.LEFT_WRIST]
    right_wrist_x, right_wrist_y = keypoint[get_keypoint.RIGHT_WRIST]
    # hip
    left_hip_x, left_hip_y = keypoint[get_keypoint.LEFT_HIP]
    right_hip_x, right_hip_y = keypoint[get_keypoint.RIGHT_HIP]
    # knee
    left_knee_x, left_knee_y = keypoint[get_keypoint.LEFT_KNEE]
    right_knee_x, right_knee_y = keypoint[get_keypoint.RIGHT_KNEE]
    # ankle
    left_ankle_x, left_ankle_y = keypoint[get_keypoint.LEFT_ANKLE]
    right_ankle_x, right_ankle_y = keypoint[get_keypoint.RIGHT_ANKLE]

    return [
        nose_x, nose_y,
        left_eye_x, left_eye_y,
        right_eye_x, right_eye_y,
        left_ear_x, left_ear_y,
        right_ear_x, right_ear_y,
        left_shoulder_x, left_shoulder_y,
        right_shoulder_x, right_shoulder_y,
        left_elbow_x, left_elbow_y,
        right_elbow_x, right_elbow_y,
        left_wrist_x, left_wrist_y,
        right_wrist_x, right_wrist_y,
        left_hip_x, left_hip_y,
        right_hip_x, right_hip_y,
        left_knee_x, left_knee_y,
        right_knee_x, right_knee_y,
        left_ankle_x, left_ankle_y,
        right_ankle_x, right_ankle_y
    ]

# %%
dataset_csv_train = []
for pose in pose_list:
    # Using a set to store valid image extensions
    valid_extensions = {'jpg', 'jpeg', 'png', 'bmp'}

    # List all files in the directory
    image_path_list = []
    for ext in valid_extensions:
        image_path_list.extend(glob.glob(f'{dataset_root_train}/{pose}/*.{ext}'))

    for image_path in image_path_list:
        # get image_name
        image_name = image_path.split('/')[-1]
        # read numpy image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip to the next image if reading fails

        # get height width image
        height, width = image.shape[:2]

        # detect pose using yolov8-pose
        results = model.predict(image, save=False)[0]
        results_keypoint = results.keypoints.xyn.cpu().numpy()

        # Check if only one person is detected
        if len(results_keypoint) == 1:
            result_keypoint = results_keypoint[0]
            if len(result_keypoint) == 17:
                keypoint_list = extract_keypoint(result_keypoint)

                # insert image_name, label at index 0, 1
                keypoint_list.insert(0, image_path)
                keypoint_list.insert(1, pose)
                dataset_csv_train.append(keypoint_list)
        else:
            print("------------------------------------------------------------------------")
            print(f"More than one person detected in image: {image_path}. Ignoring pose landmarks.")
            print("------------------------------------------------------------------------")
# Out:
# 0: 1280x1024 1 person, 252.1ms
# Speed: 6.9ms preprocess, 252.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1024x1280 1 person, 173.4ms
# Speed: 6.4ms preprocess, 173.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 512x1280 1 person, 96.6ms
# Speed: 4.6ms preprocess, 96.6ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 1280)
#
# 0: 640x1280 1 person, 110.9ms
# Speed: 4.8ms preprocess, 110.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 768x1280 1 person, 130.5ms
# Speed: 8.0ms preprocess, 130.5ms inference, 1.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 (no detections), 211.0ms
# Speed: 8.7ms preprocess, 211.0ms inference, 0.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 704x1280 1 person, 125.4ms
# Speed: 6.0ms preprocess, 125.4ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 (no detections), 150.9ms
# Speed: 5.8ms preprocess, 150.9ms inference, 0.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 512x1280 1 person, 89.2ms
# Speed: 4.9ms preprocess, 89.2ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 1280)
#
# 0: 896x1280 1 person, 155.2ms
# Speed: 7.3ms preprocess, 155.2ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 640x1280 1 person, 111.2ms
# Speed: 5.9ms preprocess, 111.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 832x1280 1 person, 149.1ms
# Speed: 5.6ms preprocess, 149.1ms inference, 1.9ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1024x1280 1 person, 175.0ms
# Speed: 6.5ms preprocess, 175.0ms inference, 2.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 768x1280 1 person, 131.8ms
# Speed: 6.1ms preprocess, 131.8ms inference, 1.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 704x1280 1 person, 123.4ms
# Speed: 6.1ms preprocess, 123.4ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 768x1280 1 person, 130.2ms
# Speed: 6.0ms preprocess, 130.2ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 128.0ms
# Speed: 5.6ms preprocess, 128.0ms inference, 1.3ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 130.4ms
# Speed: 5.5ms preprocess, 130.4ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 130.0ms
# Speed: 5.7ms preprocess, 130.0ms inference, 2.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 832x1280 2 persons, 144.8ms
# Speed: 7.4ms preprocess, 144.8ms inference, 2.2ms postprocess per image at shape (1, 3, 832, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000228.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 896x1280 1 person, 156.1ms
# Speed: 7.2ms preprocess, 156.1ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 213.7ms
# Speed: 10.2ms preprocess, 213.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 2 persons, 146.3ms
# Speed: 6.7ms preprocess, 146.3ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000242.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 704x1280 1 person, 124.4ms
# Speed: 5.5ms preprocess, 124.4ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 832x1280 1 person, 150.5ms
# Speed: 7.4ms preprocess, 150.5ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 (no detections), 151.1ms
# Speed: 7.3ms preprocess, 151.1ms inference, 0.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 151.7ms
# Speed: 6.9ms preprocess, 151.7ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 132.0ms
# Speed: 4.9ms preprocess, 132.0ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 157.3ms
# Speed: 6.0ms preprocess, 157.3ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 166.0ms
# Speed: 7.4ms preprocess, 166.0ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 2 persons, 132.5ms
# Speed: 5.5ms preprocess, 132.5ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000370.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 768x1280 2 persons, 129.7ms
# Speed: 3.9ms preprocess, 129.7ms inference, 2.2ms postprocess per image at shape (1, 3, 768, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000403.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 896x1280 1 person, 157.7ms
# Speed: 6.5ms preprocess, 157.7ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 163.8ms
# Speed: 7.7ms preprocess, 163.8ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1024 (no detections), 170.7ms
# Speed: 7.6ms preprocess, 170.7ms inference, 0.8ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 768x1280 1 person, 129.1ms
# Speed: 7.4ms preprocess, 129.1ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 129.8ms
# Speed: 4.4ms preprocess, 129.8ms inference, 2.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 167.8ms
# Speed: 6.3ms preprocess, 167.8ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 159.4ms
# Speed: 6.5ms preprocess, 159.4ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x960 1 person, 169.8ms
# Speed: 7.8ms preprocess, 169.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 832x1280 1 person, 148.2ms
# Speed: 6.3ms preprocess, 148.2ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 129.6ms
# Speed: 7.3ms preprocess, 129.6ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x960 1 person, 170.3ms
# Speed: 7.8ms preprocess, 170.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 960x1280 1 person, 165.7ms
# Speed: 6.0ms preprocess, 165.7ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 156.0ms
# Speed: 6.5ms preprocess, 156.0ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 169.6ms
# Speed: 6.1ms preprocess, 169.6ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 155.4ms
# Speed: 9.3ms preprocess, 155.4ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 217.7ms
# Speed: 8.0ms preprocess, 217.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 152.3ms
# Speed: 6.6ms preprocess, 152.3ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 150.8ms
# Speed: 6.6ms preprocess, 150.8ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 (no detections), 153.8ms
# Speed: 6.9ms preprocess, 153.8ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1024x1280 1 person, 173.9ms
# Speed: 7.5ms preprocess, 173.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 768x1280 1 person, 132.1ms
# Speed: 5.7ms preprocess, 132.1ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 165.9ms
# Speed: 6.2ms preprocess, 165.9ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 221.6ms
# Speed: 8.5ms preprocess, 221.6ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x960 1 person, 170.1ms
# Speed: 7.1ms preprocess, 170.1ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 896x1280 1 person, 154.9ms
# Speed: 7.4ms preprocess, 154.9ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1088x1280 1 person, 194.8ms
# Speed: 8.3ms preprocess, 194.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 832x1280 1 person, 150.8ms
# Speed: 6.3ms preprocess, 150.8ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 (no detections), 129.2ms
# Speed: 8.2ms preprocess, 129.2ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 154.9ms
# Speed: 9.7ms preprocess, 154.9ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 166.8ms
# Speed: 7.6ms preprocess, 166.8ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1024x1280 1 person, 173.4ms
# Speed: 7.0ms preprocess, 173.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 640x1280 1 person, 113.5ms
# Speed: 4.9ms preprocess, 113.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 960x1280 1 person, 169.1ms
# Speed: 8.4ms preprocess, 169.1ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1088x1280 2 persons, 191.8ms
# Speed: 7.5ms preprocess, 191.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000235.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 896x1280 1 person, 157.5ms
# Speed: 6.2ms preprocess, 157.5ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 167.2ms
# Speed: 6.8ms preprocess, 167.2ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 132.7ms
# Speed: 4.8ms preprocess, 132.7ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 2 persons, 114.3ms
# Speed: 4.2ms preprocess, 114.3ms inference, 2.4ms postprocess per image at shape (1, 3, 768, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000391.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 832x1280 1 person, 154.0ms
# Speed: 6.1ms preprocess, 154.0ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 169.1ms
# Speed: 7.4ms preprocess, 169.1ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 169.2ms
# Speed: 6.3ms preprocess, 169.2ms inference, 2.3ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1088x1280 2 persons, 192.1ms
# Speed: 8.0ms preprocess, 192.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1088, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000224.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 (no detections), 220.7ms
# Speed: 12.2ms preprocess, 220.7ms inference, 0.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 640x1280 1 person, 114.2ms
# Speed: 5.3ms preprocess, 114.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 896x1280 1 person, 158.1ms
# Speed: 6.7ms preprocess, 158.1ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 2 persons, 154.0ms
# Speed: 6.3ms preprocess, 154.0ms inference, 2.4ms postprocess per image at shape (1, 3, 896, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000293.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 704x1280 1 person, 127.0ms
# Speed: 5.2ms preprocess, 127.0ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 1 person, 158.2ms
# Speed: 6.3ms preprocess, 158.2ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 153.7ms
# Speed: 6.5ms preprocess, 153.7ms inference, 2.4ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 164.3ms
# Speed: 6.4ms preprocess, 164.3ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 704x1280 1 person, 128.3ms
# Speed: 5.7ms preprocess, 128.3ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 768x1280 1 person, 131.1ms
# Speed: 6.6ms preprocess, 131.1ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1088x1280 1 person, 189.1ms
# Speed: 8.0ms preprocess, 189.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1024x1280 1 person, 171.6ms
# Speed: 7.4ms preprocess, 171.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 169.0ms
# Speed: 8.1ms preprocess, 169.0ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1024x1280 (no detections), 174.9ms
# Speed: 7.0ms preprocess, 174.9ms inference, 0.9ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1024x1280 (no detections), 174.8ms
# Speed: 6.8ms preprocess, 174.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1152x1280 1 person, 200.7ms
# Speed: 9.5ms preprocess, 200.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x1280 1 person, 222.0ms
# Speed: 9.8ms preprocess, 222.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 640x1280 1 person, 114.2ms
# Speed: 5.3ms preprocess, 114.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 768x1280 1 person, 132.7ms
# Speed: 5.7ms preprocess, 132.7ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 131.0ms
# Speed: 4.2ms preprocess, 131.0ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x896 1 person, 159.7ms
# Speed: 6.8ms preprocess, 159.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1024x1280 2 persons, 175.1ms
# Speed: 7.2ms preprocess, 175.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000340.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 896x1280 1 person, 157.9ms
# Speed: 6.9ms preprocess, 157.9ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 221.8ms
# Speed: 9.1ms preprocess, 221.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 159.0ms
# Speed: 6.8ms preprocess, 159.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 154.5ms
# Speed: 7.2ms preprocess, 154.5ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 148.9ms
# Speed: 6.5ms preprocess, 148.9ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 (no detections), 168.8ms
# Speed: 6.5ms preprocess, 168.8ms inference, 0.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 (no detections), 130.3ms
# Speed: 8.4ms preprocess, 130.3ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 704x1280 1 person, 127.3ms
# Speed: 5.0ms preprocess, 127.3ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 960x1280 1 person, 169.3ms
# Speed: 6.2ms preprocess, 169.3ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 218.1ms
# Speed: 9.1ms preprocess, 218.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 156.0ms
# Speed: 6.9ms preprocess, 156.0ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 219.1ms
# Speed: 10.4ms preprocess, 219.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 131.9ms
# Speed: 6.1ms preprocess, 131.9ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 129.9ms
# Speed: 6.1ms preprocess, 129.9ms inference, 2.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 157.4ms
# Speed: 6.6ms preprocess, 157.4ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 154.1ms
# Speed: 7.4ms preprocess, 154.1ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 152.1ms
# Speed: 9.9ms preprocess, 152.1ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 151.7ms
# Speed: 6.7ms preprocess, 151.7ms inference, 3.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 165.2ms
# Speed: 6.7ms preprocess, 165.2ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 223.5ms
# Speed: 8.9ms preprocess, 223.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 156.0ms
# Speed: 7.1ms preprocess, 156.0ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 168.3ms
# Speed: 8.5ms preprocess, 168.3ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 132.2ms
# Speed: 4.0ms preprocess, 132.2ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 2 persons, 130.3ms
# Speed: 4.0ms preprocess, 130.3ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000219.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 896x1280 1 person, 157.8ms
# Speed: 6.8ms preprocess, 157.8ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 125.1ms
# Speed: 5.8ms preprocess, 125.1ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1280 1 person, 223.7ms
# Speed: 10.0ms preprocess, 223.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 135.9ms
# Speed: 5.7ms preprocess, 135.9ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 131.4ms
# Speed: 4.0ms preprocess, 131.4ms inference, 2.2ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 704x1280 1 person, 124.9ms
# Speed: 6.1ms preprocess, 124.9ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 960x1280 1 person, 167.0ms
# Speed: 10.6ms preprocess, 167.0ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 165.9ms
# Speed: 8.2ms preprocess, 165.9ms inference, 2.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 159.7ms
# Speed: 6.2ms preprocess, 159.7ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x896 1 person, 158.1ms
# Speed: 7.2ms preprocess, 158.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1024x1280 1 person, 174.3ms
# Speed: 7.3ms preprocess, 174.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 768x1280 1 person, 134.2ms
# Speed: 6.1ms preprocess, 134.2ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1024x1280 1 person, 178.0ms
# Speed: 7.2ms preprocess, 178.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 768x1280 1 person, 133.6ms
# Speed: 6.0ms preprocess, 133.6ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 640x1280 1 person, 113.1ms
# Speed: 5.4ms preprocess, 113.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 768x1280 1 person, 132.6ms
# Speed: 4.3ms preprocess, 132.6ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 130.8ms
# Speed: 6.6ms preprocess, 130.8ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 832x1280 1 person, 151.7ms
# Speed: 6.3ms preprocess, 151.7ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 169.7ms
# Speed: 7.6ms preprocess, 169.7ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 1 person, 149.1ms
# Speed: 6.3ms preprocess, 149.1ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 704x1280 (no detections), 127.6ms
# Speed: 5.3ms preprocess, 127.6ms inference, 0.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 768x1280 1 person, 133.8ms
# Speed: 6.1ms preprocess, 133.8ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 169.3ms
# Speed: 4.8ms preprocess, 169.3ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 158.1ms
# Speed: 7.3ms preprocess, 158.1ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 132.9ms
# Speed: 3.7ms preprocess, 132.9ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 832x1280 1 person, 148.9ms
# Speed: 5.8ms preprocess, 148.9ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 172.8ms
# Speed: 6.4ms preprocess, 172.8ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 223.4ms
# Speed: 10.7ms preprocess, 223.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 1 person, 150.2ms
# Speed: 6.4ms preprocess, 150.2ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 157.8ms
# Speed: 6.9ms preprocess, 157.8ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 219.2ms
# Speed: 10.9ms preprocess, 219.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 132.3ms
# Speed: 7.5ms preprocess, 132.3ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 166.4ms
# Speed: 7.0ms preprocess, 166.4ms inference, 3.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1024x1280 1 person, 178.2ms
# Speed: 7.5ms preprocess, 178.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 1 person, 225.0ms
# Speed: 8.4ms preprocess, 225.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 159.7ms
# Speed: 7.6ms preprocess, 159.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 832x1280 1 person, 151.2ms
# Speed: 6.4ms preprocess, 151.2ms inference, 2.1ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 168.6ms
# Speed: 8.3ms preprocess, 168.6ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 704x1280 1 person, 125.5ms
# Speed: 6.4ms preprocess, 125.5ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 1 person, 155.8ms
# Speed: 6.5ms preprocess, 155.8ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 126.6ms
# Speed: 6.5ms preprocess, 126.6ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 832x1280 1 person, 150.5ms
# Speed: 6.1ms preprocess, 150.5ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 168.9ms
# Speed: 7.4ms preprocess, 168.9ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 1 person, 149.6ms
# Speed: 6.9ms preprocess, 149.6ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 157.8ms
# Speed: 6.5ms preprocess, 157.8ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 640x1280 1 person, 112.6ms
# Speed: 5.0ms preprocess, 112.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 1280x1280 1 person, 225.1ms
# Speed: 9.6ms preprocess, 225.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 704x1280 1 person, 127.3ms
# Speed: 5.4ms preprocess, 127.3ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 1 person, 158.3ms
# Speed: 6.3ms preprocess, 158.3ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 134.5ms
# Speed: 5.8ms preprocess, 134.5ms inference, 1.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 159.6ms
# Speed: 6.2ms preprocess, 159.6ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 134.2ms
# Speed: 6.1ms preprocess, 134.2ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 133.7ms
# Speed: 6.2ms preprocess, 133.7ms inference, 2.3ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 128.3ms
# Speed: 5.8ms preprocess, 128.3ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 160.4ms
# Speed: 6.9ms preprocess, 160.4ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 168.9ms
# Speed: 7.1ms preprocess, 168.9ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 1 person, 150.7ms
# Speed: 5.5ms preprocess, 150.7ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 3 persons, 156.6ms
# Speed: 6.9ms preprocess, 156.6ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000423.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1024x1280 1 person, 177.1ms
# Speed: 11.3ms preprocess, 177.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 896x1280 1 person, 159.0ms
# Speed: 6.3ms preprocess, 159.0ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 220.5ms
# Speed: 8.2ms preprocess, 220.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 640x1280 1 person, 114.8ms
# Speed: 5.1ms preprocess, 114.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 768x1280 1 person, 135.6ms
# Speed: 5.8ms preprocess, 135.6ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 157.7ms
# Speed: 6.6ms preprocess, 157.7ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x768 2 persons, 133.5ms
# Speed: 6.0ms preprocess, 133.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 768)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000425.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 768x1280 1 person, 137.3ms
# Speed: 5.5ms preprocess, 137.3ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 223.0ms
# Speed: 8.4ms preprocess, 223.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 155.1ms
# Speed: 6.2ms preprocess, 155.1ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 2 persons, 169.9ms
# Speed: 6.8ms preprocess, 169.9ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000182.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1088 1 person, 201.1ms
# Speed: 9.0ms preprocess, 201.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x1280 1 person, 226.9ms
# Speed: 8.6ms preprocess, 226.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 4 persons, 152.0ms
# Speed: 5.8ms preprocess, 152.0ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000274.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 224.7ms
# Speed: 8.8ms preprocess, 224.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 223.2ms
# Speed: 8.5ms preprocess, 223.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 171.2ms
# Speed: 6.5ms preprocess, 171.2ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1152x1280 1 person, 199.3ms
# Speed: 9.1ms preprocess, 199.3ms inference, 2.1ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x1280 1 person, 221.6ms
# Speed: 9.1ms preprocess, 221.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 704x1280 1 person, 127.8ms
# Speed: 5.2ms preprocess, 127.8ms inference, 1.6ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 768x1280 1 person, 135.7ms
# Speed: 5.5ms preprocess, 135.7ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x896 1 person, 159.4ms
# Speed: 6.9ms preprocess, 159.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 960x1280 1 person, 170.8ms
# Speed: 5.9ms preprocess, 170.8ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 134.4ms
# Speed: 5.9ms preprocess, 134.4ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1088 1 person, 201.9ms
# Speed: 8.7ms preprocess, 201.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 832x1280 1 person, 150.3ms
# Speed: 6.1ms preprocess, 150.3ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 163.5ms
# Speed: 7.9ms preprocess, 163.5ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 167.2ms
# Speed: 8.5ms preprocess, 167.2ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1152x1280 1 person, 203.8ms
# Speed: 14.0ms preprocess, 203.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 704x1280 1 person, 127.4ms
# Speed: 5.7ms preprocess, 127.4ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 (no detections), 156.9ms
# Speed: 6.5ms preprocess, 156.9ms inference, 0.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 2 persons, 133.9ms
# Speed: 4.3ms preprocess, 133.9ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/00000255.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 960x1280 1 person, 171.6ms
# Speed: 10.4ms preprocess, 171.6ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1024x1280 1 person, 176.8ms
# Speed: 7.3ms preprocess, 176.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 896x1280 1 person, 158.5ms
# Speed: 6.4ms preprocess, 158.5ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 168.9ms
# Speed: 6.6ms preprocess, 168.9ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 169.3ms
# Speed: 8.0ms preprocess, 169.3ms inference, 3.3ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 167.1ms
# Speed: 7.1ms preprocess, 167.1ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 169.7ms
# Speed: 7.1ms preprocess, 169.7ms inference, 2.3ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 1 person, 151.8ms
# Speed: 6.3ms preprocess, 151.8ms inference, 2.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 169.0ms
# Speed: 8.1ms preprocess, 169.0ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 168.2ms
# Speed: 6.4ms preprocess, 168.2ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 169.4ms
# Speed: 7.0ms preprocess, 169.4ms inference, 3.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 (no detections), 223.0ms
# Speed: 8.2ms preprocess, 223.0ms inference, 0.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x960 1 person, 173.0ms
# Speed: 7.9ms preprocess, 173.0ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 896x1280 1 person, 157.9ms
# Speed: 6.9ms preprocess, 157.9ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 148.4ms
# Speed: 6.2ms preprocess, 148.4ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x1280 (no detections), 221.3ms
# Speed: 7.8ms preprocess, 221.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 171.6ms
# Speed: 6.4ms preprocess, 171.6ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 224.8ms
# Speed: 8.2ms preprocess, 224.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 221.6ms
# Speed: 8.2ms preprocess, 221.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 221.8ms
# Speed: 7.8ms preprocess, 221.8ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 1 person, 150.5ms
# Speed: 5.9ms preprocess, 150.5ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x1280 1 person, 225.5ms
# Speed: 9.0ms preprocess, 225.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 162.1ms
# Speed: 6.5ms preprocess, 162.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 832x1280 3 persons, 151.3ms
# Speed: 5.8ms preprocess, 151.3ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/goddess/00000198.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 960x1280 1 person, 169.5ms
# Speed: 7.8ms preprocess, 169.5ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x960 1 person, 173.8ms
# Speed: 7.5ms preprocess, 173.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 768x1280 1 person, 133.9ms
# Speed: 4.3ms preprocess, 133.9ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 171.8ms
# Speed: 6.6ms preprocess, 171.8ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 134.2ms
# Speed: 3.9ms preprocess, 134.2ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 704x1280 1 person, 125.3ms
# Speed: 5.7ms preprocess, 125.3ms inference, 1.6ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 832x1280 1 person, 154.1ms
# Speed: 5.8ms preprocess, 154.1ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 170.2ms
# Speed: 6.1ms preprocess, 170.2ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 704x1280 1 person, 126.3ms
# Speed: 5.5ms preprocess, 126.3ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x896 1 person, 163.7ms
# Speed: 6.7ms preprocess, 163.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 704x1280 1 person, 127.3ms
# Speed: 5.7ms preprocess, 127.3ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1280 1 person, 225.5ms
# Speed: 7.9ms preprocess, 225.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 164.2ms
# Speed: 6.9ms preprocess, 164.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 157.6ms
# Speed: 8.4ms preprocess, 157.6ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 126.2ms
# Speed: 6.1ms preprocess, 126.2ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 1 person, 159.2ms
# Speed: 10.1ms preprocess, 159.2ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 157.1ms
# Speed: 6.2ms preprocess, 157.1ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 131.8ms
# Speed: 5.5ms preprocess, 131.8ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 169.8ms
# Speed: 7.8ms preprocess, 169.8ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 168.0ms
# Speed: 6.9ms preprocess, 168.0ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 158.2ms
# Speed: 8.8ms preprocess, 158.2ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 155.5ms
# Speed: 11.3ms preprocess, 155.5ms inference, 2.4ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 227.3ms
# Speed: 10.1ms preprocess, 227.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 162.1ms
# Speed: 6.3ms preprocess, 162.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1152x1280 1 person, 201.3ms
# Speed: 8.2ms preprocess, 201.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x1280 1 person, 227.6ms
# Speed: 7.5ms preprocess, 227.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 137.2ms
# Speed: 3.8ms preprocess, 137.2ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 129.6ms
# Speed: 6.1ms preprocess, 129.6ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 222.3ms
# Speed: 8.7ms preprocess, 222.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 167.3ms
# Speed: 8.8ms preprocess, 167.3ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 134.2ms
# Speed: 5.8ms preprocess, 134.2ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 159.3ms
# Speed: 9.5ms preprocess, 159.3ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 226.3ms
# Speed: 8.3ms preprocess, 226.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 134.1ms
# Speed: 6.6ms preprocess, 134.1ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1024 1 person, 177.2ms
# Speed: 6.6ms preprocess, 177.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 704x1280 1 person, 127.5ms
# Speed: 6.0ms preprocess, 127.5ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 1 person, 160.8ms
# Speed: 7.3ms preprocess, 160.8ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 155.9ms
# Speed: 7.1ms preprocess, 155.9ms inference, 2.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 226.7ms
# Speed: 7.3ms preprocess, 226.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 157.3ms
# Speed: 9.1ms preprocess, 157.3ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 151.1ms
# Speed: 6.3ms preprocess, 151.1ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 159.1ms
# Speed: 7.2ms preprocess, 159.1ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 156.7ms
# Speed: 6.2ms preprocess, 156.7ms inference, 2.3ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x896 1 person, 162.2ms
# Speed: 7.3ms preprocess, 162.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x896 1 person, 159.3ms
# Speed: 7.2ms preprocess, 159.3ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1088 2 persons, 202.1ms
# Speed: 8.8ms preprocess, 202.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1088)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/goddess/00000136.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 960x1280 1 person, 169.2ms
# Speed: 8.0ms preprocess, 169.2ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 226.5ms
# Speed: 9.3ms preprocess, 226.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 222.2ms
# Speed: 8.6ms preprocess, 222.2ms inference, 1.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 159.3ms
# Speed: 6.5ms preprocess, 159.3ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 133.9ms
# Speed: 4.3ms preprocess, 133.9ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1024x1280 1 person, 182.5ms
# Speed: 6.3ms preprocess, 182.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1024x1280 1 person, 177.3ms
# Speed: 7.0ms preprocess, 177.3ms inference, 2.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 171.9ms
# Speed: 6.7ms preprocess, 171.9ms inference, 2.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 168.3ms
# Speed: 8.7ms preprocess, 168.3ms inference, 2.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 160.0ms
# Speed: 7.9ms preprocess, 160.0ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 155.2ms
# Speed: 8.8ms preprocess, 155.2ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 156.2ms
# Speed: 6.7ms preprocess, 156.2ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 129.3ms
# Speed: 4.9ms preprocess, 129.3ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1280 1 person, 226.8ms
# Speed: 9.5ms preprocess, 226.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 134.4ms
# Speed: 6.8ms preprocess, 134.4ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1024x1280 1 person, 183.0ms
# Speed: 8.6ms preprocess, 183.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 896x1280 1 person, 156.8ms
# Speed: 6.5ms preprocess, 156.8ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x896 1 person, 163.8ms
# Speed: 6.6ms preprocess, 163.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 960x1280 1 person, 170.4ms
# Speed: 6.6ms preprocess, 170.4ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 224.9ms
# Speed: 9.2ms preprocess, 224.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 223.8ms
# Speed: 8.0ms preprocess, 223.8ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 225.6ms
# Speed: 8.8ms preprocess, 225.6ms inference, 3.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 704x1280 1 person, 129.8ms
# Speed: 5.6ms preprocess, 129.8ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 960x1280 1 person, 172.3ms
# Speed: 6.1ms preprocess, 172.3ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1152 1 person, 211.5ms
# Speed: 8.0ms preprocess, 211.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 768x1280 1 person, 135.2ms
# Speed: 5.6ms preprocess, 135.2ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1024x1280 1 person, 177.5ms
# Speed: 7.0ms preprocess, 177.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 768x1280 1 person, 135.1ms
# Speed: 6.3ms preprocess, 135.1ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 228.7ms
# Speed: 7.7ms preprocess, 228.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 136.1ms
# Speed: 6.0ms preprocess, 136.1ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1152x1280 1 person, 203.1ms
# Speed: 7.5ms preprocess, 203.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 896x1280 1 person, 161.6ms
# Speed: 8.9ms preprocess, 161.6ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1088x1280 1 person, 199.7ms
# Speed: 7.6ms preprocess, 199.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x1280 1 person, 226.4ms
# Speed: 10.7ms preprocess, 226.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 172.2ms
# Speed: 6.2ms preprocess, 172.2ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 704x1280 1 person, 129.2ms
# Speed: 5.8ms preprocess, 129.2ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 768x1280 1 person, 133.9ms
# Speed: 8.3ms preprocess, 133.9ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 133.8ms
# Speed: 6.1ms preprocess, 133.8ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 130.5ms
# Speed: 5.7ms preprocess, 130.5ms inference, 2.2ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 159.0ms
# Speed: 7.0ms preprocess, 159.0ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 156.9ms
# Speed: 9.7ms preprocess, 156.9ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1152 1 person, 209.3ms
# Speed: 7.1ms preprocess, 209.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 960x1280 1 person, 170.7ms
# Speed: 6.3ms preprocess, 170.7ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 3 persons, 152.7ms
# Speed: 5.9ms preprocess, 152.7ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/goddess/00000188.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x768 1 person, 137.9ms
# Speed: 6.3ms preprocess, 137.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 768)
#
# 0: 896x1280 1 person, 160.7ms
# Speed: 6.8ms preprocess, 160.7ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 135.2ms
# Speed: 5.7ms preprocess, 135.2ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x768 1 person, 135.9ms
# Speed: 6.0ms preprocess, 135.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 768)
#
# 0: 1280x1280 1 person, 229.0ms
# Speed: 8.5ms preprocess, 229.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 2 persons, 167.6ms
# Speed: 6.8ms preprocess, 167.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/goddess/00000216.jpg. Ignoring pose landmarks.
# ...
# ------------------------------------------------------------------------
#
# 0: 896x1280 1 person, 163.7ms
# Speed: 6.2ms preprocess, 163.7ms inference, 2.4ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 177.4ms
# Speed: 7.0ms preprocess, 177.4ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 136.2ms
# Speed: 9.3ms preprocess, 136.2ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 136.8ms
# Speed: 5.5ms preprocess, 136.8ms inference, 2.2ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 134.8ms
# Speed: 7.7ms preprocess, 134.8ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1088x1280 1 person, 204.1ms
# Speed: 7.7ms preprocess, 204.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 768x1280 1 person, 140.3ms
# Speed: 3.8ms preprocess, 140.3ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 139.3ms
# Speed: 6.5ms preprocess, 139.3ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 238.3ms
# Speed: 11.1ms preprocess, 238.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 1 person, 157.3ms
# Speed: 6.4ms preprocess, 157.3ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 179.0ms
# Speed: 7.0ms preprocess, 179.0ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 163.5ms
# Speed: 7.2ms preprocess, 163.5ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 141.1ms
# Speed: 5.7ms preprocess, 141.1ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 164.8ms
# Speed: 6.0ms preprocess, 164.8ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1024x1280 1 person, 185.6ms
# Speed: 7.8ms preprocess, 185.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 178.9ms
# Speed: 8.5ms preprocess, 178.9ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 165.5ms
# Speed: 7.0ms preprocess, 165.5ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 154.4ms
# Speed: 6.7ms preprocess, 154.4ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x1280 1 person, 235.9ms
# Speed: 10.1ms preprocess, 235.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 1 person, 180.8ms
# Speed: 7.6ms preprocess, 180.8ms inference, 2.2ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1216 1 person, 229.7ms
# Speed: 9.2ms preprocess, 229.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 896x1280 1 person, 165.5ms
# Speed: 9.6ms preprocess, 165.5ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 234.5ms
# Speed: 10.1ms preprocess, 234.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 704x1280 1 person, 128.9ms
# Speed: 7.0ms preprocess, 128.9ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 960x1280 1 person, 176.3ms
# Speed: 7.3ms preprocess, 176.3ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 230.1ms
# Speed: 10.2ms preprocess, 230.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 1 person, 186.2ms
# Speed: 8.7ms preprocess, 186.2ms inference, 2.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1216 1 person, 227.8ms
# Speed: 11.9ms preprocess, 227.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x1280 5 persons, 235.9ms
# Speed: 8.7ms preprocess, 235.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior2/00000222.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 233.1ms
# Speed: 9.0ms preprocess, 233.1ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 236.4ms
# Speed: 8.4ms preprocess, 236.4ms inference, 3.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 2 persons, 169.6ms
# Speed: 6.9ms preprocess, 169.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior2/00000225.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x832 1 person, 160.3ms
# Speed: 6.6ms preprocess, 160.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 896x1280 1 person, 165.2ms
# Speed: 7.7ms preprocess, 165.2ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1024 1 person, 182.9ms
# Speed: 9.0ms preprocess, 182.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 960x1280 1 person, 176.7ms
# Speed: 6.8ms preprocess, 176.7ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 4 persons, 141.9ms
# Speed: 3.9ms preprocess, 141.9ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior2/00000141.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 960x1280 1 person, 173.4ms
# Speed: 6.9ms preprocess, 173.4ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 176.9ms
# Speed: 6.7ms preprocess, 176.9ms inference, 2.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 704x1280 2 persons, 133.5ms
# Speed: 5.2ms preprocess, 133.5ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior2/00000264.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 704x1280 1 person, 128.9ms
# Speed: 6.6ms preprocess, 128.9ms inference, 2.6ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1152 3 persons, 217.3ms
# Speed: 7.7ms preprocess, 217.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1152)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior2/00000289.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1088x1280 1 person, 201.3ms
# Speed: 10.0ms preprocess, 201.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 896x1280 1 person, 167.7ms
# Speed: 6.4ms preprocess, 167.7ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 162.4ms
# Speed: 7.0ms preprocess, 162.4ms inference, 2.3ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1088x1280 11 persons, 205.7ms
# Speed: 7.7ms preprocess, 205.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior2/00000326.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 704x1280 1 person, 135.5ms
# Speed: 7.2ms preprocess, 135.5ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1280 1 person, 233.5ms
# Speed: 8.7ms preprocess, 233.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 230.8ms
# Speed: 11.7ms preprocess, 230.8ms inference, 3.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 176.6ms
# Speed: 8.5ms preprocess, 176.6ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 137.3ms
# Speed: 6.5ms preprocess, 137.3ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 139.5ms
# Speed: 4.3ms preprocess, 139.5ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 137.3ms
# Speed: 6.2ms preprocess, 137.3ms inference, 2.2ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 162.9ms
# Speed: 7.7ms preprocess, 162.9ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 2 persons, 140.3ms
# Speed: 4.0ms preprocess, 140.3ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior2/00000174.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 960x1280 1 person, 179.7ms
# Speed: 6.4ms preprocess, 179.7ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 1 person, 158.7ms
# Speed: 5.9ms preprocess, 158.7ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 140.6ms
# Speed: 5.6ms preprocess, 140.6ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 163.7ms
# Speed: 9.3ms preprocess, 163.7ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 136.0ms
# Speed: 6.6ms preprocess, 136.0ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 229.0ms
# Speed: 10.6ms preprocess, 229.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 161.9ms
# Speed: 9.6ms preprocess, 161.9ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1152x1280 1 person, 213.1ms
# Speed: 8.1ms preprocess, 213.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 896x1280 1 person, 161.4ms
# Speed: 7.6ms preprocess, 161.4ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1024 1 person, 182.7ms
# Speed: 7.2ms preprocess, 182.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 896x1280 1 person, 165.6ms
# Speed: 6.9ms preprocess, 165.6ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1024x1280 1 person, 185.0ms
# Speed: 7.1ms preprocess, 185.0ms inference, 2.0ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 768x1280 1 person, 138.6ms
# Speed: 4.1ms preprocess, 138.6ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 180.0ms
# Speed: 7.1ms preprocess, 180.0ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 139.8ms
# Speed: 6.1ms preprocess, 139.8ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 160.8ms
# Speed: 11.2ms preprocess, 160.8ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 233.3ms
# Speed: 11.6ms preprocess, 233.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 140.5ms
# Speed: 4.2ms preprocess, 140.5ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1152x1280 1 person, 213.5ms
# Speed: 9.4ms preprocess, 213.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 768x1280 2 persons, 141.2ms
# Speed: 6.3ms preprocess, 141.2ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior2/00000337.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 960x1280 1 person, 179.5ms
# Speed: 8.0ms preprocess, 179.5ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 234.1ms
# Speed: 12.2ms preprocess, 234.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 448x1280 1 person, 83.5ms
# Speed: 4.2ms preprocess, 83.5ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 1280)
#
# 0: 896x1280 1 person, 163.9ms
# Speed: 6.8ms preprocess, 163.9ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 162.1ms
# Speed: 7.8ms preprocess, 162.1ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1152x1280 1 person, 215.8ms
# Speed: 8.3ms preprocess, 215.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 896x1280 1 person, 166.2ms
# Speed: 6.3ms preprocess, 166.2ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 141.0ms
# Speed: 7.0ms preprocess, 141.0ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 137.3ms
# Speed: 5.7ms preprocess, 137.3ms inference, 2.4ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 164.3ms
# Speed: 6.8ms preprocess, 164.3ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 161.9ms
# Speed: 7.8ms preprocess, 161.9ms inference, 2.3ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x960 1 person, 180.9ms
# Speed: 8.0ms preprocess, 180.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x1280 1 person, 236.1ms
# Speed: 9.2ms preprocess, 236.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 162.5ms
# Speed: 6.9ms preprocess, 162.5ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1152x1280 1 person, 217.8ms
# Speed: 8.4ms preprocess, 217.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1216x1280 2 persons, 225.1ms
# Speed: 9.7ms preprocess, 225.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1216, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior2/00000438.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 512x1280 1 person, 94.9ms
# Speed: 4.1ms preprocess, 94.9ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 1280)
#
# 0: 1280x1024 1 person, 185.2ms
# Speed: 9.0ms preprocess, 185.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 896x1280 1 person, 163.1ms
# Speed: 7.3ms preprocess, 163.1ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 162.2ms
# Speed: 6.5ms preprocess, 162.2ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x1280 1 person, 231.6ms
# Speed: 10.2ms preprocess, 231.6ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 165.0ms
# Speed: 8.4ms preprocess, 165.0ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1088 1 person, 211.1ms
# Speed: 7.6ms preprocess, 211.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 960x1280 1 person, 179.8ms
# Speed: 6.5ms preprocess, 179.8ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 138.8ms
# Speed: 6.6ms preprocess, 138.8ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1088x1280 1 person, 199.4ms
# Speed: 10.4ms preprocess, 199.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x960 1 person, 181.1ms
# Speed: 8.2ms preprocess, 181.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x1280 1 person, 232.5ms
# Speed: 10.2ms preprocess, 232.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 140.5ms
# Speed: 3.7ms preprocess, 140.5ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)

# %%
dataset_csv_test = []
for pose in pose_list:
    # Using a set to store valid image extensions
    valid_extensions = {'jpg', 'jpeg', 'png', 'bmp'}

    # List all files in the directory
    image_path_list = []
    for ext in valid_extensions:
        image_path_list.extend(glob.glob(f'{dataset_root_test}/{pose}/*.{ext}'))

    for image_path in image_path_list:
        # get image_name
        image_name = image_path.split('/')[-1]
        # read numpy image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip to the next image if reading fails

        # get height width image
        height, width = image.shape[:2]

        # detect pose using yolov8-pose
        results = model.predict(image, save=False)[0]
        results_keypoint = results.keypoints.xyn.cpu().numpy()

        # Check if only one person is detected
        if len(results_keypoint) == 1:
            result_keypoint = results_keypoint[0]
            if len(result_keypoint) == 17:
                keypoint_list = extract_keypoint(result_keypoint)

                # insert image_name, label at index 0, 1
                keypoint_list.insert(0, image_path)
                keypoint_list.insert(1, pose)
                dataset_csv_test.append(keypoint_list)
        else:
            print("------------------------------------------------------------------------")
            print(f"More than one person detected in image: {image_path}. Ignoring pose landmarks.")
            print("------------------------------------------------------------------------")
# Out:
# 0: 1280x1280 1 person, 305.0ms
# Speed: 8.2ms preprocess, 305.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 1 person, 150.6ms
# Speed: 7.1ms preprocess, 150.6ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 161.6ms
# Speed: 6.4ms preprocess, 161.6ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 223.0ms
# Speed: 8.1ms preprocess, 223.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0:
ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 229.5ms
# Speed: 8.8ms preprocess, 229.5ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 161.8ms
# Speed: 7.1ms preprocess, 161.8ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 160.2ms
# Speed: 7.4ms preprocess, 160.2ms inference, 3.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 174.5ms
# Speed: 6.6ms preprocess, 174.5ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 158.7ms
# Speed: 6.6ms preprocess, 158.7ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 225.4ms
# Speed: 8.2ms preprocess, 225.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 142.9ms
# Speed: 5.7ms preprocess, 142.9ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 159.9ms
# Speed: 6.9ms preprocess, 159.9ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 173.7ms
# Speed: 7.3ms preprocess, 173.7ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 (no detections), 156.5ms
# Speed: 7.4ms preprocess, 156.5ms inference, 0.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 152.3ms
# Speed: 8.3ms preprocess, 152.3ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 136.1ms
# Speed: 3.9ms preprocess, 136.1ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 162.1ms
# Speed: 7.0ms preprocess, 162.1ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 172.4ms
# Speed: 6.3ms preprocess, 172.4ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 1 person, 153.0ms
# Speed: 7.1ms preprocess, 153.0ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 133.0ms
# Speed: 6.1ms preprocess, 133.0ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 132.8ms
# Speed: 6.7ms preprocess, 132.8ms inference, 2.2ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 230.7ms
# Speed: 8.9ms preprocess, 230.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 640x1280 1 person, 116.0ms
# Speed: 5.2ms preprocess, 116.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 896x1280 1 person, 159.7ms
# Speed: 8.1ms preprocess, 159.7ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1024x1280 1 person, 183.2ms
# Speed: 7.2ms preprocess, 183.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 768x1280 1 person, 137.2ms
# Speed: 5.9ms preprocess, 137.2ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 159.4ms
# Speed: 7.8ms preprocess, 159.4ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 152.3ms
# Speed: 9.2ms preprocess, 152.3ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 136.5ms
# Speed: 4.2ms preprocess, 136.5ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 161.6ms
# Speed: 6.3ms preprocess, 161.6ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 159.9ms
# Speed: 6.5ms preprocess, 159.9ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 169.7ms
# Speed: 9.1ms preprocess, 169.7ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 640x1280 1 person, 117.8ms
# Speed: 5.3ms preprocess, 117.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 1280x1280 1 person, 229.9ms
# Speed: 8.5ms preprocess, 229.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0:
5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 1 person, 183.3ms
# Speed: 9.9ms preprocess, 183.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 1 person, 231.5ms
# Speed: 11.5ms preprocess, 231.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 157.5ms
# Speed: 7.7ms preprocess, 157.5ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x960 1 person, 179.7ms
# Speed: 9.5ms preprocess, 179.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x960 1 person, 176.3ms
# Speed: 7.7ms preprocess, 176.3ms inference, 3.0ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 960x1280 1 person, 173.7ms
# Speed: 8.1ms preprocess, 173.7ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x960 1 person, 177.2ms
# Speed: 9.0ms preprocess, 177.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 896x1280 1 person, 162.6ms
# Speed: 6.5ms preprocess, 162.6ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x896 1 person, 168.6ms
# Speed: 6.3ms preprocess, 168.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 960x1280 1 person, 173.5ms
# Speed: 7.0ms preprocess, 173.5ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 174.5ms
# Speed: 6.6ms preprocess, 174.5ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 138.2ms
# Speed: 5.7ms preprocess, 138.2ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 228.9ms
# Speed: 9.9ms preprocess, 228.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 1 person, 155.1ms
# Speed: 5.8ms preprocess, 155.1ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1088x1280 1 person, 202.1ms
# Speed: 7.1ms preprocess, 202.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 960x1280 2 persons, 175.5ms
# Speed: 6.3ms preprocess, 175.5ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/goddess/00000012.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 768x1280 1 person, 138.8ms
# Speed: 6.0ms preprocess, 138.8ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 162.1ms
# Speed: 6.2ms preprocess, 162.1ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 138.5ms
# Speed: 6.0ms preprocess, 138.5ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 232.6ms
# Speed: 12.1ms preprocess, 232.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1088x1280 1 person, 201.3ms
# Speed: 8.3ms preprocess, 201.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x1216 1 person, 222.6ms
# Speed: 15.5ms preprocess, 222.6ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 960x1280 1 person, 172.6ms
# Speed: 8.4ms preprocess, 172.6ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 704x1280 1 person, 126.4ms
# Speed: 7.8ms preprocess, 126.4ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 960x1280 1 person, 173.3ms
# Speed: 8.9ms preprocess, 173.3ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1024x1280 1 person, 191.2ms
# Speed: 7.7ms preprocess, 191.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1088 1 person, 204.8ms
# Speed: 11.7ms preprocess, 204.8ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1088x1280 1 person, 204.5ms
# Speed: 7.9ms preprocess, 204.5ms inference, 2.0ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1024x1280 1 person, 183.4ms
# Speed: 7.8ms preprocess, 183.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 174.1ms
# Speed: 9.2ms preprocess, 174.1ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1088 1 person, 210.9ms
# Speed: 7.2ms preprocess, 210.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1152x1280 1 person, 206.4ms
# Speed: 8.2ms preprocess, 206.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x1216 1 person, 226.0ms
# Speed: 9.5ms preprocess, 226.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 832x1280 1 person, 155.4ms
# Speed: 7.0ms preprocess, 155.4ms inference, 2.3ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 174.4ms
# Speed: 11.0ms preprocess, 174.4ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1024x1280 1 person, 184.6ms
# Speed: 8.4ms preprocess, 184.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1024x1280 1 person, 183.6ms
# Speed: 6.7ms preprocess, 183.6ms inference, 2.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 896x1280 1 person, 162.4ms
# Speed: 6.5ms preprocess, 162.4ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 236.3ms
# Speed: 8.4ms preprocess, 236.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 138.4ms
# Speed: 5.3ms preprocess, 138.4ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 164.0ms
# Speed: 6.0ms preprocess, 164.0ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 177.1ms
# Speed: 6.0ms preprocess, 177.1ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 175.3ms
# Speed: 6.3ms preprocess, 175.3ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 231.3ms
# Speed: 12.1ms preprocess, 231.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1216 1 person, 226.1ms
# Speed: 9.0ms preprocess, 226.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 896x1280 1 person, 166.3ms
# Speed: 6.2ms preprocess, 166.3ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 231.9ms
# Speed: 8.6ms preprocess, 231.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 172.4ms
# Speed: 9.9ms preprocess, 172.4ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 162.4ms
# Speed: 6.2ms preprocess, 162.4ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 157.6ms
# Speed: 5.9ms preprocess, 157.6ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1088x1280 1 person, 203.5ms
# Speed: 7.0ms preprocess, 203.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x1280 1 person, 236.7ms
# Speed: 8.7ms preprocess, 236.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 135.7ms
# Speed: 4.1ms preprocess, 135.7ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 177.3ms
# Speed: 6.5ms preprocess, 177.3ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 234.4ms
# Speed: 12.2ms preprocess, 234.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 162.2ms
# Speed: 8.1ms preprocess, 162.2ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 231.9ms
# Speed: 9.8ms preprocess, 231.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 175.3ms
# Speed: 6.2ms preprocess, 175.3ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1088x1280 1 person, 200.3ms
# Speed: 8.2ms preprocess, 200.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 896x1280 1 person, 163.1ms
# Speed: 8.5ms preprocess, 163.1ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 153.6ms
# Speed: 6.3ms preprocess, 153.6ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 138.0ms
# Speed: 6.1ms preprocess, 138.0ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1088 1 person, 208.5ms
# Speed: 8.6ms preprocess, 208.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x896 3 persons, 166.4ms
# Speed: 8.5ms preprocess, 166.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/goddess/00000007.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 768x1280 1 person, 140.7ms
# Speed: 5.7ms preprocess, 140.7ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1152x1280 1 person, 209.6ms
# Speed: 8.6ms preprocess, 209.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1152x1280 1 person, 209.6ms
# Speed: 7.8ms preprocess, 209.6ms inference, 2.4ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x896 1 person, 167.7ms
# Speed: 7.2ms preprocess, 167.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 164.0ms
# Speed: 6.7ms preprocess, 164.0ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 576x1280 1 person, 111.5ms
# Speed: 4.6ms preprocess, 111.5ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1280)
#
# 0: 768x1280 1 person, 138.2ms
# Speed: 5.6ms preprocess, 138.2ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 230.5ms
# Speed: 8.3ms preprocess, 230.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 1 person, 157.0ms
# Speed: 5.8ms preprocess, 157.0ms inference, 2.0ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1088x1280 1 person, 198.0ms
# Speed: 8.3ms preprocess, 198.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 640x1280 1 person, 119.3ms
# Speed: 4.7ms preprocess, 119.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 704x1280 1 person, 130.9ms
# Speed: 6.2ms preprocess, 130.9ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1280 1 person, 228.5ms
# Speed: 9.5ms preprocess, 228.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 231.2ms
# Speed: 8.8ms preprocess, 231.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 2 persons, 183.7ms
# Speed: 7.5ms preprocess, 183.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/goddess/00000090.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 237.3ms
# Speed: 8.3ms preprocess, 237.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 225.3ms
# Speed: 8.8ms preprocess, 225.3ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 165.0ms
# Speed: 6.1ms preprocess, 165.0ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 228.3ms
# Speed: 8.4ms preprocess, 228.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 159.2ms
# Speed: 7.1ms preprocess, 159.2ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 160.9ms
# Speed: 7.6ms preprocess, 160.9ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 138.0ms
# Speed: 8.0ms preprocess, 138.0ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 227.4ms
# Speed: 8.3ms preprocess, 227.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 162.8ms
# Speed: 6.9ms preprocess, 162.8ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 161.4ms
# Speed: 7.0ms preprocess, 161.4ms inference, 2.3ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 129.8ms
# Speed: 6.5ms preprocess, 129.8ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 704x1280 1 person, 128.3ms
# Speed: 5.2ms preprocess, 128.3ms inference, 2.3ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 832x1280 1 person, 157.0ms
# Speed: 6.9ms preprocess, 157.0ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 137.7ms
# Speed: 5.7ms preprocess, 137.7ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 176.2ms
# Speed: 6.9ms preprocess, 176.2ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 139.0ms
# Speed: 6.0ms preprocess, 139.0ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 138.5ms
# Speed: 5.4ms preprocess, 138.5ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 226.3ms
# Speed: 9.4ms preprocess, 226.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 576x1280 1 person, 110.7ms
# Speed: 4.4ms preprocess, 110.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1280)
#
# 0: 768x1280 1 person, 136.5ms
# Speed: 7.1ms preprocess, 136.5ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 135.6ms
# Speed: 6.7ms preprocess, 135.6ms inference, 2.4ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 2 persons, 234.6ms
# Speed: 8.8ms preprocess, 234.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/plank/00000108.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 896x1280 1 person, 161.5ms
# Speed: 9.7ms preprocess, 161.5ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 134.6ms
# Speed: 6.5ms preprocess, 134.6ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 137.3ms
# Speed: 3.9ms preprocess, 137.3ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1024x1280 1 person, 186.5ms
# Speed: 7.7ms preprocess, 186.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 832x1280 1 person, 155.6ms
# Speed: 7.0ms preprocess, 155.6ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 160.6ms
# Speed: 10.0ms preprocess, 160.6ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 157.8ms
# Speed: 6.0ms preprocess, 157.8ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 229.0ms
# Speed: 8.7ms preprocess, 229.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1088x1280 1 person, 201.7ms
# Speed: 11.6ms preprocess, 201.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 640x1280 1 person, 118.0ms
# Speed: 6.2ms preprocess, 118.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 896x1280 1 person, 163.1ms
# Speed: 9.9ms preprocess, 163.1ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 233.5ms
# Speed: 8.6ms preprocess, 233.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 139.1ms
# Speed: 5.7ms preprocess, 139.1ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1088x1280 1 person, 200.5ms
# Speed: 10.8ms preprocess, 200.5ms inference, 2.9ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 704x1280 1 person, 130.9ms
# Speed: 5.3ms preprocess, 130.9ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x896 1 person, 168.6ms
# Speed: 7.6ms preprocess, 168.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 768x1280 1 person, 137.7ms
# Speed: 5.1ms preprocess, 137.7ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 158.8ms
# Speed: 9.6ms preprocess, 158.8ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 127.9ms
# Speed: 6.4ms preprocess, 127.9ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 1 person, 162.1ms
# Speed: 8.9ms preprocess, 162.1ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 130.1ms
# Speed: 5.7ms preprocess, 130.1ms inference, 1.9ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 768x1280 1 person, 139.6ms
# Speed: 3.9ms preprocess, 139.6ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 161.8ms
# Speed: 8.4ms preprocess, 161.8ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 160.8ms
# Speed: 8.4ms preprocess, 160.8ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 171.4ms
# Speed: 7.3ms preprocess, 171.4ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 232.0ms
# Speed: 9.4ms preprocess, 232.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 235.7ms
# Speed: 8.7ms preprocess, 235.7ms inference, 2.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 704x1280 1 person, 130.4ms
# Speed: 5.9ms preprocess, 130.4ms inference, 1.9ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x896 1 person, 166.0ms
# Speed: 8.2ms preprocess, 166.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 768x1280 1 person, 140.4ms
# Speed: 4.3ms preprocess, 140.4ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 163.3ms
# Speed: 7.7ms preprocess, 163.3ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 173.5ms
# Speed: 10.0ms preprocess, 173.5ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 162.8ms
# Speed: 8.2ms preprocess, 162.8ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 158.2ms
# Speed: 9.5ms preprocess, 158.2ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 179.1ms
# Speed: 6.0ms preprocess, 179.1ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 162.3ms
# Speed: 7.1ms preprocess, 162.3ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x960 1 person, 178.5ms
# Speed: 7.0ms preprocess, 178.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 640x1280 1 person, 119.2ms
# Speed: 6.0ms preprocess, 119.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 896x1280 2 persons, 164.8ms
# Speed: 7.6ms preprocess, 164.8ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/plank/00000103.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 768x1280 1 person, 138.7ms
# Speed: 3.8ms preprocess, 138.7ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 135.5ms
# Speed: 8.1ms preprocess, 135.5ms inference, 2.3ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1088x1280 1 person, 199.1ms
# Speed: 11.8ms preprocess, 199.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 896x1280 1 person, 159.3ms
# Speed: 8.0ms preprocess, 159.3ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 138.5ms
# Speed: 6.1ms preprocess, 138.5ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 134.0ms
# Speed: 6.3ms preprocess, 134.0ms inference, 2.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 230.1ms
# Speed: 7.9ms preprocess, 230.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 230.9ms
# Speed: 9.5ms preprocess, 230.9ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 228.9ms
# Speed: 8.8ms preprocess, 228.9ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 163.2ms
# Speed: 9.7ms preprocess, 163.2ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 156.9ms
# Speed: 9.8ms preprocess, 156.9ms inference, 2.3ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 161.1ms
# Speed: 6.3ms preprocess, 161.1ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 139.5ms
# Speed: 5.9ms preprocess, 139.5ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x896 1 person, 167.5ms
# Speed: 7.4ms preprocess, 167.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 704x1280 1 person, 127.9ms
# Speed: 6.9ms preprocess, 127.9ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 768x1280 1 person, 137.4ms
# Speed: 5.4ms preprocess, 137.4ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 134.6ms
# Speed: 5.9ms preprocess, 134.6ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 160.3ms
# Speed: 6.8ms preprocess, 160.3ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 129.4ms
# Speed: 5.1ms preprocess, 129.4ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1280 1 person, 233.6ms
# Speed: 12.2ms preprocess, 233.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 163.2ms
# Speed: 8.4ms preprocess, 163.2ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 158.3ms
# Speed: 7.3ms preprocess, 158.3ms inference, 2.3ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1024 1 person, 181.2ms
# Speed: 10.6ms preprocess, 181.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 704x1280 1 person, 129.9ms
# Speed: 5.3ms preprocess, 129.9ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 768x1280 1 person, 135.1ms
# Speed: 8.0ms preprocess, 135.1ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 228.9ms
# Speed: 10.2ms preprocess, 228.9ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 1 person, 185.6ms
# Speed: 8.9ms preprocess, 185.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 896x1280 1 person, 163.1ms
# Speed: 12.2ms preprocess, 163.1ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 229.3ms
# Speed: 8.4ms preprocess, 229.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 175.8ms
# Speed: 7.2ms preprocess, 175.8ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 163.6ms
# Speed: 7.7ms preprocess, 163.6ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 137.1ms
# Speed: 8.6ms preprocess, 137.1ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 138.7ms
# Speed: 3.9ms preprocess, 138.7ms inference, 3.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 227.6ms
# Speed: 9.5ms preprocess, 227.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x960 1 person, 179.1ms
# Speed: 7.7ms preprocess, 179.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1152x1280 1 person, 210.5ms
# Speed: 10.7ms preprocess, 210.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x1088 1 person, 207.0ms
# Speed: 7.2ms preprocess, 207.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x1280 1 person, 237.3ms
# Speed: 9.3ms preprocess, 237.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 165.1ms
# Speed: 6.9ms preprocess, 165.1ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 640x1280 1 person, 119.2ms
# Speed: 4.5ms preprocess, 119.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 768x1280 1 person, 142.4ms
# Speed: 5.9ms preprocess, 142.4ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 3 persons, 161.9ms
# Speed: 8.7ms preprocess, 161.9ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/plank/00000119.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1152x1280 1 person, 208.6ms
# Speed: 12.2ms preprocess, 208.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 960x1280 1 person, 175.2ms
# Speed: 10.4ms preprocess, 175.2ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 137.4ms
# Speed: 6.1ms preprocess, 137.4ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 165.0ms
# Speed: 7.1ms preprocess, 165.0ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 159.5ms
# Speed: 9.6ms preprocess, 159.5ms inference, 2.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 234.2ms
# Speed: 12.3ms preprocess, 234.2ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 138.2ms
# Speed: 4.6ms preprocess, 138.2ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 161.9ms
# Speed: 8.5ms preprocess, 161.9ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 160.0ms
# Speed: 6.1ms preprocess, 160.0ms inference, 2.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 174.7ms
# Speed: 11.8ms preprocess, 174.7ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 1 person, 151.6ms
# Speed: 7.6ms preprocess, 151.6ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 172.4ms
# Speed: 9.8ms preprocess, 172.4ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x896 1 person, 166.0ms
# Speed: 6.8ms preprocess, 166.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 768x1280 1 person, 137.6ms
# Speed: 6.6ms preprocess, 137.6ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x896 1 person, 167.1ms
# Speed: 8.1ms preprocess, 167.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x896 1 person, 161.7ms
# Speed: 9.5ms preprocess, 161.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 159.5ms
# Speed: 9.0ms preprocess, 159.5ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x896 1 person, 165.0ms
# Speed: 6.4ms preprocess, 165.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x896 1 person, 162.4ms
# Speed: 9.8ms preprocess, 162.4ms inference, 3.9ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1280 1 person, 227.6ms
# Speed: 10.2ms preprocess, 227.6ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 164.6ms
# Speed: 7.0ms preprocess, 164.6ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x896 1 person, 165.3ms
# Speed: 8.3ms preprocess, 165.3ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1280 1 person, 228.8ms
# Speed: 9.9ms preprocess, 228.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 163.0ms
# Speed: 6.1ms preprocess, 163.0ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 138.9ms
# Speed: 4.1ms preprocess, 138.9ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x896 1 person, 166.9ms
# Speed: 10.3ms preprocess, 166.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1280 1 person, 224.8ms
# Speed: 11.3ms preprocess, 224.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 138.7ms
# Speed: 3.9ms preprocess, 138.7ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 233.8ms
# Speed: 8.8ms preprocess, 233.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 2 persons, 162.2ms
# Speed: 13.7ms preprocess, 162.2ms inference, 2.5ms postprocess per image at shape (1, 3, 896, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/tree/00000048.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x832 2 persons, 162.2ms
# Speed: 8.3ms preprocess, 162.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 832)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/tree/00000055.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x896 1 person, 166.9ms
# Speed: 8.0ms preprocess, 166.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1280 1 person, 230.4ms
# Speed: 9.3ms preprocess, 230.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 163.0ms
# Speed: 9.5ms preprocess, 163.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1152x1280 1 person, 206.7ms
# Speed: 9.7ms preprocess, 206.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 704x1280 1 person, 127.7ms
# Speed: 6.6ms preprocess, 127.7ms inference, 1.9ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x960 1 person, 182.4ms
# Speed: 7.8ms preprocess, 182.4ms inference, 2.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x1280 1 person, 232.4ms
# Speed: 8.9ms preprocess, 232.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 226.1ms
# Speed: 10.5ms preprocess, 226.1ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 166.9ms
# Speed: 6.8ms preprocess, 166.9ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1280 1 person, 231.4ms
# Speed: 18.7ms preprocess, 231.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 157.0ms
# Speed: 9.9ms preprocess, 157.0ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 133.1ms
# Speed: 5.9ms preprocess, 133.1ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x896 1 person, 165.8ms
# Speed: 7.8ms preprocess, 165.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1280 1 person, 235.1ms
# Speed: 8.6ms preprocess, 235.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 142.7ms
# Speed: 5.9ms preprocess, 142.7ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 234.2ms
# Speed: 9.7ms preprocess, 234.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1152x1280 1 person, 211.7ms
# Speed: 8.0ms preprocess, 211.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x832 1 person, 161.4ms
# Speed: 8.0ms preprocess, 161.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1280x896 1 person, 165.3ms
# Speed: 8.5ms preprocess, 165.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1280 1 person, 233.7ms
# Speed: 8.9ms preprocess, 233.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 141.1ms
# Speed: 6.0ms preprocess, 141.1ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1088 1 person, 210.1ms
# Speed: 7.7ms preprocess, 210.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 896x1280 1 person, 162.5ms
# Speed: 9.5ms preprocess, 162.5ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 233.3ms
# Speed: 12.7ms preprocess, 233.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 157.7ms
# Speed: 9.3ms preprocess, 157.7ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x896 1 person, 168.7ms
# Speed: 10.0ms preprocess, 168.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 163.1ms
# Speed: 7.1ms preprocess, 163.1ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 238.6ms
# Speed: 8.7ms preprocess, 238.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 167.2ms
# Speed: 6.7ms preprocess, 167.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x896 1 person, 163.4ms
# Speed: 9.1ms preprocess, 163.4ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 164.5ms
# Speed: 7.3ms preprocess, 164.5ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 140.0ms
# Speed: 3.8ms preprocess, 140.0ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 159.9ms
# Speed: 6.4ms preprocess, 159.9ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x704 1 person, 133.5ms
# Speed: 5.5ms preprocess, 133.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x1024 1 person, 181.9ms
# Speed: 7.7ms preprocess, 181.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x896 1 person, 169.7ms
# Speed: 7.4ms preprocess, 169.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x960 1 person, 175.4ms
# Speed: 6.8ms preprocess, 175.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x1088 1 person, 208.7ms
# Speed: 6.5ms preprocess, 208.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x1088 1 person, 205.9ms
# Speed: 7.7ms preprocess, 205.9ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 768x1280 1 person, 137.7ms
# Speed: 6.1ms preprocess, 137.7ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x896 1 person, 163.8ms
# Speed: 6.8ms preprocess, 163.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1280 1 person, 229.4ms
# Speed: 10.7ms preprocess, 229.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 163.9ms
# Speed: 8.3ms preprocess, 163.9ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1024 1 person, 181.6ms
# Speed: 7.4ms preprocess, 181.6ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x896 1 person, 166.3ms
# Speed: 6.8ms preprocess, 166.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x896 1 person, 163.7ms
# Speed: 6.0ms preprocess, 163.7ms inference, 3.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 704x1280 1 person, 133.3ms
# Speed: 5.1ms preprocess, 133.3ms inference, 1.6ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1280 1 person, 230.1ms
# Speed: 8.9ms preprocess, 230.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 1 person, 183.1ms
# Speed: 6.6ms preprocess, 183.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 (no detections), 231.4ms
# Speed: 9.5ms preprocess, 231.4ms inference, 0.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 1 person, 185.1ms
# Speed: 7.4ms preprocess, 185.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 896x1280 1 person, 165.4ms
# Speed: 9.0ms preprocess, 165.4ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 (no detections), 231.1ms
# Speed: 9.9ms preprocess, 231.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 230.7ms
# Speed: 8.5ms preprocess, 230.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 1 person, 184.7ms
# Speed: 7.8ms preprocess, 184.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 704x1280 1 person, 134.0ms
# Speed: 5.2ms preprocess, 134.0ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1024x1280 1 person, 183.6ms
# Speed: 7.8ms preprocess, 183.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x896 1 person, 166.2ms
# Speed: 7.9ms preprocess, 166.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 161.4ms
# Speed: 7.5ms preprocess, 161.4ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1216 1 person, 224.0ms
# Speed: 9.3ms preprocess, 224.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 896x1280 1 person, 168.5ms
# Speed: 6.8ms preprocess, 168.5ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x832 1 person, 161.6ms
# Speed: 7.5ms preprocess, 161.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1024x1280 1 person, 186.3ms
# Speed: 8.3ms preprocess, 186.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 1 person, 235.8ms
# Speed: 7.4ms preprocess, 235.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 1 person, 182.8ms
# Speed: 11.5ms preprocess, 182.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 180.6ms
# Speed: 5.7ms preprocess, 180.6ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 161.9ms
# Speed: 9.0ms preprocess, 161.9ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1088x1280 1 person, 201.1ms
# Speed: 7.6ms preprocess, 201.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 896x1280 1 person, 169.1ms
# Speed: 6.5ms preprocess, 169.1ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x832 1 person, 161.9ms
# Speed: 6.8ms preprocess, 161.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1152x1280 1 person, 208.2ms
# Speed: 7.8ms preprocess, 208.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1088x1280 1 person, 206.3ms
# Speed: 7.6ms preprocess, 206.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 768x1280 1 person, 137.8ms
# Speed: 6.3ms preprocess, 137.8ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 232.9ms
# Speed: 8.2ms preprocess, 232.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x832 1 person, 159.8ms
# Speed: 7.5ms preprocess, 159.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1280x1280 1 person, 233.6ms
# Speed: 10.2ms preprocess, 233.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 233.1ms
# Speed: 9.9ms preprocess, 233.1ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/warrior2/00000099.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 235.7ms
# Speed: 8.9ms preprocess, 235.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1024 1 person, 187.0ms
# Speed: 6.2ms preprocess, 187.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1024x1280 1 person, 185.0ms
# Speed: 8.3ms preprocess, 185.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 448x1280 1 person, 83.4ms
# Speed: 4.6ms preprocess, 83.4ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 1280)
#
# 0: 1152x1280 1 person, 211.2ms
# Speed: 8.6ms preprocess, 211.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1152x1280 1 person, 211.0ms
# Speed: 8.6ms preprocess, 211.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 960x1280 1 person, 179.4ms
# Speed: 6.5ms preprocess, 179.4ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 234.5ms
# Speed: 8.0ms preprocess, 234.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1088x1280 1 person, 203.5ms
# Speed: 7.2ms preprocess, 203.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 832x1280 1 person, 158.8ms
# Speed: 6.3ms preprocess, 158.8ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 177.1ms
# Speed: 6.4ms preprocess, 177.1ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 138.3ms
# Speed: 4.2ms preprocess, 138.3ms inference, 1.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 231.4ms
# Speed: 8.6ms preprocess, 231.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 165.5ms
# Speed: 10.0ms preprocess, 165.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 164.7ms
# Speed: 7.1ms preprocess, 164.7ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1024x1280 1 person, 183.4ms
# Speed: 7.3ms preprocess, 183.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 177.9ms
# Speed: 8.3ms preprocess, 177.9ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 139.3ms
# Speed: 5.7ms preprocess, 139.3ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x896 1 person, 166.8ms
# Speed: 9.7ms preprocess, 166.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 163.4ms
# Speed: 9.4ms preprocess, 163.4ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1088x1280 1 person, 203.8ms
# Speed: 7.4ms preprocess, 203.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1088x1280 1 person, 202.4ms
# Speed: 7.2ms preprocess, 202.4ms inference, 3.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 896x1280 1 person, 161.0ms
# Speed: 8.3ms preprocess, 161.0ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 140.4ms
# Speed: 6.0ms preprocess, 140.4ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 164.0ms
# Speed: 8.4ms preprocess, 164.0ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 131.6ms
# Speed: 5.5ms preprocess, 131.6ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 1 person, 165.9ms
# Speed: 5.7ms preprocess, 165.9ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 130.3ms
# Speed: 5.7ms preprocess, 130.3ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1216 1 person, 227.2ms
# Speed: 8.7ms preprocess, 227.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 896x1280 1 person, 165.1ms
# Speed: 6.2ms preprocess, 165.1ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 236.4ms
# Speed: 8.9ms preprocess, 236.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 1 person, 187.2ms
# Speed: 7.4ms preprocess, 187.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 173.7ms
# Speed: 9.9ms preprocess, 173.7ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1024x1280 1 person, 183.5ms
# Speed: 8.1ms preprocess, 183.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 896x1280 1 person, 163.2ms
# Speed: 6.1ms preprocess, 163.2ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 237.0ms
# Speed: 12.4ms preprocess, 237.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 1 person, 185.0ms
# Speed: 7.4ms preprocess, 185.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1024 1 person, 182.7ms
# Speed: 6.6ms preprocess, 182.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x832 1 person, 161.7ms
# Speed: 6.6ms preprocess, 161.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 896x1280 1 person, 163.0ms
# Speed: 8.7ms preprocess, 163.0ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 233.4ms
# Speed: 9.1ms preprocess, 233.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 231.8ms
# Speed: 8.6ms preprocess, 231.8ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 166.1ms
# Speed: 10.3ms preprocess, 166.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 768x1280 1 person, 139.7ms
# Speed: 6.3ms preprocess, 139.7ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x960 1 person, 179.7ms
# Speed: 7.8ms preprocess, 179.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x1280 1 person, 232.7ms
# Speed: 12.4ms preprocess, 232.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 232.9ms
# Speed: 9.6ms preprocess, 232.9ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 235.8ms
# Speed: 7.9ms preprocess, 235.8ms inference, 4.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 163.2ms
# Speed: 9.8ms preprocess, 163.2ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 176.0ms
# Speed: 7.5ms preprocess, 176.0ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 234.2ms
# Speed: 9.2ms preprocess, 234.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1024 1 person, 181.5ms
# Speed: 9.1ms preprocess, 181.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1216 1 person, 232.0ms
# Speed: 9.1ms preprocess, 232.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 896x1280 1 person, 163.6ms
# Speed: 9.0ms preprocess, 163.6ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1216 1 person, 227.8ms
# Speed: 9.4ms preprocess, 227.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x1280 1 person, 231.8ms
# Speed: 10.6ms preprocess, 231.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 137.7ms
# Speed: 8.6ms preprocess, 137.7ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 162.1ms
# Speed: 9.6ms preprocess, 162.1ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 138.7ms
# Speed: 6.5ms preprocess, 138.7ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1024x1280 1 person, 184.4ms
# Speed: 8.1ms preprocess, 184.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x896 1 person, 167.4ms
# Speed: 7.0ms preprocess, 167.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 165.4ms
# Speed: 6.4ms preprocess, 165.4ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 178.6ms
# Speed: 5.8ms preprocess, 178.6ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 166.3ms
# Speed: 5.5ms preprocess, 166.3ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1024x1280 1 person, 183.0ms
# Speed: 11.0ms preprocess, 183.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 768x1280 1 person, 136.4ms
# Speed: 6.0ms preprocess, 136.4ms inference, 1.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 832x1280 1 person, 157.6ms
# Speed: 6.2ms preprocess, 157.6ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x1280 1 person, 235.3ms
# Speed: 9.4ms preprocess, 235.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 231.9ms
# Speed: 9.5ms preprocess, 231.9ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 165.0ms
# Speed: 8.7ms preprocess, 165.0ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 176.2ms
# Speed: 6.9ms preprocess, 176.2ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 162.9ms
# Speed: 5.6ms preprocess, 162.9ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1088x1280 1 person, 202.8ms
# Speed: 10.1ms preprocess, 202.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x832 1 person, 160.7ms
# Speed: 6.8ms preprocess, 160.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1024x1280 1 person, 184.1ms
# Speed: 7.5ms preprocess, 184.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 175.3ms
# Speed: 7.9ms preprocess, 175.3ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 176.0ms
# Speed: 7.2ms preprocess, 176.0ms inference, 2.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 133.7ms
# Speed: 8.7ms preprocess, 133.7ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)

# %%
# Create a list of column headings
column_headings = ['image_path', 'label',
                   'nose_x', 'nose_y',
                   'left_eye_x', 'left_eye_y',
                   'right_eye_x', 'right_eye_y',
                   'left_ear_x', 'left_ear_y',
                   'right_ear_x', 'right_ear_y',
                   'left_shoulder_x', 'left_shoulder_y',
                   'right_shoulder_x', 'right_shoulder_y',
                   'left_elbow_x', 'left_elbow_y',
                   'right_elbow_x', 'right_elbow_y',
                   'left_wrist_x', 'left_wrist_y',
                   'right_wrist_x', 'right_wrist_y',
                   'left_hip_x', 'left_hip_y',
                   'right_hip_x', 'right_hip_y',
                   'left_knee_x', 'left_knee_y',
                   'right_knee_x', 'right_knee_y',
                   'left_ankle_x', 'left_ankle_y',
                   'right_ankle_x', 'right_ankle_y']

with open('train_data_yolo.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)

    # Write the column headings as the first row
    writer.writerow(column_headings)

    # Write the list data to the CSV file
    writer.writerows(dataset_csv_train)



# Create a list of column headings
column_headings = ['image_path', 'label',
                   'nose_x', 'nose_y',
                   'left_eye_x', 'left_eye_y',
                   'right_eye_x', 'right_eye_y',
                   'left_ear_x', 'left_ear_y',
                   'right_ear_x', 'right_ear_y',
                   'left_shoulder_x', 'left_shoulder_y',
                   'right_shoulder_x', 'right_shoulder_y',
                   'left_elbow_x', 'left_elbow_y',
                   'right_elbow_x', 'right_elbow_y',
                   'left_wrist_x', 'left_wrist_y',
                   'right_wrist_x', 'right_wrist_y',
                   'left_hip_x', 'left_hip_y',
                   'right_hip_x', 'right_hip_y',
                   'left_knee_x', 'left_knee_y',
                   'right_knee_x', 'right_knee_y',
                   'left_ankle_x', 'left_ankle_y',
                   'right_ankle_x', 'right_ankle_y']

with open('test_data_yolo.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)

    # Write the column headings as the first row
    writer.writerow(column_headings)

    # Write the list data to the CSV file
    writer.writerows(dataset_csv_test)

# %%
train_df = pd.read_csv('train_data_yolo.csv')
test_df = pd.read_csv('test_data_yolo.csv')

train_df.to_csv('train_data_yolo.csv', index=False)
test_df.to_csv('test_data_yolo.csv', index=False)

# %%
# !cp train_data_yolo.csv /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/
# !cp test_data_yolo.csv /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/

# %%
train_df = train_df.drop('image_path', axis=1)
test_df = test_df.drop('image_path', axis=1)
encoder = LabelEncoder()
y_label_train = train_df['label']
y_train = encoder.fit_transform(y_label_train)
y_label_test = test_df['label']
y_test = encoder.fit_transform(y_label_test)
train_df = train_df.drop('label',axis=1)
X_train = train_df
test_df = test_df.drop('label',axis=1)
X_test = test_df
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
y_train = y_train.astype('int64')
y_test = y_test.astype('int64')

# %%
model = tf.keras.models.Sequential()
model.add(layers.Input(shape=(X_train.shape[1],)))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(num_classes, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_60 (Dense)            (None, 256)               8960
#
#  dense_61 (Dense)            (None, 128)               32896
#
#  dense_62 (Dense)            (None, 64)                8256
#
#  dense_63 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 50437 (197.02 KB)
# Trainable params: 50437 (197.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = 'weights_yolo.keras'
checkpoint = ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/100
# 30/31 [============================>.] - ETA: 0s - loss: 1.3796 - accuracy: 0.4344
# Epoch 1: val_accuracy improved from -inf to 0.58259, saving model to weights_yolo.keras
# 31/31 [==============================] - 2s 12ms/step - loss: 1.3718 - accuracy: 0.4410 - val_loss: 0.9972 - val_accuracy: 0.5826
# Epoch 2/100
# 31/31 [==============================] - ETA: 0s - loss: 0.9551 - accuracy: 0.6062
# Epoch 2: val_accuracy improved from 0.58259 to 0.63616, saving model to weights_yolo.keras
# 31/31 [==============================] - 0s 6ms/step - loss: 0.9551 - accuracy: 0.6062 - val_loss: 0.7348 - val_accuracy: 0.6362
# Epoch 3/100
# 18/31 [================>.............] - ETA: 0s - loss: 0.8084 - accuracy: 0.6910
# Epoch 3: val_accuracy improved from 0.63616 to 0.73884, saving model to weights_yolo.keras
# 31/31 [==============================] - 0s 6ms/step - loss: 0.7894 - accuracy: 0.7005 - val_loss: 0.5930 - val_accuracy: 0.7388
# Epoch 4/100
# 17/31 [===============>..............] - ETA: 0s - loss: 0.6517 - accuracy: 0.7996
# Epoch 4: val_accuracy improved from 0.73884 to 0.84152, saving model to weights_yolo.keras
# 31/31 [==============================] - 0s 6ms/step - loss: 0.6518 - accuracy: 0.7908 - val_loss: 0.4748 - val_accuracy: 0.8415
# Epoch 5/100
# 18/31 [================>.............] - ETA: 0s - loss: 0.5516 - accuracy: 0.8177
# Epoch 5: val_accuracy improved from 0.84152 to 0.85268, saving model to weights_yolo.keras
# 31/31 [==============================] - 0s 6ms/step - loss: 0.5728 - accuracy: 0.8072 - val_loss: 0.4821 - val_accuracy: 0.8527
# Epoch 6/100
# 18/31 [================>.............] - ETA: 0s - loss: 0.5338 - accuracy: 0.8281
# Epoch 6: val_accuracy improved from 0.85268 to 0.88170, saving model to weights_yolo.keras
# 31/31 [==============================] - 0s 6ms/step - loss: 0.5216 - accuracy: 0.8215 - val_loss: 0.3945 - val_accuracy: 0.8817
# Epoch 7/100
# 17/31 [===============>..............] - ETA: 0s - loss: 0.5012 - accuracy: 0.8382
# Epoch 7: val_accuracy improved from 0.88170 to 0.89062, saving model to weights_yolo.keras
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4730 - accuracy: 0.8503 - val_loss: 0.3058 - val_accuracy: 0.8906
# Epoch 8/100
# 17/31 [===============>..............] - ETA: 0s - loss: 0.3959 - accuracy: 0.8879
# Epoch 8: val_accuracy improved from 0.89062 to 0.90848, saving model to weights_yolo.keras
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4104 - accuracy: 0.8615 - val_loss: 0.2821 - val_accuracy: 0.9085
# Epoch 9/100
# 18/31 [================>.............] - ETA: 0s - loss: 0.3784 - accuracy: 0.8663
# Epoch 9: val_accuracy improved from 0.90848 to 0.93304, saving model to weights_yolo.keras
# 31/31 [==============================] - 0s 6ms/step - loss: 0.3786 - accuracy: 0.8779 - val_loss: 0.2239 - val_accuracy: 0.9330
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0934 - accuracy: 0.9662 - val_loss: 0.1230 - val_accuracy: 0.9665
# Epoch 41/100
# 18/31 [================>.............] - ETA: 0s - loss: 0.0966 - accuracy: 0.9688
# Epoch 41: val_accuracy did not improve from 0.97321
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1009 - accuracy: 0.9672 - val_loss: 0.0888 - val_accuracy: 0.9643
# Epoch 42/100
# 18/31 [================>.............] - ETA: 0s - loss: 0.0780 - accuracy: 0.9757
# Epoch 42: val_accuracy did not improve from 0.97321
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0832 - accuracy: 0.9733 - val_loss: 0.1521 - val_accuracy: 0.9576
# Epoch 43/100
# 19/31 [=================>............] - ETA: 0s - loss: 0.0908 - accuracy: 0.9688
# Epoch 43: val_accuracy did not improve from 0.97321
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1084 - accuracy: 0.9590 - val_loss: 0.1061 - val_accuracy: 0.9710
# Epoch 44/100
# 19/31 [=================>............] - ETA: 0s - loss: 0.0617 - accuracy: 0.9819
# Epoch 44: val_accuracy did not improve from 0.97321
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0803 - accuracy: 0.9744 - val_loss: 0.1201 - val_accuracy: 0.9710
# Epoch 45/100
# 19/31 [=================>............] - ETA: 0s - loss: 0.0846 - accuracy: 0.9737
# Epoch 45: val_accuracy did not improve from 0.97321
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0818 - accuracy: 0.9764 - val_loss: 0.0914 - val_accuracy: 0.9643

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f"Training and Validation Accuracy of YoloV8 model for {dataset_name}")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.savefig("Accuracy_Graph_Yolo.png")
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f"Training and Validation Loss of YoloV8 model for {dataset_name}")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.savefig("Loss_Graph_Yolo.png")
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0914 - accuracy: 0.9643
# [0.09140036255121231, 0.9642857313156128]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
class_names = encoder.classes_

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f"Confusion Matrix of YoloV8 model for {dataset_name}")
plt.savefig("Confusion_Matrix_Yolo.png")
plt.show()

class_report = classification_report(y_test, y_pred, target_names=class_names)
print(class_report)
# Out:
# 14/14 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#      downdog       0.96      0.96      0.96        91
#      goddess       0.94      0.96      0.95        77
#        plank       0.97      0.95      0.96       108
#         tree       0.97      0.98      0.98        66
#     warrior2       0.98      0.97      0.98       106
#
#     accuracy                           0.96       448
#    macro avg       0.96      0.97      0.96       448
# weighted avg       0.96      0.96      0.96       448

# %%
with open('history_for_yolo.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_yolo.keras', 'history_for_yolo.pkl', 'Accuracy_Graph_Yolo.png', 'Loss_Graph_Yolo.png', 'Confusion_Matrix_Yolo.png']
zip_filename = 'results_yolo.zip'
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Kaggle_Dataset/
