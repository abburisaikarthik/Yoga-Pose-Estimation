# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount = False)
# Out:
# Mounted at /content/drive/

# %%
# !rm -rf /content/dataset/ /content/test/ /content/train/

# %%
# !unzip /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/custom_dataset/dataset.zip
# Out:
# Archive:  /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/custom_dataset/dataset.zip
#    creating: dataset/
#    creating: dataset/test/
#    creating: dataset/test/bridge/
#   inflating: dataset/test/bridge/bridge_test_1.png
#   inflating: dataset/test/bridge/bridge_test_10.png
#   inflating: dataset/test/bridge/bridge_test_11.png
#   inflating: dataset/test/bridge/bridge_test_12.png
#   inflating: dataset/test/bridge/bridge_test_13.png
#   inflating: dataset/test/bridge/bridge_test_14.png
#   inflating: dataset/test/bridge/bridge_test_15.png
#   inflating: dataset/test/bridge/bridge_test_16.png
#   inflating: dataset/test/bridge/bridge_test_17.png
#   inflating: dataset/test/bridge/bridge_test_18.png
#   inflating: dataset/test/bridge/bridge_test_19.png
#   inflating: dataset/test/bridge/bridge_test_2.png
#   inflating: dataset/test/bridge/bridge_test_20.png
#   inflating: dataset/test/bridge/bridge_test_21.png
#   inflating: dataset/test/bridge/bridge_test_22.png
#   inflating: dataset/test/bridge/bridge_test_23.png
#   inflating: dataset/test/bridge/bridge_test_24.png
#   inflating: dataset/test/bridge/bridge_test_25.png
#   inflating: dataset/test/bridge/bridge_test_26.png
#   inflating: dataset/test/bridge/bridge_test_27.png
#   inflating: dataset/test/bridge/bridge_test_28.png
#   inflating: dataset/test/bridge/bridge_test_29.png
#   inflating: dataset/test/bridge/bridge_test_3.png
#   inflating: dataset/test/bridge/bridge_test_30.png
#   inflating: dataset/test/bridge/bridge_test_31.png
#   inflating: dataset/test/bridge/bridge_test_32.png
#   inflating: dataset/test/bridge/bridge_test_33.png
#   inflating: dataset/test/bridge/bridge_test_34.png
#   inflating: dataset/test/bridge/bridge_test_35.png
#   inflating: dataset/test/bridge/bridge_test_36.png
#   inflating: dataset/test/bridge/bridge_test_37.png
#   inflating: dataset/test/bridge/bridge_test_38.png
#   inflating: dataset/test/bridge/bridge_test_39.png
#   inflating: dataset/test/bridge/bridge_test_4.png
#   inflating: dataset/test/bridge/bridge_test_40.png
#   inflating: dataset/test/bridge/bridge_test_41.png
#   inflating: dataset/test/bridge/bridge_test_42.png
#   inflating: dataset/test/bridge/bridge_test_43.png
#   inflating: dataset/test/bridge/bridge_test_44.png
#   inflating: dataset/test/bridge/bridge_test_45.png
#   inflating: dataset/test/bridge/bridge_test_46.png
#   inflating: dataset/test/bridge/bridge_test_47.png
#   inflating: dataset/test/bridge/bridge_test_48.png
#   inflating: dataset/test/bridge/bridge_test_49.png
#   inflating: dataset/test/bridge/bridge_test_5.png
#   inflating: dataset/test/bridge/bridge_test_50.png
#   inflating: dataset/test/bridge/bridge_test_51.png
#   inflating: dataset/test/bridge/bridge_test_52.png
#   inflating: dataset/test/bridge/bridge_test_53.png
#   inflating: dataset/test/bridge/bridge_test_6.png
#   inflating: dataset/test/bridge/bridge_test_7.png
#   inflating: dataset/test/bridge/bridge_test_8.png
#   inflating: dataset/test/bridge/bridge_test_9.png
#    creating: dataset/test/diamond/
#  extracting: dataset/test/diamond/diamond_test_1.png
#  extracting: dataset/test/diamond/diamond_test_10.png
#  extracting: dataset/test/diamond/diamond_test_11.png
#  extracting: dataset/test/diamond/diamond_test_12.png
#  extracting: dataset/test/diamond/diamond_test_13.png
#  extracting: dataset/test/diamond/diamond_test_14.png
#  extracting: dataset/test/diamond/diamond_test_15.png
#  extracting: dataset/test/diamond/diamond_test_16.png
#  extracting: dataset/test/diamond/diamond_test_17.png
#   inflating: dataset/test/diamond/diamond_test_18.png
#  extracting: dataset/test/diamond/diamond_test_19.png
#  extracting: dataset/test/diamond/diamond_test_2.png
#  extracting: dataset/test/diamond/diamond_test_20.png
#   inflating: dataset/test/diamond/diamond_test_21.png
#  extracting: dataset/test/diamond/diamond_test_22.png
#  extracting: dataset/test/diamond/diamond_test_23.png
#   inflating: dataset/test/diamond/diamond_test_24.png
#  extracting: dataset/test/diamond/diamond_test_25.png
#  extracting: dataset/test/diamond/diamond_test_26.png
#  extracting: dataset/test/diamond/diamond_test_27.png
#  extracting: dataset/test/diamond/diamond_test_28.png
#  extracting: dataset/test/diamond/diamond_test_29.png
#  extracting: dataset/test/diamond/diamond_test_3.png
#  extracting: dataset/test/diamond/diamond_test_30.png
#  extracting: dataset/test/diamond/diamond_test_31.png
#  extracting: dataset/test/diamond/diamond_test_32.png
#  extracting: dataset/test/diamond/diamond_test_33.png
#   inflating: dataset/test/diamond/diamond_test_34.png
#  extracting: dataset/test/diamond/diamond_test_35.png
#  extracting: dataset/test/diamond/diamond_test_36.png
#  extracting: dataset/test/diamond/diamond_test_37.png
#  extracting: dataset/test/diamond/diamond_test_38.png
#  extracting: dataset/test/diamond/diamond_test_39.png
#  extracting: dataset/test/diamond/diamond_test_4.png
#  extracting: dataset/test/diamond/diamond_test_40.png
#  extracting: dataset/test/diamond/diamond_test_41.png
#  extracting: dataset/test/diamond/diamond_test_42.png
#  extracting: dataset/test/diamond/diamond_test_43.png
#  extracting: dataset/test/diamond/diamond_test_44.png
#  extracting: dataset/test/diamond/diamond_test_45.png
#  extracting: dataset/test/diamond/diamond_test_46.png
#  extracting: dataset/test/diamond/diamond_test_47.png
#  extracting: dataset/test/diamond/diamond_test_48.png
#  extracting: dataset/test/diamond/diamond_test_49.png
#  extracting: dataset/test/diamond/diamond_test_5.png
#   inflating: dataset/test/diamond/diamond_test_50.png
#  extracting: dataset/test/diamond/diamond_test_6.png
#  extracting: dataset/test/diamond/diamond_test_7.png
#   inflating: dataset/test/diamond/diamond_test_8.png
#  extracting: dataset/test/diamond/diamond_test_9.png
#    creating: dataset/test/downdog/
#   inflating: dataset/test/downdog/downdog_test_1.png
#  extracting: dataset/test/downdog/downdog_test_10.png
#   inflating: dataset/test/downdog/downdog_test_11.png
#  extracting: dataset/test/downdog/downdog_test_12.png
#   inflating: dataset/test/downdog/downdog_test_13.png
#   inflating: dataset/test/downdog/downdog_test_14.png
#   inflating: dataset/test/downdog/downdog_test_15.png
#  extracting: dataset/test/downdog/downdog_test_16.png
#   inflating: dataset/test/Padmasana/padmasana_test_26.png
#   inflating: dataset/test/Padmasana/padmasana_test_27.png
#   inflating: dataset/test/Padmasana/padmasana_test_28.png
#   inflating: dataset/test/Padmasana/padmasana_test_29.png
#   inflating: dataset/test/Padmasana/padmasana_test_3.png
#   inflating: dataset/test/Padmasana/padmasana_test_30.png
#   inflating: dataset/test/Padmasana/padmasana_test_31.png
#   inflating: dataset/test/Padmasana/padmasana_test_32.png
#   inflating: dataset/test/Padmasana/padmasana_test_33.png
#   inflating: dataset/test/Padmasana/padmasana_test_34.png
#   inflating: dataset/test/Padmasana/padmasana_test_35.png
#   inflating: dataset/test/Padmasana/padmasana_test_36.png
#   inflating: dataset/test/Padmasana/padmasana_test_37.png
#   inflating: dataset/test/Padmasana/padmasana_test_38.png
#   inflating: dataset/test/Padmasana/padmasana_test_39.png
#   inflating: dataset/test/Padmasana/padmasana_test_4.png
#   inflating: dataset/test/Padmasana/padmasana_test_40.png
#   inflating: dataset/test/Padmasana/padmasana_test_41.png
#   inflating: dataset/test/Padmasana/padmasana_test_42.png
#   inflating: dataset/test/Padmasana/padmasana_test_43.png
#   inflating: dataset/test/Padmasana/padmasana_test_44.png
#   inflating: dataset/test/Padmasana/padmasana_test_45.png
#   inflating: dataset/test/Padmasana/padmasana_test_46.png
#   inflating: dataset/test/Padmasana/padmasana_test_47.png
#   inflating: dataset/test/Padmasana/padmasana_test_48.png
#   inflating: dataset/test/Padmasana/padmasana_test_49.png
#   inflating: dataset/test/Padmasana/padmasana_test_5.png
#   inflating: dataset/test/Padmasana/padmasana_test_50.png
#   inflating: dataset/test/Padmasana/padmasana_test_51.png
#   inflating: dataset/test/Padmasana/padmasana_test_52.png
#   inflating: dataset/test/Padmasana/padmasana_test_53.png
#   inflating: dataset/test/Padmasana/padmasana_test_54.png
#   inflating: dataset/test/Padmasana/padmasana_test_55.png
#   inflating: dataset/test/Padmasana/padmasana_test_56.png
#   inflating: dataset/test/Padmasana/padmasana_test_57.png
#   inflating: dataset/test/Padmasana/padmasana_test_58.png
#   inflating: dataset/test/Padmasana/padmasana_test_59.png
#   inflating: dataset/test/Padmasana/padmasana_test_6.png
#   inflating: dataset/test/Padmasana/padmasana_test_60.png
#   inflating: dataset/test/Padmasana/padmasana_test_7.png
#   inflating: dataset/test/Padmasana/padmasana_test_8.png
#   inflating: dataset/test/Padmasana/padmasana_test_9.png
#    creating: dataset/test/plank/
#   inflating: dataset/test/plank/plank_test_1.png
#   inflating: dataset/test/plank/plank_test_10.png
#   inflating: dataset/test/plank/plank_test_11.png
#   inflating: dataset/test/plank/plank_test_12.png
#   inflating: dataset/test/plank/plank_test_13.png
#   inflating: dataset/test/plank/plank_test_14.png
#   inflating: dataset/test/plank/plank_test_15.png
#   inflating: dataset/test/plank/plank_test_16.png
#   inflating: dataset/test/plank/plank_test_17.png
#   inflating: dataset/test/plank/plank_test_18.png
#   inflating: dataset/test/plank/plank_test_19.png
#   inflating: dataset/test/plank/plank_test_2.png
#  extracting: dataset/test/plank/plank_test_20.png
#   inflating: dataset/test/plank/plank_test_21.png
#  extracting: dataset/test/plank/plank_test_22.png
#   inflating: dataset/test/plank/plank_test_23.png
#  extracting: dataset/test/plank/plank_test_24.png
#   inflating: dataset/test/plank/plank_test_25.png
#  extracting: dataset/test/plank/plank_test_26.png
#   inflating: dataset/test/plank/plank_test_27.png
#   inflating: dataset/test/plank/plank_test_28.png
#   inflating: dataset/test/plank/plank_test_29.png
#   inflating: dataset/test/plank/plank_test_3.png
#  extracting: dataset/test/plank/plank_test_30.png
#   inflating: dataset/test/plank/plank_test_31.png
#  extracting: dataset/test/plank/plank_test_32.png
#   inflating: dataset/test/plank/plank_test_33.png
#   inflating: dataset/test/plank/plank_test_34.png
#   inflating: dataset/test/plank/plank_test_35.png
#   inflating: dataset/test/plank/plank_test_36.png
#   inflating: dataset/test/plank/plank_test_37.png
#   inflating: dataset/test/plank/plank_test_38.png
#   inflating: dataset/test/plank/plank_test_39.png
#   inflating: dataset/test/plank/plank_test_4.png
#   inflating: dataset/test/plank/plank_test_40.png
#   inflating: dataset/test/plank/plank_test_41.png
#   inflating: dataset/test/plank/plank_test_42.png
#   inflating: dataset/test/plank/plank_test_43.png
#   inflating: dataset/test/plank/plank_test_44.png
#   inflating: dataset/test/plank/plank_test_45.png
#   inflating: dataset/test/plank/plank_test_46.png
#   inflating: dataset/test/plank/plank_test_47.png
#   inflating: dataset/test/plank/plank_test_48.png
#   inflating: dataset/test/plank/plank_test_49.png
#   inflating: dataset/test/plank/plank_test_5.png
#   inflating: dataset/test/plank/plank_test_50.png
#   inflating: dataset/test/plank/plank_test_6.png
#   inflating: dataset/test/plank/plank_test_7.png
#   inflating: dataset/test/plank/plank_test_8.png
#   inflating: dataset/test/plank/plank_test_9.png
#    creating: dataset/test/seated_forward_fold/
#   inflating: dataset/test/seated_forward_fold/seated_forward_fold_test_1.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_10.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_11.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_12.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_13.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_14.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_15.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_16.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_17.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_18.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_19.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_2.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_20.png
#   inflating: dataset/test/seated_forward_fold/seated_forward_fold_test_21.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_22.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_23.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_24.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_25.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_26.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_27.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_28.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_29.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_3.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_30.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_31.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_32.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_33.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_34.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_35.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_36.png
#   inflating: dataset/test/seated_forward_fold/seated_forward_fold_test_37.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_38.png
#   inflating: dataset/test/seated_forward_fold/seated_forward_fold_test_39.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_4.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_40.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_41.png
#   inflating: dataset/test/seated_forward_fold/seated_forward_fold_test_42.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_43.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_44.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_45.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_46.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_47.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_48.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_49.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_5.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_50.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_6.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_7.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_8.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_9.png
#    creating: dataset/test/tree/
#   inflating: dataset/test/tree/tree_test_1.png
#  extracting: dataset/test/tree/tree_test_10.png
#   inflating: dataset/test/tree/tree_test_11.png
#  extracting: dataset/test/tree/tree_test_12.png
#   inflating: dataset/test/tree/tree_test_13.png
#   inflating: dataset/test/tree/tree_test_14.png
#   inflating: dataset/test/tree/tree_test_15.png
#  extracting: dataset/test/tree/tree_test_16.png
#   inflating: dataset/test/tree/tree_test_17.png
#  extracting: dataset/test/tree/tree_test_18.png
#  extracting: dataset/test/warrior2/warrior2_test_22.png
#   inflating: dataset/test/warrior2/warrior2_test_23.png
#  extracting: dataset/test/warrior2/warrior2_test_24.png
#   inflating: dataset/test/warrior2/warrior2_test_25.png
#  extracting: dataset/test/warrior2/warrior2_test_26.png
#   inflating: dataset/test/warrior2/warrior2_test_27.png
#  extracting: dataset/test/warrior2/warrior2_test_28.png
#   inflating: dataset/test/warrior2/warrior2_test_29.png
#   inflating: dataset/test/warrior2/warrior2_test_3.png
#  extracting: dataset/test/warrior2/warrior2_test_30.png
#   inflating: dataset/test/warrior2/warrior2_test_31.png
#  extracting: dataset/test/warrior2/warrior2_test_32.png
#   inflating: dataset/test/warrior2/warrior2_test_33.png
#   inflating: dataset/test/warrior2/warrior2_test_34.png
#  extracting: dataset/test/warrior2/warrior2_test_35.png
#   inflating: dataset/test/warrior2/warrior2_test_36.png
#   inflating: dataset/test/warrior2/warrior2_test_37.png
#  extracting: dataset/test/warrior2/warrior2_test_38.png
#   inflating: dataset/test/warrior2/warrior2_test_39.png
#  extracting: dataset/test/warrior2/warrior2_test_4.png
#  extracting: dataset/test/warrior2/warrior2_test_40.png
#  extracting: dataset/test/warrior2/warrior2_test_41.png
#   inflating: dataset/test/warrior2/warrior2_test_42.png
#   inflating: dataset/test/warrior2/warrior2_test_43.png
#  extracting: dataset/test/warrior2/warrior2_test_44.png
#  extracting: dataset/test/warrior2/warrior2_test_45.png
#  extracting: dataset/test/warrior2/warrior2_test_46.png
#   inflating: dataset/test/warrior2/warrior2_test_47.png
#   inflating: dataset/test/warrior2/warrior2_test_48.png
#   inflating: dataset/test/warrior2/warrior2_test_49.png
#   inflating: dataset/test/warrior2/warrior2_test_5.png
#  extracting: dataset/test/warrior2/warrior2_test_50.png
#  extracting: dataset/test/warrior2/warrior2_test_51.png
#   inflating: dataset/test/warrior2/warrior2_test_52.png
#  extracting: dataset/test/warrior2/warrior2_test_6.png
#   inflating: dataset/test/warrior2/warrior2_test_7.png
#   inflating: dataset/test/warrior2/warrior2_test_8.png
#   inflating: dataset/test/warrior2/warrior2_test_9.png
#    creating: dataset/test/wheel/
#   inflating: dataset/test/wheel/wheel_test_1.png
#   inflating: dataset/test/wheel/wheel_test_10.png
#   inflating: dataset/test/wheel/wheel_test_11.png
#   inflating: dataset/test/wheel/wheel_test_12.png
#   inflating: dataset/test/wheel/wheel_test_13.png
#   inflating: dataset/test/wheel/wheel_test_14.png
#   inflating: dataset/test/wheel/wheel_test_15.png
#   inflating: dataset/test/wheel/wheel_test_16.png
#   inflating: dataset/test/wheel/wheel_test_17.png
#   inflating: dataset/test/wheel/wheel_test_18.png
#   inflating: dataset/test/wheel/wheel_test_19.png
#   inflating: dataset/test/wheel/wheel_test_2.png
#   inflating: dataset/test/wheel/wheel_test_20.png
#   inflating: dataset/test/wheel/wheel_test_21.png
#   inflating: dataset/test/wheel/wheel_test_22.png
#   inflating: dataset/test/wheel/wheel_test_23.png
#   inflating: dataset/test/wheel/wheel_test_24.png
#   inflating: dataset/test/wheel/wheel_test_25.png
#   inflating: dataset/test/wheel/wheel_test_26.png
#   inflating: dataset/test/wheel/wheel_test_27.png
#   inflating: dataset/test/wheel/wheel_test_28.png
#   inflating: dataset/test/wheel/wheel_test_29.png
#   inflating: dataset/test/wheel/wheel_test_3.png
#   inflating: dataset/test/wheel/wheel_test_30.png
#   inflating: dataset/test/wheel/wheel_test_31.png
#   inflating: dataset/test/wheel/wheel_test_32.png
#   inflating: dataset/test/wheel/wheel_test_33.png
#   inflating: dataset/test/wheel/wheel_test_34.png
#   inflating: dataset/test/wheel/wheel_test_35.png
#   inflating: dataset/test/wheel/wheel_test_36.png
#   inflating: dataset/test/wheel/wheel_test_37.png
#   inflating: dataset/test/wheel/wheel_test_38.png
#   inflating: dataset/test/wheel/wheel_test_39.png
#   inflating: dataset/test/wheel/wheel_test_4.png
#   inflating: dataset/test/wheel/wheel_test_40.png
#   inflating: dataset/test/wheel/wheel_test_41.png
#   inflating: dataset/test/wheel/wheel_test_42.png
#   inflating: dataset/test/wheel/wheel_test_43.png
#   inflating: dataset/test/wheel/wheel_test_44.png
#   inflating: dataset/test/wheel/wheel_test_45.png
#   inflating: dataset/test/wheel/wheel_test_46.png
#   inflating: dataset/test/wheel/wheel_test_47.png
#   inflating: dataset/test/wheel/wheel_test_5.png
#   inflating: dataset/test/wheel/wheel_test_6.png
#   inflating: dataset/test/wheel/wheel_test_7.png
#   inflating: dataset/test/wheel/wheel_test_8.png
#   inflating: dataset/test/wheel/wheel_test_9.png
#    creating: dataset/train/
#    creating: dataset/train/bridge/
#   inflating: dataset/train/bridge/bridge_train_1.png
#   inflating: dataset/train/bridge/bridge_train_10.png
#   inflating: dataset/train/bridge/bridge_train_100.png
#   inflating: dataset/train/bridge/bridge_train_101.png
#   inflating: dataset/train/bridge/bridge_train_102.png
#   inflating: dataset/train/bridge/bridge_train_103.png
#   inflating: dataset/train/bridge/bridge_train_104.png
#   inflating: dataset/train/bridge/bridge_train_105.png
#   inflating: dataset/train/bridge/bridge_train_106.png
#   inflating: dataset/train/bridge/bridge_train_107.png
#   inflating: dataset/train/bridge/bridge_train_108.png
#   inflating: dataset/train/bridge/bridge_train_109.png
#   inflating: dataset/train/bridge/bridge_train_11.png
#   inflating: dataset/train/bridge/bridge_train_110.png
#   inflating: dataset/train/bridge/bridge_train_111.png
#   inflating: dataset/train/bridge/bridge_train_112.png
#   inflating: dataset/train/bridge/bridge_train_113.png
#   inflating: dataset/train/bridge/bridge_train_114.png
#   inflating: dataset/train/bridge/bridge_train_115.png
#   inflating: dataset/train/bridge/bridge_train_116.png
#   inflating: dataset/train/bridge/bridge_train_117.png
#   inflating: dataset/train/bridge/bridge_train_118.png
#   inflating: dataset/train/bridge/bridge_train_119.png
#   inflating: dataset/train/bridge/bridge_train_12.png
#   inflating: dataset/train/bridge/bridge_train_120.png
#   inflating: dataset/train/bridge/bridge_train_121.png
#   inflating: dataset/train/bridge/bridge_train_122.png
#   inflating: dataset/train/bridge/bridge_train_123.png
#   inflating: dataset/train/bridge/bridge_train_124.png
#   inflating: dataset/train/bridge/bridge_train_125.png
#   inflating: dataset/train/bridge/bridge_train_99.png
#    creating: dataset/train/diamond/
#  extracting: dataset/train/diamond/diamond_train_1.png
#  extracting: dataset/train/diamond/diamond_train_10.png
#  extracting: dataset/train/diamond/diamond_train_100.png
#  extracting: dataset/train/diamond/diamond_train_101.png
#  extracting: dataset/train/diamond/diamond_train_102.png
#  extracting: dataset/train/diamond/diamond_train_103.png
#  extracting: dataset/train/diamond/diamond_train_104.png
#   inflating: dataset/train/diamond/diamond_train_105.png
#  extracting: dataset/train/diamond/diamond_train_106.png
#  extracting: dataset/train/diamond/diamond_train_107.png
#  extracting: dataset/train/diamond/diamond_train_108.png
#  extracting: dataset/train/diamond/diamond_train_109.png
#  extracting: dataset/train/diamond/diamond_train_11.png
#   inflating: dataset/train/diamond/diamond_train_110.png
#  extracting: dataset/train/diamond/diamond_train_111.png
#  extracting: dataset/train/diamond/diamond_train_112.png
#  extracting: dataset/train/diamond/diamond_train_113.png
#  extracting: dataset/train/diamond/diamond_train_114.png
#   inflating: dataset/train/diamond/diamond_train_115.png
#  extracting: dataset/train/diamond/diamond_train_116.png
#  extracting: dataset/train/diamond/diamond_train_117.png
#   inflating: dataset/train/diamond/diamond_train_118.png
#  extracting: dataset/train/diamond/diamond_train_119.png
#  extracting: dataset/train/diamond/diamond_train_12.png
#  extracting: dataset/train/diamond/diamond_train_120.png
#  extracting: dataset/train/diamond/diamond_train_121.png
#  extracting: dataset/train/diamond/diamond_train_122.png
#  extracting: dataset/train/diamond/diamond_train_123.png
#  extracting: dataset/train/diamond/diamond_train_124.png
#  extracting: dataset/train/diamond/diamond_train_125.png
#  extracting: dataset/train/diamond/diamond_train_126.png
#  extracting: dataset/train/diamond/diamond_train_127.png
#  extracting: dataset/train/diamond/diamond_train_128.png
#  extracting: dataset/train/diamond/diamond_train_129.png
#  extracting: dataset/train/diamond/diamond_train_13.png
#   inflating: dataset/train/diamond/diamond_train_130.png
#  extracting: dataset/train/diamond/diamond_train_131.png
#  extracting: dataset/train/diamond/diamond_train_132.png
#   inflating: dataset/train/diamond/diamond_train_133.png
#  extracting: dataset/train/diamond/diamond_train_134.png
#  extracting: dataset/train/diamond/diamond_train_135.png
#  extracting: dataset/train/diamond/diamond_train_136.png
#  extracting: dataset/train/diamond/diamond_train_137.png
#  extracting: dataset/train/diamond/diamond_train_138.png
#  extracting: dataset/train/diamond/diamond_train_139.png
#  extracting: dataset/train/diamond/diamond_train_14.png
#  extracting: dataset/train/diamond/diamond_train_140.png
#  extracting: dataset/train/diamond/diamond_train_141.png
#  extracting: dataset/train/diamond/diamond_train_142.png
#   inflating: dataset/train/diamond/diamond_train_143.png
#  extracting: dataset/train/diamond/diamond_train_144.png
#  extracting: dataset/train/diamond/diamond_train_145.png
#  extracting: dataset/train/diamond/diamond_train_146.png
#   inflating: dataset/train/diamond/diamond_train_147.png
#  extracting: dataset/train/diamond/diamond_train_148.png
#  extracting: dataset/train/diamond/diamond_train_149.png
#  extracting: dataset/train/diamond/diamond_train_15.png
#  extracting: dataset/train/diamond/diamond_train_150.png
#  extracting: dataset/train/diamond/diamond_train_151.png
#  extracting: dataset/train/diamond/diamond_train_152.png
#  extracting: dataset/train/diamond/diamond_train_153.png
#  extracting: dataset/train/diamond/diamond_train_154.png
#   inflating: dataset/train/diamond/diamond_train_155.png
#   inflating: dataset/train/diamond/diamond_train_156.png
#  extracting: dataset/train/diamond/diamond_train_157.png
#  extracting: dataset/train/diamond/diamond_train_158.png
#  extracting: dataset/train/diamond/diamond_train_159.png
#  extracting: dataset/train/diamond/diamond_train_16.png
#  extracting: dataset/train/diamond/diamond_train_160.png
#  extracting: dataset/train/diamond/diamond_train_161.png
#   inflating: dataset/train/diamond/diamond_train_162.png
#  extracting: dataset/train/diamond/diamond_train_163.png
#  extracting: dataset/train/diamond/diamond_train_164.png
#  extracting: dataset/train/diamond/diamond_train_165.png
#  extracting: dataset/train/diamond/diamond_train_166.png
#  extracting: dataset/train/diamond/diamond_train_167.png
#  extracting: dataset/train/diamond/diamond_train_168.png
#  extracting: dataset/train/diamond/diamond_train_169.png
#  extracting: dataset/train/diamond/diamond_train_17.png
#  extracting: dataset/train/diamond/diamond_train_170.png
#  extracting: dataset/train/diamond/diamond_train_171.png
#  extracting: dataset/train/diamond/diamond_train_172.png
#  extracting: dataset/train/diamond/diamond_train_173.png
#  extracting: dataset/train/diamond/diamond_train_174.png
#  extracting: dataset/train/diamond/diamond_train_175.png
#  extracting: dataset/train/diamond/diamond_train_176.png
#  extracting: dataset/train/diamond/diamond_train_177.png
#  extracting: dataset/train/diamond/diamond_train_178.png
#  extracting: dataset/train/diamond/diamond_train_179.png
#  extracting: dataset/train/diamond/diamond_train_18.png
#  extracting: dataset/train/diamond/diamond_train_180.png
# ...
#  extracting: dataset/train/warrior2/warrior2_train_196.png
#  extracting: dataset/train/warrior2/warrior2_train_197.png
#  extracting: dataset/train/warrior2/warrior2_train_198.png
#  extracting: dataset/train/warrior2/warrior2_train_199.png
#  extracting: dataset/train/warrior2/warrior2_train_2.png
#  extracting: dataset/train/warrior2/warrior2_train_20.png
#  extracting: dataset/train/warrior2/warrior2_train_200.png
#  extracting: dataset/train/warrior2/warrior2_train_201.png
#  extracting: dataset/train/warrior2/warrior2_train_202.png
#  extracting: dataset/train/warrior2/warrior2_train_203.png
#   inflating: dataset/train/warrior2/warrior2_train_204.png
#   inflating: dataset/train/warrior2/warrior2_train_205.png
#   inflating: dataset/train/warrior2/warrior2_train_21.png
#   inflating: dataset/train/warrior2/warrior2_train_22.png
#   inflating: dataset/train/warrior2/warrior2_train_23.png
#  extracting: dataset/train/warrior2/warrior2_train_24.png
#   inflating: dataset/train/warrior2/warrior2_train_25.png
#   inflating: dataset/train/warrior2/warrior2_train_26.png
#   inflating: dataset/train/warrior2/warrior2_train_27.png
#  extracting: dataset/train/warrior2/warrior2_train_28.png
#   inflating: dataset/train/warrior2/warrior2_train_29.png
#   inflating: dataset/train/warrior2/warrior2_train_3.png
#   inflating: dataset/train/warrior2/warrior2_train_30.png
#   inflating: dataset/train/warrior2/warrior2_train_31.png
#   inflating: dataset/train/warrior2/warrior2_train_32.png
#   inflating: dataset/train/wheel/wheel_train_77.png
#   inflating: dataset/train/wheel/wheel_train_78.png
#   inflating: dataset/train/wheel/wheel_train_79.png
#   inflating: dataset/train/wheel/wheel_train_8.png
#   inflating: dataset/train/wheel/wheel_train_80.png
#   inflating: dataset/train/wheel/wheel_train_81.png
#   inflating: dataset/train/wheel/wheel_train_82.png
#   inflating: dataset/train/wheel/wheel_train_83.png
#   inflating: dataset/train/wheel/wheel_train_84.png
#   inflating: dataset/train/wheel/wheel_train_85.png
#   inflating: dataset/train/wheel/wheel_train_86.png
#   inflating: dataset/train/wheel/wheel_train_87.png
#   inflating: dataset/train/wheel/wheel_train_88.png
#   inflating: dataset/train/wheel/wheel_train_89.png
#   inflating: dataset/train/wheel/wheel_train_9.png
#   inflating: dataset/train/wheel/wheel_train_90.png
#   inflating: dataset/train/wheel/wheel_train_91.png
#   inflating: dataset/train/wheel/wheel_train_92.png
#   inflating: dataset/train/wheel/wheel_train_93.png
#   inflating: dataset/train/wheel/wheel_train_94.png
#   inflating: dataset/train/wheel/wheel_train_95.png
#   inflating: dataset/train/wheel/wheel_train_96.png
#   inflating: dataset/train/wheel/wheel_train_97.png
#   inflating: dataset/train/wheel/wheel_train_98.png
#   inflating: dataset/train/wheel/wheel_train_99.png

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
import os
import itertools
import sys
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection

# !wget -q -O movenet_thunder.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# !git clone https://github.com/tensorflow/examples.git
pose_sample_rpi_path = os.path.join(os.getcwd(), 'examples/lite/examples/pose_estimation/raspberry_pi')
sys.path.append(pose_sample_rpi_path)

# Load MoveNet Thunder model
import utils
from data import BodyPart
from ml import Movenet
movenet = Movenet('movenet_thunder')

np.random.seed(42)
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 23737, done.
# remote: Counting objects: 100% (701/701), done.
# remote: Compressing objects: 100% (439/439), done.
# remote: Total 23737 (delta 234), reused 618 (delta 174), pack-reused 23036
# Receiving objects: 100% (23737/23737), 44.19 MiB | 12.02 MiB/s, done.
# Resolving deltas: 100% (12882/12882), done.

# %%
train_df = pd.read_csv('/content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/custom_dataset/train_data_MoveNet_Reseized.csv')
test_df = pd.read_csv('/content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/custom_dataset/test_data_MoveNet_Resized.csv')

# %%
train_df.head()
# Out:
#                            file_name  NOSE_x  NOSE_y  NOSE_score  LEFT_EYE_x  \
# 0    Padmasana/padmasana_train_1.png    87.0    39.0    0.682804        93.0
# 1   Padmasana/padmasana_train_10.png   110.0    60.0    0.738992       116.0
# 2  Padmasana/padmasana_train_100.png   116.0    89.0    0.712361       122.0
# 3  Padmasana/padmasana_train_101.png   100.0    75.0    0.858466       107.0
# 4  Padmasana/padmasana_train_102.png   114.0    56.0    0.865506       118.0
#
#    LEFT_EYE_y  LEFT_EYE_score  RIGHT_EYE_x  RIGHT_EYE_y  RIGHT_EYE_score  ...  \
# 0        33.0        0.817314         81.0         33.0         0.889812  ...
# 1        58.0        0.435181        105.0         58.0         0.464757  ...
# 2        85.0        0.617106        110.0         86.0         0.844396  ...
# 3        68.0        0.946382         91.0         70.0         0.821778  ...
# 4        53.0        0.713721        109.0         54.0         0.935193  ...
#
#    RIGHT_KNEE_y  RIGHT_KNEE_score  LEFT_ANKLE_x  LEFT_ANKLE_y  \
# 0         199.0          0.902004          74.0         182.0
# 1         130.0          0.576601         102.0         158.0
# 2         168.0          0.595692         100.0         174.0
# 3         204.0          0.760352          92.0         189.0
# 4         176.0          0.825088         106.0         185.0
#
#    LEFT_ANKLE_score  RIGHT_ANKLE_x  RIGHT_ANKLE_y  RIGHT_ANKLE_score  \
# 0          0.784689           98.0          191.0           0.656110
# 1          0.760766          117.0          155.0           0.691795
# 2          0.246014          130.0          173.0           0.318669
# 3          0.837257          119.0          188.0           0.845381
# 4          0.745232          119.0          187.0           0.650972
#
#    class_no  class_name
# 0         0   Padmasana
# 1         0   Padmasana
# 2         0   Padmasana
# 3         0   Padmasana
# 4         0   Padmasana
#
# [5 rows x 54 columns]

# %%
train_path = '/content/dataset/train/'
class_names = os.listdir(train_path)
count = 0
for class_name in class_names:
    class_path = os.path.join(train_path, class_name)
    all_files = os.listdir(class_path)
    for file in all_files:
        file_path = os.path.join(class_path,file)
        name_to_check_df = class_name + "/" + file
        if train_df['file_name'].isin([name_to_check_df]).any():
            count+=1
        else:
            os.remove(file_path)
            print(f"Removed: {file_path}")
# Out:
# Removed: /content/dataset/train/wheel/wheel_train_70.png
# Removed: /content/dataset/train/wheel/wheel_train_99.png
# Removed: /content/dataset/train/wheel/wheel_train_68.png
# Removed: /content/dataset/train/wheel/wheel_train_28.png
# Removed: /content/dataset/train/wheel/wheel_train_59.png
# Removed: /content/dataset/train/wheel/wheel_train_185.png
# Removed: /content/dataset/train/wheel/wheel_train_164.png
# Removed: /content/dataset/train/wheel/wheel_train_13.png
# Removed: /content/dataset/train/wheel/wheel_train_50.png
# Removed: /content/dataset/train/wheel/wheel_train_101.png
# Removed: /content/dataset/train/wheel/wheel_train_65.png
# Removed: /content/dataset/train/wheel/wheel_train_58.png
# Removed: /content/dataset/train/wheel/wheel_train_116.png
# Removed: /content/dataset/train/wheel/wheel_train_172.png
# Removed: /content/dataset/train/wheel/wheel_train_94.png
# Removed: /content/dataset/train/wheel/wheel_train_81.png
# Removed: /content/dataset/train/wheel/wheel_train_179.png
# Removed: /content/dataset/train/wheel/wheel_train_92.png
# Removed: /content/dataset/train/wheel/wheel_train_131.png
# Removed: /content/dataset/train/wheel/wheel_train_48.png
# Removed: /content/dataset/train/wheel/wheel_train_166.png
# Removed: /content/dataset/train/wheel/wheel_train_155.png
# Removed: /content/dataset/train/wheel/wheel_train_181.png
# Removed: /content/dataset/train/wheel/wheel_train_103.png
# Removed: /content/dataset/train/wheel/wheel_train_80.png
# Removed: /content/dataset/train/wheel/wheel_train_138.png
# Removed: /content/dataset/train/wheel/wheel_train_75.png
# Removed: /content/dataset/train/wheel/wheel_train_148.png
# Removed: /content/dataset/train/wheel/wheel_train_60.png
# Removed: /content/dataset/train/wheel/wheel_train_41.png
# Removed: /content/dataset/train/wheel/wheel_train_162.png
# Removed: /content/dataset/train/wheel/wheel_train_105.png
# Removed: /content/dataset/train/wheel/wheel_train_12.png
# Removed: /content/dataset/train/wheel/wheel_train_42.png
# Removed: /content/dataset/train/wheel/wheel_train_45.png
# Removed: /content/dataset/train/wheel/wheel_train_126.png
# Removed: /content/dataset/train/wheel/wheel_train_4.png
# Removed: /content/dataset/train/wheel/wheel_train_128.png
# Removed: /content/dataset/train/Padmasana/padmasana_train_119.png
# Removed: /content/dataset/train/Padmasana/padmasana_train_130.png
# Removed: /content/dataset/train/Padmasana/padmasana_train_136.png
# Removed: /content/dataset/train/Padmasana/padmasana_train_184.png
# Removed: /content/dataset/train/Padmasana/padmasana_train_196.png
# Removed: /content/dataset/train/Padmasana/padmasana_train_118.png
# Removed: /content/dataset/train/bridge/bridge_train_122.png
# Removed: /content/dataset/train/bridge/bridge_train_44.png
# Removed: /content/dataset/train/bridge/bridge_train_153.png
# Removed: /content/dataset/train/bridge/bridge_train_178.png
# Removed: /content/dataset/train/bridge/bridge_train_31.png

# %%
if len(train_df) == count:
    print("Irrelevant Files were removed")
else:
    print("Irrelevant Files were not removed")
# Out:
# Irrelevant Files were removed

# %%
test_path = '/content/dataset/test/'
class_names = os.listdir(test_path)
count = 0
for class_name in class_names:
    class_path = os.path.join(test_path, class_name)
    all_files = os.listdir(class_path)
    for file in all_files:
        file_path = os.path.join(class_path,file)
        name_to_check_df = class_name + "/" + file
        if test_df['file_name'].isin([name_to_check_df]).any():
            count+=1
        else:
            os.remove(file_path)
            print(f"Removed: {file_path}")
# Out:
# Removed: /content/dataset/test/wheel/wheel_test_3.png
# Removed: /content/dataset/test/wheel/wheel_test_36.png
# Removed: /content/dataset/test/wheel/wheel_test_2.png
# Removed: /content/dataset/test/wheel/wheel_test_46.png
# Removed: /content/dataset/test/wheel/wheel_test_7.png
# Removed: /content/dataset/test/wheel/wheel_test_26.png
# Removed: /content/dataset/test/wheel/wheel_test_14.png
# Removed: /content/dataset/test/wheel/wheel_test_37.png
# Removed: /content/dataset/test/wheel/wheel_test_43.png
# Removed: /content/dataset/test/wheel/wheel_test_42.png
# Removed: /content/dataset/test/diamond/diamond_test_26.png
# Removed: /content/dataset/test/diamond/diamond_test_37.png
# Removed: /content/dataset/test/diamond/diamond_test_34.png
# Removed: /content/dataset/test/diamond/diamond_test_42.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_30.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_46.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_9.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_16.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_15.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_21.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_22.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_28.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_47.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_7.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_2.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_45.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_27.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_26.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_50.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_1.png
# Removed: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_48.png
# Removed: /content/dataset/test/plank/plank_test_16.png
# Removed: /content/dataset/test/plank/plank_test_10.png
# Removed: /content/dataset/test/plank/plank_test_39.png
# Removed: /content/dataset/test/tree/tree_test_5.png
# Removed: /content/dataset/test/downdog/downdog_test_39.png
# Removed: /content/dataset/test/downdog/downdog_test_52.png

# %%
if len(test_df) == count:
    print("Irrelevant Files were removed")
else:
    print("Irrelevant Files were not removed")
# Out:
# Irrelevant Files were removed

# %%
def preprocess_df(df):
    df = df.dropna()
    df = df.reset_index(drop=True)
    print('-----------------------------------------------------------')
    print(f"The Length of dataframe is = {len(df)}")
    print('-----------------------------------------------------------')
    unique_classes = df['class_name'].unique()
    print('-----------------------------------------------------------')
    print('The List of Unqiue classes:')
    print(unique_classes)
    print('-----------------------------------------------------------')
    print('-----------------------------------------------------------')
    print('The number of classes = ',len(unique_classes))
    print('-----------------------------------------------------------')
    any_null_values = df.isnull().values.any()
    print('-----------------------------------------------------------')
    print("\nAre there any null values in the DataFrame?")
    print(any_null_values)
    print('-----------------------------------------------------------')
    return df, len(unique_classes)

def load_landmarks(df):
    df.drop(columns=['file_name'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    X = df.astype('float64')
    y = keras.utils.to_categorical(y)
    return X, y, classes, x_images, df

def get_center_point(landmarks, left_bodypart, right_bodypart):
  """Calculates the center point of the two given landmarks."""

  left = tf.gather(landmarks, left_bodypart.value, axis=1)
  right = tf.gather(landmarks, right_bodypart.value, axis=1)
  center = left * 0.5 + right * 0.5
  return center


def get_pose_size(landmarks, torso_size_multiplier=2.5):
  """Calculates pose size.

  It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
  """
  # Hips center
  hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)

  # Shoulders center
  shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

  # Torso size as the minimum body size
  torso_size = tf.linalg.norm(shoulders_center - hips_center)

  # Pose center
  pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                     BodyPart.RIGHT_HIP)
  pose_center_new = tf.expand_dims(pose_center_new, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to
  # perform substraction
  pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

  # Dist to pose center
  d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
  # Max dist to pose center
  max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

  # Normalize scale
  pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)

  return pose_size


def normalize_pose_landmarks(landmarks):
  """Normalizes the landmarks translation by moving the pose center to (0,0) and
  scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
  pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)
  pose_center = tf.expand_dims(pose_center, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to perform
  # substraction
  pose_center = tf.broadcast_to(pose_center,
                                [tf.size(landmarks) // (17*2), 17, 2])
  landmarks = landmarks - pose_center

  # Scale the landmarks to a constant pose size
  pose_size = get_pose_size(landmarks)
  landmarks /= pose_size

  return landmarks


def landmarks_to_embedding(landmarks_and_scores):
  """Converts the input landmarks into a pose embedding."""
  # Reshape the flat input into a matrix with shape=(17, 3)
  reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

  # Normalize landmarks 2D
  landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])

  # Flatten the normalized landmark coordinates into a vector
  embedding = keras.layers.Flatten()(landmarks)

  return embedding

# Define a function to load and preprocess images
def load_and_preprocess_image(file_path):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, (224, 224))  # Resize image to match ResNet50 input shape
    img = tf.keras.applications.resnet50.preprocess_input(img)
    return img

# %%
len(train_df)
# Out:
# 1898

# %%
classes = train_df['class_name'].unique()
classes
# Out:
# array(['Padmasana', 'bridge', 'diamond', 'downdog', 'goddess', 'plank',
#        'seated_forward_fold', 'tree', 'warrior2', 'wheel'], dtype=object)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import ResNet50
import pandas as pd
import numpy as np
import os
import utils
from data import BodyPart
from ml import Movenet

# %%
# Path to the directory containing the images
image_path_train = '/content/dataset/train/'
image_path_test = '/content/dataset/test/'
# Load and preprocess images and add them as a column named 'image' to the DataFrame
train_df['image'] = train_df['file_name'].apply(lambda x: load_and_preprocess_image(os.path.join(image_path_train, x)))
test_df['image'] = test_df['file_name'].apply(lambda x: load_and_preprocess_image(os.path.join(image_path_test, x)))
# Display the DataFrame with the added 'image' column

# %%
X_train_landmarks, y_train_landmarks, classes, x_train_images, _ = load_landmarks(train_df)
X_test_landmarks, y_test_landmarks, _, x_test_images, _ = load_landmarks(test_df)

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras import backend as K
class BilinearPooling(layers.Layer):
    def __init__(self, **kwargs):
        super(BilinearPooling, self).__init__(**kwargs)

    def build(self, input_shape):
        super(BilinearPooling, self).build(input_shape)

    def call(self, inputs):
        x1, x2 = inputs
        batch_size = K.shape(x1)[0]
        num_channels = K.shape(x1)[-1]

        x1_flat = K.reshape(x1, (batch_size, -1, num_channels))
        x2_flat = K.reshape(x2, (batch_size, -1, num_channels))

        bilinear_pooling = K.batch_dot(x1_flat, x2_flat, axes=[1, 1]) / K.prod(K.cast(K.shape(x1_flat)[1:-1], 'float32'))

        return K.sqrt(K.abs(bilinear_pooling) + 1e-8)

    def compute_output_shape(self, input_shape):
        return (input_shape[0][0], input_shape[0][-1])

# %%
# Define landmark input
landmark_inputs = keras.Input(shape=(51), name='landmark_input')
landmark_inputs = landmarks_to_embedding(landmark_inputs)
landmark_layer = keras.layers.Dense(256, activation=tf.nn.relu6)(landmark_inputs)
landmark_layer = keras.layers.Dropout(0.3)(landmark_layer)
landmark_layer = keras.layers.Dense(64, activation=tf.nn.relu6)(landmark_layer)
landmark_layer = keras.layers.Dropout(0.3)(landmark_layer)

# Define ResNet50 model for image inputs
resnet_model = ResNet50(include_top=False, input_shape=(224, 224, 3))
for layer in resnet_model.layers:
    layer.trainable = False

# Define image input
image_inputs = keras.Input(shape=(224, 224, 3), name='image_input')
resnet_output = resnet_model(image_inputs)
resnet_output = keras.layers.Flatten()(resnet_output)
resnet_output = keras.layers.Dense(256, activation = 'relu')(resnet_output)
resnet_output = keras.layers.BatchNormalization()(resnet_output)
resnet_output = keras.layers.Dropout(0.5)(resnet_output)
resnet_output = keras.layers.Dense(64, activation = 'relu')(resnet_output)
resnet_output = keras.layers.BatchNormalization()(resnet_output)
resnet_output = keras.layers.Dropout(0.5)(resnet_output)

# Calculate scaled dot-product attention
attention_scores = keras.layers.Dot(axes=-1)([landmark_layer, resnet_output])
attention_scores = keras.layers.Softmax()(attention_scores)  # Normalize attention weights

# Apply attention weights
weighted_landmark = keras.layers.Multiply()([landmark_layer, attention_scores])
weighted_image = keras.layers.Multiply()([resnet_output, attention_scores])

# Combine weighted representations - consider alternatives to just averaging
combined_features = keras.layers.Average()([weighted_landmark, weighted_image])
combined_features = keras.layers.BatchNormalization()(combined_features)
# Output layer for multi-class classification
outputs = keras.layers.Dense(len(classes), activation='softmax')(combined_features)

# Define the updated hybrid model
hybrid_model = keras.Model(inputs=[landmark_inputs, image_inputs], outputs=outputs)
hybrid_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  image_input (InputLayer)    [(None, 224, 224, 3)]        0         []
#
#  resnet50 (Functional)       (None, 7, 7, 2048)           2358771   ['image_input[0][0]']
#                                                           2
#
#  flatten_1 (Flatten)         (None, 100352)               0         ['resnet50[0][0]']
#
#  dense_7 (Dense)             (None, 256)                  2569036   ['flatten_1[0][0]']
#                                                           8
#
#  landmark_input (InputLayer  [(None, 51)]                 0         []
#  )
#
#  batch_normalization_3 (Bat  (None, 256)                  1024      ['dense_7[0][0]']
#  chNormalization)
#
#  dense_5 (Dense)             (None, 256)                  13312     ['landmark_input[0][0]']
#
#  dropout_6 (Dropout)         (None, 256)                  0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 256)                  0         ['dense_5[0][0]']
#
#  dense_8 (Dense)             (None, 64)                   16448     ['dropout_6[0][0]']
#
#  dense_6 (Dense)             (None, 64)                   16448     ['dropout_4[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64)                   256       ['dense_8[0][0]']
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                   0         ['dense_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 64)                   0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dot_1 (Dot)                 (None, 1)                    0         ['dropout_5[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  softmax_1 (Softmax)         (None, 1)                    0         ['dot_1[0][0]']
#
#  multiply_2 (Multiply)       (None, 64)                   0         ['dropout_5[0][0]',
#                                                                      'softmax_1[0][0]']
#
#  multiply_3 (Multiply)       (None, 64)                   0         ['dropout_7[0][0]',
#                                                                      'softmax_1[0][0]']
#
#  average_1 (Average)         (None, 64)                   0         ['multiply_2[0][0]',
#                                                                      'multiply_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64)                   256       ['average_1[0][0]']
#  chNormalization)
#
#  dense_9 (Dense)             (None, 10)                   650       ['batch_normalization_5[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 49326474 (188.17 MB)
# Trainable params: 25737994 (98.18 MB)
# Non-trainable params: 23588480 (89.98 MB)
# __________________________________________________________________________________________________

# %%
import keras

# Visualize the model
keras.utils.plot_model(hybrid_model, expand_nested=False, dpi=100, show_shapes=True)

# %%
print(X_train_landmarks.shape)
print(x_train_images.shape)
# Out:
# (1898, 51)
# (1898,)

# %%
X_train_landmarks_np = X_train_landmarks.values.astype('float64')
x_train_images_np = np.stack(x_train_images.values)
y_train_landmarks_np = y_train_landmarks

X_test_landmarks_np = X_test_landmarks.values.astype('float64')
y_test_landmarks_np = y_test_landmarks
x_test_images_np = np.stack(x_test_images.values)

# %%
print(type(X_train_landmarks_np))
print(type(x_train_images_np))
print(type(y_train_landmarks_np))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
hybrid_model.compile(
    optimizer= 'adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Add a checkpoint callback to store the checkpoint that has the highest
# validation accuracy.
checkpoint_path = "weights_hybrid.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='max')
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                              patience=20)

# Start training
history = hybrid_model.fit([X_train_landmarks_np, x_train_images_np],y_train_landmarks_np,
                    epochs=100,
                    batch_size=32,
                    validation_data = ([X_test_landmarks_np, x_test_images_np], y_test_landmarks_np),
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/100
# 60/60 [==============================] - ETA: 0s - loss: 1.3811 - accuracy: 0.5553
# Epoch 1: val_accuracy improved from -inf to 0.83640, saving model to weights_hybrid.keras
# 60/60 [==============================] - 12s 110ms/step - loss: 1.3811 - accuracy: 0.5553 - val_loss: 0.4679 - val_accuracy: 0.8364
# Epoch 2/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.5207 - accuracy: 0.8761
# Epoch 2: val_accuracy improved from 0.83640 to 0.96933, saving model to weights_hybrid.keras
# 60/60 [==============================] - 4s 69ms/step - loss: 0.5201 - accuracy: 0.8762 - val_loss: 0.1816 - val_accuracy: 0.9693
# Epoch 3/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.2770 - accuracy: 0.9497
# Epoch 3: val_accuracy did not improve from 0.96933
# 60/60 [==============================] - 2s 35ms/step - loss: 0.2779 - accuracy: 0.9494 - val_loss: 0.1398 - val_accuracy: 0.9693
# Epoch 4/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.1828 - accuracy: 0.9709
# Epoch 4: val_accuracy improved from 0.96933 to 0.98364, saving model to weights_hybrid.keras
# 60/60 [==============================] - 4s 71ms/step - loss: 0.1830 - accuracy: 0.9705 - val_loss: 0.1032 - val_accuracy: 0.9836
# Epoch 5/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.1120 - accuracy: 0.9915
# Epoch 5: val_accuracy did not improve from 0.98364
# 60/60 [==============================] - 2s 34ms/step - loss: 0.1119 - accuracy: 0.9916 - val_loss: 0.0869 - val_accuracy: 0.9796
# Epoch 6/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0859 - accuracy: 0.9910
# Epoch 6: val_accuracy improved from 0.98364 to 0.98773, saving model to weights_hybrid.keras
# 60/60 [==============================] - 4s 67ms/step - loss: 0.0870 - accuracy: 0.9910 - val_loss: 0.0664 - val_accuracy: 0.9877
# Epoch 7/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0726 - accuracy: 0.9921
# Epoch 7: val_accuracy did not improve from 0.98773
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0725 - accuracy: 0.9921 - val_loss: 0.0772 - val_accuracy: 0.9796
# Epoch 8/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0541 - accuracy: 0.9936
# Epoch 8: val_accuracy did not improve from 0.98773
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0546 - accuracy: 0.9937 - val_loss: 0.0686 - val_accuracy: 0.9816
# Epoch 9/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0432 - accuracy: 0.9974
# Epoch 9: val_accuracy did not improve from 0.98773
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0433 - accuracy: 0.9974 - val_loss: 0.0602 - val_accuracy: 0.9836
# Epoch 10/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0363 - accuracy: 0.9974
# Epoch 10: val_accuracy did not improve from 0.98773
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0363 - accuracy: 0.9974 - val_loss: 0.0534 - val_accuracy: 0.9857
# Epoch 11/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9979
# Epoch 11: val_accuracy improved from 0.98773 to 0.98978, saving model to weights_hybrid.keras
# 60/60 [==============================] - 4s 67ms/step - loss: 0.0313 - accuracy: 0.9979 - val_loss: 0.0508 - val_accuracy: 0.9898
# Epoch 12/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0278 - accuracy: 0.9974
# Epoch 12: val_accuracy improved from 0.98978 to 0.99182, saving model to weights_hybrid.keras
# 60/60 [==============================] - 4s 72ms/step - loss: 0.0279 - accuracy: 0.9974 - val_loss: 0.0469 - val_accuracy: 0.9918
# Epoch 13/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 0.9989
# Epoch 13: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0233 - accuracy: 0.9989 - val_loss: 0.0428 - val_accuracy: 0.9877
# Epoch 14/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0216 - accuracy: 0.9989
# Epoch 14: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0215 - accuracy: 0.9989 - val_loss: 0.0444 - val_accuracy: 0.9918
# Epoch 15/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0191 - accuracy: 0.9989
# Epoch 15: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0191 - accuracy: 0.9989 - val_loss: 0.0431 - val_accuracy: 0.9898
# Epoch 16/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0166 - accuracy: 0.9989
# Epoch 16: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0165 - accuracy: 0.9989 - val_loss: 0.0458 - val_accuracy: 0.9877
# Epoch 17/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 0.9989
# Epoch 17: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0158 - accuracy: 0.9989 - val_loss: 0.0674 - val_accuracy: 0.9857
# Epoch 18/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9877
# Epoch 19/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0116 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.0446 - val_accuracy: 0.9836
# Epoch 20/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9877
# Epoch 21/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0115 - accuracy: 0.9995
# Epoch 21: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0115 - accuracy: 0.9995 - val_loss: 0.0419 - val_accuracy: 0.9877
# Epoch 22/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9995
# Epoch 22: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0095 - accuracy: 0.9995 - val_loss: 0.0404 - val_accuracy: 0.9898
# Epoch 23/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9995
# Epoch 23: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0082 - accuracy: 0.9995 - val_loss: 0.0459 - val_accuracy: 0.9836
# Epoch 24/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9995
# Epoch 24: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0090 - accuracy: 0.9995 - val_loss: 0.0357 - val_accuracy: 0.9857
# Epoch 25/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9995
# Epoch 25: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0092 - accuracy: 0.9989 - val_loss: 0.0380 - val_accuracy: 0.9898
# Epoch 26/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0116 - accuracy: 0.9974
# Epoch 26: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0116 - accuracy: 0.9974 - val_loss: 0.0395 - val_accuracy: 0.9898
# Epoch 27/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0105 - accuracy: 0.9995 - val_loss: 0.0428 - val_accuracy: 0.9877
# Epoch 28/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0301 - accuracy: 0.9915
# Epoch 28: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0303 - accuracy: 0.9916 - val_loss: 0.0523 - val_accuracy: 0.9816
# Epoch 29/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0200 - accuracy: 0.9963
# Epoch 29: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0199 - accuracy: 0.9963 - val_loss: 0.0690 - val_accuracy: 0.9734
# Epoch 30/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0163 - accuracy: 0.9974
# Epoch 30: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 33ms/step - loss: 0.0163 - accuracy: 0.9974 - val_loss: 0.0563 - val_accuracy: 0.9775
# Epoch 31/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0134 - accuracy: 0.9979
# Epoch 31: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0138 - accuracy: 0.9979 - val_loss: 0.0594 - val_accuracy: 0.9796
# Epoch 32/100
# 59/60 [============================>.] - ETA: 0s - loss: 0.0161 - accuracy: 0.9958
# Epoch 32: val_accuracy did not improve from 0.99182
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0164 - accuracy: 0.9958 - val_loss: 0.0600 - val_accuracy: 0.9816

# %%
from matplotlib import pyplot as plt


# Plot training & validation accuracy values
plt.figure(figsize=(6, 6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training & Validation Accuracy for Hybrid Model for Yoga-10 Dataset')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_Hybrid.png')
plt.show()
# Plot training & validation loss values
plt.figure(figsize=(6, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training & Validation Loss for Hybrid Model for Yoga-10 Dataset')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_Hybrid.png')

plt.show()

# %%
hybrid_model = tf.keras.models.load_model('weights_hybrid.keras')
hybrid_model.evaluate([X_test_landmarks_np, x_test_images_np], y_test_landmarks_np)
# Out:
# 16/16 [==============================] - 3s 25ms/step - loss: 0.0469 - accuracy: 0.9918
# [0.04686073213815689, 0.9918200373649597]

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
y_pred = hybrid_model.predict([X_test_landmarks_np, x_test_images_np])
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test_landmarks_np, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of Hybrid Model with Yoga-10 Dataset')
plt.savefig('Confusion_Matrix_Hybrid.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 16/16 [==============================] - 0s 23ms/step
#                      precision    recall  f1-score   support
#
#           Padmasana       0.98      1.00      0.99        60
#              bridge       0.96      1.00      0.98        53
#             diamond       1.00      0.98      0.99        46
#             downdog       1.00      0.98      0.99        54
#             goddess       1.00      1.00      1.00        50
#               plank       1.00      1.00      1.00        47
# seated_forward_fold       1.00      1.00      1.00        33
#                tree       1.00      1.00      1.00        57
#            warrior2       1.00      1.00      1.00        52
#               wheel       0.97      0.95      0.96        37
#
#            accuracy                           0.99       489
#           macro avg       0.99      0.99      0.99       489
#        weighted avg       0.99      0.99      0.99       489

# %%
import zipfile
import os
import pickle

with open('history_for_Hybrid.pkl', 'wb') as f:
    pickle.dump(history, f)

def create_zip(files_to_zip, zip_filename):
    with zipfile.ZipFile(zip_filename, 'w') as zipf:
        for file in files_to_zip:
            # Add the file to the zip archive
            zipf.write(file, os.path.basename(file))

# Example: List of files to be included in the zip
files_to_zip = ['Accuracy_Graph_Hybrid.png', 'Loss_Graph_Hybrid.png', 'history_for_Hybrid.pkl', 'weights_hybrid.keras', 'Confusion_Matrix_Hybrid.png']

# Specify the name of the zip file
zip_filename = 'results_Hybrid_With_Attention_Mechanism_and_Late_Fusion.zip'

# Create the zip file
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} /content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/custom_dataset/
