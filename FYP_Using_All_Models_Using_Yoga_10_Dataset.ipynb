#   inflating: dataset/test/bridge/bridge_test_8.png
#   inflating: dataset/test/bridge/bridge_test_9.png
#    creating: dataset/test/diamond/
#  extracting: dataset/test/diamond/diamond_test_1.png
#  extracting: dataset/test/diamond/diamond_test_10.png
#  extracting: dataset/test/diamond/diamond_test_11.png
#  extracting: dataset/test/diamond/diamond_test_12.png
#  extracting: dataset/test/diamond/diamond_test_13.png
#  extracting: dataset/test/diamond/diamond_test_14.png
#  extracting: dataset/test/diamond/diamond_test_15.png
#  extracting: dataset/test/diamond/diamond_test_16.png
#  extracting: dataset/test/diamond/diamond_test_17.png
#   inflating: dataset/test/diamond/diamond_test_18.png
#  extracting: dataset/test/diamond/diamond_test_19.png
#  extracting: dataset/test/diamond/diamond_test_2.png
#  extracting: dataset/test/diamond/diamond_test_20.png
#   inflating: dataset/test/diamond/diamond_test_21.png
#  extracting: dataset/test/diamond/diamond_test_22.png
#  extracting: dataset/test/diamond/diamond_test_23.png
#   inflating: dataset/test/diamond/diamond_test_24.png
#  extracting: dataset/test/diamond/diamond_test_25.png
#  extracting: dataset/test/diamond/diamond_test_26.png
#  extracting: dataset/test/diamond/diamond_test_27.png
#  extracting: dataset/test/diamond/diamond_test_28.png
#  extracting: dataset/test/diamond/diamond_test_29.png
#  extracting: dataset/test/diamond/diamond_test_3.png
#  extracting: dataset/test/diamond/diamond_test_30.png
#  extracting: dataset/test/diamond/diamond_test_31.png
#  extracting: dataset/test/diamond/diamond_test_32.png
#  extracting: dataset/test/diamond/diamond_test_33.png
#   inflating: dataset/test/diamond/diamond_test_34.png
#  extracting: dataset/test/diamond/diamond_test_35.png
#  extracting: dataset/test/diamond/diamond_test_36.png
#  extracting: dataset/test/diamond/diamond_test_37.png
#  extracting: dataset/test/diamond/diamond_test_38.png
#  extracting: dataset/test/diamond/diamond_test_39.png
#  extracting: dataset/test/diamond/diamond_test_4.png
#  extracting: dataset/test/diamond/diamond_test_40.png
#  extracting: dataset/test/diamond/diamond_test_41.png
#  extracting: dataset/test/diamond/diamond_test_42.png
#  extracting: dataset/test/diamond/diamond_test_43.png
#  extracting: dataset/test/diamond/diamond_test_44.png
#  extracting: dataset/test/diamond/diamond_test_45.png
#  extracting: dataset/test/diamond/diamond_test_46.png
#  extracting: dataset/test/diamond/diamond_test_47.png
#  extracting: dataset/test/diamond/diamond_test_48.png
#  extracting: dataset/test/diamond/diamond_test_49.png
#  extracting: dataset/test/diamond/diamond_test_5.png
#   inflating: dataset/test/diamond/diamond_test_50.png
#  extracting: dataset/test/diamond/diamond_test_6.png
#  extracting: dataset/test/diamond/diamond_test_7.png
#   inflating: dataset/test/diamond/diamond_test_8.png
#  extracting: dataset/test/diamond/diamond_test_9.png
#    creating: dataset/test/downdog/
#   inflating: dataset/test/downdog/downdog_test_1.png
#  extracting: dataset/test/downdog/downdog_test_10.png
#   inflating: dataset/test/downdog/downdog_test_11.png
#  extracting: dataset/test/downdog/downdog_test_12.png
#   inflating: dataset/test/downdog/downdog_test_13.png
#   inflating: dataset/test/downdog/downdog_test_14.png
#   inflating: dataset/test/plank/plank_test_17.png
#   inflating: dataset/test/plank/plank_test_18.png
#   inflating: dataset/test/plank/plank_test_19.png
#   inflating: dataset/test/plank/plank_test_2.png
#  extracting: dataset/test/plank/plank_test_20.png
#   inflating: dataset/test/plank/plank_test_21.png
#  extracting: dataset/test/plank/plank_test_22.png
#   inflating: dataset/test/plank/plank_test_23.png
#  extracting: dataset/test/plank/plank_test_24.png
#   inflating: dataset/test/plank/plank_test_25.png
#  extracting: dataset/test/plank/plank_test_26.png
#   inflating: dataset/test/plank/plank_test_27.png
#   inflating: dataset/test/plank/plank_test_28.png
#   inflating: dataset/test/plank/plank_test_29.png
#   inflating: dataset/test/plank/plank_test_3.png
#  extracting: dataset/test/plank/plank_test_30.png
#   inflating: dataset/test/plank/plank_test_31.png
#  extracting: dataset/test/plank/plank_test_32.png
#   inflating: dataset/test/plank/plank_test_33.png
#   inflating: dataset/test/plank/plank_test_34.png
#   inflating: dataset/test/plank/plank_test_35.png
#   inflating: dataset/test/plank/plank_test_36.png
#   inflating: dataset/test/plank/plank_test_37.png
#   inflating: dataset/test/plank/plank_test_38.png
#   inflating: dataset/test/plank/plank_test_39.png
#   inflating: dataset/test/plank/plank_test_4.png
#   inflating: dataset/test/plank/plank_test_40.png
#   inflating: dataset/test/plank/plank_test_41.png
#   inflating: dataset/test/plank/plank_test_42.png
#   inflating: dataset/test/plank/plank_test_43.png
#   inflating: dataset/test/plank/plank_test_44.png
#   inflating: dataset/test/plank/plank_test_45.png
#   inflating: dataset/test/plank/plank_test_46.png
#   inflating: dataset/test/plank/plank_test_47.png
#   inflating: dataset/test/plank/plank_test_48.png
#   inflating: dataset/test/plank/plank_test_49.png
#   inflating: dataset/test/plank/plank_test_5.png
#   inflating: dataset/test/plank/plank_test_50.png
#   inflating: dataset/test/plank/plank_test_6.png
#   inflating: dataset/test/plank/plank_test_7.png
#   inflating: dataset/test/plank/plank_test_8.png
#   inflating: dataset/test/plank/plank_test_9.png
#    creating: dataset/test/seated_forward_fold/
#   inflating: dataset/test/seated_forward_fold/seated_forward_fold_test_1.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_10.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_11.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_12.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_13.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_14.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_15.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_16.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_17.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_18.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_19.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_2.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_20.png
#   inflating: dataset/test/seated_forward_fold/seated_forward_fold_test_21.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_22.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_23.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_24.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_25.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_26.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_27.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_28.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_29.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_3.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_30.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_31.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_32.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_33.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_34.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_35.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_36.png
#   inflating: dataset/test/seated_forward_fold/seated_forward_fold_test_37.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_38.png
#   inflating: dataset/test/seated_forward_fold/seated_forward_fold_test_39.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_4.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_40.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_41.png
#   inflating: dataset/test/seated_forward_fold/seated_forward_fold_test_42.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_43.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_44.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_45.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_46.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_47.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_48.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_49.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_5.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_50.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_6.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_7.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_8.png
#  extracting: dataset/test/seated_forward_fold/seated_forward_fold_test_9.png
#    creating: dataset/test/tree/
#   inflating: dataset/test/tree/tree_test_1.png
#  extracting: dataset/test/tree/tree_test_10.png
#   inflating: dataset/test/tree/tree_test_11.png
#  extracting: dataset/test/tree/tree_test_12.png
#   inflating: dataset/test/tree/tree_test_13.png
#   inflating: dataset/test/tree/tree_test_14.png
#   inflating: dataset/test/tree/tree_test_15.png
#  extracting: dataset/test/tree/tree_test_16.png
#   inflating: dataset/test/tree/tree_test_17.png
#  extracting: dataset/test/warrior2/warrior2_test_20.png
#   inflating: dataset/test/warrior2/warrior2_test_21.png
#  extracting: dataset/test/warrior2/warrior2_test_22.png
#   inflating: dataset/test/warrior2/warrior2_test_23.png
#  extracting: dataset/test/warrior2/warrior2_test_24.png
#   inflating: dataset/test/warrior2/warrior2_test_25.png
#  extracting: dataset/test/warrior2/warrior2_test_26.png
#   inflating: dataset/test/warrior2/warrior2_test_27.png
#  extracting: dataset/test/warrior2/warrior2_test_28.png
#   inflating: dataset/test/warrior2/warrior2_test_29.png
#   inflating: dataset/test/warrior2/warrior2_test_3.png
#  extracting: dataset/test/warrior2/warrior2_test_30.png
#   inflating: dataset/test/warrior2/warrior2_test_31.png
#  extracting: dataset/test/warrior2/warrior2_test_32.png
#   inflating: dataset/test/warrior2/warrior2_test_33.png
#   inflating: dataset/test/warrior2/warrior2_test_34.png
#  extracting: dataset/test/warrior2/warrior2_test_35.png
#   inflating: dataset/test/warrior2/warrior2_test_36.png
#   inflating: dataset/test/warrior2/warrior2_test_37.png
#  extracting: dataset/test/warrior2/warrior2_test_38.png
#   inflating: dataset/test/warrior2/warrior2_test_39.png
#  extracting: dataset/test/warrior2/warrior2_test_4.png
#  extracting: dataset/test/warrior2/warrior2_test_40.png
#  extracting: dataset/test/warrior2/warrior2_test_41.png
#   inflating: dataset/test/warrior2/warrior2_test_42.png
#   inflating: dataset/test/warrior2/warrior2_test_43.png
#  extracting: dataset/test/warrior2/warrior2_test_44.png
#  extracting: dataset/test/warrior2/warrior2_test_45.png
#  extracting: dataset/test/warrior2/warrior2_test_46.png
#   inflating: dataset/test/warrior2/warrior2_test_47.png
#   inflating: dataset/test/warrior2/warrior2_test_48.png
#   inflating: dataset/test/warrior2/warrior2_test_49.png
#   inflating: dataset/test/warrior2/warrior2_test_5.png
#  extracting: dataset/test/warrior2/warrior2_test_50.png
#  extracting: dataset/test/warrior2/warrior2_test_51.png
#   inflating: dataset/test/warrior2/warrior2_test_52.png
#  extracting: dataset/test/warrior2/warrior2_test_6.png
#   inflating: dataset/test/warrior2/warrior2_test_7.png
#   inflating: dataset/test/warrior2/warrior2_test_8.png
#   inflating: dataset/test/warrior2/warrior2_test_9.png
#    creating: dataset/test/wheel/
#   inflating: dataset/test/wheel/wheel_test_1.png
#   inflating: dataset/test/wheel/wheel_test_10.png
#   inflating: dataset/test/wheel/wheel_test_11.png
#   inflating: dataset/test/wheel/wheel_test_12.png
#   inflating: dataset/test/wheel/wheel_test_13.png
#   inflating: dataset/test/wheel/wheel_test_14.png
#   inflating: dataset/test/wheel/wheel_test_15.png
#   inflating: dataset/test/wheel/wheel_test_16.png
#   inflating: dataset/test/wheel/wheel_test_17.png
#   inflating: dataset/test/wheel/wheel_test_18.png
#   inflating: dataset/test/wheel/wheel_test_19.png
#   inflating: dataset/test/wheel/wheel_test_2.png
#   inflating: dataset/test/wheel/wheel_test_20.png
#   inflating: dataset/test/wheel/wheel_test_21.png
#   inflating: dataset/test/wheel/wheel_test_22.png
#   inflating: dataset/test/wheel/wheel_test_23.png
#   inflating: dataset/test/wheel/wheel_test_24.png
#   inflating: dataset/test/wheel/wheel_test_25.png
#   inflating: dataset/test/wheel/wheel_test_26.png
#   inflating: dataset/test/wheel/wheel_test_27.png
#   inflating: dataset/test/wheel/wheel_test_28.png
#   inflating: dataset/test/wheel/wheel_test_29.png
#   inflating: dataset/test/wheel/wheel_test_3.png
#   inflating: dataset/test/wheel/wheel_test_30.png
#   inflating: dataset/test/wheel/wheel_test_31.png
#   inflating: dataset/test/wheel/wheel_test_32.png
#   inflating: dataset/test/wheel/wheel_test_33.png
#   inflating: dataset/test/wheel/wheel_test_34.png
#   inflating: dataset/test/wheel/wheel_test_35.png
#   inflating: dataset/test/wheel/wheel_test_36.png
#   inflating: dataset/test/wheel/wheel_test_37.png
#   inflating: dataset/test/wheel/wheel_test_38.png
#   inflating: dataset/test/wheel/wheel_test_39.png
#   inflating: dataset/test/wheel/wheel_test_4.png
#   inflating: dataset/test/wheel/wheel_test_40.png
#   inflating: dataset/test/wheel/wheel_test_41.png
#   inflating: dataset/test/wheel/wheel_test_42.png
#   inflating: dataset/test/wheel/wheel_test_43.png
#   inflating: dataset/test/wheel/wheel_test_44.png
#   inflating: dataset/test/wheel/wheel_test_45.png
#   inflating: dataset/test/wheel/wheel_test_46.png
#   inflating: dataset/test/wheel/wheel_test_47.png
#   inflating: dataset/test/wheel/wheel_test_5.png
#   inflating: dataset/test/wheel/wheel_test_6.png
#   inflating: dataset/test/wheel/wheel_test_7.png
#   inflating: dataset/test/wheel/wheel_test_8.png
#   inflating: dataset/test/wheel/wheel_test_9.png
#    creating: dataset/train/
#    creating: dataset/train/bridge/
#   inflating: dataset/train/bridge/bridge_train_1.png
#   inflating: dataset/train/bridge/bridge_train_10.png
#   inflating: dataset/train/bridge/bridge_train_100.png
#   inflating: dataset/train/bridge/bridge_train_101.png
#   inflating: dataset/train/bridge/bridge_train_102.png
#   inflating: dataset/train/bridge/bridge_train_103.png
#   inflating: dataset/train/bridge/bridge_train_104.png
#   inflating: dataset/train/bridge/bridge_train_105.png
#   inflating: dataset/train/bridge/bridge_train_106.png
#   inflating: dataset/train/bridge/bridge_train_107.png
#   inflating: dataset/train/bridge/bridge_train_108.png
#   inflating: dataset/train/bridge/bridge_train_109.png
#   inflating: dataset/train/bridge/bridge_train_11.png
#   inflating: dataset/train/bridge/bridge_train_110.png
#   inflating: dataset/train/bridge/bridge_train_111.png
#   inflating: dataset/train/bridge/bridge_train_112.png
#   inflating: dataset/train/bridge/bridge_train_113.png
#   inflating: dataset/train/bridge/bridge_train_114.png
#   inflating: dataset/train/bridge/bridge_train_115.png
#   inflating: dataset/train/bridge/bridge_train_116.png
#   inflating: dataset/train/bridge/bridge_train_117.png
#   inflating: dataset/train/bridge/bridge_train_118.png
#   inflating: dataset/train/bridge/bridge_train_119.png
#   inflating: dataset/train/bridge/bridge_train_12.png
#   inflating: dataset/train/bridge/bridge_train_120.png
#   inflating: dataset/train/bridge/bridge_train_121.png
#   inflating: dataset/train/bridge/bridge_train_92.png
#   inflating: dataset/train/bridge/bridge_train_93.png
#   inflating: dataset/train/bridge/bridge_train_94.png
#   inflating: dataset/train/bridge/bridge_train_95.png
#   inflating: dataset/train/bridge/bridge_train_96.png
#   inflating: dataset/train/bridge/bridge_train_97.png
#   inflating: dataset/train/bridge/bridge_train_98.png
#   inflating: dataset/train/bridge/bridge_train_99.png
#    creating: dataset/train/diamond/
#  extracting: dataset/train/diamond/diamond_train_1.png
#  extracting: dataset/train/diamond/diamond_train_10.png
#  extracting: dataset/train/diamond/diamond_train_100.png
#  extracting: dataset/train/diamond/diamond_train_101.png
#  extracting: dataset/train/diamond/diamond_train_102.png
#  extracting: dataset/train/diamond/diamond_train_103.png
#  extracting: dataset/train/diamond/diamond_train_104.png
#   inflating: dataset/train/diamond/diamond_train_105.png
#  extracting: dataset/train/diamond/diamond_train_106.png
#  extracting: dataset/train/diamond/diamond_train_107.png
#  extracting: dataset/train/diamond/diamond_train_108.png
#  extracting: dataset/train/diamond/diamond_train_109.png
#  extracting: dataset/train/diamond/diamond_train_11.png
#   inflating: dataset/train/diamond/diamond_train_110.png
#  extracting: dataset/train/diamond/diamond_train_111.png
#  extracting: dataset/train/diamond/diamond_train_112.png
#  extracting: dataset/train/diamond/diamond_train_113.png
#  extracting: dataset/train/diamond/diamond_train_114.png
#   inflating: dataset/train/diamond/diamond_train_115.png
#  extracting: dataset/train/diamond/diamond_train_116.png
#  extracting: dataset/train/diamond/diamond_train_117.png
#   inflating: dataset/train/diamond/diamond_train_118.png
#  extracting: dataset/train/diamond/diamond_train_119.png
#  extracting: dataset/train/diamond/diamond_train_12.png
#  extracting: dataset/train/diamond/diamond_train_120.png
#  extracting: dataset/train/diamond/diamond_train_121.png
#  extracting: dataset/train/diamond/diamond_train_122.png
#  extracting: dataset/train/diamond/diamond_train_123.png
#  extracting: dataset/train/diamond/diamond_train_124.png
#  extracting: dataset/train/diamond/diamond_train_125.png
#  extracting: dataset/train/diamond/diamond_train_126.png
#  extracting: dataset/train/diamond/diamond_train_127.png
#  extracting: dataset/train/diamond/diamond_train_128.png
#  extracting: dataset/train/diamond/diamond_train_129.png
#  extracting: dataset/train/diamond/diamond_train_13.png
#   inflating: dataset/train/diamond/diamond_train_130.png
#  extracting: dataset/train/diamond/diamond_train_131.png
#  extracting: dataset/train/diamond/diamond_train_132.png
#   inflating: dataset/train/diamond/diamond_train_133.png
#  extracting: dataset/train/diamond/diamond_train_134.png
#  extracting: dataset/train/diamond/diamond_train_135.png
#  extracting: dataset/train/diamond/diamond_train_136.png
#  extracting: dataset/train/diamond/diamond_train_137.png
#  extracting: dataset/train/diamond/diamond_train_138.png
#  extracting: dataset/train/diamond/diamond_train_139.png
#  extracting: dataset/train/diamond/diamond_train_14.png
#  extracting: dataset/train/diamond/diamond_train_140.png
#  extracting: dataset/train/diamond/diamond_train_141.png
#  extracting: dataset/train/diamond/diamond_train_142.png
#   inflating: dataset/train/diamond/diamond_train_143.png
#  extracting: dataset/train/diamond/diamond_train_144.png
#  extracting: dataset/train/diamond/diamond_train_145.png
#  extracting: dataset/train/diamond/diamond_train_146.png
#   inflating: dataset/train/diamond/diamond_train_147.png
#  extracting: dataset/train/diamond/diamond_train_148.png
#  extracting: dataset/train/diamond/diamond_train_149.png
#  extracting: dataset/train/diamond/diamond_train_15.png
#  extracting: dataset/train/diamond/diamond_train_150.png
#  extracting: dataset/train/diamond/diamond_train_151.png
#  extracting: dataset/train/diamond/diamond_train_152.png
#  extracting: dataset/train/diamond/diamond_train_153.png
#  extracting: dataset/train/diamond/diamond_train_154.png
#   inflating: dataset/train/diamond/diamond_train_155.png
#   inflating: dataset/train/diamond/diamond_train_156.png
#  extracting: dataset/train/diamond/diamond_train_157.png
#  extracting: dataset/train/diamond/diamond_train_158.png
#  extracting: dataset/train/diamond/diamond_train_159.png
#  extracting: dataset/train/diamond/diamond_train_16.png
#  extracting: dataset/train/diamond/diamond_train_160.png
#  extracting: dataset/train/diamond/diamond_train_161.png
#   inflating: dataset/train/diamond/diamond_train_162.png
#  extracting: dataset/train/diamond/diamond_train_163.png
#  extracting: dataset/train/diamond/diamond_train_164.png
#  extracting: dataset/train/diamond/diamond_train_165.png
#  extracting: dataset/train/diamond/diamond_train_166.png
#  extracting: dataset/train/diamond/diamond_train_167.png
#  extracting: dataset/train/diamond/diamond_train_168.png
#  extracting: dataset/train/diamond/diamond_train_169.png
#  extracting: dataset/train/diamond/diamond_train_17.png
#  extracting: dataset/train/diamond/diamond_train_170.png
#  extracting: dataset/train/diamond/diamond_train_171.png
#  extracting: dataset/train/diamond/diamond_train_172.png
#  extracting: dataset/train/diamond/diamond_train_173.png
#  extracting: dataset/train/diamond/diamond_train_174.png
#  extracting: dataset/train/diamond/diamond_train_175.png
#  extracting: dataset/train/diamond/diamond_train_176.png
#  extracting: dataset/train/diamond/diamond_train_177.png
#  extracting: dataset/train/diamond/diamond_train_178.png
#  extracting: dataset/train/diamond/diamond_train_179.png
#  extracting: dataset/train/diamond/diamond_train_18.png
#  extracting: dataset/train/diamond/diamond_train_180.png
# ...
#  extracting: dataset/train/warrior2/warrior2_train_196.png
#  extracting: dataset/train/warrior2/warrior2_train_197.png
#  extracting: dataset/train/warrior2/warrior2_train_198.png
#  extracting: dataset/train/warrior2/warrior2_train_199.png
#  extracting: dataset/train/warrior2/warrior2_train_2.png
#  extracting: dataset/train/warrior2/warrior2_train_20.png
#  extracting: dataset/train/warrior2/warrior2_train_200.png
#  extracting: dataset/train/warrior2/warrior2_train_201.png
#  extracting: dataset/train/warrior2/warrior2_train_202.png
#  extracting: dataset/train/warrior2/warrior2_train_203.png
#   inflating: dataset/train/warrior2/warrior2_train_204.png
#   inflating: dataset/train/warrior2/warrior2_train_205.png
#   inflating: dataset/train/warrior2/warrior2_train_21.png
#   inflating: dataset/train/warrior2/warrior2_train_22.png
#   inflating: dataset/train/warrior2/warrior2_train_23.png
#  extracting: dataset/train/warrior2/warrior2_train_24.png
#   inflating: dataset/train/wheel/wheel_train_65.png
#   inflating: dataset/train/wheel/wheel_train_66.png
#   inflating: dataset/train/wheel/wheel_train_67.png
#   inflating: dataset/train/wheel/wheel_train_68.png
#   inflating: dataset/train/wheel/wheel_train_69.png
#   inflating: dataset/train/wheel/wheel_train_7.png
#   inflating: dataset/train/wheel/wheel_train_70.png
#   inflating: dataset/train/wheel/wheel_train_71.png
#   inflating: dataset/train/wheel/wheel_train_72.png
#   inflating: dataset/train/wheel/wheel_train_73.png
#   inflating: dataset/train/wheel/wheel_train_74.png
#   inflating: dataset/train/wheel/wheel_train_75.png
#   inflating: dataset/train/wheel/wheel_train_76.png
#   inflating: dataset/train/wheel/wheel_train_77.png
#   inflating: dataset/train/wheel/wheel_train_78.png
#   inflating: dataset/train/wheel/wheel_train_79.png
#   inflating: dataset/train/wheel/wheel_train_8.png
#   inflating: dataset/train/wheel/wheel_train_80.png
#   inflating: dataset/train/wheel/wheel_train_81.png
#   inflating: dataset/train/wheel/wheel_train_82.png
#   inflating: dataset/train/wheel/wheel_train_83.png
#   inflating: dataset/train/wheel/wheel_train_84.png
#   inflating: dataset/train/wheel/wheel_train_85.png
#   inflating: dataset/train/wheel/wheel_train_86.png
#   inflating: dataset/train/wheel/wheel_train_87.png
#   inflating: dataset/train/wheel/wheel_train_88.png
#   inflating: dataset/train/wheel/wheel_train_89.png
#   inflating: dataset/train/wheel/wheel_train_9.png
#   inflating: dataset/train/wheel/wheel_train_90.png
#   inflating: dataset/train/wheel/wheel_train_91.png
#   inflating: dataset/train/wheel/wheel_train_92.png
#   inflating: dataset/train/wheel/wheel_train_93.png
#   inflating: dataset/train/wheel/wheel_train_94.png
#   inflating: dataset/train/wheel/wheel_train_95.png
#   inflating: dataset/train/wheel/wheel_train_96.png
#   inflating: dataset/train/wheel/wheel_train_97.png
#   inflating: dataset/train/wheel/wheel_train_98.png
#   inflating: dataset/train/wheel/wheel_train_99.png

# %%
# !pip install mediapipe
# !pip install ultralytics
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.8/34.8 MB 39.5 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.23)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.25.2)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.8.0.76)
# Requirement already satisfied: protobuf<4,>=3.11 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.20.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.10 sounddevice-0.4.6
# Collecting ultralytics
#   Downloading ultralytics-8.1.20-py3-none-any.whl (716 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.3/716.3 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.1.20

# %%
import numpy as np
import pandas as pd
import os
import cv2
import csv
import itertools
import sys
import tempfile
import tqdm
import zipfile
import pickle
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import seaborn as sns
import mediapipe as mp
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
from pydantic import BaseModel
from PIL import Image
import glob

# %%
dataset_name = 'Yoga-10 Dataset'
train_dir = '/content/dataset/train'
test_dir = '/content/dataset/test'
path_to_save = '/content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/custom_dataset/'

# %% [markdown]
# # Xception Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)  # Automatically detects image format
        img = tf.image.resize(img, (299, 299))  # Resize image to match Xception input shape
        img = tf.keras.applications.xception.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue

    return df

def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df

train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Error loading image /content/dataset/train/downdog/downdog_train_197.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/train/downdog/downdog_train_41.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/train/downdog/downdog_train_79.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/test/downdog/downdog_test_39.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/test/downdog/downdog_test_52.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# (2084, 299, 299, 3)
# (524, 299, 299, 3)
# (2084, 10)
# (524, 10)

# %%
xception_model = tf.keras.applications.Xception(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
xception_model.trainable = False

model = tf.keras.Sequential([
    xception_model,
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.6),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.6),
    keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer= keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 5s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  flatten (Flatten)           (None, 204800)            0
#
#  dense (Dense)               (None, 256)               52429056
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  batch_normalization_5 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 73308914 (279.65 MB)
# Trainable params: 52446794 (200.07 MB)
# Non-trainable params: 20862120 (79.58 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_Xception.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 66/66 [==============================] - ETA: 0s - loss: 2.0520 - accuracy: 0.3882
# Epoch 1: val_accuracy improved from -inf to 0.80916, saving model to weights_Xception.keras
# 66/66 [==============================] - 40s 413ms/step - loss: 2.0520 - accuracy: 0.3882 - val_loss: 0.6108 - val_accuracy: 0.8092
# Epoch 2/50
# 65/66 [============================>.] - ETA: 0s - loss: 1.1245 - accuracy: 0.6226
# Epoch 2: val_accuracy improved from 0.80916 to 0.89122, saving model to weights_Xception.keras
# 66/66 [==============================] - 22s 338ms/step - loss: 1.1234 - accuracy: 0.6233 - val_loss: 0.3768 - val_accuracy: 0.8912
# Epoch 3/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.7741 - accuracy: 0.7529
# Epoch 3: val_accuracy improved from 0.89122 to 0.92176, saving model to weights_Xception.keras
# 66/66 [==============================] - 23s 349ms/step - loss: 0.7733 - accuracy: 0.7529 - val_loss: 0.2731 - val_accuracy: 0.9218
# Epoch 4/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.5690 - accuracy: 0.8212
# Epoch 4: val_accuracy improved from 0.92176 to 0.94847, saving model to weights_Xception.keras
# 66/66 [==============================] - 23s 345ms/step - loss: 0.5688 - accuracy: 0.8215 - val_loss: 0.2078 - val_accuracy: 0.9485
# Epoch 5/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.4123 - accuracy: 0.8750
# Epoch 5: val_accuracy improved from 0.94847 to 0.95038, saving model to weights_Xception.keras
# 66/66 [==============================] - 23s 342ms/step - loss: 0.4141 - accuracy: 0.8743 - val_loss: 0.1660 - val_accuracy: 0.9504
# Epoch 6/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.3683 - accuracy: 0.8875
# Epoch 6: val_accuracy improved from 0.95038 to 0.96374, saving model to weights_Xception.keras
# 66/66 [==============================] - 22s 341ms/step - loss: 0.3700 - accuracy: 0.8872 - val_loss: 0.1416 - val_accuracy: 0.9637
# Epoch 7/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.2998 - accuracy: 0.9125
# 66/66 [==============================] - 20s 298ms/step - loss: 0.0779 - accuracy: 0.9755 - val_loss: 0.0740 - val_accuracy: 0.9790
# Epoch 28/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0836 - accuracy: 0.9764
# Epoch 28: val_accuracy did not improve from 0.98282
# 66/66 [==============================] - 20s 298ms/step - loss: 0.0835 - accuracy: 0.9765 - val_loss: 0.0743 - val_accuracy: 0.9790
# Epoch 29/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0587 - accuracy: 0.9861
# Epoch 29: val_accuracy did not improve from 0.98282
# 66/66 [==============================] - 20s 298ms/step - loss: 0.0588 - accuracy: 0.9861 - val_loss: 0.0683 - val_accuracy: 0.9828
# Epoch 30/50
# 66/66 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9880
# Epoch 30: val_accuracy did not improve from 0.98282
# 66/66 [==============================] - 20s 298ms/step - loss: 0.0503 - accuracy: 0.9880 - val_loss: 0.0745 - val_accuracy: 0.9752

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of Xception with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_Xception.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of Xception with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_Xception.png')
plt.show()

# %%
model = tf.keras.models.load_model("weights_Xception.keras")
model.evaluate(X_test, y_test)
# Out:
# 17/17 [==============================] - 5s 219ms/step - loss: 0.0738 - accuracy: 0.9828
# [0.07375642657279968, 0.982824444770813]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of Xception with {dataset_name}')
plt.savefig('Confusion_Matrix_Xception.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 17/17 [==============================] - 5s 230ms/step
#                      precision    recall  f1-score   support
#
#           Padmasana       1.00      1.00      1.00        60
#              bridge       1.00      0.98      0.99        53
#             diamond       0.94      1.00      0.97        50
#             downdog       0.93      0.96      0.95        54
#             goddess       1.00      0.98      0.99        50
#               plank       1.00      0.98      0.99        50
# seated_forward_fold       1.00      1.00      1.00        50
#                tree       1.00      1.00      1.00        58
#            warrior2       0.98      0.96      0.97        52
#               wheel       0.98      0.96      0.97        47
#
#            accuracy                           0.98       524
#           macro avg       0.98      0.98      0.98       524
#        weighted avg       0.98      0.98      0.98       524

# %%
import zipfile
import os
import pickle

with open('history_for_Xception.pkl', 'wb') as f:
    pickle.dump(history, f)

def create_zip(files_to_zip, zip_filename):
    with zipfile.ZipFile(zip_filename, 'w') as zipf:
        for file in files_to_zip:
            # Add the file to the zip archive
            zipf.write(file, os.path.basename(file))

# Example: List of files to be included in the zip
files_to_zip = ['Accuracy_Graph_Xception.png', 'Loss_Graph_Xception.png', 'history_for_Xception.pkl', 'weights_Xception.keras', 'Confusion_Matrix_Xception.png']

# Specify the name of the zip file
zip_filename = 'results_Xception.zip'

# Create the zip file
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # EfficientNetB0 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)
        img = tf.image.resize(img, (224, 224))
        img = tf.keras.applications.efficientnet.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df

def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Error loading image /content/dataset/train/downdog/downdog_train_197.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/train/downdog/downdog_train_41.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/train/downdog/downdog_train_79.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/test/downdog/downdog_test_39.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/test/downdog/downdog_test_52.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# (2084, 224, 224, 3)
# (524, 224, 224, 3)
# (2084, 10)
# (524, 10)

# %%
efficient_net_model = tf.keras.applications.EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
efficient_net_model.trainable = False

model = tf.keras.Sequential([
    efficient_net_model,
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer= keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 7, 7, 1280)        4049571
#  )
#
#  flatten_1 (Flatten)         (None, 62720)             0
#
#  dense_3 (Dense)             (None, 256)               16056576
#
#  batch_normalization_6 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 64)                16448
#
#  batch_normalization_7 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 20124525 (76.77 MB)
# Trainable params: 16074314 (61.32 MB)
# Non-trainable params: 4050211 (15.45 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_EfficientNetB0.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 66/66 [==============================] - ETA: 0s - loss: 1.2112 - accuracy: 0.6252
# Epoch 1: val_accuracy improved from -inf to 0.92557, saving model to weights_EfficientNetB0.keras
# 66/66 [==============================] - 20s 179ms/step - loss: 1.2112 - accuracy: 0.6252 - val_loss: 0.2091 - val_accuracy: 0.9256
# Epoch 2/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.4334 - accuracy: 0.8740
# Epoch 2: val_accuracy improved from 0.92557 to 0.96947, saving model to weights_EfficientNetB0.keras
# 66/66 [==============================] - 7s 111ms/step - loss: 0.4328 - accuracy: 0.8743 - val_loss: 0.1003 - val_accuracy: 0.9695
# Epoch 3/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.2843 - accuracy: 0.9240
# Epoch 3: val_accuracy improved from 0.96947 to 0.97710, saving model to weights_EfficientNetB0.keras
# 66/66 [==============================] - 7s 104ms/step - loss: 0.2864 - accuracy: 0.9232 - val_loss: 0.0854 - val_accuracy: 0.9771
# Epoch 4/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.1819 - accuracy: 0.9591
# Epoch 4: val_accuracy improved from 0.97710 to 0.98092, saving model to weights_EfficientNetB0.keras
# 66/66 [==============================] - 7s 104ms/step - loss: 0.1818 - accuracy: 0.9592 - val_loss: 0.0655 - val_accuracy: 0.9809
# Epoch 5/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.1466 - accuracy: 0.9663
# Epoch 5: val_accuracy did not improve from 0.98092
# 66/66 [==============================] - 5s 79ms/step - loss: 0.1472 - accuracy: 0.9659 - val_loss: 0.0685 - val_accuracy: 0.9752
# Epoch 6/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.1056 - accuracy: 0.9764
# Epoch 6: val_accuracy did not improve from 0.98092
# 66/66 [==============================] - 5s 80ms/step - loss: 0.1061 - accuracy: 0.9760 - val_loss: 0.0674 - val_accuracy: 0.9790
# Epoch 7/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0809 - accuracy: 0.9841
# Epoch 7: val_accuracy did not improve from 0.98092
# 66/66 [==============================] - 5s 79ms/step - loss: 0.0807 - accuracy: 0.9842 - val_loss: 0.0671 - val_accuracy: 0.9790
# Epoch 8/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0665 - accuracy: 0.9894
# Epoch 8: val_accuracy did not improve from 0.98092
# 66/66 [==============================] - 5s 79ms/step - loss: 0.0669 - accuracy: 0.9894 - val_loss: 0.0626 - val_accuracy: 0.9809
# Epoch 9/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0592 - accuracy: 0.9899
# Epoch 9: val_accuracy did not improve from 0.98092
# 66/66 [==============================] - 5s 79ms/step - loss: 0.0592 - accuracy: 0.9899 - val_loss: 0.0543 - val_accuracy: 0.9809
# Epoch 10/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9933
# Epoch 10: val_accuracy did not improve from 0.98092
# 66/66 [==============================] - 5s 79ms/step - loss: 0.0515 - accuracy: 0.9933 - val_loss: 0.0540 - val_accuracy: 0.9790
# Epoch 11/50
# Epoch 21: val_accuracy did not improve from 0.98664
# 66/66 [==============================] - 5s 79ms/step - loss: 0.0301 - accuracy: 0.9909 - val_loss: 0.0534 - val_accuracy: 0.9790
# Epoch 22/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0358 - accuracy: 0.9928
# Epoch 22: val_accuracy did not improve from 0.98664
# 66/66 [==============================] - 5s 79ms/step - loss: 0.0361 - accuracy: 0.9928 - val_loss: 0.0596 - val_accuracy: 0.9790
# Epoch 23/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9880
# Epoch 23: val_accuracy did not improve from 0.98664
# 66/66 [==============================] - 5s 79ms/step - loss: 0.0424 - accuracy: 0.9880 - val_loss: 0.0461 - val_accuracy: 0.9847
# Epoch 24/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0297 - accuracy: 0.9923
# Epoch 24: val_accuracy did not improve from 0.98664
# 66/66 [==============================] - 5s 79ms/step - loss: 0.0297 - accuracy: 0.9923 - val_loss: 0.0404 - val_accuracy: 0.9847

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of EfficientNetB0 with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_EfficientNetB0.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of EfficientNetB0 with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_EfficientNetB0.png')
plt.show()

# %%
model = tf.keras.models.load_model('weights_EfficientNetB0.keras')
model.evaluate(X_test, y_test)
# Out:
# 17/17 [==============================] - 4s 61ms/step - loss: 0.0540 - accuracy: 0.9866
# [0.05404011532664299, 0.9866412281990051]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of EfficientNetB0 with {dataset_name}')
plt.savefig('Confusion_Matrix_EfficientNetB0.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 17/17 [==============================] - 2s 60ms/step
#                      precision    recall  f1-score   support
#
#           Padmasana       0.98      0.98      0.98        60
#              bridge       0.96      1.00      0.98        53
#             diamond       1.00      0.98      0.99        50
#             downdog       1.00      1.00      1.00        54
#             goddess       0.98      0.96      0.97        50
#               plank       1.00      1.00      1.00        50
# seated_forward_fold       1.00      0.98      0.99        50
#                tree       0.97      1.00      0.98        58
#            warrior2       0.98      0.98      0.98        52
#               wheel       1.00      0.98      0.99        47
#
#            accuracy                           0.99       524
#           macro avg       0.99      0.99      0.99       524
#        weighted avg       0.99      0.99      0.99       524

# %%
with open('history_for_EfficientNetB0.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_EfficientNetB0.keras', 'history_for_EfficientNetB0.pkl', 'Confusion_Matrix_EfficientNetB0.png', 'Loss_Graph_EfficientNetB0.png', 'Accuracy_Graph_EfficientNetB0.png']
zip_filename = 'results_EfficientNetB0.zip'

create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # Inception-V3

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)
        img = tf.image.resize(img, (224, 224))
        img = tf.keras.applications.inception_v3.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df


def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Error loading image /content/dataset/train/downdog/downdog_train_197.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/train/downdog/downdog_train_41.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/train/downdog/downdog_train_79.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/test/downdog/downdog_test_39.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/test/downdog/downdog_test_52.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# (2084, 224, 224, 3)
# (524, 224, 224, 3)
# (2084, 10)
# (524, 10)

# %%
inception_model = tf.keras.applications.InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
inception_model.trainable = False

model = tf.keras.Sequential([
    inception_model,
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer= keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 5s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten_2 (Flatten)         (None, 51200)             0
#
#  dense_6 (Dense)             (None, 256)               13107456
#
#  batch_normalization_102 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 64)                16448
#
#  batch_normalization_103 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 34928618 (133.24 MB)
# Trainable params: 13125194 (50.07 MB)
# Non-trainable params: 21803424 (83.17 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_InceptionV3.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 66/66 [==============================] - ETA: 0s - loss: 1.4572 - accuracy: 0.5465
# Epoch 1: val_accuracy improved from -inf to 0.74809, saving model to weights_InceptionV3.keras
# 66/66 [==============================] - 23s 217ms/step - loss: 1.4572 - accuracy: 0.5465 - val_loss: 0.7693 - val_accuracy: 0.7481
# Epoch 2/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.6602 - accuracy: 0.7889
# Epoch 2: val_accuracy improved from 0.74809 to 0.94466, saving model to weights_InceptionV3.keras
# 66/66 [==============================] - 8s 120ms/step - loss: 0.6598 - accuracy: 0.7893 - val_loss: 0.2454 - val_accuracy: 0.9447
# Epoch 3/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.4208 - accuracy: 0.8745
# Epoch 3: val_accuracy improved from 0.94466 to 0.95038, saving model to weights_InceptionV3.keras
# 66/66 [==============================] - 8s 129ms/step - loss: 0.4214 - accuracy: 0.8748 - val_loss: 0.2042 - val_accuracy: 0.9504
# Epoch 4/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.3074 - accuracy: 0.9178
# Epoch 4: val_accuracy did not improve from 0.95038
# 66/66 [==============================] - 6s 90ms/step - loss: 0.3077 - accuracy: 0.9179 - val_loss: 0.1812 - val_accuracy: 0.9427
# Epoch 5/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.2345 - accuracy: 0.9370
# Epoch 5: val_accuracy did not improve from 0.95038
# 66/66 [==============================] - 6s 89ms/step - loss: 0.2357 - accuracy: 0.9367 - val_loss: 0.1490 - val_accuracy: 0.9504
# Epoch 6/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.2022 - accuracy: 0.9500
# Epoch 6: val_accuracy improved from 0.95038 to 0.95420, saving model to weights_InceptionV3.keras
# 66/66 [==============================] - 8s 118ms/step - loss: 0.2023 - accuracy: 0.9501 - val_loss: 0.1700 - val_accuracy: 0.9542
# Epoch 7/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.1378 - accuracy: 0.9736
# Epoch 7: val_accuracy improved from 0.95420 to 0.95802, saving model to weights_InceptionV3.keras
# 66/66 [==============================] - 8s 120ms/step - loss: 0.1377 - accuracy: 0.9736 - val_loss: 0.1334 - val_accuracy: 0.9580
# Epoch 8/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9769
# Epoch 8: val_accuracy improved from 0.95802 to 0.96565, saving model to weights_InceptionV3.keras
# 66/66 [==============================] - 8s 118ms/step - loss: 0.1081 - accuracy: 0.9760 - val_loss: 0.1259 - val_accuracy: 0.9656
# Epoch 9/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.1270 - accuracy: 0.9678
# Epoch 9: val_accuracy did not improve from 0.96565
# 66/66 [==============================] - 6s 89ms/step - loss: 0.1271 - accuracy: 0.9679 - val_loss: 0.1251 - val_accuracy: 0.9656
# Epoch 10/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0928 - accuracy: 0.9803
# Epoch 10: val_accuracy improved from 0.96565 to 0.97137, saving model to weights_InceptionV3.keras
# 66/66 [==============================] - 8s 116ms/step - loss: 0.0931 - accuracy: 0.9803 - val_loss: 0.1237 - val_accuracy: 0.9714
# Epoch 21: val_accuracy did not improve from 0.97328
# 66/66 [==============================] - 6s 89ms/step - loss: 0.0721 - accuracy: 0.9794 - val_loss: 0.1903 - val_accuracy: 0.9427
# Epoch 22/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0652 - accuracy: 0.9822
# Epoch 22: val_accuracy did not improve from 0.97328
# 66/66 [==============================] - 6s 89ms/step - loss: 0.0668 - accuracy: 0.9813 - val_loss: 0.1192 - val_accuracy: 0.9637

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of InceptionV3 with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_InceptionV3.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of InceptionV3 with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_InceptionV3.png')
plt.show()

# %%
# model = tf.keras.models.load_model('weights_InceptionV3.keras')
model.evaluate(X_test, y_test)
# Out:
# 17/17 [==============================] - 1s 70ms/step - loss: 0.1192 - accuracy: 0.9637
# [0.11915075778961182, 0.9637404680252075]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of Inception-V3 with {dataset_name}')
plt.savefig('Confusion_Matrix_InceptionV3.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 17/17 [==============================] - 2s 71ms/step
#                      precision    recall  f1-score   support
#
#           Padmasana       0.92      0.98      0.95        60
#              bridge       0.96      0.98      0.97        53
#             diamond       0.96      0.92      0.94        50
#             downdog       0.90      0.98      0.94        54
#             goddess       0.98      0.94      0.96        50
#               plank       0.98      0.96      0.97        50
# seated_forward_fold       1.00      0.96      0.98        50
#                tree       0.98      1.00      0.99        58
#            warrior2       0.98      0.98      0.98        52
#               wheel       1.00      0.91      0.96        47
#
#            accuracy                           0.96       524
#           macro avg       0.97      0.96      0.96       524
#        weighted avg       0.97      0.96      0.96       524

# %%
with open('history_InceptionV3.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['Accuracy_Graph_InceptionV3.png', 'Loss_Graph_InceptionV3.png', 'Confusion_Matrix_InceptionV3.png', 'history_InceptionV3.pkl', 'weights_InceptionV3.keras']
zip_filename = "results_InceptionV3.zip"
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # MobileNet V2 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)
        img = tf.image.resize(img, (224, 224))
        img = tf.keras.applications.mobilenet_v2.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df


def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Error loading image /content/dataset/train/downdog/downdog_train_197.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/train/downdog/downdog_train_41.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/train/downdog/downdog_train_79.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/test/downdog/downdog_test_39.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/test/downdog/downdog_test_52.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# (2084, 224, 224, 3)
# (524, 224, 224, 3)
# (2084, 10)
# (524, 10)

# %%
mobile_net = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
mobile_net.trainable = False

model = tf.keras.Sequential([
    mobile_net,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 2s 0us/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  flatten_3 (Flatten)         (None, 62720)             0
#
#  dense_9 (Dense)             (None, 256)               16056576
#
#  batch_normalization_104 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 64)                16448
#
#  batch_normalization_105 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 18332938 (69.93 MB)
# Trainable params: 16074314 (61.32 MB)
# Non-trainable params: 2258624 (8.62 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_MobileNetV2.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 66/66 [==============================] - ETA: 0s - loss: 1.3277 - accuracy: 0.5840
# Epoch 1: val_accuracy improved from -inf to 0.87023, saving model to weights_MobileNetV2.keras
# 66/66 [==============================] - 13s 115ms/step - loss: 1.3277 - accuracy: 0.5840 - val_loss: 0.3872 - val_accuracy: 0.8702
# Epoch 2/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.4926 - accuracy: 0.8519
# Epoch 2: val_accuracy improved from 0.87023 to 0.94847, saving model to weights_MobileNetV2.keras
# 66/66 [==============================] - 5s 76ms/step - loss: 0.4957 - accuracy: 0.8512 - val_loss: 0.1601 - val_accuracy: 0.9485
# Epoch 3/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.3473 - accuracy: 0.9087

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of MobileNetV2 with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_MobileNetV2.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of MobileNetV2 with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_MobileNetV2.png')
plt.show()

# %%
model = tf.keras.models.load_model("weights_MobileNetV2.keras")
model.evaluate(X_test, y_test)
# Out:
# 17/17 [==============================] - 2s 41ms/step - loss: 0.0588 - accuracy: 0.9866
# [0.058795247226953506, 0.9866412281990051]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of MobileNetV2 with {dataset_name}')
plt.savefig('Confusion_Matrix_MobileNetV2.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 17/17 [==============================] - 1s 40ms/step
#                      precision    recall  f1-score   support
#
#           Padmasana       0.98      0.98      0.98        60
#              bridge       0.98      0.98      0.98        53
#             diamond       0.98      0.98      0.98        50
#             downdog       0.96      1.00      0.98        54
#             goddess       1.00      0.96      0.98        50
#               plank       1.00      0.96      0.98        50
# seated_forward_fold       1.00      1.00      1.00        50
#                tree       0.97      1.00      0.98        58
#            warrior2       1.00      1.00      1.00        52
#               wheel       1.00      1.00      1.00        47
#
#            accuracy                           0.99       524
#           macro avg       0.99      0.99      0.99       524
#        weighted avg       0.99      0.99      0.99       524

# %%
with open('history_for_MoblieNetV2.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_MobileNetV2.keras', 'history_for_MoblieNetV2.pkl', 'Loss_Graph_MobileNetV2.png', 'Accuracy_Graph_MobileNetV2.png', 'Confusion_Matrix_MobileNetV2.png']
zip_filename = 'results_MobileNetV2.zip'
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # ResNet50 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)
        img = tf.image.resize(img, (224, 224))
        img = tf.keras.applications.resnet50.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df


def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Error loading image /content/dataset/train/downdog/downdog_train_197.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/train/downdog/downdog_train_41.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/train/downdog/downdog_train_79.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/test/downdog/downdog_test_39.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/test/downdog/downdog_test_52.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# (2084, 224, 224, 3)
# (524, 224, 224, 3)
# (2084, 10)
# (524, 10)

# %%
resnet_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
resnet_model.trainable = False

model = tf.keras.Sequential([
    resnet_model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_4 (Flatten)         (None, 100352)            0
#
#  dense_12 (Dense)            (None, 256)               25690368
#
#  batch_normalization_106 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 64)                16448
#
#  batch_normalization_107 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 49296458 (188.05 MB)
# Trainable params: 25708106 (98.07 MB)
# Non-trainable params: 23588352 (89.98 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_ResNet50.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 66/66 [==============================] - ETA: 0s - loss: 1.2309 - accuracy: 0.6118
# Epoch 1: val_accuracy improved from -inf to 0.90840, saving model to weights_ResNet50.keras
# 66/66 [==============================] - 22s 217ms/step - loss: 1.2309 - accuracy: 0.6118 - val_loss: 0.3463 - val_accuracy: 0.9084
# Epoch 2/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.4497 - accuracy: 0.8774
# Epoch 2: val_accuracy improved from 0.90840 to 0.96565, saving model to weights_ResNet50.keras
# 66/66 [==============================] - 10s 157ms/step - loss: 0.4496 - accuracy: 0.8772 - val_loss: 0.1373 - val_accuracy: 0.9656
# Epoch 3/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.2423 - accuracy: 0.9409
# Epoch 3: val_accuracy improved from 0.96565 to 0.97328, saving model to weights_ResNet50.keras
# Epoch 14/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.9942
# Epoch 14: val_accuracy did not improve from 0.98473
# 66/66 [==============================] - 8s 125ms/step - loss: 0.0298 - accuracy: 0.9938 - val_loss: 0.0626 - val_accuracy: 0.9733
# Epoch 15/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0329 - accuracy: 0.9937
# Epoch 15: val_accuracy did not improve from 0.98473
# 66/66 [==============================] - 8s 125ms/step - loss: 0.0329 - accuracy: 0.9938 - val_loss: 0.0759 - val_accuracy: 0.9752
# Epoch 16/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0266 - accuracy: 0.9957
# Epoch 16: val_accuracy did not improve from 0.98473
# 66/66 [==============================] - 8s 125ms/step - loss: 0.0266 - accuracy: 0.9957 - val_loss: 0.0755 - val_accuracy: 0.9733
# Epoch 17/50
# 65/66 [============================>.] - ETA: 0s - loss: 0.0209 - accuracy: 0.9966
# Epoch 17: val_accuracy did not improve from 0.98473
# 66/66 [==============================] - 8s 124ms/step - loss: 0.0209 - accuracy: 0.9966 - val_loss: 0.0596 - val_accuracy: 0.9733

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of ResNet50 with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_ResNet50.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of ResNet50 with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_ResNet50.png')
plt.show()

# %%
model = keras.models.load_model('weights_ResNet50.keras')
model.evaluate(X_test, y_test)
# Out:
# 17/17 [==============================] - 3s 95ms/step - loss: 0.0576 - accuracy: 0.9847
# [0.057568490505218506, 0.9847328066825867]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of ResNet50 with {dataset_name}')
plt.savefig('Confusion_Matrix_ResNet50.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 17/17 [==============================] - 2s 93ms/step
#                      precision    recall  f1-score   support
#
#           Padmasana       0.98      0.98      0.98        60
#              bridge       0.91      1.00      0.95        53
#             diamond       1.00      0.98      0.99        50
#             downdog       0.96      1.00      0.98        54
#             goddess       1.00      1.00      1.00        50
#               plank       1.00      1.00      1.00        50
# seated_forward_fold       1.00      0.98      0.99        50
#                tree       1.00      1.00      1.00        58
#            warrior2       1.00      1.00      1.00        52
#               wheel       1.00      0.89      0.94        47
#
#            accuracy                           0.98       524
#           macro avg       0.99      0.98      0.98       524
#        weighted avg       0.99      0.98      0.98       524

# %%
with open('history_for_ResNet50.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['history_for_ResNet50.pkl', 'weights_ResNet50.keras', 'Loss_Graph_ResNet50.png', 'Accuracy_Graph_ResNet50.png', 'Confusion_Matrix_ResNet50.png']
zip_filename = 'results_ResNet50.zip'

create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # Vgg16 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)
        img = tf.image.resize(img, (224, 224))
        img = tf.keras.applications.vgg16.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df


def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Error loading image /content/dataset/train/downdog/downdog_train_197.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/train/downdog/downdog_train_41.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/train/downdog/downdog_train_79.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/test/downdog/downdog_test_39.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# Error loading image /content/dataset/test/downdog/downdog_test_52.png: {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP required. [Op:DecodeImage] name:
# (2084, 224, 224, 3)
# (524, 224, 224, 3)
# (2084, 10)
# (524, 10)

# %%
vgg_model = keras.applications.vgg16.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
vgg_model.trainable = False

model = tf.keras.Sequential([
    vgg_model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_5 (Flatten)         (None, 25088)             0
#
#  dense_15 (Dense)            (None, 256)               6422784
#
#  batch_normalization_108 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 64)                16448
#
#  batch_normalization_109 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 21155850 (80.70 MB)
# Trainable params: 6440522 (24.57 MB)
# Non-trainable params: 14715328 (56.13 MB)
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = 'weights_Vgg16.keras'
checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_
# Epoch 11: val_accuracy did not improve from 0.98473
# 66/66 [==============================] - 10s 158ms/step - loss: 0.0341 - accuracy: 0.9957 - val_loss: 0.0584 - val_accuracy: 0.9828
# Epoch 12/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0329 - accuracy: 0.9962
# Epoch 12: val_accuracy did not improve from 0.98473
# 66/66 [==============================] - 10s 157ms/step - loss: 0.0330 - accuracy: 0.9962 - val_loss: 0.0569 - val_accuracy: 0.9847
# Epoch 13/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0326 - accuracy: 0.9952
# Epoch 13: val_accuracy did not improve from 0.98473
# 66/66 [==============================] - 10s 157ms/step - loss: 0.0341 - accuracy: 0.9942 - val_loss: 0.0679 - val_accuracy: 0.9809
# Epoch 14/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9928
# Epoch 14: val_accuracy did not improve from 0.98473
# 66/66 [==============================] - 10s 158ms/step - loss: 0.0441 - accuracy: 0.9928 - val_loss: 0.0764 - val_accuracy: 0.9790
# Epoch 15/100
# 65/66 [============================>.] - ETA: 0s - loss: 0.0385 - accuracy: 0.9918
# Epoch 15: val_accuracy did not improve from 0.98473
# 66/66 [==============================] - 10s 158ms/step - loss: 0.0387 - accuracy: 0.9918 - val_loss: 0.0676 - val_accuracy: 0.9828

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of Vgg16 with {dataset_name}')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_Vgg16.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of Vgg16 with {dataset_name}')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_Vgg16.png')
plt.show()

# %%
model = keras.models.load_model('weights_Vgg16.keras')
model.evaluate(X_test, y_test)
# Out:
# 17/17 [==============================] - 2s 119ms/step - loss: 0.0692 - accuracy: 0.9847
# [0.06919698417186737, 0.9847328066825867]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of Vgg16 with {dataset_name}')
plt.savefig('Confusion_Matrix_Vgg16.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 17/17 [==============================] - 2s 121ms/step
#                      precision    recall  f1-score   support
#
#           Padmasana       1.00      0.98      0.99        60
#              bridge       0.95      1.00      0.97        53
#             diamond       0.98      0.98      0.98        50
#             downdog       1.00      0.98      0.99        54
#             goddess       1.00      0.98      0.99        50
#               plank       1.00      0.96      0.98        50
# seated_forward_fold       1.00      1.00      1.00        50
#                tree       0.97      1.00      0.98        58
#            warrior2       1.00      1.00      1.00        52
#               wheel       0.96      0.96      0.96        47
#
#            accuracy                           0.98       524
#           macro avg       0.99      0.98      0.98       524
#        weighted avg       0.99      0.98      0.98       524

# %%
with open('history_for_Vgg16.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_Vgg16.keras', 'history_for_Vgg16.pkl', 'Confusion_Matrix_Vgg16.png', 'Accuracy_Graph_Vgg16.png', 'Loss_Graph_Vgg16.png']
zip_filename = 'results_Vgg16.zip'

create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # MoveNet Model

# %% [markdown]
# # Downloading MoveNet Model from TF Hub

# %%
# Download model from TF Hub and check out inference code from GitHub
# !wget -q -O movenet_thunder.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# !git clone https://github.com/tensorflow/examples.git
pose_sample_rpi_path = os.path.join(os.getcwd(), 'examples/lite/examples/pose_estimation/raspberry_pi')
sys.path.append(pose_sample_rpi_path)

# Load MoveNet Thunder model
import utils
from data import BodyPart
from ml import Movenet
movenet = Movenet('movenet_thunder')

# Define function to run pose estimation using MoveNet Thunder.
# You'll apply MoveNet's cropping algorithm and run inference multiple times on
# the input image to improve pose estimation accuracy.
def detect(input_tensor, inference_count=5):
  """Runs detection on an input image.

  Args:
    input_tensor: A [height, width, 3] Tensor of type tf.float32.
      Note that height and width can be anything since the image will be
      immediately resized according to the needs of the model within this
      function.
    inference_count: Number of times the model should run repeatly on the
      same input image to improve detection accuracy.

  Returns:
    A Person entity detected by the MoveNet.SinglePose.
  """

  image_height, image_width, channel = input_tensor.shape

  # Detect pose using the full input image
  movenet.detect(input_tensor.numpy(), reset_crop_region=True)

  # Repeatedly using previous detection result to identify the region of
  # interest and only croping that region to improve detection accuracy
  for _ in range(inference_count - 1):
    person = movenet.detect(input_tensor.numpy(),
                            reset_crop_region=False)

  return person
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 23737, done.
# remote: Counting objects: 100% (701/701), done.
# remote: Compressing objects: 100% (428/428), done.
# remote: Total 23737 (delta 230), reused 559 (delta 185), pack-reused 23036
# Receiving objects: 100% (23737/23737), 44.19 MiB | 13.59 MiB/s, done.
# Resolving deltas: 100% (12878/12878), done.

# %%
def draw_prediction_on_image(
    image, person, crop_region=None, close_figure=True,
    keep_input_size=False):
  """Draws the keypoint predictions on image.

  Args:
    image: An numpy array with shape [height, width, channel] representing the
      pixel values of the input image.
    person: A person entity returned from the MoveNet.SinglePose model.
    close_figure: Whether to close the plt figure after the function returns.
    keep_input_size: Whether to keep the size of the input image.

  Returns:
    An numpy array with shape [out_height, out_width, channel] representing the
    image overlaid with keypoint predictions.
  """
  # Draw the detection result on top of the image.
  image_np = utils.visualize(image, [person])

  # Plot the image with detection results.
  height, width, channel = image.shape
  aspect_ratio = float(width) / height
  fig, ax = plt.subplots(figsize=(12 * aspect_ratio, 12))
  im = ax.imshow(image_np)

  if close_figure:
    plt.close(fig)

  if not keep_input_size:
    image_np = utils.keep_aspect_ratio_resizer(image_np, (512, 512))

  return image_np

# %%
class MoveNetPreprocessor(object):
  """Helper class to preprocess pose sample images for classification."""

  def __init__(self,
               images_in_folder,
               images_out_folder,
               csvs_out_path):
    """Creates a preprocessor to detection pose from images and save as CSV.

    Args:
      images_in_folder: Path to the folder with the input images. It should
        follow this structure:
        yoga_poses
        |__ downdog
            |______ 00000128.jpg
            |______ 00000181.bmp
            |______ ...
        |__ goddess
            |______ 00000243.jpg
            |______ 00000306.jpg
            |______ ...
        ...
      images_out_folder: Path to write the images overlay with detected
        landmarks. These images are useful when you need to debug accuracy
        issues.
      csvs_out_path: Path to write the CSV containing the detected landmark
        coordinates and label of each image that can be used to train a pose
        classification model.
    """
    self._images_in_folder = images_in_folder
    self._images_out_folder = images_out_folder
    self._csvs_out_path = csvs_out_path
    self._messages = []

    # Create a temp dir to store the pose CSVs per class
    self._csvs_out_folder_per_class = tempfile.mkdtemp()

    # Get list of pose classes and print image statistics
    self._pose_class_names = sorted(
        [n for n in os.listdir(self._images_in_folder) if not n.startswith('.')]
        )

  def process(self, per_pose_class_limit=None, detection_threshold=0.1):
    """Preprocesses images in the given folder.
    Args:
      per_pose_class_limit: Number of images to load. As preprocessing usually
        takes time, this parameter can be specified to make the reduce of the
        dataset for testing.
      detection_threshold: Only keep images with all landmark confidence score
        above this threshold.
    """
    # Loop through the classes and preprocess its images
    for pose_class_name in self._pose_class_names:
      print('Preprocessing', pose_class_name, file=sys.stderr)

      # Paths for the pose class.
      images_in_folder = os.path.join(self._images_in_folder, pose_class_name)
      images_out_folder = os.path.join(self._images_out_folder, pose_class_name)
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  pose_class_name + '.csv')
      if not os.path.exists(images_out_folder):
        os.makedirs(images_out_folder)

      # Detect landmarks in each image and write it to a CSV file
      with open(csv_out_path, 'w') as csv_out_file:
        csv_out_writer = csv.writer(csv_out_file,
                                    delimiter=',',
                                    quoting=csv.QUOTE_MINIMAL)
        # Get list of images
        image_names = sorted(
            [n for n in os.listdir(images_in_folder) if not n.startswith('.')])
        if per_pose_class_limit is not None:
          image_names = image_names[:per_pose_class_limit]

        valid_image_count = 0

        # Detect pose landmarks from each image
        for image_name in tqdm.tqdm(image_names):
          image_path = os.path.join(images_in_folder, image_name)

          try:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image,channels = 3)
          except:
            self._messages.append('Skipped ' + image_path + '. Invalid image.')
            continue
          else:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image,channels = 3)
            image_height, image_width, channel = image.shape

          # Skip images that isn't RGB because Movenet requires RGB images
          if channel != 3:
            self._messages.append('Skipped ' + image_path +
                                  '. Image isn\'t in RGB format.')
            continue
          person = detect(image)

          # Save landmarks if all landmarks were detected
          min_landmark_score = min(
              [keypoint.score for keypoint in person.keypoints])
          should_keep_image = min_landmark_score >= detection_threshold
          if not should_keep_image:
            self._messages.append('Skipped ' + image_path +
                                  '. No pose was confidentlly detected.')
            continue

          valid_image_count += 1

          # Draw the prediction result on top of the image for debugging later
          output_overlay = draw_prediction_on_image(
              image.numpy().astype(np.uint8), person,
              close_figure=True, keep_input_size=True)

          # Write detection result into an image file
          output_frame = cv2.cvtColor(output_overlay, cv2.COLOR_RGB2BGR)
          cv2.imwrite(os.path.join(images_out_folder, image_name), output_frame)

          # Get landmarks and scale it to the same size as the input image
          pose_landmarks = np.array(
              [[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score]
                for keypoint in person.keypoints],
              dtype=np.float32)

          # Write the landmark coordinates to its per-class CSV file
          coordinates = pose_landmarks.flatten().astype(str).tolist()
          csv_out_writer.writerow([image_name] + coordinates)

        if not valid_image_count:
          raise RuntimeError(
              'No valid images found for the "{}" class.'
              .format(pose_class_name))

    # Print the error message collected during preprocessing.
    print('\n'.join(self._messages))

    # Combine all per-class CSVs into a single output file
    all_landmarks_df = self._all_landmarks_as_dataframe()
    all_landmarks_df.to_csv(self._csvs_out_path, index=False)

  def class_names(self):
    """List of classes found in the training dataset."""
    return self._pose_class_names

  def _all_landmarks_as_dataframe(self):
    """Merge all per-class CSVs into a single dataframe."""
    total_df = None
    for class_index, class_name in enumerate(self._pose_class_names):
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  class_name + '.csv')
      per_class_df = pd.read_csv(csv_out_path, header=None)

      # Add the labels
      per_class_df['class_no'] = [class_index]*len(per_class_df)
      per_class_df['class_name'] = [class_name]*len(per_class_df)

      # Append the folder name to the filename column (first column)
      per_class_df[per_class_df.columns[0]] = (os.path.join(class_name, '')
        + per_class_df[per_class_df.columns[0]].astype(str))

      if total_df is None:
        # For the first class, assign its data to the total dataframe
        total_df = per_class_df
      else:
        # Concatenate each class's data into the total dataframe
        total_df = pd.concat([total_df, per_class_df], axis=0)

    list_name = [[bodypart.name + '_x', bodypart.name + '_y',
                  bodypart.name + '_score'] for bodypart in BodyPart]
    header_name = []
    for columns_name in list_name:
      header_name += columns_name
    header_name = ['file_name'] + header_name
    header_map = {total_df.columns[i]: header_name[i]
                  for i in range(len(header_name))}

    total_df.rename(header_map, axis=1, inplace=True)

    return total_df

# %% [markdown]
# # Testing MoveNet Model

# %%
image = tf.io.read_file('/content/dataset/test/bridge/bridge_test_1.png')
image = tf.io.decode_jpeg(image)
person = detect(image)
_ = draw_prediction_on_image(image.numpy(), person, crop_region=None,
                            close_figure=False, keep_input_size=True)

# %%
dataset_in = '/content/dataset/'

# %%
images_in_train_folder = os.path.join(dataset_in, 'train')
images_out_train_folder = 'poses_images_out_train'
csvs_out_train_path = 'train_data_MoveNet.csv'

preprocessor = MoveNetPreprocessor(
    images_in_folder=images_in_train_folder,
    images_out_folder=images_out_train_folder,
    csvs_out_path=csvs_out_train_path,
)

preprocessor.process(per_pose_class_limit=None)
# Out:
# Preprocessing Padmasana
# 100%|██████████| 240/240 [01:14<00:00,  3.21it/s]
# Preprocessing bridge
# 100%|██████████| 211/211 [00:23<00:00,  8.81it/s]
# Preprocessing diamond
# 100%|██████████| 200/200 [00:23<00:00,  8.44it/s]
# Preprocessing downdog
# 100%|██████████| 220/220 [00:58<00:00,  3.77it/s]
# Preprocessing goddess
# 100%|██████████| 197/197 [00:36<00:00,  5.43it/s]
# Preprocessing plank
# 100%|██████████| 198/198 [00:28<00:00,  6.85it/s]
# Preprocessing seated_forward_fold
# 100%|██████████| 200/200 [00:19<00:00, 10.02it/s]
# Preprocessing tree
# 100%|██████████| 231/231 [01:00<00:00,  3.84it/s]
# Preprocessing warrior2
# 100%|██████████| 205/205 [00:35<00:00,  5.76it/s]
# Preprocessing wheel
# 100%|██████████| 185/185 [00:21<00:00,  8.48it/s]
# Skipped /content/dataset/train/bridge/bridge_train_116.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/bridge/bridge_train_44.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/bridge/bridge_train_79.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/diamond/diamond_train_104.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/diamond/diamond_train_2.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/diamond/diamond_train_3.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/diamond/diamond_train_4.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/diamond/diamond_train_73.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/diamond/diamond_train_92.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/diamond/diamond_train_93.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/downdog_train_159.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/downdog_train_177.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/downdog_train_197.png. Invalid image.
# Skipped /content/dataset/train/downdog/downdog_train_204.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/downdog/downdog_train_41.png. Invalid image.
# Skipped /content/dataset/train/downdog/downdog_train_79.png. Invalid image.
# Skipped /content/dataset/train/goddess/goddess_train_197.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/plank/plank_train_125.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/plank/plank_train_66.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_110.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_120.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_121.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_126.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_128.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_135.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_140.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_155.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_163.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_183.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_22.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_23.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_24.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_25.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_30.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_31.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_32.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_38.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_41.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_43.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_47.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_51.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_53.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_55.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_60.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_68.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_79.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_82.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_86.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_91.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_94.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_96.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/seated_forward_fold/seatedforwardfold_train_99.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/tree/tree_train_126.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/tree/tree_train_169.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/tree/tree_train_192.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/warrior2/warrior2_train_17.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/wheel/wheel_train_110.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/wheel/wheel_train_113.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/wheel/wheel_train_182.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/wheel/wheel_train_25.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/wheel/wheel_train_44.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/wheel/wheel_train_68.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/wheel/wheel_train_75.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/wheel/wheel_train_8.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/wheel/wheel_train_9.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/wheel/wheel_train_92.png. No pose was confidentlly detected.
# Skipped /content/dataset/train/wheel/wheel_train_96.png. No pose was confidentlly detected.

# %%
images_in_test_folder = os.path.join(dataset_in, 'test')
images_out_test_folder = 'poses_images_out_test'
csvs_out_test_path = 'test_data_MoveNet.csv'

preprocessor = MoveNetPreprocessor(
    images_in_folder=images_in_test_folder,
    images_out_folder=images_out_test_folder,
    csvs_out_path=csvs_out_test_path,
)

preprocessor.process(per_pose_class_limit=None)
# Out:
# Preprocessing Padmasana
# 100%|██████████| 60/60 [00:22<00:00,  2.62it/s]
# Preprocessing bridge
# 100%|██████████| 53/53 [00:05<00:00,  9.37it/s]
# Preprocessing diamond
# 100%|██████████| 50/50 [00:05<00:00,  8.77it/s]
# Preprocessing downdog
# 100%|██████████| 56/56 [00:14<00:00,  3.86it/s]
# Preprocessing goddess
# 100%|██████████| 50/50 [00:08<00:00,  5.86it/s]
# Preprocessing plank
# 100%|██████████| 50/50 [00:08<00:00,  5.96it/s]
# Preprocessing seated_forward_fold
# 100%|██████████| 50/50 [00:05<00:00,  9.65it/s]
# Preprocessing tree
# 100%|██████████| 58/58 [00:13<00:00,  4.42it/s]
# Preprocessing warrior2
# 100%|██████████| 52/52 [00:09<00:00,  5.22it/s]
# Preprocessing wheel
# 100%|██████████| 47/47 [00:05<00:00,  8.46it/s]
# Skipped /content/dataset/test/bridge/bridge_test_11.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/diamond/diamond_test_28.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/downdog/downdog_test_39.png. Invalid image.
# Skipped /content/dataset/test/downdog/downdog_test_52.png. Invalid image.
# Skipped /content/dataset/test/seated_forward_fold/seated_forward_fold_test_1.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/seated_forward_fold/seated_forward_fold_test_16.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/seated_forward_fold/seated_forward_fold_test_41.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/seated_forward_fold/seated_forward_fold_test_45.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/seated_forward_fold/seated_forward_fold_test_46.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/seated_forward_fold/seated_forward_fold_test_47.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/seated_forward_fold/seated_forward_fold_test_48.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/seated_forward_fold/seated_forward_fold_test_5.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/seated_forward_fold/seated_forward_fold_test_9.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/tree/tree_test_1.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior2/warrior2_test_2.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/wheel/wheel_test_31.png. No pose was confidentlly detected.
# Skipped /content/dataset/test/wheel/wheel_test_42.png. No pose was confidentlly detected.

# %%
# !cp {csvs_out_train_path} {path_to_save}
# !cp {csvs_out_test_path} {path_to_save}

# %%
def load_pose_landmarks(csv_path):
  """Loads a CSV created by MoveNetPreprocessor.

  Returns:
    X: Detected landmark coordinates and scores of shape (N, 17 * 3)
    y: Ground truth labels of shape (N, label_count)
    classes: The list of all class names found in the dataset
    dataframe: The CSV loaded as a Pandas dataframe features (X) and ground
      truth labels (y) to use later to train a pose classification model.
  """

  # Load the CSV file
  dataframe = pd.read_csv(csv_path)
  df_to_process = dataframe.copy()

  # Drop the file_name columns as you don't need it during training.
  df_to_process.drop(columns=['file_name'], inplace=True)

  # Extract the list of class names
  classes = df_to_process.pop('class_name').unique()

  # Extract the labels
  y = df_to_process.pop('class_no')

  # Convert the input features and labels into the correct format for training.
  X = df_to_process.astype('float64')
  y = keras.utils.to_categorical(y)

  return X, y, classes, dataframe

# %%
# Load the train data
X, y, class_names, _ = load_pose_landmarks(csvs_out_train_path)

X_train = X
y_train = y
# Load the test data
X_test, y_test, _, df_test = load_pose_landmarks(csvs_out_test_path)

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
  """Calculates the center point of the two given landmarks."""

  left = tf.gather(landmarks, left_bodypart.value, axis=1)
  right = tf.gather(landmarks, right_bodypart.value, axis=1)
  center = left * 0.5 + right * 0.5
  return center


def get_pose_size(landmarks, torso_size_multiplier=2.5):
  """Calculates pose size.

  It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
  """
  # Hips center
  hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)

  # Shoulders center
  shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

  # Torso size as the minimum body size
  torso_size = tf.linalg.norm(shoulders_center - hips_center)

  # Pose center
  pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                     BodyPart.RIGHT_HIP)
  pose_center_new = tf.expand_dims(pose_center_new, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to
  # perform substraction
  pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

  # Dist to pose center
  d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
  # Max dist to pose center
  max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

  # Normalize scale
  pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)

  return pose_size


def normalize_pose_landmarks(landmarks):
  """Normalizes the landmarks translation by moving the pose center to (0,0) and
  scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
  pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)
  pose_center = tf.expand_dims(pose_center, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to perform
  # substraction
  pose_center = tf.broadcast_to(pose_center,
                                [tf.size(landmarks) // (17*2), 17, 2])
  landmarks = landmarks - pose_center

  # Scale the landmarks to a constant pose size
  pose_size = get_pose_size(landmarks)
  landmarks /= pose_size

  return landmarks


def landmarks_to_embedding(landmarks_and_scores):
  """Converts the input landmarks into a pose embedding."""
  # Reshape the flat input into a matrix with shape=(17, 3)
  reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

  # Normalize landmarks 2D
  landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])

  # Flatten the normalized landmark coordinates into a vector
  embedding = keras.layers.Flatten()(landmarks)

  return embedding

# %%
# Define the model
inputs = tf.keras.Input(shape=(51))
embedding = landmarks_to_embedding(inputs)

layer = keras.layers.Dense(128, activation=tf.nn.relu6)(embedding)
layer = keras.layers.Dropout(0.5)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.5)(layer)
outputs = keras.layers.Dense(len(class_names), activation="softmax")(layer)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 51)]                 0         []
#
#  reshape (Reshape)           (None, 17, 3)                0         ['input_7[0][0]']
#
#  tf.__operators__.getitem (  (None, 17, 2)                0         ['reshape[0][0]']
#  SlicingOpLambda)
#
#  tf.compat.v1.gather (TFOpL  (None, 2)                    0         ['tf.__operators__.getitem[0][
#  ambda)                                                             0]']
#
#  tf.compat.v1.gather_1 (TFO  (None, 2)                    0         ['tf.__operators__.getitem[0][
#  pLambda)                                                           0]']
#
#  tf.math.multiply (TFOpLamb  (None, 2)                    0         ['tf.compat.v1.gather[0][0]']
#  da)
#
#  tf.math.multiply_1 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_1[0][0]'
#  mbda)                                                              ]
#
#  tf.__operators__.add (TFOp  (None, 2)                    0         ['tf.math.multiply[0][0]',
#  Lambda)                                                             'tf.math.multiply_1[0][0]']
#
#  tf.compat.v1.size (TFOpLam  ()                           0         ['tf.__operators__.getitem[0][
#  bda)                                                               0]']
#
#  tf.expand_dims (TFOpLambda  (None, 1, 2)                 0         ['tf.__operators__.add[0][0]']
#  )
#
#  tf.compat.v1.floor_div (TF  ()                           0         ['tf.compat.v1.size[0][0]']
#  OpLambda)
#
#  tf.broadcast_to (TFOpLambd  (None, 17, 2)                0         ['tf.expand_dims[0][0]',
#  a)                                                                  'tf.compat.v1.floor_div[0][0]
#                                                                     ']
#
#  tf.math.subtract (TFOpLamb  (None, 17, 2)                0         ['tf.__operators__.getitem[0][
#  da)                                                                0]',
#                                                                      'tf.broadcast_to[0][0]']
#
#  tf.compat.v1.gather_6 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.compat.v1.gather_7 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.math.multiply_6 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_6[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_7 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_7[0][0]'
#  mbda)                                                              ]
#
#  tf.__operators__.add_3 (TF  (None, 2)                    0         ['tf.math.multiply_6[0][0]',
#  OpLambda)                                                           'tf.math.multiply_7[0][0]']
#
#  tf.compat.v1.size_1 (TFOpL  ()                           0         ['tf.math.subtract[0][0]']
#  ambda)
#
#  tf.compat.v1.gather_4 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.compat.v1.gather_5 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.compat.v1.gather_2 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.compat.v1.gather_3 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.expand_dims_1 (TFOpLamb  (None, 1, 2)                 0         ['tf.__operators__.add_3[0][0]
#  da)                                                                ']
#
#  tf.compat.v1.floor_div_1 (  ()                           0         ['tf.compat.v1.size_1[0][0]']
#  TFOpLambda)
#
#  tf.math.multiply_4 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_4[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_5 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_5[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_2 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_2[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_3 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_3[0][0]'
#  mbda)                                                              ]
#
#  tf.broadcast_to_1 (TFOpLam  (None, 17, 2)                0         ['tf.expand_dims_1[0][0]',
#  bda)                                                                'tf.compat.v1.floor_div_1[0][
#                                                                     0]']
#
#  tf.__operators__.add_2 (TF  (None, 2)                    0         ['tf.math.multiply_4[0][0]',
#  OpLambda)                                                           'tf.math.multiply_5[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 2)                    0         ['tf.math.multiply_2[0][0]',
#  OpLambda)                                                           'tf.math.multiply_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLa  (None, 17, 2)                0         ['tf.math.subtract[0][0]',
#  mbda)                                                               'tf.broadcast_to_1[0][0]']
#
#  tf.math.subtract_1 (TFOpLa  (None, 2)                    0         ['tf.__operators__.add_2[0][0]
#  mbda)                                                              ',
#                                                                      'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  tf.compat.v1.gather_8 (TFO  (17, 2)                      0         ['tf.math.subtract_2[0][0]']
#  pLambda)
#
#  tf.compat.v1.norm (TFOpLam  ()                           0         ['tf.math.subtract_1[0][0]']
#  bda)
#
#  tf.compat.v1.norm_1 (TFOpL  (2,)                         0         ['tf.compat.v1.gather_8[0][0]'
#  ambda)                                                             ]
#
#  tf.math.multiply_8 (TFOpLa  ()                           0         ['tf.compat.v1.norm[0][0]']
#  mbda)
#
#  tf.math.reduce_max (TFOpLa  ()                           0         ['tf.compat.v1.norm_1[0][0]']
#  mbda)
#
#  tf.math.maximum (TFOpLambd  ()                           0         ['tf.math.multiply_8[0][0]',
#  a)                                                                  'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv (TFOpLambd  (None, 17, 2)                0         ['tf.math.subtract[0][0]',
#  a)                                                                  'tf.math.maximum[0][0]']
#
#  flatten_6 (Flatten)         (None, 34)                   0         ['tf.math.truediv[0][0]']
#
#  dense_18 (Dense)            (None, 128)                  4480      ['flatten_6[0][0]']
#
#  dropout_12 (Dropout)        (None, 128)                  0         ['dense_18[0][0]']
#
#  dense_19 (Dense)            (None, 64)                   8256      ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)        (None, 64)                   0         ['dense_19[0][0]']
#
#  dense_20 (Dense)            (None, 10)                   650       ['dropout_13[0][0]']
#
# ==================================================================================================
# Total params: 13386 (52.29 KB)
# Trainable params: 13386 (52.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Add a checkpoint callback to store the checkpoint that has the highest
# validation accuracy.
checkpoint_path = "weights_MoveNet.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='max')
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                              patience=20)

# Start training
history = model.fit(X_train, y_train,
                    epochs=200,
                    batch_size=16,
                    validation_data=(X_test,y_test),
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/200
# 112/127 [=========================>....] - ETA: 0s - loss: 2.1389 - accuracy: 0.2439
# Epoch 1: val_accuracy improved from -inf to 0.37328, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 2s 7ms/step - loss: 2.1021 - accuracy: 0.2550 - val_loss: 1.7798 - val_accuracy: 0.3733
# Epoch 2/200
# 113/127 [=========================>....] - ETA: 0s - loss: 1.6127 - accuracy: 0.3827
# Epoch 2: val_accuracy improved from 0.37328 to 0.59136, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 4ms/step - loss: 1.5970 - accuracy: 0.3911 - val_loss: 1.3610 - val_accuracy: 0.5914
# Epoch 3/200
# 125/127 [============================>.] - ETA: 0s - loss: 1.2945 - accuracy: 0.5190
# Epoch 3: val_accuracy improved from 0.59136 to 0.65815, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 5ms/step - loss: 1.2941 - accuracy: 0.5183 - val_loss: 1.0915 - val_accuracy: 0.6582
# Epoch 4/200
# 127/127 [==============================] - ETA: 0s - loss: 1.1029 - accuracy: 0.5812
# Epoch 4: val_accuracy improved from 0.65815 to 0.72102, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 5ms/step - loss: 1.1029 - accuracy: 0.5812 - val_loss: 0.9291 - val_accuracy: 0.7210
# Epoch 5/200
# 113/127 [=========================>....] - ETA: 0s - loss: 0.9989 - accuracy: 0.6073
# Epoch 5: val_accuracy improved from 0.72102 to 0.73477, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 5ms/step - loss: 1.0017 - accuracy: 0.6074 - val_loss: 0.7910 - val_accuracy: 0.7348
# Epoch 6/200
# 112/127 [=========================>....] - ETA: 0s - loss: 0.8908 - accuracy: 0.6618
# Epoch 6: val_accuracy did not improve from 0.73477
# 127/127 [==============================] - 1s 4ms/step - loss: 0.8796 - accuracy: 0.6629 - val_loss: 0.6913 - val_accuracy: 0.7308
# Epoch 7/200
# 126/127 [============================>.] - ETA: 0s - loss: 0.8175 - accuracy: 0.7014
# Epoch 7: val_accuracy improved from 0.73477 to 0.80354, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 5ms/step - loss: 0.8178 - accuracy: 0.7015 - val_loss: 0.6148 - val_accuracy: 0.8035
# Epoch 8/200
# 114/127 [=========================>....] - ETA: 0s - loss: 0.7204 - accuracy: 0.7248
# Epoch 8: val_accuracy improved from 0.80354 to 0.81532, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 5ms/step - loss: 0.7250 - accuracy: 0.7203 - val_loss: 0.5499 - val_accuracy: 0.8153
# Epoch 9/200
# 113/127 [=========================>....] - ETA: 0s - loss: 0.6850 - accuracy: 0.7566
# Epoch 9: val_accuracy improved from 0.81532 to 0.82122, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 5ms/step - loss: 0.6794 - accuracy: 0.7564 - val_loss: 0.4913 - val_accuracy: 0.8212
# Epoch 10/200
# 112/127 [=========================>....] - ETA: 0s - loss: 0.6396 - accuracy: 0.7489
# Epoch 10: val_accuracy improved from 0.82122 to 0.82908, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 5ms/step - loss: 0.6283 - accuracy: 0.7569 - val_loss: 0.4721 - val_accuracy: 0.8291
# Epoch 11/200
# 115/127 [==========================>...] - ETA: 0s - loss: 0.5914 - accuracy: 0.7788
# Epoch 11: val_accuracy did not improve from 0.82908
# 127/127 [==============================] - 0s 4ms/step - loss: 0.5889 - accuracy: 0.7802 - val_loss: 0.4505 - val_accuracy: 0.8193
# Epoch 12/200
# 112/127 [=========================>....] - ETA: 0s - loss: 0.5375 - accuracy: 0.8052
# Epoch 12: val_accuracy did not improve from 0.82908
# 127/127 [==============================] - 0s 4ms/step - loss: 0.5469 - accuracy: 0.8005 - val_loss: 0.4187 - val_accuracy: 0.7898
# Epoch 13/200
# 127/127 [==============================] - ETA: 0s - loss: 0.5196 - accuracy: 0.8030
# Epoch 13: val_accuracy improved from 0.82908 to 0.84872, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 5ms/step - loss: 0.5196 - accuracy: 0.8030 - val_loss: 0.3934 - val_accuracy: 0.8487
# Epoch 14/200
# 112/127 [=========================>....] - ETA: 0s - loss: 0.5258 - accuracy: 0.8086
# Epoch 14: val_accuracy improved from 0.84872 to 0.85658, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 5ms/step - loss: 0.5285 - accuracy: 0.8059 - val_loss: 0.3776 - val_accuracy: 0.8566
# Epoch 15/200
# 125/127 [============================>.] - ETA: 0s - loss: 0.4816 - accuracy: 0.8275
# Epoch 15: val_accuracy did not improve from 0.85658
# 127/127 [==============================] - 1s 4ms/step - loss: 0.4835 - accuracy: 0.8257 - val_loss: 0.3669 - val_accuracy: 0.8448
# Epoch 16/200
# 124/127 [============================>.] - ETA: 0s - loss: 0.4594 - accuracy: 0.8221
# Epoch 16: val_accuracy did not improve from 0.85658
# 127/127 [==============================] - 1s 4ms/step - loss: 0.4592 - accuracy: 0.8228 - val_loss: 0.3698 - val_accuracy: 0.8546
# Epoch 17/200
# 123/127 [============================>.] - ETA: 0s - loss: 0.4384 - accuracy: 0.8394
# Epoch 17: val_accuracy improved from 0.85658 to 0.86051, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 5ms/step - loss: 0.4360 - accuracy: 0.8401 - val_loss: 0.3303 - val_accuracy: 0.8605
# Epoch 18/200
# 122/127 [===========================>..] - ETA: 0s - loss: 0.4374 - accuracy: 0.8361
# Epoch 18: val_accuracy improved from 0.86051 to 0.87230, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 5ms/step - loss: 0.4359 - accuracy: 0.8371 - val_loss: 0.3195 - val_accuracy: 0.8723
# Epoch 19/200
# 127/127 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.8495
# Epoch 19: val_accuracy improved from 0.87230 to 0.88212, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 5ms/step - loss: 0.4146 - accuracy: 0.8495 - val_loss: 0.3048 - val_accuracy: 0.8821
# Epoch 20/200
# 113/127 [=========================>....] - ETA: 0s - loss: 0.4189 - accuracy: 0.8468
# Epoch 20: val_accuracy improved from 0.88212 to 0.88409, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 4ms/step - loss: 0.4152 - accuracy: 0.8480 - val_loss: 0.3012 - val_accuracy: 0.8841
# Epoch 21/200
# 114/127 [=========================>....] - ETA: 0s - loss: 0.3893 - accuracy: 0.8564
# Epoch 21: val_accuracy improved from 0.88409 to 0.89195, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 4ms/step - loss: 0.3868 - accuracy: 0.8584 - val_loss: 0.2924 - val_accuracy: 0.8919
# Epoch 22/200
# 119/127 [===========================>..] - ETA: 0s - loss: 0.3787 - accuracy: 0.8577
# Epoch 22: val_accuracy did not improve from 0.89195
# 127/127 [==============================] - 0s 4ms/step - loss: 0.3785 - accuracy: 0.8579 - val_loss: 0.2937 - val_accuracy: 0.8743
# Epoch 23/200
# 120/127 [===========================>..] - ETA: 0s - loss: 0.3620 - accuracy: 0.8682
# Epoch 23: val_accuracy did not improve from 0.89195
# 127/127 [==============================] - 0s 4ms/step - loss: 0.3650 - accuracy: 0.8668 - val_loss: 0.2763 - val_accuracy: 0.8900
# Epoch 24/200
# 118/127 [==========================>...] - ETA: 0s - loss: 0.3644 - accuracy: 0.8628
# Epoch 24: val_accuracy improved from 0.89195 to 0.89391, saving model to weights_MoveNet.keras
# 127/127 [==============================] - 1s 4ms/step - loss: 0.3653 - accuracy: 0.8639 - val_loss: 0.2757 - val_accuracy: 0.8939
# Epoch 25/200
# 117/127 [==========================>...] - ETA: 0s - loss: 0.3380 - accuracy: 0.8825
# Epoch 25: val_accuracy improved from 0.89391 to 0.89587, saving model to weights_MoveNet.keras

plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.savefig("Accuracy_Graph_MoveNet.png")
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of MoveNet for {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.savefig("Loss_Graph_MoveNet.png")
plt.show()

# %%
# Evaluate the model using the TEST dataset
model = keras.models.load_model('weights_MoveNet.keras')
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0770 - accuracy: 0.9862

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of MoveNet for {dataset_name}')
plt.savefig("Confusion_Matrix_MoveNet.png")
plt.show()

class_report = classification_report(y_true, y_pred, target_names=class_names)
print(class_report)
# Out:
# 16/16 [==============================] - 0s 2ms/step
#                      precision    recall  f1-score   support
#
#           Padmasana       1.00      1.00      1.00        60
#              bridge       1.00      1.00      1.00        52
#             diamond       1.00      1.00      1.00        49
#             downdog       0.98      0.98      0.98        54
#             goddess       1.00      0.98      0.99        50
#               plank       1.00      0.98      0.99        50
# seated_forward_fold       1.00      1.00      1.00        41
#                tree       0.92      1.00      0.96        57
#            warrior2       1.00      0.94      0.97        51
#               wheel       0.98      0.98      0.98        45
#
#            accuracy                           0.99       509
#           macro avg       0.99      0.99      0.99       509
#        weighted avg       0.99      0.99      0.99       509

# %%
with open('history_for_MoveNet.pkl', 'wb') as f:
    pickle.dump(history, f)

files_to_zip = ['weights_MoveNet.keras', 'history_for_MoveNet.pkl', 'Confusion_Matrix_MoveNet.png','Accuracy_Graph_MoveNet.png','Loss_Graph_MoveNet.png' ]
zip_filename = 'results_MoveNet.zip'
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # MediaPipe Model

# %%
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.3, model_complexity=2)
mp_drawing = mp.solutions.drawing_utils
# Out:
# Downloading model to /usr/local/lib/python3.10/dist-packages/mediapipe/modules/pose_landmark/pose_landmark_heavy.tflite

# %%
# Read an image from the specified path.
sample_img = cv2.imread('/content/dataset/test/bridge/bridge_test_1.png')
sample_img = cv2.cvtColor(sample_img, cv2.COLOR_BGR2RGB)
# Specify a size of the figure.
plt.figure(figsize = [10, 10])
results = pose.process(sample_img)
img_copy = sample_img.copy()

# Check if any landmarks are found.
if results.pose_landmarks:

    # Draw Pose landmarks on the sample image.
    mp_drawing.draw_landmarks(image=img_copy, landmark_list=results.pose_landmarks, connections=mp_pose.POSE_CONNECTIONS)

    # Specify a size of the figure.
    fig = plt.figure(figsize = [10, 10])

    # Display the output image with the landmarks drawn, also convert BGR to RGB for display.
    plt.title("Output");plt.axis('off');plt.imshow(img_copy);plt.show()

# %%
def detectPose(image, pose, display=True):
    '''
    This function performs pose detection on an image.
    Args:
        image: The input image with a prominent person whose pose landmarks needs to be detected.
        pose: The pose setup function required to perform the pose detection.
        display: A boolean value that is if set to true the function displays the original input image, the resultant image,
                 and the pose landmarks in 3D plot and returns nothing.
    Returns:
        output_image: The input image with the detected pose landmarks drawn.
        landmarks: A list of dictionaries representing the detected landmarks with name, x, y, and score.
    '''

    # Create a copy of the input image.
    output_image = image.copy()

    # Convert the image from BGR into RGB format.
    imageRGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Perform the Pose Detection.
    results = pose.process(imageRGB)

    # Retrieve the height and width of the input image.
    height, width, _ = image.shape

    # Initialize a list to store the detected landmarks.
    landmarks = []

    # Check if any landmarks are detected.
    if results.pose_landmarks:
        # Draw Pose landmarks on the output image.
        mp_drawing.draw_landmarks(image=output_image, landmark_list=results.pose_landmarks, connections=mp_pose.POSE_CONNECTIONS)

        # Iterate over the detected landmarks.
        for idx, landmark in enumerate(results.pose_landmarks.landmark):
            # Append the landmark into the list as a dictionary with name, x, y, and score.
            landmarks.append({
                'name': mp_pose.PoseLandmark(idx).name,
                'x': landmark.x * width,
                'y': landmark.y * height,
                'score': landmark.visibility
            })

    # Check if the original input image and the resultant image are specified to be displayed.
    if display:
        # Display the original input image and the resultant image.
        plt.figure(figsize=[22, 22])
        plt.subplot(121);plt.imshow(image[:,:,::-1]);plt.title("Original Image");plt.axis('off');
        plt.subplot(122);plt.imshow(output_image[:,:,::-1]);plt.title("Output Image");plt.axis('off');

        # Also Plot the Pose landmarks in 3D.
        mp_drawing.plot_landmarks(results.pose_world_landmarks, mp_pose.POSE_CONNECTIONS)

    # Otherwise
    else:
        # Return the output image and the found landmarks.
        return output_image, landmarks

def landmarks_list_to_df(landmarks):
    # Convert the list of dictionaries to a DataFrame
    landmarks_df = pd.DataFrame(landmarks)

    # Initialize an empty list to store the transformed data
    transformed_data = []

    # Loop through each row of the DataFrame
    for index, row in landmarks_df.iterrows():
        transformed_row = dict()
        for landmark in row:
            if landmark is not None:
                name_x = landmark['name']+"_x"
                name_y = landmark['name']+'_y'
                name_score = landmark['name']+'_score'
                transformed_row[name_x] = landmark['x']
                transformed_row[name_y] = landmark['y']
                transformed_row[name_score] = landmark['score']
        transformed_data.append(transformed_row)

        # print()
    # Convert the transformed data list to a DataFrame
    landmarks_df_transformed = pd.DataFrame(transformed_data)
    return landmarks_df_transformed

def create_landmarks_dataframe(dataset_dir, pose):
    image_paths_train = []
    image_paths_test = []
    landmarks_train = []
    landmarks_test = []
    pose_name_train = []
    pose_name_test = []
    class_labels = {}
    class_label_counter = 0
    for root, _, files in os.walk(dataset_dir):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
                image_path = os.path.join(root, file)
                img = cv2.imread(image_path)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                istrain = root.split(os.path.sep)[-2]
                o_img, landmark = detectPose(img, pose, display=False)
                if len(landmark)==0:
                    print(image_path)
                    print(landmark)
                    print()

                if landmark:
                    if istrain == 'train':
                        image_paths_train.append(image_path)
                        landmarks_train.append(landmark)
                        folder_name = root.split(os.path.sep)[-1]
                        pose_name_train.append(folder_name)
                        if folder_name not in class_labels:
                            class_labels[folder_name] = class_label_counter
                            class_label_counter += 1
                    else:
                        image_paths_test.append(image_path)
                        landmarks_test.append(landmark)
                        folder_name = root.split(os.path.sep)[-1]
                        pose_name_test.append(folder_name)
                        if folder_name not in class_labels:
                            class_labels[folder_name] = class_label_counter
                            class_label_counter += 1

    landmarks_train_df = landmarks_list_to_df(landmarks_train)
    landmarks_test_df = landmarks_list_to_df(landmarks_test)

    train_df = pd.DataFrame({'path': image_paths_train, 'pose_name': pose_name_train})
    test_df = pd.DataFrame({'path': image_paths_test, 'pose_name': pose_name_test})

    train_df['label'] = train_df['pose_name'].map(class_labels)
    test_df['label'] = test_df['pose_name'].map(class_labels)

    # # Combine the DataFrames horizontally
    train_combined_df = pd.concat([train_df, landmarks_train_df], axis=1)
    test_combined_df = pd.concat([test_df, landmarks_test_df], axis=1)

    return train_combined_df, test_combined_df

# %%
train_df, test_df = create_landmarks_dataframe('/content/dataset', pose)
# Out:
# /content/dataset/test/plank/plank_test_39.png
# []
#
# /content/dataset/test/downdog/downdog_test_55.png
# []
#
# /content/dataset/test/downdog/downdog_test_42.png
# []
#
# /content/dataset/test/seated_forward_fold/seated_forward_fold_test_22.png
# []
#
# /content/dataset/test/seated_forward_fold/seated_forward_fold_test_38.png
# []
#
# /content/dataset/test/seated_forward_fold/seated_forward_fold_test_21.png
# []
#
# /content/dataset/test/seated_forward_fold/seated_forward_fold_test_34.png
# []
#
# /content/dataset/test/seated_forward_fold/seated_forward_fold_test_29.png
# []
#
# /content/dataset/test/seated_forward_fold/seated_forward_fold_test_48.png
# []
#
# /content/dataset/test/seated_forward_fold/seated_forward_fold_test_1.png
# []
#
# /content/dataset/test/seated_forward_fold/seated_forward_fold_test_27.png
# []
#
# /content/dataset/test/wheel/wheel_test_36.png
# []
#
# /content/dataset/test/diamond/diamond_test_15.png
# []
#
# /content/dataset/test/Padmasana/padmasana_test_43.png
# []
#
# /content/dataset/test/tree/tree_test_25.png
# []
#
# /content/dataset/test/tree/tree_test_15.png
# []
#
# /content/dataset/train/plank/plank_train_125.png
# []
#
# /content/dataset/train/plank/plank_train_66.png
# []
#
# /content/dataset/train/plank/plank_train_155.png
# []
#
# /content/dataset/train/plank/plank_train_114.png
# []
#
# /content/dataset/train/downdog/downdog_train_147.png
# []
#
# /content/dataset/train/downdog/downdog_train_149.png
# []
#
# /content/dataset/train/downdog/downdog_train_126.png
# []
#
# /content/dataset/train/downdog/downdog_train_188.png
# []
#
# /content/dataset/train/downdog/downdog_train_47.png
# []
#
# /content/dataset/train/downdog/downdog_train_207.png
# []
#
# /content/dataset/train/goddess/goddess_train_48.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_37.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_143.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_115.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_91.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_141.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_100.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_111.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_43.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_41.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_38.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_163.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_102.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_101.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_62.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_58.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_27.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_107.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_124.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_63.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_51.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_78.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_127.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_166.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_71.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_56.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_17.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_180.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_153.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_142.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_2.png
# []
#
# /content/dataset/train/seated_forward_fold/seatedforwardfold_train_134.png
# []
#
# /content/dataset/train/bridge/bridge_train_149.png
# []
#
# /content/dataset/train/bridge/bridge_train_9.png
# []
#
# /content/dataset/train/warrior2/warrior2_train_78.png
# []
#
# /content/dataset/train/warrior2/warrior2_train_3.png
# []
#
# /content/dataset/train/warrior2/warrior2_train_54.png
# []
#
# /content/dataset/train/warrior2/warrior2_train_160.png
# []
#
# /content/dataset/train/warrior2/warrior2_train_118.png
# []
#
# /content/dataset/train/wheel/wheel_train_50.png
# []
#
# /content/dataset/train/wheel/wheel_train_175.png
# []
#
# /content/dataset/train/wheel/wheel_train_21.png
# []
#
# /content/dataset/train/wheel/wheel_train_92.png
# []
#
# /content/dataset/train/wheel/wheel_train_12.png
# []
#
# /content/dataset/train/wheel/wheel_train_39.png
# []
#
# /content/dataset/train/diamond/diamond_train_170.png
# []
#
# /content/dataset/train/diamond/diamond_train_196.png
# []
#
# /content/dataset/train/diamond/diamond_train_29.png
# []
#
# /content/dataset/train/diamond/diamond_train_123.png
# []
#
# /content/dataset/train/diamond/diamond_train_34.png
# []
#
# /content/dataset/train/diamond/diamond_train_17.png
# []
#
# /content/dataset/train/diamond/diamond_train_168.png
# []
#
# /content/dataset/train/diamond/diamond_train_159.png
# []
#
# /content/dataset/train/diamond/diamond_train_174.png
# []
#
# /content/dataset/train/Padmasana/padmasana_train_49.png
# []
#
# /content/dataset/train/Padmasana/padmasana_train_121.png
# []
#
# /content/dataset/train/tree/tree_train_190.png
# []
#
# /content/dataset/train/tree/tree_train_168.png
# []
#
# /content/dataset/train/tree/tree_train_40.png
# []
#
# /content/dataset/train/tree/tree_train_80.png
# []
#
# /content/dataset/train/tree/tree_train_1.png
# []
#
# /content/dataset/train/tree/tree_train_7.png
# []
#
# /content/dataset/train/tree/tree_train_157.png
# []
#
# /content/dataset/train/tree/tree_train_148.png
# []

# %%
train_df.to_csv('train_data_MediaPipe.csv', index=False)
test_df.to_csv('test_data_MediaPipe.csv', index=False)

# %%
# !cp train_data_MediaPipe.csv {path_to_save}
# !cp test_data_MediaPipe.csv {path_to_save}

# %%
def load_pose_landmarks(dataframe):
  """Loads a CSV created by MoveNetPreprocessor.

  Returns:
    X: Detected landmark coordinates and scores of shape (N, 17 * 3)
    y: Ground truth labels of shape (N, label_count)
    classes: The list of all class names found in the dataset
    dataframe: The CSV loaded as a Pandas dataframe features (X) and ground
      truth labels (y) to use later to train a pose classification model.
  """

  df_to_process = dataframe.copy()

  # Drop the file_name columns as you don't need it during training.
  df_to_process.drop(columns=['path'], inplace=True)

  # Extract the list of class names
  classes = df_to_process.pop('pose_name').unique()

  # Extract the labels
  y = df_to_process.pop('label')

  # Convert the input features and labels into the correct format for training.
  X = df_to_process.astype('float64')
  y = keras.utils.to_categorical(y)

  return X, y, classes, dataframe

# %%
X_train, y_train, class_names_train, _ = load_pose_landmarks(train_df)
X_test, y_test, class_names_test, _ = load_pose_landmarks(test_df)
# Combine the train and test class names to ensure consistency
class_names = np.unique(np.concatenate((class_names_train, class_names_test), axis=0))

# Build the neural network model
input_shape = X_train.shape[1:]
num_classes = len(class_names)

# %%
model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=input_shape),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(num_classes, activation='softmax')
])

# Compile the model with learning rate
learning_rate = 0.001
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_33 (Dense)            (None, 256)               25600
#
#  batch_normalization_116 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  dense_34 (Dense)            (None, 128)               32896
#
#  batch_normalization_117 (B  (None, 128)               512
#  atchNormalization)
#
#  dropout_18 (Dropout)        (None, 128)               0
#
#  dense_35 (Dense)            (None, 64)                8256
#
#  batch_normalization_118 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_19 (Dropout)        (None, 64)                0
#
#  dense_36 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 69194 (270.29 KB)
# Trainable params: 68298 (266.79 KB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)
checkpoint_pth = 'weights_MediaPipe.keras'
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, verbose = 1)
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_
# Epoch 31: val_accuracy did not improve from 0.95294
# 63/63 [==============================] - 0s 6ms/step - loss: 0.3066 - accuracy: 0.9041 - val_loss: 0.8955 - val_accuracy: 0.7275
# Epoch 32/100
# 54/63 [========================>.....] - ETA: 0s - loss: 0.3164 - accuracy: 0.8935
# Epoch 32: val_accuracy did not improve from 0.95294
# 63/63 [==============================] - 0s 6ms/step - loss: 0.3259 - accuracy: 0.8907 - val_loss: 0.6319 - val_accuracy: 0.8843
# Epoch 33/100
# 55/63 [=========================>....] - ETA: 0s - loss: 0.2945 - accuracy: 0.9108
# Epoch 33: val_accuracy did not improve from 0.95294
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2839 - accuracy: 0.9151 - val_loss: 0.4738 - val_accuracy: 0.9294
# Epoch 34/100
# 55/63 [=========================>....] - ETA: 0s - loss: 0.2747 - accuracy: 0.9097
# Epoch 34: val_accuracy did not improve from 0.95294
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2760 - accuracy: 0.9126 - val_loss: 0.6676 - val_accuracy: 0.8549
# Epoch 35/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.2818 - accuracy: 0.9213
# Epoch 35: val_accuracy did not improve from 0.95294
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2867 - accuracy: 0.9180 - val_loss: 0.6195 - val_accuracy: 0.8627
# Epoch 36/100
# 56/63 [=========================>....] - ETA: 0s - loss: 0.2822 - accuracy: 0.9152
# Epoch 36: val_accuracy did not improve from 0.95294
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2746 - accuracy: 0.9165 - val_loss: 0.5305 - val_accuracy: 0.9137
# Epoch 37/100
# 54/63 [========================>.....] - ETA: 0s - loss: 0.2627 - accuracy: 0.9138
# Epoch 37: val_accuracy did not improve from 0.95294
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2583 - accuracy: 0.9160 - val_loss: 0.7860 - val_accuracy: 0.7922
# Epoch 38/100
# 53/63 [========================>.....] - ETA: 0s - loss: 0.2870 - accuracy: 0.9021
# Epoch 38: val_accuracy did not improve from 0.95294
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2859 - accuracy: 0.9061 - val_loss: 0.5597 - val_accuracy: 0.8804

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of MediaPipe for {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.savefig("Accuracy_Graph_MediaPipe.png")
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of MediaPipe for {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.savefig("Loss_Graph_MediaPipe.png")
plt.show()

# %%
model = keras.models.load_model('weights_MediaPipe.keras')
model.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.9529
# [0.39474254846572876, 0.9529411792755127]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize = (6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of MediaPipe for {dataset_name}')
plt.savefig("Confusion_Matrix_MediaPipe.png")
plt.show()

class_report = classification_report(y_true, y_pred, target_names=class_names)
print(class_report)
# Out:
# 16/16 [==============================] - 0s 2ms/step
#                      precision    recall  f1-score   support
#
#           Padmasana       0.87      0.96      0.91        49
#              bridge       0.93      0.98      0.95        54
#             diamond       1.00      0.92      0.96        50
#             downdog       1.00      0.93      0.96        42
#             goddess       0.96      0.94      0.95        53
#               plank       0.93      0.96      0.94        52
# seated_forward_fold       0.94      0.96      0.95        46
#                tree       1.00      0.96      0.98        49
#            warrior2       1.00      0.98      0.99        59
#               wheel       0.93      0.93      0.93        56
#
#            accuracy                           0.95       510
#           macro avg       0.96      0.95      0.95       510
#        weighted avg       0.95      0.95      0.95       510

# %%
with open('history_MediaPipe.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_MediaPipe.keras', 'history_MediaPipe.pkl', 'Confusion_Matrix_MediaPipe.png', 'Accuracy_Graph_MediaPipe.png', 'Loss_Graph_MediaPipe.png']
zip_filename = 'results_MediaPipe.zip'
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # Yolo Model

# %%
model = YOLO(model='yolov8x-pose-p6.pt')
image = cv2.imread('/content/dataset/test/bridge/bridge_test_1.png')
result = model.predict(image, save=False)[0]
result_keypoint = result.keypoints.xyn.cpu().numpy()[0]
Image.fromarray(cv2.cvtColor(result.plot(), cv2.COLOR_BGR2RGB))
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8x-pose-p6.pt to 'yolov8x-pose-p6.pt'...
# 100%|██████████| 190M/190M [00:02<00:00, 79.6MB/s]
# 0: 896x1280 1 person, 152.3ms
# Speed: 16.1ms preprocess, 152.3ms inference, 873.5ms postprocess per image at shape (1, 3, 896, 1280)
# <PIL.Image.Image image mode=RGB size=236x157>

# %%
class GetKeypoint(BaseModel):
    NOSE:           int = 0
    LEFT_EYE:       int = 1
    RIGHT_EYE:      int = 2
    LEFT_EAR:       int = 3
    RIGHT_EAR:      int = 4
    LEFT_SHOULDER:  int = 5
    RIGHT_SHOULDER: int = 6
    LEFT_ELBOW:     int = 7
    RIGHT_ELBOW:    int = 8
    LEFT_WRIST:     int = 9
    RIGHT_WRIST:    int = 10
    LEFT_HIP:       int = 11
    RIGHT_HIP:      int = 12
    LEFT_KNEE:      int = 13
    RIGHT_KNEE:     int = 14
    LEFT_ANKLE:     int = 15
    RIGHT_ANKLE:    int = 16

get_keypoint = GetKeypoint()

# %%
dataset_root_train = '/content/dataset/train'
dataset_root_test = '/content/dataset/test'
pose_list = sorted(os.listdir(dataset_root_train))
pose_list
# Out:
# ['Padmasana',
#  'bridge',
#  'diamond',
#  'downdog',
#  'goddess',
#  'plank',
#  'seated_forward_fold',
#  'tree',
#  'warrior2',
#  'wheel']

# %%
def extract_keypoint(keypoint):
    # nose
    nose_x, nose_y = keypoint[get_keypoint.NOSE]
    # eye
    left_eye_x, left_eye_y = keypoint[get_keypoint.LEFT_EYE]
    right_eye_x, right_eye_y = keypoint[get_keypoint.RIGHT_EYE]
    # ear
    left_ear_x, left_ear_y = keypoint[get_keypoint.LEFT_EAR]
    right_ear_x, right_ear_y = keypoint[get_keypoint.RIGHT_EAR]
    # shoulder
    left_shoulder_x, left_shoulder_y = keypoint[get_keypoint.LEFT_SHOULDER]
    right_shoulder_x, right_shoulder_y = keypoint[get_keypoint.RIGHT_SHOULDER]
    # elbow
    left_elbow_x, left_elbow_y = keypoint[get_keypoint.LEFT_ELBOW]
    right_elbow_x, right_elbow_y = keypoint[get_keypoint.RIGHT_ELBOW]
    # wrist
    left_wrist_x, left_wrist_y = keypoint[get_keypoint.LEFT_WRIST]
    right_wrist_x, right_wrist_y = keypoint[get_keypoint.RIGHT_WRIST]
    # hip
    left_hip_x, left_hip_y = keypoint[get_keypoint.LEFT_HIP]
    right_hip_x, right_hip_y = keypoint[get_keypoint.RIGHT_HIP]
    # knee
    left_knee_x, left_knee_y = keypoint[get_keypoint.LEFT_KNEE]
    right_knee_x, right_knee_y = keypoint[get_keypoint.RIGHT_KNEE]
    # ankle
    left_ankle_x, left_ankle_y = keypoint[get_keypoint.LEFT_ANKLE]
    right_ankle_x, right_ankle_y = keypoint[get_keypoint.RIGHT_ANKLE]

    return [
        nose_x, nose_y,
        left_eye_x, left_eye_y,
        right_eye_x, right_eye_y,
        left_ear_x, left_ear_y,
        right_ear_x, right_ear_y,
        left_shoulder_x, left_shoulder_y,
        right_shoulder_x, right_shoulder_y,
        left_elbow_x, left_elbow_y,
        right_elbow_x, right_elbow_y,
        left_wrist_x, left_wrist_y,
        right_wrist_x, right_wrist_y,
        left_hip_x, left_hip_y,
        right_hip_x, right_hip_y,
        left_knee_x, left_knee_y,
        right_knee_x, right_knee_y,
        left_ankle_x, left_ankle_y,
        right_ankle_x, right_ankle_y
    ]

# %%
dataset_csv_train = []
for pose in pose_list:
    # Using a set to store valid image extensions
    valid_extensions = {'jpg', 'jpeg', 'png', 'bmp'}

    # List all files in the directory
    image_path_list = []
    for ext in valid_extensions:
        image_path_list.extend(glob.glob(f'{dataset_root_train}/{pose}/*.{ext}'))

    for image_path in image_path_list:
        # get image_name
        image_name = image_path.split('/')[-1]
        # read numpy image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip to the next image if reading fails

        # get height width image
        height, width = image.shape[:2]

        # detect pose using yolov8-pose
        results = model.predict(image, save=False)[0]
        results_keypoint = results.keypoints.xyn.cpu().numpy()

        # Check if only one person is detected
        if len(results_keypoint) == 1:
            result_keypoint = results_keypoint[0]
            if len(result_keypoint) == 17:
                keypoint_list = extract_keypoint(result_keypoint)

                # insert image_name, label at index 0, 1
                keypoint_list.insert(0, image_path)
                keypoint_list.insert(1, pose)
                dataset_csv_train.append(keypoint_list)
        else:
            print("------------------------------------------------------------------------")
            print(f"More than one person detected in image: {image_path}. Ignoring pose landmarks.")
            print("------------------------------------------------------------------------")
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 1088x1280 1 person, 220.7ms
# Speed: 6.9ms preprocess, 220.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x1088 1 person, 230.3ms
# Speed: 7.0ms preprocess, 230.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 960x1280 1 person, 191.5ms
# Speed: 5.2ms preprocess, 191.5ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x960 1 person, 197.1ms
# Speed: 6.3ms preprocess, 197.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x896 1 person, 184.2ms
# Speed: 5.8ms preprocess, 184.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x960 1 person, 192.4ms
# Speed: 5.8ms preprocess, 192.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x832 2 persons, 181.5ms
# Speed: 4.9ms preprocess, 181.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 832)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/diamond/diamond_train_35.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x960 1 person, 197.8ms
# Speed: 6.5ms preprocess, 197.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1216x1280 1 person, 243.1ms
# Speed: 7.1ms preprocess, 243.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1280x1152 1 person, 236.6ms
# Speed: 7.0ms preprocess, 236.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x896 1 person, 188.2ms
# Speed: 5.6ms preprocess, 188.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1024 1 person, 201.3ms
# Speed: 6.5ms preprocess, 201.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1024 1 person, 193.5ms
# Speed: 6.2ms preprocess, 193.5ms inference, 2.7ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x896 1 person, 181.7ms
# Speed: 6.1ms preprocess, 181.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x960 1 person, 200.1ms
# Speed: 6.2ms preprocess, 200.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 896x1280 1 person, 182.0ms
# Speed: 6.4ms preprocess, 182.0ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1152 1 person, 244.0ms
# Speed: 7.4ms preprocess, 244.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x960 2 persons, 195.9ms
# Speed: 5.3ms preprocess, 195.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/diamond/diamond_train_4.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x960 1 person, 193.2ms
# Speed: 7.0ms preprocess, 193.2ms inference, 3.1ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x1024 1 person, 201.0ms
# Speed: 6.8ms preprocess, 201.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1152 1 person, 242.2ms
# Speed: 6.8ms preprocess, 242.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x1152 1 person, 243.5ms
# Speed: 7.0ms preprocess, 243.5ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x1152 1 person, 241.3ms
# Speed: 7.0ms preprocess, 241.3ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 896x1280 1 person, 184.2ms
# Speed: 6.1ms preprocess, 184.2ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x896 1 person, 185.5ms
# Speed: 5.9ms preprocess, 185.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1024x1280 1 person, 204.1ms
# Speed: 6.4ms preprocess, 204.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 768x1280 1 person, 154.2ms
# Speed: 4.7ms preprocess, 154.2ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x640 1 person, 138.5ms
# Speed: 4.2ms preprocess, 138.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 640)
#
# 0: 1280x896 1 person, 187.0ms
# Speed: 6.1ms preprocess, 187.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1152 1 person, 240.1ms
# Speed: 7.6ms preprocess, 240.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1216x1280 1 person, 244.0ms
# Speed: 7.3ms preprocess, 244.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1280x1280 1 person, 261.7ms
# Speed: 8.3ms preprocess, 261.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1024 1 person, 208.7ms
# Speed: 6.8ms preprocess, 208.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1280 1 person, 259.0ms
# Speed: 8.0ms preprocess, 259.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x832 1 person, 182.8ms
# Speed: 5.1ms preprocess, 182.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1280x1216 1 person, 255.5ms
# Speed: 7.2ms preprocess, 255.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x896 1 person, 190.4ms
# Speed: 6.1ms preprocess, 190.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x768 2 persons, 154.7ms
# Speed: 5.1ms preprocess, 154.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 768)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/diamond/diamond_train_33.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1152x1280 1 person, 231.7ms
# Speed: 8.5ms preprocess, 231.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x1216 1 person, 247.0ms
# Speed: 7.4ms preprocess, 247.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x960 1 person, 198.3ms
# Speed: 6.3ms preprocess, 198.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x896 1 person, 188.4ms
# Speed: 5.5ms preprocess, 188.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1280 1 person, 264.3ms
# Speed: 8.0ms preprocess, 264.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1216 1 person, 256.2ms
# Speed: 7.2ms preprocess, 256.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x960 1 person, 204.1ms
# Speed: 5.8ms preprocess, 204.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x1024 1 person, 204.6ms
# Speed: 6.8ms preprocess, 204.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1280 1 person, 266.2ms
# Speed: 7.9ms preprocess, 266.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x832 1 person, 175.1ms
# Speed: 5.8ms preprocess, 175.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1280x896 1 person, 186.7ms
# Speed: 6.1ms preprocess, 186.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1024 1 person, 198.6ms
# Speed: 7.0ms preprocess, 198.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1088 1 person, 230.7ms
# Speed: 7.4ms preprocess, 230.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x1088 1 person, 235.2ms
# Speed: 7.1ms preprocess, 235.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x1152 1 person, 238.9ms
# Speed: 8.0ms preprocess, 238.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x960 1 person, 207.3ms
# Speed: 6.3ms preprocess, 207.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x1280 1 person, 265.6ms
# Speed: 7.1ms preprocess, 265.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 190.6ms
# Speed: 5.5ms preprocess, 190.6ms inference, 3.4ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1024x1280 1 person, 204.8ms
# Speed: 12.1ms preprocess, 204.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x832 3 persons, 179.3ms
# Speed: 5.8ms preprocess, 179.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 832)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/diamond/diamond_train_32.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1024 1 person, 201.7ms
# Speed: 6.8ms preprocess, 201.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1216 1 person, 259.2ms
# Speed: 7.0ms preprocess, 259.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x512 1 person, 149.1ms
# Speed: 3.5ms preprocess, 149.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 512)
#
# 0: 1280x1024 1 person, 200.9ms
# Speed: 9.1ms preprocess, 200.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1152x1280 1 person, 234.7ms
# Speed: 7.8ms preprocess, 234.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x1280 1 person, 264.2ms
# Speed: 8.9ms preprocess, 264.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1152 1 person, 263.5ms
# Speed: 7.3ms preprocess, 263.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x1024 1 person, 205.8ms
# Speed: 6.8ms preprocess, 205.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1152x1280 1 person, 238.5ms
# Speed: 7.4ms preprocess, 238.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1024x1280 1 person, 205.1ms
# Speed: 6.8ms preprocess, 205.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x960 1 person, 209.9ms
# Speed: 6.8ms preprocess, 209.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x960 1 person, 203.8ms
# Speed: 6.3ms preprocess, 203.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 960x1280 1 person, 199.5ms
# Speed: 5.6ms preprocess, 199.5ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1024 1 person, 202.6ms
# Speed: 6.5ms preprocess, 202.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1152 1 person, 245.5ms
# Speed: 7.7ms preprocess, 245.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x1024 1 person, 206.6ms
# Speed: 6.7ms preprocess, 206.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x832 4 persons, 184.4ms
# Speed: 5.5ms preprocess, 184.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 832)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/diamond/diamond_train_31.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 260.9ms
# Speed: 9.7ms preprocess, 260.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1152x1280 1 person, 237.5ms
# Speed: 7.8ms preprocess, 237.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x896 1 person, 190.0ms
# Speed: 6.0ms preprocess, 190.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1216 1 person, 248.2ms
# Speed: 8.1ms preprocess, 248.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x1280 1 person, 267.4ms
# Speed: 8.8ms preprocess, 267.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 267.5ms
# Speed: 8.7ms preprocess, 267.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x960 1 person, 200.8ms
# Speed: 6.4ms preprocess, 200.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x896 1 person, 194.3ms
# Speed: 6.4ms preprocess, 194.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1216 1 person, 255.4ms
# Speed: 8.3ms preprocess, 255.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1088x1280 1 person, 228.5ms
# Speed: 7.1ms preprocess, 228.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x1280 1 person, 266.4ms
# Speed: 8.6ms preprocess, 266.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 196.5ms
# Speed: 5.8ms preprocess, 196.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1280 1 person, 267.5ms
# Speed: 9.0ms preprocess, 267.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1024 1 person, 210.3ms
# Speed: 6.3ms preprocess, 210.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1152 1 person, 240.0ms
# Speed: 6.9ms preprocess, 240.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x704 1 person, 160.0ms
# Speed: 4.3ms preprocess, 160.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x832 1 person, 179.1ms
# Speed: 5.4ms preprocess, 179.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1216x1280 1 person, 255.6ms
# Speed: 8.5ms preprocess, 255.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1152x1280 1 person, 240.6ms
# Speed: 7.4ms preprocess, 240.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x896 1 person, 194.2ms
# Speed: 5.8ms preprocess, 194.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x832 1 person, 184.4ms
# Speed: 5.7ms preprocess, 184.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1216x1280 1 person, 255.0ms
# Speed: 8.4ms preprocess, 255.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1280x1280 1 person, 266.9ms
# Speed: 9.3ms preprocess, 266.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1152 1 person, 250.0ms
# Speed: 7.7ms preprocess, 250.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x832 1 person, 187.6ms
# Speed: 5.9ms preprocess, 187.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1280x1152 1 person, 240.9ms
# Speed: 8.3ms preprocess, 240.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x1280 1 person, 263.7ms
# Speed: 8.7ms preprocess, 263.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x832 1 person, 184.7ms
# Speed: 5.6ms preprocess, 184.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 960x1280 1 person, 202.5ms
# Speed: 6.8ms preprocess, 202.5ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x960 1 person, 205.2ms
# Speed: 6.4ms preprocess, 205.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x896 1 person, 185.0ms
# Speed: 6.5ms preprocess, 185.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1216 1 person, 260.7ms
# Speed: 7.5ms preprocess, 260.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x1024 1 person, 206.2ms
# Speed: 7.2ms preprocess, 206.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1024 1 person, 206.3ms
# Speed: 7.2ms preprocess, 206.3ms inference, 3.0ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x896 1 person, 187.9ms
# Speed: 5.8ms preprocess, 187.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x832 1 person, 181.3ms
# Speed: 5.8ms preprocess, 181.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1280x1280 1 person, 264.2ms
# Speed: 8.1ms preprocess, 264.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1024 1 person, 205.0ms
# Speed: 6.5ms preprocess, 205.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x832 1 person, 183.5ms
# Speed: 5.3ms preprocess, 183.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1280x960 1 person, 201.0ms
# Speed: 6.7ms preprocess, 201.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x768 1 person, 158.6ms
# Speed: 4.7ms preprocess, 158.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 768)
#
# 0: 1280x1088 1 person, 233.9ms
# Speed: 7.1ms preprocess, 233.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 832x1280 1 person, 172.2ms
# Speed: 6.2ms preprocess, 172.2ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x960 1 person, 205.0ms
# Speed: 6.6ms preprocess, 205.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x576 1 person, 133.5ms
# Speed: 4.1ms preprocess, 133.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 576)
#
# 0: 1280x1024 1 person, 205.3ms
# Speed: 7.8ms preprocess, 205.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1088x1280 1 person, 231.6ms
# Speed: 7.8ms preprocess, 231.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x832 2 persons, 176.5ms
# Speed: 5.8ms preprocess, 176.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 832)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/diamond/diamond_train_86.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 259.2ms
# Speed: 8.8ms preprocess, 259.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1216 1 person, 253.7ms
# Speed: 8.1ms preprocess, 253.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x1088 1 person, 234.0ms
# Speed: 7.6ms preprocess, 234.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x1152 1 person, 242.9ms
# Speed: 8.7ms preprocess, 242.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1024x1280 1 person, 212.4ms
# Speed: 6.4ms preprocess, 212.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 1 person, 252.7ms
# Speed: 7.7ms preprocess, 252.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x768 1 person, 155.2ms
# Speed: 5.5ms preprocess, 155.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 768)
#
# 0: 1280x1088 1 person, 232.6ms
# Speed: 8.1ms preprocess, 232.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x1024 3 persons, 200.9ms
# Speed: 6.0ms preprocess, 200.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1024)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/diamond/diamond_train_159.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1216 1 person, 256.6ms
# Speed: 8.7ms preprocess, 256.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x1152 1 person, 238.5ms
# Speed: 8.0ms preprocess, 238.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 832x1280 1 person, 172.9ms
# Speed: 5.9ms preprocess, 172.9ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x1216 1 person, 253.0ms
# Speed: 7.7ms preprocess, 253.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x1024 1 person, 205.9ms
# Speed: 6.8ms preprocess, 205.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1088 1 person, 239.2ms
# Speed: 7.2ms preprocess, 239.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x832 1 person, 178.1ms
# Speed: 5.9ms preprocess, 178.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1280x1088 1 person, 229.7ms
# Speed: 7.2ms preprocess, 229.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 960x1280 1 person, 194.2ms
# Speed: 6.4ms preprocess, 194.2ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1152 1 person, 235.6ms
# Speed: 7.9ms preprocess, 235.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x896 1 person, 184.1ms
# Speed: 5.5ms preprocess, 184.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1088 1 person, 234.2ms
# Speed: 7.0ms preprocess, 234.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x1216 1 person, 255.9ms
# Speed: 8.4ms preprocess, 255.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x1024 1 person, 198.3ms
# Speed: 6.6ms preprocess, 198.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 960x1280 1 person, 195.4ms
# Speed: 6.5ms preprocess, 195.4ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 263.6ms
# Speed: 8.9ms preprocess, 263.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 261.6ms
# Speed: 8.3ms preprocess, 261.6ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x960 1 person, 198.1ms
# Speed: 6.4ms preprocess, 198.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 960x1280 1 person, 199.2ms
# Speed: 6.0ms preprocess, 199.2ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1024 1 person, 201.7ms
# Speed: 6.8ms preprocess, 201.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1216 1 person, 246.8ms
# Speed: 8.2ms preprocess, 246.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x832 1 person, 176.3ms
# Speed: 5.8ms preprocess, 176.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1280x640 1 person, 136.9ms
# Speed: 4.7ms preprocess, 136.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 640)
#
# 0: 1280x896 1 person, 185.9ms
# Speed: 6.1ms preprocess, 185.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1024 1 person, 204.2ms
# Speed: 6.9ms preprocess, 204.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1088 1 person, 229.2ms
# Speed: 7.1ms preprocess, 229.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 960x1280 1 person, 195.2ms
# Speed: 7.1ms preprocess, 195.2ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1152 1 person, 234.5ms
# Speed: 7.5ms preprocess, 234.5ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x1280 1 person, 262.3ms
# Speed: 8.2ms preprocess, 262.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1088x1280 1 person, 225.5ms
# Speed: 6.6ms preprocess, 225.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1024x1280 2 persons, 203.2ms
# Speed: 6.9ms preprocess, 203.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/diamond/diamond_train_12.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1088 1 person, 227.1ms
# Speed: 7.0ms preprocess, 227.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x960 1 person, 198.1ms
# Speed: 6.5ms preprocess, 198.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x896 1 person, 179.0ms
# Speed: 5.4ms preprocess, 179.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1088 1 person, 227.2ms
# Speed: 7.1ms preprocess, 227.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 896x1280 1 person, 179.0ms
# Speed: 5.9ms preprocess, 179.0ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x704 1 person, 148.6ms
# Speed: 4.8ms preprocess, 148.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x768 1 person, 157.4ms
# Speed: 4.5ms preprocess, 157.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 768)
#
# 0: 1280x1024 1 person, 201.0ms
# Speed: 7.1ms preprocess, 201.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1088 1 person, 224.5ms
# Speed: 6.9ms preprocess, 224.5ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x960 1 person, 196.8ms
# Speed: 7.0ms preprocess, 196.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1024x1280 1 person, 192.7ms
# Speed: 8.4ms preprocess, 192.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1152 1 person, 240.2ms
# Speed: 7.1ms preprocess, 240.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x1152 1 person, 236.6ms
# Speed: 7.6ms preprocess, 236.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x1024 1 person, 198.5ms
# Speed: 6.9ms preprocess, 198.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x896 1 person, 181.3ms
# Speed: 6.0ms preprocess, 181.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x960 1 person, 190.2ms
# Speed: 8.0ms preprocess, 190.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 832x1280 1 person, 170.5ms
# Speed: 5.6ms preprocess, 170.5ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x1088 1 person, 222.3ms
# Speed: 7.5ms preprocess, 222.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x704 1 person, 147.9ms
# Speed: 5.2ms preprocess, 147.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x896 1 person, 185.1ms
# Speed: 5.8ms preprocess, 185.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 832x1280 1 person, 171.0ms
# Speed: 6.9ms preprocess, 171.0ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x960 1 person, 194.7ms
# Speed: 7.2ms preprocess, 194.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1024x1280 1 person, 201.1ms
# Speed: 7.7ms preprocess, 201.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 832x1280 1 person, 171.2ms
# Speed: 5.5ms preprocess, 171.2ms inference, 1.9ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 177.4ms
# Speed: 6.5ms preprocess, 177.4ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x704 1 person, 148.2ms
# Speed: 5.0ms preprocess, 148.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1152x1280 1 person, 232.1ms
# Speed: 7.8ms preprocess, 232.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1216x1280 1 person, 246.1ms
# Speed: 7.9ms preprocess, 246.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 960x1280 1 person, 187.9ms
# Speed: 6.8ms preprocess, 187.9ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 186.1ms
# Speed: 10.2ms preprocess, 186.1ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 170.6ms
# Speed: 8.4ms preprocess, 170.6ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 191.0ms
# Speed: 6.0ms preprocess, 191.0ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 185.9ms
# Speed: 8.2ms preprocess, 185.9ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 145.8ms
# Speed: 5.7ms preprocess, 145.8ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 704x1280 1 person, 145.9ms
# Speed: 5.2ms preprocess, 145.9ms inference, 1.5ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 1 person, 174.4ms
# Speed: 7.0ms preprocess, 174.4ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 640x1280 1 person, 129.2ms
# Speed: 6.3ms preprocess, 129.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 896x1280 1 person, 173.9ms
# Speed: 9.1ms preprocess, 173.9ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 167.7ms
# Speed: 6.0ms preprocess, 167.7ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 147.3ms
# Speed: 5.9ms preprocess, 147.3ms inference, 1.6ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 768x1280 1 person, 152.2ms
# Speed: 4.8ms preprocess, 152.2ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 704x1280 1 person, 138.5ms
# Speed: 5.2ms preprocess, 138.5ms inference, 1.6ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 832x1280 1 person, 162.8ms
# Speed: 9.2ms preprocess, 162.8ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 173.2ms
# Speed: 7.1ms preprocess, 173.2ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1216 1 person, 246.7ms
# Speed: 6.9ms preprocess, 246.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 896x1280 1 person, 182.6ms
# Speed: 6.3ms preprocess, 182.6ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 169.4ms
# Speed: 11.3ms preprocess, 169.4ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 170.2ms
# Speed: 9.0ms preprocess, 170.2ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 165.1ms
# Speed: 5.9ms preprocess, 165.1ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 704x1280 1 person, 138.5ms
# Speed: 5.8ms preprocess, 138.5ms inference, 1.6ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 768x1280 1 person, 152.7ms
# Speed: 6.3ms preprocess, 152.7ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 252.5ms
# Speed: 9.1ms preprocess, 252.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 187.1ms
# Speed: 7.7ms preprocess, 187.1ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0:
ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 170.9ms
# Speed: 8.3ms preprocess, 170.9ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 162.9ms
# Speed: 7.3ms preprocess, 162.9ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 173.4ms
# Speed: 6.8ms preprocess, 173.4ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 163.2ms
# Speed: 6.1ms preprocess, 163.2ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 704x1280 1 person, 145.6ms
# Speed: 6.0ms preprocess, 145.6ms inference, 1.5ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1024 1 person, 197.2ms
# Speed: 6.6ms preprocess, 197.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 768x1280 1 person, 145.7ms
# Speed: 6.0ms preprocess, 145.7ms inference, 1.4ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 832x1280 1 person, 164.6ms
# Speed: 6.5ms preprocess, 164.6ms inference, 2.1ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 832x1280 1 person, 160.8ms
# Speed: 5.4ms preprocess, 160.8ms inference, 1.9ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 151.1ms
# Speed: 6.0ms preprocess, 151.1ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 832x1280 1 person, 163.0ms
# Speed: 6.2ms preprocess, 163.0ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x896 1 person, 176.1ms
# Speed: 6.5ms preprocess, 176.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1024 1 person, 194.7ms
# Speed: 6.8ms preprocess, 194.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 768x1280 1 person, 144.3ms
# Speed: 7.1ms preprocess, 144.3ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 245.3ms
# Speed: 8.9ms preprocess, 245.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 170.5ms
# Speed: 7.3ms preprocess, 170.5ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x896 1 person, 175.5ms
# Speed: 6.7ms preprocess, 175.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 640x1280 1 person, 120.8ms
# Speed: 4.8ms preprocess, 120.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 960x1280 1 person, 186.6ms
# Speed: 10.3ms preprocess, 186.6ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 704x1280 1 person, 138.7ms
# Speed: 4.8ms preprocess, 138.7ms inference, 1.5ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 1 person, 170.7ms
# Speed: 5.7ms preprocess, 170.7ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 187.6ms
# Speed: 6.8ms preprocess, 187.6ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x896 1 person, 175.8ms
# Speed: 9.3ms preprocess, 175.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 960x1280 1 person, 184.2ms
# Speed: 7.8ms preprocess, 184.2ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1024x1280 1 person, 196.2ms
# Speed: 6.1ms preprocess, 196.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 187.8ms
# Speed: 5.9ms preprocess, 187.8ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 191.5ms
# Speed: 6.4ms preprocess, 191.5ms inference, 2.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1024x1280 1 person, 193.6ms
# Speed: 8.4ms preprocess, 193.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 187.9ms
# Speed: 5.8ms preprocess, 187.9ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 704x1280 1 person, 143.1ms
# Speed: 4.6ms preprocess, 143.1ms inference, 1.5ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1280 1 person, 240.8ms
# Speed: 13.1ms preprocess, 240.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 172.4ms
# Speed: 5.4ms preprocess, 172.4ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 185.4ms
# Speed: 7.4ms preprocess, 185.4ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 194.0ms
# Speed: 7.6ms preprocess, 194.0ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 1 person, 165.5ms
# Speed: 7.1ms preprocess, 165.5ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 832x1280 1 person, 162.1ms
# Speed: 6.5ms preprocess, 162.1ms inference, 2.1ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 169.8ms
# Speed: 7.4ms preprocess, 169.8ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 168.5ms
# Speed: 7.4ms preprocess, 168.5ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 192.4ms
# Speed: 6.5ms preprocess, 192.4ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 175.8ms
# Speed: 6.8ms preprocess, 175.8ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 149.4ms
# Speed: 6.1ms preprocess, 149.4ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 173.5ms
# Speed: 6.9ms preprocess, 173.5ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 185.0ms
# Speed: 7.8ms preprocess, 185.0ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 184.2ms
# Speed: 8.9ms preprocess, 184.2ms inference, 2.4ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 185.1ms
# Speed: 9.1ms preprocess, 185.1ms inference, 2.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 187.7ms
# Speed: 6.8ms preprocess, 187.7ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 2 persons, 184.3ms
# Speed: 7.2ms preprocess, 184.3ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/downdog/downdog_train_134.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 960x1280 1 person, 185.0ms
# Speed: 5.9ms preprocess, 185.0ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 148.4ms
# Speed: 6.5ms preprocess, 148.4ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 246.8ms
# Speed: 9.4ms preprocess, 246.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 175.8ms
# Speed: 5.4ms preprocess, 175.8ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 170.9ms
# Speed: 9.4ms preprocess, 170.9ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x896 1 person, 175.0ms
# Speed: 14.0ms preprocess, 175.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 170.3ms
# Speed: 8.4ms preprocess, 170.3ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 168.1ms
# Speed: 5.9ms preprocess, 168.1ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1152x1280 1 person, 226.2ms
# Speed: 8.9ms preprocess, 226.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 832x1280 1 person, 161.6ms
# Speed: 6.5ms preprocess, 161.6ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 145.2ms
# Speed: 7.6ms preprocess, 145.2ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 832x1280 1 person, 164.0ms
# Speed: 5.5ms preprocess, 164.0ms inference, 1.9ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 188.3ms
# Speed: 9.3ms preprocess, 188.3ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x896 1 person, 173.3ms
# Speed: 9.3ms preprocess, 173.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 960x1280 1 person, 188.2ms
# Speed: 8.4ms preprocess, 188.2ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 250.7ms
# Speed: 9.1ms preprocess, 250.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 185.9ms
# Speed: 6.2ms preprocess, 185.9ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 173.3ms
# Speed: 7.4ms preprocess, 173.3ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 173.9ms
# Speed: 6.7ms preprocess, 173.9ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 173.1ms
# Speed: 6.0ms preprocess, 173.1ms inference, 2.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 147.5ms
# Speed: 3.6ms preprocess, 147.5ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 184.0ms
# Speed: 6.6ms preprocess, 184.0ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 193.1ms
# Speed: 7.6ms preprocess, 193.1ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 176.3ms
# Speed: 5.6ms preprocess, 176.3ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 167.2ms
# Speed: 8.6ms preprocess, 167.2ms inference, 3.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 149.7ms
# Speed: 7.6ms preprocess, 149.7ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 704x1280 1 person, 142.1ms
# Speed: 6.9ms preprocess, 142.1ms inference, 1.5ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 1 person, 175.8ms
# Speed: 5.6ms preprocess, 175.8ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 184.9ms
# Speed: 6.4ms preprocess, 184.9ms inference, 4.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 165.9ms
# Speed: 8.2ms preprocess, 165.9ms inference, 2.0ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1024x1280 1 person, 196.5ms
# Speed: 7.4ms preprocess, 196.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 185.2ms
# Speed: 8.6ms preprocess, 185.2ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 257.6ms
# Speed: 8.9ms preprocess, 257.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 169.4ms
# Speed: 7.4ms preprocess, 169.4ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 150.4ms
# Speed: 6.7ms preprocess, 150.4ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 189.1ms
# Speed: 8.0ms preprocess, 189.1ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 172.5ms
# Speed: 9.7ms preprocess, 172.5ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 163.5ms
# Speed: 9.6ms preprocess, 163.5ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 147.4ms
# Speed: 6.8ms preprocess, 147.4ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1088x1280 1 person, 218.4ms
# Speed: 6.7ms preprocess, 218.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 640x1280 1 person, 123.8ms
# Speed: 4.6ms preprocess, 123.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 1280x896 1 person, 176.6ms
# Speed: 9.1ms preprocess, 176.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 768x1280 1 person, 147.9ms
# Speed: 5.9ms preprocess, 147.9ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 832x1280 1 person, 165.6ms
# Speed: 7.0ms preprocess, 165.6ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 148.1ms
# Speed: 5.2ms preprocess, 148.1ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 152.1ms
# Speed: 6.2ms preprocess, 152.1ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 191.9ms
# Speed: 7.3ms preprocess, 191.9ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 181.5ms
# Speed: 6.5ms preprocess, 181.5ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 165.8ms
# Speed: 6.2ms preprocess, 165.8ms inference, 1.4ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 156.5ms
# Speed: 5.4ms preprocess, 156.5ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 153.1ms
# Speed: 5.3ms preprocess, 153.1ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 179.0ms
# Speed: 6.1ms preprocess, 179.0ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 195.9ms
# Speed: 6.3ms preprocess, 195.9ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 194.3ms
# Speed: 5.9ms preprocess, 194.3ms inference, 3.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 1 person, 171.3ms
# Speed: 7.6ms preprocess, 171.3ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 150.7ms
# ...
# Speed: 6.3ms preprocess, 180.0ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.3ms
# Speed: 6.4ms preprocess, 180.3ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.0ms
# Speed: 7.2ms preprocess, 179.0ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 155.3ms
# Speed: 5.2ms preprocess, 155.3ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x896 1 person, 178.5ms
# Speed: 6.9ms preprocess, 178.5ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 180.2ms
# Speed: 6.1ms preprocess, 180.2ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 156.3ms
# Speed: 6.4ms preprocess, 156.3ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 180.1ms
# Speed: 6.6ms preprocess, 180.1ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 197.1ms
# Speed: 6.7ms preprocess, 197.1ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 179.3ms
# Speed: 6.4ms preprocess, 179.3ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 153.5ms
# Speed: 5.5ms preprocess, 153.5ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 179.1ms
# Speed: 6.6ms preprocess, 179.1ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.9ms
# Speed: 6.3ms preprocess, 180.9ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 172.6ms
# Speed: 6.9ms preprocess, 172.6ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 178.5ms
# Speed: 6.1ms preprocess, 178.5ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.2ms
# Speed: 7.3ms preprocess, 180.2ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 178.2ms
# Speed: 6.6ms preprocess, 178.2ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 177.6ms
# Speed: 6.2ms preprocess, 177.6ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 173.8ms
# Speed: 7.2ms preprocess, 173.8ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 172.5ms
# Speed: 5.7ms preprocess, 172.5ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 152.5ms
# Speed: 5.7ms preprocess, 152.5ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 178.9ms
# Speed: 6.3ms preprocess, 178.9ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 177.7ms
# Speed: 6.6ms preprocess, 177.7ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 177.4ms
# Speed: 6.4ms preprocess, 177.4ms inference, 3.3ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 174.8ms
# Speed: 6.4ms preprocess, 174.8ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 181.4ms
# Speed: 6.6ms preprocess, 181.4ms inference, 2.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x896 1 person, 183.9ms
# Speed: 7.9ms preprocess, 183.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1280 1 person, 259.5ms
# Speed: 8.3ms preprocess, 259.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x960 1 person, 194.8ms
# Speed: 7.0ms preprocess, 194.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 896x1280 1 person, 179.7ms
# Speed: 7.1ms preprocess, 179.7ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 2 persons, 174.9ms
# Speed: 6.2ms preprocess, 174.9ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/wheel/wheel_train_134.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 896x1280 1 person, 176.2ms
# Speed: 6.6ms preprocess, 176.2ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 195.8ms
# Speed: 6.5ms preprocess, 195.8ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 1 person, 175.0ms
# Speed: 6.3ms preprocess, 175.0ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 174.7ms
# Speed: 6.0ms preprocess, 174.7ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 177.4ms
# Speed: 5.9ms preprocess, 177.4ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 177.9ms
# Speed: 6.2ms preprocess, 177.9ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 255.6ms
# Speed: 7.7ms preprocess, 255.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 176.0ms
# Speed: 6.1ms preprocess, 176.0ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 176.0ms
# Speed: 5.6ms preprocess, 176.0ms inference, 2.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 150.5ms
# Speed: 5.5ms preprocess, 150.5ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 2 persons, 183.3ms
# Speed: 6.3ms preprocess, 183.3ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/wheel/wheel_train_110.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 258.7ms
# Speed: 9.2ms preprocess, 258.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 154.4ms
# Speed: 6.9ms preprocess, 154.4ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 182.1ms
# Speed: 6.6ms preprocess, 182.1ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 173.3ms
# Speed: 6.8ms preprocess, 173.3ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 176.5ms
# Speed: 8.1ms preprocess, 176.5ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.1ms
# Speed: 6.8ms preprocess, 179.1ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.0ms
# Speed: 6.1ms preprocess, 180.0ms inference, 4.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 181.6ms
# Speed: 7.3ms preprocess, 181.6ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.1ms
# Speed: 6.2ms preprocess, 179.1ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 178.2ms
# Speed: 5.8ms preprocess, 178.2ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 177.3ms
# Speed: 6.2ms preprocess, 177.3ms inference, 2.4ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 197.8ms
# Speed: 6.1ms preprocess, 197.8ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 183.4ms
# Speed: 6.0ms preprocess, 183.4ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 177.4ms
# Speed: 6.0ms preprocess, 177.4ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 173.8ms
# Speed: 5.9ms preprocess, 173.8ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.6ms
# Speed: 6.4ms preprocess, 179.6ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.4ms
# Speed: 6.1ms preprocess, 180.4ms inference, 3.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 174.6ms
# Speed: 6.2ms preprocess, 174.6ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.2ms
# Speed: 6.0ms preprocess, 179.2ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 181.2ms
# Speed: 6.8ms preprocess, 181.2ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.5ms
# Speed: 7.3ms preprocess, 180.5ms inference, 3.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 182.4ms
# Speed: 7.1ms preprocess, 182.4ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 169.9ms
# Speed: 6.9ms preprocess, 169.9ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 151.8ms
# Speed: 5.4ms preprocess, 151.8ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 178.5ms
# Speed: 6.4ms preprocess, 178.5ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.9ms
# Speed: 6.7ms preprocess, 179.9ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.3ms
# Speed: 5.9ms preprocess, 180.3ms inference, 3.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 195.3ms
# Speed: 6.1ms preprocess, 195.3ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 177.1ms
# Speed: 6.0ms preprocess, 177.1ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 173.9ms
# Speed: 6.0ms preprocess, 173.9ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 158.1ms
# Speed: 6.3ms preprocess, 158.1ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 152.8ms
# Speed: 5.4ms preprocess, 152.8ms inference, 1.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 2 persons, 179.4ms
# Speed: 5.7ms preprocess, 179.4ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/wheel/wheel_train_13.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 896x1280 1 person, 174.9ms
# Speed: 7.6ms preprocess, 174.9ms inference, 2.3ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person,
ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 157.5ms
# Speed: 5.2ms preprocess, 157.5ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 180.1ms
# Speed: 5.8ms preprocess, 180.1ms inference, 1.4ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.9ms
# Speed: 7.1ms preprocess, 179.9ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.9ms
# Speed: 6.3ms preprocess, 179.9ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.0ms
# Speed: 6.6ms preprocess, 179.0ms inference, 2.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 2 persons, 179.5ms
# Speed: 6.3ms preprocess, 179.5ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/wheel/wheel_train_51.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------

# %%
dataset_csv_test = []
for pose in pose_list:
    # Using a set to store valid image extensions
    valid_extensions = {'jpg', 'jpeg', 'png', 'bmp'}

    # List all files in the directory
    image_path_list = []
    for ext in valid_extensions:
        image_path_list.extend(glob.glob(f'{dataset_root_test}/{pose}/*.{ext}'))

    for image_path in image_path_list:
        # get image_name
        image_name = image_path.split('/')[-1]
        # read numpy image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip to the next image if reading fails

        # get height width image
        height, width = image.shape[:2]

        # detect pose using yolov8-pose
        results = model.predict(image, save=False)[0]
        results_keypoint = results.keypoints.xyn.cpu().numpy()

        # Check if only one person is detected
        if len(results_keypoint) == 1:
            result_keypoint = results_keypoint[0]
            if len(result_keypoint) == 17:
                keypoint_list = extract_keypoint(result_keypoint)

                # insert image_name, label at index 0, 1
                keypoint_list.insert(0, image_path)
                keypoint_list.insert(1, pose)
                dataset_csv_test.append(keypoint_list)
        else:
            print("------------------------------------------------------------------------")
            print(f"More than one person detected in image: {image_path}. Ignoring pose landmarks.")
            print("------------------------------------------------------------------------")
# Out:
# 0: 1280x896 1 person, 228.5ms
# Speed: 9.5ms preprocess, 228.5ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1216x1280 1 person, 231.2ms
# Speed: 7.7ms preprocess, 231.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1280x832 1 person, 167.9ms
# Speed: 6.7ms preprocess, 167.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 960x1280 1 person, 184.0ms
# Speed: 7.3ms preprocess, 184.0ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 181.7ms
# Speed: 7.7ms preprocess, 181.7ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 181.5ms
# Speed: 9.3ms preprocess, 181.5ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1024 1 person, 189.3ms
# Speed: 6.2ms preprocess, 189.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x896 1 person, 173.8ms
# Speed: 6.4ms preprocess, 173.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 960x1280 1 person, 183.3ms
# Speed: 7.5ms preprocess, 183.3ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x896 1 person, 179.7ms
# Speed: 6.3ms preprocess, 179.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x896 1 person, 173.7ms
# Speed: 6.3ms preprocess, 173.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 175.2ms
# Speed: 8.1ms preprocess, 175.2ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x960 1 person, 193.9ms
# Speed: 6.3ms preprocess, 193.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 960x1280 1 person, 184.7ms
# Speed: 7.5ms preprocess, 184.7ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1152x1280 1 person, 220.4ms
# Speed: 8.8ms preprocess, 220.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 960x1280 1 person, 185.9ms
# Speed: 7.7ms preprocess, 185.9ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 172.1ms
# Speed: 6.6ms preprocess, 172.1ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 185.4ms
# Speed: 7.3ms preprocess, 185.4ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 2 persons, 243.4ms
# Speed: 8.7ms preprocess, 243.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/Padmasana/padmasana_test_25.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 960x1280 1 person, 186.5ms
# Speed: 7.5ms preprocess, 186.5ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x896 1 person, 177.8ms
# Speed: 7.1ms preprocess, 177.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 960x1280 1 person, 186.4ms
# Speed: 7.5ms preprocess, 186.4ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 174.1ms
# Speed: 6.4ms preprocess, 174.1ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1088x1280 1 person, 214.2ms
# Speed: 8.3ms preprocess, 214.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 960x1280 1 person, 185.3ms
# Speed: 7.7ms preprocess, 185.3ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x960 1 person, 189.5ms
# Speed: 7.0ms preprocess, 189.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 960x1280 1 person, 188.8ms
# Speed: 7.6ms preprocess, 188.8ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 183.6ms
# Speed: 11.3ms preprocess, 183.6ms inference, 3.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 185.5ms
# Speed: 7.9ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x704 1 person, 144.8ms
# Speed: 4.6ms preprocess, 144.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x832 1 person, 169.3ms
# Speed: 7.4ms preprocess, 169.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1088x1280 1 person, 225.7ms
# Speed: 7.4ms preprocess, 225.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x832 1 person, 177.7ms
# Speed: 6.5ms preprocess, 177.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 960x1280 1 person, 187.4ms
# Speed: 7.5ms preprocess, 187.4ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 173.1ms
# Speed: 9.3ms preprocess, 173.1ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1024x1280 1 person, 195.6ms
# Speed: 8.2ms preprocess, 195.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 188.8ms
# Speed: 7.7ms preprocess, 188.8ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 186.0ms
# Speed: 7.3ms preprocess, 186.0ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 187.4ms
# Speed: 7.3ms preprocess, 187.4ms inference, 1.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 188.4ms
# Speed: 7.4ms preprocess, 188.4ms inference, 3.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 186.7ms
# Speed: 7.6ms preprocess, 186.7ms inference, 2.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 149.8ms
# Speed: 5.5ms preprocess, 149.8ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 190.1ms
# Speed: 7.4ms preprocess, 190.1ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 191.4ms
# Speed: 7.9ms preprocess, 191.4ms inference, 2.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x832 1 person, 174.9ms
# Speed: 6.8ms preprocess, 174.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1280x1152 1 person, 233.8ms
# Speed: 8.1ms preprocess, 233.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 960x1280 1 person, 191.6ms
# Speed: 7.7ms preprocess, 191.6ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 175.9ms
# Speed: 9.4ms preprocess, 175.9ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 190.0ms
# Speed: 7.6ms preprocess, 190.0ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x832 1 person, 174.3ms
# Speed: 6.5ms preprocess, 174.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1280x896 1 person, 180.4ms
# Speed: 9.6ms preprocess, 180.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x832 1 person, 171.7ms
# Speed: 7.0ms preprocess, 171.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 960x1280 1 person, 191.8ms
# Speed: 7.9ms preprocess, 191.8ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x896 1 person, 179.5ms
# Speed: 7.1ms preprocess, 179.5ms inference, 3.0ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 960x1280 1 person, 192.4ms
# Speed: 8.3ms preprocess, 192.4ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x832 1 person, 172.1ms
# Speed: 7.3ms preprocess, 172.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 896x1280 1 person, 175.0ms
# Speed: 9.0ms preprocess, 175.0ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 194.3ms
# Speed: 8.3ms preprocess, 194.3ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 190.2ms
# Speed: 7.6ms preprocess, 190.2ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x896 1 person, 184.9ms
# Speed: 6.9ms preprocess, 184.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 768x1280 1 person, 149.9ms
# Speed: 5.1ms preprocess, 149.9ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 188.7ms
# Speed: 5.4ms preprocess, 188.7ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 182.3ms
# Speed: 6.0ms preprocess, 182.3ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.5ms
# Speed: 6.0ms preprocess, 180.5ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 181.7ms
# Speed: 5.4ms preprocess, 181.7ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 171.5ms
# Speed: 5.0ms preprocess, 171.5ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 185.8ms
# Speed: 6.1ms preprocess, 185.8ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 184.0ms
# Speed: 6.0ms preprocess, 184.0ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 181.6ms
# Speed: 5.9ms preprocess, 181.6ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 153.6ms
# Speed: 5.2ms preprocess, 153.6ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 1 person, 199.9ms
# Speed: 5.5ms preprocess, 199.9ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 188.5ms
# Speed: 5.3ms preprocess, 188.5ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 161.6ms
# Speed: 5.9ms preprocess, 161.6ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 200.2ms
# Speed: 5.2ms preprocess, 200.2ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 182.9ms
# Speed: 5.8ms preprocess, 182.9ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.8ms
# Speed: 6.2ms preprocess, 180.8ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.1ms
# Speed: 6.4ms preprocess, 179.1ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 178.7ms
# Speed: 6.2ms preprocess, 178.7ms inference, 2.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 183.6ms
# Speed: 5.5ms preprocess, 183.6ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 156.3ms
# Speed: 4.8ms preprocess, 156.3ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 181.6ms
# Speed: 5.9ms preprocess, 181.6ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 152.8ms
# Speed: 4.7ms preprocess, 152.8ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 185.8ms
# Speed: 6.0ms preprocess, 185.8ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 175.8ms
# Speed: 6.9ms preprocess, 175.8ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 185.3ms
# Speed: 5.9ms preprocess, 185.3ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 175.5ms
# Speed: 4.7ms preprocess, 175.5ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x1024 1 person, 205.0ms
# Speed: 5.8ms preprocess, 205.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 640x1280 1 person, 133.8ms
# Speed: 4.7ms preprocess, 133.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 768x1280 1 person, 157.5ms
# Speed: 4.5ms preprocess, 157.5ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 180.8ms
# Speed: 6.0ms preprocess, 180.8ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 185.1ms
# Speed: 5.8ms preprocess, 185.1ms inference, 3.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 193.3ms
# Speed: 5.4ms preprocess, 193.3ms inference, 3.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 185.1ms
# Speed: 5.9ms preprocess, 185.1ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 188.7ms
# Speed: 6.0ms preprocess, 188.7ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 179.4ms
# Speed: 5.2ms preprocess, 179.4ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 832x1280 1 person, 174.5ms
# Speed: 5.4ms preprocess, 174.5ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 190.8ms
# Speed: 5.6ms preprocess, 190.8ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 187.4ms
# Speed: 5.0ms preprocess, 187.4ms inference, 2.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 185.6ms
# Speed: 5.9ms preprocess, 185.6ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 186.7ms
# Speed: 5.6ms preprocess, 186.7ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 158.9ms
# Speed: 4.9ms preprocess, 158.9ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 187.4ms
# Speed: 6.6ms preprocess, 187.4ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 185.0ms
# Speed: 6.0ms preprocess, 185.0ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 157.3ms
# Speed: 4.6ms preprocess, 157.3ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 189.0ms
# Speed: 5.2ms preprocess, 189.0ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 185.1ms
# Speed: 6.1ms preprocess, 185.1ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x896 1 person, 191.9ms
# Speed: 5.9ms preprocess, 191.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 832x1280 1 person, 182.2ms
# Speed: 5.5ms preprocess, 182.2ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 189.6ms
# Speed: 6.1ms preprocess, 189.6ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 189.6ms
# Speed: 6.3ms preprocess, 189.6ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 271.5ms
# Speed: 7.5ms preprocess, 271.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 184.8ms
# Speed: 5.9ms preprocess, 184.8ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 185.4ms
# Speed: 7.2ms preprocess, 185.4ms inference, 3.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1216 1 person, 267.6ms
# Speed: 7.5ms preprocess, 267.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1216x1280 1 person, 259.9ms
# Speed: 7.6ms preprocess, 259.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1280x1152 1 person, 249.1ms
# Speed: 7.1ms preprocess, 249.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x1152 1 person, 249.9ms
# Speed: 7.2ms preprocess, 249.9ms inference, 3.3ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x704 2 persons, 160.1ms
# Speed: 4.6ms preprocess, 160.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/diamond/diamond_test_41.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x896 1 person, 189.0ms
# Speed: 5.7ms preprocess, 189.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 832x1280 1 person, 176.3ms
# Speed: 5.3ms preprocess, 176.3ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x1152 1 person, 246.5ms
# Speed: 7.1ms preprocess, 246.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x1280 1 person, 284.5ms
# Speed: 8.2ms preprocess, 284.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1216 1 person, 259.5ms
# Speed: 7.8ms preprocess, 259.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x1216 1 person, 262.5ms
# Speed: 7.0ms preprocess, 262.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x1280 1 person, 268.7ms
# Speed: 8.3ms preprocess, 268.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1088 1 person, 248.6ms
# Speed: 7.2ms preprocess, 248.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x832 1 person, 186.7ms
# Speed: 5.4ms preprocess, 186.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1088x1280 1 person, 238.8ms
# Speed: 6.4ms preprocess, 238.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1216x1280 1 person, 262.7ms
# Speed: 6.8ms preprocess, 262.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1280x1024 1 person, 217.9ms
# Speed: 6.2ms preprocess, 217.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x960 1 person, 210.8ms
# Speed: 5.9ms preprocess, 210.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1152x1280 1 person, 240.7ms
# Speed: 7.0ms preprocess, 240.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x512 2 persons, 106.2ms
# Speed: 3.3ms preprocess, 106.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 512)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/diamond/diamond_test_39.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1152 1 person, 248.9ms
# Speed: 7.0ms preprocess, 248.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x1280 1 person, 282.5ms
# Speed: 7.6ms preprocess, 282.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1088x1280 1 person, 237.9ms
# Speed: 6.6ms preprocess, 237.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1152x1280 1 person, 252.6ms
# Speed: 6.8ms preprocess, 252.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x832 1 person, 187.7ms
# Speed: 5.2ms preprocess, 187.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 832)
#
# 0: 1280x768 1 person, 159.9ms
# Speed: 4.8ms preprocess, 159.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 768)
#
# 0: 1280x1088 1 person, 242.9ms
# Speed: 6.9ms preprocess, 242.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1216x1280 1 person, 266.6ms
# Speed: 7.2ms preprocess, 266.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1024x1280 1 person, 216.9ms
# Speed: 6.9ms preprocess, 216.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1216 1 person, 267.5ms
# Speed: 7.7ms preprocess, 267.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x960 1 person, 210.7ms
# Speed: 5.5ms preprocess, 210.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x1024 1 person, 215.7ms
# Speed: 6.9ms preprocess, 215.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1088x1280 1 person, 239.3ms
# Speed: 6.8ms preprocess, 239.3ms inference, 1.4ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x1152 1 person, 253.5ms
# Speed: 7.6ms preprocess, 253.5ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1024x1280 1 person, 219.0ms
# Speed: 5.8ms preprocess, 219.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1024 2 persons, 215.4ms
# Speed: 6.3ms preprocess, 215.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/diamond/diamond_test_34.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1216x1280 1 person, 259.7ms
# Speed: 7.1ms preprocess, 259.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1280x960 1 person, 209.4ms
# Speed: 6.3ms preprocess, 209.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x960 1 person, 210.6ms
# Speed: 6.3ms preprocess, 210.6ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x1088 1 person, 242.4ms
# Speed: 6.8ms preprocess, 242.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1280x960 1 person, 209.5ms
# Speed: 5.8ms preprocess, 209.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x704 1 person, 154.9ms
# Speed: 4.4ms preprocess, 154.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 704)
#
# 0: 1280x1280 1 person, 275.5ms
# Speed: 7.3ms preprocess, 275.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1088 1 person, 241.9ms
# Speed: 7.2ms preprocess, 241.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1088x1280 1 person, 238.4ms
# Speed: 6.6ms preprocess, 238.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x768 1 person, 161.3ms
# Speed: 4.9ms preprocess, 161.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 768)
#
# 0: 1088x1280 1 person, 234.4ms
# Speed: 7.1ms preprocess, 234.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1216x1280 1 person, 255.4ms
# Speed: 8.1ms preprocess, 255.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1280x832 2 persons, 181.9ms
# Speed: 5.6ms preprocess, 181.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 832)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/diamond/diamond_test_26.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 272.6ms
# Speed: 7.8ms preprocess, 272.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 1 person, 179.0ms
# Speed: 6.9ms preprocess, 179.0ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 832x1280 1 person, 170.2ms
# Speed: 7.2ms preprocess, 170.2ms inference, 2.0ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x1280 1 person, 260.1ms
# Speed: 7.9ms preprocess, 260.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 179.4ms
# Speed: 10.0ms preprocess, 179.4ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 171.3ms
# Speed: 6.5ms preprocess, 171.3ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x1280 1 person, 268.8ms
# Speed: 8.5ms preprocess, 268.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 1 person, 192.1ms
# Speed: 8.3ms preprocess, 192.1ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 159.2ms
# Speed: 5.3ms preprocess, 159.2ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 177.8ms
# Speed: 6.8ms preprocess, 177.8ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 195.3ms
# Speed: 8.1ms preprocess, 195.3ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 1 person, 170.4ms
# Speed: 5.0ms preprocess, 170.4ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 184.9ms
# Speed: 7.0ms preprocess, 184.9ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 161.5ms
# Speed: 5.3ms preprocess, 161.5ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 172.5ms
# Speed: 9.0ms preprocess, 172.5ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 178.5ms
# Speed: 6.0ms preprocess, 178.5ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 143.3ms
# Speed: 5.4ms preprocess, 143.3ms inference, 1.5ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1024x1280 1 person, 203.0ms
# Speed: 6.8ms preprocess, 203.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 768x1280 1 person, 172.0ms
# Speed: 5.3ms preprocess, 172.0ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 704x1280 1 person, 143.5ms
# Speed: 5.2ms preprocess, 143.5ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 960x1280 1 person, 199.2ms
# Speed: 6.6ms preprocess, 199.2ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 768x1280 1 person, 150.2ms
# Speed: 5.5ms preprocess, 150.2ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 151.5ms
# Speed: 5.6ms preprocess, 151.5ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 184.6ms
# Speed: 6.7ms preprocess, 184.6ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 155.1ms
# Speed: 5.5ms preprocess, 155.1ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1024x1280 1 person, 207.2ms
# Speed: 6.2ms preprocess, 207.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1024x1280 1 person, 204.0ms
# Speed: 8.2ms preprocess, 204.0ms inference, 3.0ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 832x1280 1 person, 167.9ms
# Speed: 5.6ms preprocess, 167.9ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 148.2ms
# Speed: 5.6ms preprocess, 148.2ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 151.0ms
# Speed: 6.1ms preprocess, 151.0ms inference, 1.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 271.2ms
# Speed: 9.5ms preprocess, 271.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 176.7ms
# Speed: 6.4ms preprocess, 176.7ms inference, 1.4ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 262.5ms
# Speed: 7.4ms preprocess, 262.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 178.8ms
# Speed: 6.8ms preprocess, 178.8ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 154.4ms
# Speed: 5.7ms preprocess, 154.4ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x896 1 person, 184.9ms
# Speed: 6.6ms preprocess, 184.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 896x1280 1 person, 179.0ms
# Speed: 6.2ms preprocess, 179.0ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 187.8ms
# Speed: 6.4ms preprocess, 187.8ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 195.5ms
# Speed: 7.3ms preprocess, 195.5ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 832x1280 1 person, 169.7ms
# Speed: 5.9ms preprocess, 169.7ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 149.8ms
# Speed: 6.1ms preprocess, 149.8ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 177.2ms
# Speed: 6.0ms preprocess, 177.2ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.1ms
# Speed: 7.6ms preprocess, 180.1ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 162.7ms
# Speed: 6.8ms preprocess, 162.7ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 178.4ms
# Speed: 6.1ms preprocess, 178.4ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 832x1280 1 person, 166.7ms
# Speed: 5.6ms preprocess, 166.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 576x1280 1 person, 124.3ms
# Speed: 4.5ms preprocess, 124.3ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1280)
#
# 0: 1280x1280 1 person, 259.4ms
# Speed: 7.9ms preprocess, 259.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 173.5ms
# Speed: 13.8ms preprocess, 173.5ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 143.9ms
# Speed: 5.6ms preprocess, 143.9ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 149.2ms
# Speed: 3.3ms preprocess, 149.2ms inference, 2.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 146.3ms
# Speed: 5.6ms preprocess, 146.3ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 832x1280 1 person, 177.5ms
# Speed: 6.9ms preprocess, 177.5ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 148.0ms
# Speed: 5.5ms preprocess, 148.0ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 960x1280 2 persons, 192.4ms
# Speed: 8.2ms preprocess, 192.4ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/downdog/downdog_test_15.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 896x1280 1 person, 178.0ms
# Speed: 6.4ms preprocess, 178.0ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 191.3ms
# Speed: 6.8ms preprocess, 191.3ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1152x1280 1 person, 227.5ms
# Speed: 9.1ms preprocess, 227.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 960x1280 1 person, 189.5ms
# Speed: 7.9ms preprocess, 189.5ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1088x1280 1 person, 217.3ms
# Speed: 8.4ms preprocess, 217.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1152x1280 1 person, 228.7ms
# Speed: 9.2ms preprocess, 228.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1024x1280 1 person, 203.9ms
# Speed: 8.0ms preprocess, 203.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1152 1 person, 236.7ms
# Speed: 7.9ms preprocess, 236.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1152x1280 1 person, 227.8ms
# Speed: 8.9ms preprocess, 227.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1152x1280 1 person, 227.0ms
# Speed: 8.4ms preprocess, 227.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x1280 1 person, 254.5ms
# Speed: 7.0ms preprocess, 254.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1088x1280 1 person, 222.0ms
# Speed: 7.4ms preprocess, 222.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 960x1280 1 person, 193.4ms
# Speed: 7.9ms preprocess, 193.4ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1152x1280 1 person, 224.3ms
# Speed: 10.1ms preprocess, 224.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1088x1280 1 person, 212.5ms
# Speed: 8.3ms preprocess, 212.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x1216 1 person, 249.1ms
# Speed: 8.6ms preprocess, 249.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1024x1280 1 person, 201.4ms
# Speed: 8.5ms preprocess, 201.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1024x1280 1 person, 193.3ms
# Speed: 7.8ms preprocess, 193.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 1 person, 251.0ms
# Speed: 7.2ms preprocess, 251.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1216x1280 1 person, 240.7ms
# Speed: 9.3ms preprocess, 240.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1280x1216 1 person, 257.8ms
# Speed: 8.3ms preprocess, 257.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1152x1280 1 person, 222.0ms
# Speed: 9.1ms preprocess, 222.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x1088 1 person, 232.8ms
# Speed: 7.3ms preprocess, 232.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1088)
#
# 0: 1088x1280 2 persons, 213.4ms
# Speed: 8.5ms preprocess, 213.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1088, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/goddess/goddess_test_30.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1024 1 person, 196.5ms
# Speed: 7.2ms preprocess, 196.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 1280x1216 1 person, 244.2ms
# Speed: 8.4ms preprocess, 244.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x960 1 person, 198.6ms
# Speed: 6.2ms preprocess, 198.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x1280 1 person, 256.7ms
# Speed: 7.7ms preprocess, 256.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 253.2ms
# Speed: 7.1ms preprocess, 253.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 170.9ms
# Speed: 7.2ms preprocess, 170.9ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 251.2ms
# Speed: 7.2ms preprocess, 251.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1088x1280 1 person, 212.5ms
# Speed: 8.5ms preprocess, 212.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1024x1280 1 person, 207.6ms
# Speed: 6.6ms preprocess, 207.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 1 person, 249.0ms
# Speed: 8.8ms preprocess, 249.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 257.2ms
# Speed: 8.3ms preprocess, 257.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 249.2ms
# Speed: 7.6ms preprocess, 249.2ms inference, 3.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1216x1280 1 person, 239.2ms
# Speed: 9.3ms preprocess, 239.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 896x1280 1 person, 171.5ms
# Speed: 7.1ms preprocess, 171.5ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 186.3ms
# Speed: 7.8ms preprocess, 186.3ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 256.6ms
# Speed: 7.6ms preprocess, 256.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1088x1280 1 person, 196.5ms
# Speed: 8.1ms preprocess, 196.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x1152 1 person, 233.3ms
# Speed: 7.9ms preprocess, 233.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 1280x960 1 person, 192.5ms
# Speed: 6.5ms preprocess, 192.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 832x1280 1 person, 162.4ms
# Speed: 6.3ms preprocess, 162.4ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1152x1280 1 person, 222.9ms
# Speed: 9.3ms preprocess, 222.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x1216 1 person, 239.2ms
# Speed: 11.2ms preprocess, 239.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1024x1280 1 person, 198.5ms
# Speed: 8.4ms preprocess, 198.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 1 person, 255.0ms
# Speed: 7.1ms preprocess, 255.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 1 person, 196.8ms
# Speed: 7.5ms preprocess, 196.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 1 person, 259.2ms
# Speed: 7.0ms preprocess, 259.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 247.9ms
# Speed: 7.4ms preprocess, 247.9ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1088x1280 1 person, 220.3ms
# Speed: 9.0ms preprocess, 220.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 640x1280 1 person, 128.4ms
# Speed: 3.5ms preprocess, 128.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 704x1280 1 person, 137.4ms
# Speed: 4.7ms preprocess, 137.4ms inference, 1.5ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1280 1 person, 240.8ms
# Speed: 7.2ms preprocess, 240.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 158.4ms
# Speed: 4.9ms preprocess, 158.4ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 640x1280 1 person, 125.2ms
# Speed: 4.7ms preprocess, 125.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 1152x1280 1 person, 214.1ms
# Speed: 11.3ms preprocess, 214.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 640x1280 1 person, 124.9ms
# Speed: 5.5ms preprocess, 124.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 896x1280 1 person, 176.3ms
# Speed: 5.8ms preprocess, 176.3ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 512x1280 1 person, 97.5ms
# Speed: 3.4ms preprocess, 97.5ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 1280)
#
# 0: 896x1280 1 person, 171.3ms
# Speed: 9.0ms preprocess, 171.3ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 640x1280 1 person, 123.8ms
# Speed: 4.6ms preprocess, 123.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 1280x1280 1 person, 245.2ms
# Speed: 7.3ms preprocess, 245.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 247.8ms
# Speed: 7.2ms preprocess, 247.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 178.8ms
# Speed: 5.7ms preprocess, 178.8ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 173.2ms
# Speed: 6.7ms preprocess, 173.2ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 247.5ms
# Speed: 7.2ms preprocess, 247.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 173.8ms
# Speed: 6.2ms preprocess, 173.8ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 252.4ms
# Speed: 7.0ms preprocess, 252.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 248.0ms
# Speed: 7.4ms preprocess, 248.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 144.9ms
# Speed: 6.3ms preprocess, 144.9ms inference, 1.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 576x1280 1 person, 113.6ms
# Speed: 5.7ms preprocess, 113.6ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 1280)
#
# 0: 896x1280 1 person, 173.1ms
# Speed: 9.8ms preprocess, 173.1ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 237.6ms
# Speed: 7.7ms preprocess, 237.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 640x1280 1 person, 124.6ms
# Speed: 4.9ms preprocess, 124.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 768x1280 1 person, 144.9ms
# Speed: 4.9ms preprocess, 144.9ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 162.5ms
# Speed: 5.2ms preprocess, 162.5ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1280x1280 1 person, 253.4ms
# Speed: 7.9ms preprocess, 253.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 704x1280 1 person, 134.5ms
# Speed: 6.2ms preprocess, 134.5ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 1 person, 170.5ms
# Speed: 6.7ms preprocess, 170.5ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 640x1280 1 person, 127.3ms
# Speed: 3.8ms preprocess, 127.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 896x1280 1 person, 177.6ms
# Speed: 5.8ms preprocess, 177.6ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 256.7ms
# Speed: 7.6ms preprocess, 256.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 173.8ms
# Speed: 7.6ms preprocess, 173.8ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 576x1280 1 person, 110.8ms
# Speed: 4.6ms preprocess, 110.8ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1280)
#
# 0: 640x1280 1 person, 124.2ms
# Speed: 4.8ms preprocess, 124.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 1280x1280 1 person, 240.3ms
# Speed: 7.0ms preprocess, 240.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 256.1ms
# Speed: 7.1ms preprocess, 256.1ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 154.0ms
# Speed: 3.7ms preprocess, 154.0ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 640x1280 1 person, 129.3ms
# Speed: 4.2ms preprocess, 129.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 1280x1280 1 person, 240.8ms
# Speed: 8.1ms preprocess, 240.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 384x1280 1 person, 77.0ms
# Speed: 3.3ms preprocess, 77.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 1280)
#
# 0: 704x1280 1 person, 138.0ms
# Speed: 6.0ms preprocess, 138.0ms inference, 1.4ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 896x1280 1 person, 173.8ms
# Speed: 7.2ms preprocess, 173.8ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 512x1280 1 person, 94.3ms
# Speed: 4.7ms preprocess, 94.3ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 1280)
#
# 0: 704x1280 1 person, 137.4ms
# Speed: 5.9ms preprocess, 137.4ms inference, 1.6ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1280x1280 1 person, 247.7ms
# Speed: 7.1ms preprocess, 247.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 146.7ms
# Speed: 6.5ms preprocess, 146.7ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 640x1280 1 person, 121.6ms
# Speed: 6.2ms preprocess, 121.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 1280x1280 1 person, 238.4ms
# Speed: 7.9ms preprocess, 238.4ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 172.0ms
# Speed: 7.0ms preprocess, 172.0ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 512x1280 1 person, 100.7ms
# Speed: 3.3ms preprocess, 100.7ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 1280)
#
# 0: 704x1280 1 person, 138.7ms
# Speed: 4.9ms preprocess, 138.7ms inference, 1.6ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 640x1280 1 person, 136.2ms
# Speed: 4.4ms preprocess, 136.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 704x1280 1 person, 139.8ms
# Speed: 5.1ms preprocess, 139.8ms inference, 1.5ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 704x1280 1 person, 139.6ms
# Speed: 5.0ms preprocess, 139.6ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 704x1280 1 person, 141.3ms
# Speed: 4.7ms preprocess, 141.3ms inference, 2.2ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 832x1280 1 person, 166.4ms
# Speed: 5.3ms preprocess, 166.4ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 768x1280 1 person, 148.5ms
# Speed: 5.0ms preprocess, 148.5ms inference, 1.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 704x1280 1 person, 147.4ms
# Speed: 4.9ms preprocess, 147.4ms inference, 1.5ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 832x1280 1 person, 164.3ms
# Speed: 4.8ms preprocess, 164.3ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 512x1280 1 person, 102.2ms
# Speed: 3.5ms preprocess, 102.2ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 1280)
#
# 0: 640x1280 1 person, 127.9ms
# Speed: 4.2ms preprocess, 127.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 704x1280 1 person, 139.9ms
# Speed: 4.6ms preprocess, 139.9ms inference, 1.5ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 1024x1280 1 person, 197.3ms
# Speed: 6.0ms preprocess, 197.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 576x1280 1 person, 120.0ms
# Speed: 4.2ms preprocess, 120.0ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1280)
#
# 0: 896x1280 2 persons, 174.9ms
# Speed: 5.4ms preprocess, 174.9ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/seated_forward_fold/seated_forward_fold_test_49.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 768x1280 1 person, 151.6ms
# Speed: 4.8ms preprocess, 151.6ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 704x1280 1 person, 142.6ms
# Speed: 4.4ms preprocess, 142.6ms inference, 1.4ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 704x1280 1 person, 143.1ms
# Speed: 4.2ms preprocess, 143.1ms inference, 2.0ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 704x1280 1 person, 139.3ms
# Speed: 4.3ms preprocess, 139.3ms inference, 1.8ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 640x1280 1 person, 129.5ms
# Speed: 4.1ms preprocess, 129.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 768x1280 1 person, 148.5ms
# Speed: 4.6ms preprocess, 148.5ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 1024x1280 1 person, 200.9ms
# Speed: 6.4ms preprocess, 200.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 768x1280 1 person, 154.5ms
# Speed: 4.7ms preprocess, 154.5ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 173.7ms
# Speed: 5.7ms preprocess, 173.7ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 704x1280 1 person, 140.3ms
# Speed: 4.6ms preprocess, 140.3ms inference, 1.6ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 576x1280 1 person, 117.9ms
# Speed: 3.8ms preprocess, 117.9ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 1280)
#
# 0: 704x1280 1 person, 140.1ms
# Speed: 4.2ms preprocess, 140.1ms inference, 1.5ms postprocess per image at shape (1, 3, 704, 1280)
#
# 0: 576x1280 1 person, 119.2ms
# Speed: 3.9ms preprocess, 119.2ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 1280)
#
# 0: 640x1280 1 person, 128.2ms
# Speed: 4.4ms preprocess, 128.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 1280)
#
# 0: 832x1280 1 person, 168.5ms
# Speed: 5.4ms preprocess, 168.5ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 512x1280 1 person, 98.7ms
# Speed: 3.9ms preprocess, 98.7ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 1280)
#
# ...
#
# 0: 1280x1280 1 person, 249.6ms
# Speed: 7.6ms preprocess, 249.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 245.5ms
# Speed: 7.4ms preprocess, 245.5ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 256.6ms
# Speed: 7.6ms preprocess, 256.6ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 181.5ms
# Speed: 7.2ms preprocess, 181.5ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 960x1280 1 person, 193.3ms
# Speed: 7.2ms preprocess, 193.3ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 177.1ms
# Speed: 7.1ms preprocess, 177.1ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1152 1 person, 230.5ms
# Speed: 7.4ms preprocess, 230.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1152)
#
# 0: 960x1280 1 person, 191.8ms
# Speed: 6.1ms preprocess, 191.8ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x960 1 person, 197.4ms
# Speed: 6.1ms preprocess, 197.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1280x896 1 person, 179.6ms
# Speed: 6.7ms preprocess, 179.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x960 1 person, 193.0ms
# Speed: 6.1ms preprocess, 193.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1088x1280 1 person, 217.7ms
# Speed: 8.0ms preprocess, 217.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x1280 1 person, 251.7ms
# Speed: 8.7ms preprocess, 251.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x896 1 person, 185.5ms
# Speed: 5.9ms preprocess, 185.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1280x1216 1 person, 244.2ms
# Speed: 8.4ms preprocess, 244.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1216)
#
# 0: 1280x1280 1 person, 259.0ms
# Speed: 7.4ms preprocess, 259.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 191.3ms
# Speed: 7.3ms preprocess, 191.3ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1152x1280 1 person, 230.9ms
# Speed: 8.1ms preprocess, 230.9ms inference, 2.4ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1152x1280 1 person, 226.6ms
# Speed: 9.1ms preprocess, 226.6ms inference, 2.0ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x896 1 person, 178.6ms
# Speed: 9.3ms preprocess, 178.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 1216x1280 1 person, 245.6ms
# Speed: 7.9ms preprocess, 245.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1280x1280 1 person, 257.0ms
# Speed: 7.8ms preprocess, 257.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1216x1280 1 person, 258.6ms
# Speed: 9.7ms preprocess, 258.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1024x1280 1 person, 199.7ms
# Speed: 7.9ms preprocess, 199.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1088x1280 1 person, 218.4ms
# Speed: 7.9ms preprocess, 218.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1088x1280 1 person, 219.9ms
# Speed: 8.8ms preprocess, 219.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1088x1280 1 person, 227.5ms
# Speed: 8.1ms preprocess, 227.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1024x1280 1 person, 206.0ms
# Speed: 8.4ms preprocess, 206.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 1 person, 255.7ms
# Speed: 8.4ms preprocess, 255.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 (no detections), 253.6ms
# Speed: 8.0ms preprocess, 253.6ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 196.6ms
# Speed: 7.5ms preprocess, 196.6ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1216x1280 1 person, 245.4ms
# Speed: 8.5ms preprocess, 245.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1216, 1280)
#
# 0: 1280x1280 1 person, 257.7ms
# Speed: 9.0ms preprocess, 257.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 1 person, 168.3ms
# Speed: 7.3ms preprocess, 168.3ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1280x1280 1 person, 276.4ms
# Speed: 9.5ms preprocess, 276.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1024x1280 1 person, 202.9ms
# Speed: 9.8ms preprocess, 202.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 1 person, 259.0ms
# Speed: 8.1ms preprocess, 259.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 267.6ms
# Speed: 7.9ms preprocess, 267.6ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 274.8ms
# Speed: 8.4ms preprocess, 274.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1088x1280 1 person, 221.0ms
# Speed: 8.6ms preprocess, 221.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x960 1 person, 196.0ms
# Speed: 7.1ms preprocess, 196.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 960)
#
# 0: 1088x1280 1 person, 222.1ms
# Speed: 7.6ms preprocess, 222.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1024x1280 1 person, 213.2ms
# Speed: 8.3ms preprocess, 213.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 1 person, 265.8ms
# Speed: 7.4ms preprocess, 265.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 200.0ms
# Speed: 7.4ms preprocess, 200.0ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 260.5ms
# Speed: 7.3ms preprocess, 260.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 1 person, 172.9ms
# Speed: 6.4ms preprocess, 172.9ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 896x1280 1 person, 180.3ms
# Speed: 7.1ms preprocess, 180.3ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1024x1280 1 person, 201.3ms
# Speed: 7.5ms preprocess, 201.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 193.8ms
# Speed: 6.9ms preprocess, 193.8ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 267.9ms
# Speed: 7.4ms preprocess, 267.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 261.4ms
# Speed: 7.2ms preprocess, 261.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 268.7ms
# Speed: 8.0ms preprocess, 268.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 832x1280 1 person, 168.6ms
# Speed: 6.9ms preprocess, 168.6ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 1024x1280 1 person, 202.0ms
# Speed: 8.0ms preprocess, 202.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 1280x1280 1 person, 266.6ms
# Speed: 7.2ms preprocess, 266.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 960x1280 1 person, 202.0ms
# Speed: 8.1ms preprocess, 202.0ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 266.4ms
# Speed: 7.4ms preprocess, 266.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 177.6ms
# Speed: 7.2ms preprocess, 177.6ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 177.1ms
# Speed: 10.1ms preprocess, 177.1ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1024x1280 1 person, 202.1ms
# Speed: 7.2ms preprocess, 202.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1280)
#
# 0: 960x1280 1 person, 198.6ms
# Speed: 7.4ms preprocess, 198.6ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1088x1280 1 person, 233.2ms
# Speed: 8.0ms preprocess, 233.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 832x1280 1 person, 178.4ms
# Speed: 6.4ms preprocess, 178.4ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1280)
#
# 0: 960x1280 1 person, 193.5ms
# Speed: 7.1ms preprocess, 193.5ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 960x1280 1 person, 195.8ms
# Speed: 6.7ms preprocess, 195.8ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 1280x1280 1 person, 270.9ms
# Speed: 7.5ms preprocess, 270.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1152x1280 1 person, 241.6ms
# Speed: 8.7ms preprocess, 241.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x1280 1 person, 258.2ms
# Speed: 8.0ms preprocess, 258.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 262.2ms
# Speed: 7.8ms preprocess, 262.2ms inference, 3.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 274.3ms
# Speed: 7.7ms preprocess, 274.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 264.9ms
# Speed: 7.5ms preprocess, 264.9ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1152x1280 1 person, 236.8ms
# Speed: 8.3ms preprocess, 236.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1152, 1280)
#
# 0: 1280x1280 1 person, 264.5ms
# Speed: 8.9ms preprocess, 264.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 180.1ms
# Speed: 6.5ms preprocess, 180.1ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 183.1ms
# Speed: 6.8ms preprocess, 183.1ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.0ms
# Speed: 6.9ms preprocess, 180.0ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 181.3ms
# Speed: 6.4ms preprocess, 181.3ms inference, 3.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 185.4ms
# Speed: 6.5ms preprocess, 185.4ms inference, 2.4ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.9ms
# Speed: 6.6ms preprocess, 180.9ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 182.0ms
# Speed: 6.3ms preprocess, 182.0ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 182.6ms
# Speed: 6.1ms preprocess, 182.6ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 183.2ms
# Speed: 6.0ms preprocess, 183.2ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 183.7ms
# Speed: 6.1ms preprocess, 183.7ms inference, 2.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 185.0ms
# Speed: 6.0ms preprocess, 185.0ms inference, 2.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1024 1 person, 200.3ms
# Speed: 6.8ms preprocess, 200.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1024)
#
# 0: 896x1280 1 person, 184.2ms
# Speed: 6.6ms preprocess, 184.2ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 2 persons, 183.2ms
# Speed: 6.3ms preprocess, 183.2ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/wheel/wheel_test_14.png. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1088x1280 1 person, 225.7ms
# Speed: 8.2ms preprocess, 225.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1088, 1280)
#
# 0: 1280x1280 1 person, 266.3ms
# Speed: 8.2ms preprocess, 266.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 896x1280 1 person, 184.8ms
# Speed: 6.0ms preprocess, 184.8ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 182.6ms
# Speed: 6.2ms preprocess, 182.6ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 177.7ms
# Speed: 5.9ms preprocess, 177.7ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x1280 1 person, 258.5ms
# Speed: 8.0ms preprocess, 258.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 768x1280 1 person, 155.2ms
# Speed: 5.4ms preprocess, 155.2ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 183.3ms
# Speed: 6.3ms preprocess, 183.3ms inference, 1.7ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 178.4ms
# Speed: 6.6ms preprocess, 178.4ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 181.8ms
# Speed: 6.1ms preprocess, 181.8ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 1280x896 1 person, 183.3ms
# Speed: 5.7ms preprocess, 183.3ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 896)
#
# 0: 960x1280 1 person, 200.2ms
# Speed: 6.3ms preprocess, 200.2ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 1280)
#
# 0: 896x1280 1 person, 184.8ms
# Speed: 6.2ms preprocess, 184.8ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 154.5ms
# Speed: 5.3ms preprocess, 154.5ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 182.5ms
# Speed: 6.4ms preprocess, 182.5ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.3ms
# Speed: 6.2ms preprocess, 179.3ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 768x1280 1 person, 156.3ms
# Speed: 5.3ms preprocess, 156.3ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 896x1280 1 person, 181.7ms
# Speed: 6.8ms preprocess, 181.7ms inference, 1.6ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 178.6ms
# Speed: 6.0ms preprocess, 178.6ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 178.5ms
# Speed: 5.9ms preprocess, 178.5ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 181.6ms
# Speed: 6.0ms preprocess, 181.6ms inference, 1.8ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 184.5ms
# Speed: 6.1ms preprocess, 184.5ms inference, 2.5ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 182.2ms
# Speed: 7.2ms preprocess, 182.2ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.9ms
# Speed: 6.7ms preprocess, 179.9ms inference, 3.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.8ms
# Speed: 6.1ms preprocess, 180.8ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 182.2ms
# Speed: 5.8ms preprocess, 182.2ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 181.6ms
# Speed: 5.9ms preprocess, 181.6ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 181.5ms
# Speed: 6.1ms preprocess, 181.5ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.0ms
# Speed: 6.6ms preprocess, 180.0ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.0ms
# Speed: 6.7ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 179.5ms
# Speed: 6.7ms preprocess, 179.5ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# 0: 896x1280 1 person, 180.3ms
# Speed: 6.5ms preprocess, 180.3ms inference, 1.9ms postprocess per image at shape (1, 3, 896, 1280)

# %%
# Create a list of column headings
column_headings = ['image_path', 'label',
                   'nose_x', 'nose_y',
                   'left_eye_x', 'left_eye_y',
                   'right_eye_x', 'right_eye_y',
                   'left_ear_x', 'left_ear_y',
                   'right_ear_x', 'right_ear_y',
                   'left_shoulder_x', 'left_shoulder_y',
                   'right_shoulder_x', 'right_shoulder_y',
                   'left_elbow_x', 'left_elbow_y',
                   'right_elbow_x', 'right_elbow_y',
                   'left_wrist_x', 'left_wrist_y',
                   'right_wrist_x', 'right_wrist_y',
                   'left_hip_x', 'left_hip_y',
                   'right_hip_x', 'right_hip_y',
                   'left_knee_x', 'left_knee_y',
                   'right_knee_x', 'right_knee_y',
                   'left_ankle_x', 'left_ankle_y',
                   'right_ankle_x', 'right_ankle_y']

with open('train_data_yolo.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)

    # Write the column headings as the first row
    writer.writerow(column_headings)

    # Write the list data to the CSV file
    writer.writerows(dataset_csv_train)



# Create a list of column headings
column_headings = ['image_path', 'label',
                   'nose_x', 'nose_y',
                   'left_eye_x', 'left_eye_y',
                   'right_eye_x', 'right_eye_y',
                   'left_ear_x', 'left_ear_y',
                   'right_ear_x', 'right_ear_y',
                   'left_shoulder_x', 'left_shoulder_y',
                   'right_shoulder_x', 'right_shoulder_y',
                   'left_elbow_x', 'left_elbow_y',
                   'right_elbow_x', 'right_elbow_y',
                   'left_wrist_x', 'left_wrist_y',
                   'right_wrist_x', 'right_wrist_y',
                   'left_hip_x', 'left_hip_y',
                   'right_hip_x', 'right_hip_y',
                   'left_knee_x', 'left_knee_y',
                   'right_knee_x', 'right_knee_y',
                   'left_ankle_x', 'left_ankle_y',
                   'right_ankle_x', 'right_ankle_y']

with open('test_data_yolo.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)

    # Write the column headings as the first row
    writer.writerow(column_headings)

    # Write the list data to the CSV file
    writer.writerows(dataset_csv_test)

# %%
train_df = pd.read_csv('train_data_yolo.csv')
test_df = pd.read_csv('test_data_yolo.csv')

train_df.to_csv('train_data_yolo.csv', index=False)
test_df.to_csv('test_data_yolo.csv', index=False)

# %%
# !cp train_data_yolo.csv {path_to_save}
# !cp test_data_yolo.csv {path_to_save}

# %%
train_df = train_df.drop('image_path', axis=1)
test_df = test_df.drop('image_path', axis=1)
encoder = LabelEncoder()
y_label_train = train_df['label']
y_train = encoder.fit_transform(y_label_train)
y_label_test = test_df['label']
y_test = encoder.fit_transform(y_label_test)
train_df = train_df.drop('label',axis=1)
X_train = train_df
test_df = test_df.drop('label',axis=1)
X_test = test_df
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
y_train = y_train.astype('int64')
y_test = y_test.astype('int64')

# %%
model = tf.keras.models.Sequential()
model.add(layers.Input(shape=(X_train.shape[1],)))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(len(pose_list), activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               8960
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 50762 (198.29 KB)
# Trainable params: 50762 (198.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = 'weights_yolo.keras'
checkpoint = ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/100
# 64/64 [==============================] - ETA: 0s - loss: 1.6986 - accuracy: 0.4209
# Epoch 1: val_accuracy improved from -inf to 0.62257, saving model to weights_yolo.keras
# 64/64 [==============================] - 3s 8ms/step - loss: 1.6986 - accuracy: 0.4209 - val_loss: 1.1250 - val_accuracy: 0.6226
# Epoch 2/100
# 55/64 [========================>.....] - ETA: 0s - loss: 0.9468 - accuracy: 0.6528
# Epoch 2: val_accuracy improved from 0.62257 to 0.76654, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.9268 - accuracy: 0.6678 - val_loss: 0.7566 - val_accuracy: 0.7665
# Epoch 3/100
# 58/64 [==========================>...] - ETA: 0s - loss: 0.6483 - accuracy: 0.7845
# Epoch 3: val_accuracy improved from 0.76654 to 0.84241, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.6515 - accuracy: 0.7787 - val_loss: 0.5679 - val_accuracy: 0.8424
# Epoch 4/100
# 58/64 [==========================>...] - ETA: 0s - loss: 0.5434 - accuracy: 0.8098
# Epoch 4: val_accuracy did not improve from 0.84241
# 64/64 [==============================] - 0s 4ms/step - loss: 0.5402 - accuracy: 0.8103 - val_loss: 0.5680 - val_accuracy: 0.7938
# Epoch 5/100
# 57/64 [=========================>....] - ETA: 0s - loss: 0.4650 - accuracy: 0.8322
# Epoch 5: val_accuracy did not improve from 0.84241
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4626 - accuracy: 0.8344 - val_loss: 0.5110 - val_accuracy: 0.8405
# Epoch 6/100
# 55/64 [========================>.....] - ETA: 0s - loss: 0.4143 - accuracy: 0.8619
# Epoch 6: val_accuracy improved from 0.84241 to 0.88327, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4055 - accuracy: 0.8659 - val_loss: 0.3988 - val_accuracy: 0.8833
# Epoch 7/100
# 56/64 [=========================>....] - ETA: 0s - loss: 0.3679 - accuracy: 0.8650
# Epoch 7: val_accuracy improved from 0.88327 to 0.89494, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3614 - accuracy: 0.8669 - val_loss: 0.3725 - val_accuracy: 0.8949
# Epoch 8/100
# 55/64 [========================>.....] - ETA: 0s - loss: 0.3359 - accuracy: 0.8852
# Epoch 8: val_accuracy did not improve from 0.89494
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3288 - accuracy: 0.8876 - val_loss: 0.3700 - val_accuracy: 0.8813
# Epoch 9/100
# 55/64 [========================>.....] - ETA: 0s - loss: 0.2893 - accuracy: 0.9045
# Epoch 9: val_accuracy improved from 0.89494 to 0.90078, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2912 - accuracy: 0.9044 - val_loss: 0.3290 - val_accuracy: 0.9008
# Epoch 10/100
# 57/64 [=========================>....] - ETA: 0s - loss: 0.2467 - accuracy: 0.9243
# Epoch 10: val_accuracy did not improve from 0.90078
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2483 - accuracy: 0.9226 - val_loss: 0.3416 - val_accuracy: 0.8988
# Epoch 11/100
# 56/64 [=========================>....] - ETA: 0s - loss: 0.2438 - accuracy: 0.9180
# Epoch 11: val_accuracy improved from 0.90078 to 0.90272, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2418 - accuracy: 0.9197 - val_loss: 0.3292 - val_accuracy: 0.9027
# Epoch 12/100
# 59/64 [==========================>...] - ETA: 0s - loss: 0.2171 - accuracy: 0.9280
# Epoch 12: val_accuracy improved from 0.90272 to 0.90661, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2193 - accuracy: 0.9266 - val_loss: 0.3124 - val_accuracy: 0.9066
# Epoch 13/100
# 58/64 [==========================>...] - ETA: 0s - loss: 0.2109 - accuracy: 0.9246
# Epoch 13: val_accuracy improved from 0.90661 to 0.92023, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2089 - accuracy: 0.9256 - val_loss: 0.2790 - val_accuracy: 0.9202
# Epoch 14/100
# 58/64 [==========================>...] - ETA: 0s - loss: 0.1858 - accuracy: 0.9413
# Epoch 14: val_accuracy did not improve from 0.92023
# 64/64 [==============================] - 0s 4ms/step - loss: 0.1837 - accuracy: 0.9418 - val_loss: 0.2854 - val_accuracy: 0.9163
# Epoch 15/100
# 58/64 [==========================>...] - ETA: 0s - loss: 0.1923 - accuracy: 0.9305
# Epoch 15: val_accuracy did not improve from 0.92023
# 64/64 [==============================] - 0s 4ms/step - loss: 0.1913 - accuracy: 0.9310 - val_loss: 0.2614 - val_accuracy: 0.9183
# Epoch 16/100
# 57/64 [=========================>....] - ETA: 0s - loss: 0.1782 - accuracy: 0.9370
# Epoch 16: val_accuracy improved from 0.92023 to 0.93191, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.1826 - accuracy: 0.9349 - val_loss: 0.2447 - val_accuracy: 0.9319
# Epoch 17/100
# 57/64 [=========================>....] - ETA: 0s - loss: 0.1646 - accuracy: 0.9452
# Epoch 17: val_accuracy improved from 0.93191 to 0.93580, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.1581 - accuracy: 0.9487 - val_loss: 0.2729 - val_accuracy: 0.9358
# Epoch 18/100
# 59/64 [==========================>...] - ETA: 0s - loss: 0.1500 - accuracy: 0.9486
# Epoch 18: val_accuracy did not improve from 0.93580
# 64/64 [==============================] - 0s 4ms/step - loss: 0.1540 - accuracy: 0.9448 - val_loss: 0.2375 - val_accuracy: 0.9339
# Epoch 19/100
# 57/64 [=========================>....] - ETA: 0s - loss: 0.1362 - accuracy: 0.9561
# Epoch 19: val_accuracy improved from 0.93580 to 0.93969, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.1401 - accuracy: 0.9527 - val_loss: 0.2331 - val_accuracy: 0.9397
# Epoch 20/100
# 58/64 [==========================>...] - ETA: 0s - loss: 0.1263 - accuracy: 0.9574
# Epoch 20: val_accuracy improved from 0.93969 to 0.94163, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.1271 - accuracy: 0.9566 - val_loss: 0.2418 - val_accuracy: 0.9416
# Epoch 21/100
# 56/64 [=========================>....] - ETA: 0s - loss: 0.1201 - accuracy: 0.9576
# Epoch 21: val_accuracy improved from 0.94163 to 0.94553, saving model to weights_yolo.keras
# 64/64 [==============================] - 0s 4ms/step - loss: 0.1155 - accuracy: 0.9596 - val_loss: 0.2338 - val_accuracy: 0.9455
# Epoch 22/100
# 58/64 [==========================>...] - ETA: 0s - loss: 0.1109 - accuracy: 0.9601
# Epoch 22: val_accuracy did not improve from 0.94553
# 64/64 [==============================] - 0s 4ms/step - loss: 0.1140 - accuracy: 0.9586 - val_loss: 0.2565 - val_accuracy: 0.9397
# 51/64 [======================>.......] - ETA: 0s - loss: 0.0979 - accuracy: 0.9663
# Epoch 33: val_accuracy did not improve from 0.95914
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0991 - accuracy: 0.9650 - val_loss: 0.3202 - val_accuracy: 0.9027
# Epoch 34/100
# 58/64 [==========================>...] - ETA: 0s - loss: 0.0967 - accuracy: 0.9666
# Epoch 34: val_accuracy did not improve from 0.95914
# 64/64 [==============================] - 0s 5ms/step - loss: 0.0979 - accuracy: 0.9655 - val_loss: 0.2229 - val_accuracy: 0.9455
# Epoch 35/100
# 51/64 [======================>.......] - ETA: 0s - loss: 0.0575 - accuracy: 0.9816
# Epoch 35: val_accuracy did not improve from 0.95914
# 64/64 [==============================] - 0s 4ms/step - loss: 0.0606 - accuracy: 0.9788 - val_loss: 0.2017 - val_accuracy: 0.9591
# Epoch 36/100
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0683 - accuracy: 0.9783
# Epoch 36: val_accuracy did not improve from 0.95914
# 64/64 [==============================] - 0s 5ms/step - loss: 0.0677 - accuracy: 0.9783 - val_loss: 0.2729 - val_accuracy: 0.9300

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f"Training and Validation Accuracy of YoloV8 model for {dataset_name}")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.savefig("Accuracy_Graph_Yolo.png")
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f"Training and Validation Loss of YoloV8 model for {dataset_name}")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.savefig("Loss_Graph_Yolo.png")
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2729 - accuracy: 0.9300
# [0.27287325263023376, 0.929961085319519]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
class_names = encoder.classes_

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f"Confusion Matrix of YoloV8 model for {dataset_name}")
plt.savefig("Confusion_Matrix_Yolo.png")
plt.show()

class_report = classification_report(y_test, y_pred, target_names=class_names)
print(class_report)
# Out:
# 17/17 [==============================] - 0s 1ms/step
#                      precision    recall  f1-score   support
#
#           Padmasana       0.98      0.98      0.98        59
#              bridge       1.00      1.00      1.00        53
#             diamond       0.96      1.00      0.98        46
#             downdog       0.78      0.96      0.86        55
#             goddess       0.82      0.94      0.88        49
#               plank       0.94      0.96      0.95        50
# seated_forward_fold       0.96      1.00      0.98        47
#                tree       0.95      1.00      0.97        58
#            warrior2       1.00      0.78      0.88        51
#               wheel       1.00      0.63      0.77        46
#
#            accuracy                           0.93       514
#           macro avg       0.94      0.93      0.93       514
#        weighted avg       0.94      0.93      0.93       514

# %%
with open('history_for_yolo.pkl', 'wb') as f:
    pickle.dump(history.history, f)

def create_zip(files_to_zip, zip_filename):
    with zipfile.ZipFile(zip_filename, 'w') as zipf:
        for file in files_to_zip:
            # Add the file to the zip archive
            zipf.write(file, os.path.basename(file))


files_to_zip = ['weights_yolo.keras', 'history_for_yolo.pkl', 'Accuracy_Graph_Yolo.png', 'Loss_Graph_Yolo.png', 'Confusion_Matrix_Yolo.png']
zip_filename = 'results_yolo.zip'
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}
