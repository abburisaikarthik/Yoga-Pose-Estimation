#   inflating: /content/dataset/train/dog/guy1_dog092.jpg
#   inflating: /content/dataset/train/dog/girl2_dog065.jpg
#   inflating: /content/dataset/train/dog/guy1_dog028.jpg
#   inflating: /content/dataset/train/dog/girl1_dog097.jpg
#   inflating: /content/dataset/train/dog/guy1_dog097.jpg
#   inflating: /content/dataset/train/dog/girl2_dog055.jpg
#   inflating: /content/dataset/train/dog/girl3_dog111.jpg
#   inflating: /content/dataset/train/dog/guy1_dog063.jpg
#   inflating: /content/dataset/train/dog/girl1_dog101.jpg
#   inflating: /content/dataset/train/dog/girl1_dog114.jpg
#   inflating: /content/dataset/train/dog/girl1_dog056.jpg
#   inflating: /content/dataset/train/dog/girl3_dog106.jpg
#   inflating: /content/dataset/train/dog/girl1_dog053.jpg
#   inflating: /content/dataset/train/dog/guy1_dog070.jpg
#   inflating: /content/dataset/train/dog/girl1_dog059.jpg
#   inflating: /content/dataset/train/dog/girl2_dog105.jpg
#   inflating: /content/dataset/train/dog/girl3_dog031.jpg
#   inflating: /content/dataset/train/dog/girl3_dog052.jpg
#   inflating: /content/dataset/train/dog/guy2_dog045.jpg
#   inflating: /content/dataset/train/dog/girl1_dog095.jpg

# %% [markdown]
# # Importing Necessary Packages

# %%
# !pip install mediapipe
# !pip install ultralytics
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.8/34.8 MB 48.8 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.23)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.25.2)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.8.0.76)
# Requirement already satisfied: protobuf<4,>=3.11 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.20.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.10 sounddevice-0.4.6
# Collecting ultralytics
#   Downloading ultralytics-8.1.22-py3-none-any.whl (716 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 717.0/717.0 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.1.22

# %%
import numpy as np
import pandas as pd
import os
import cv2
import csv
import itertools
import sys
import tempfile
import tqdm
import zipfile
import pickle
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import seaborn as sns
import mediapipe as mp
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
from pydantic import BaseModel
from PIL import Image
import glob

# %%
dataset_name = 'Google Dataset Dataset'
train_dir = '/content/dataset/train'
test_dir = '/content/dataset/test'
path_to_save = '/content/drive/MyDrive/Datasets/YogaPoseEstimation/Images/Google_Dataset/'

# %% [markdown]
# # Xception Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)
        img = tf.image.resize(img, (299, 299))
        img = tf.keras.applications.xception.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue

    return df

def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df

train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1000, 299, 299, 3)
# (495, 299, 299, 3)
# (1000, 5)
# (495, 5)

# %%
xception_model = tf.keras.applications.Xception(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
xception_model.trainable = False

model = tf.keras.Sequential([
    xception_model,
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.6),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.6),
    keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer= keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 5s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  flatten (Flatten)           (None, 204800)            0
#
#  dense (Dense)               (None, 256)               52429056
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  batch_normalization_5 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 73308589 (279.65 MB)
# Trainable params: 52446469 (200.07 MB)
# Non-trainable params: 20862120 (79.58 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_Xception.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 1.5278 - accuracy: 0.4910
# Epoch 1: val_accuracy improved from -inf to 0.74949, saving model to weights_Xception.keras
# 32/32 [==============================] - 31s 604ms/step - loss: 1.5278 - accuracy: 0.4910 - val_loss: 0.8520 - val_accuracy: 0.7495
# Epoch 2/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7020 - accuracy: 0.7230
# Epoch 2: val_accuracy improved from 0.74949 to 0.90101, saving model to weights_Xception.keras
# 32/32 [==============================] - 13s 426ms/step - loss: 0.7020 - accuracy: 0.7230 - val_loss: 0.4072 - val_accuracy: 0.9010
# Epoch 3/50
# 32/32 [==============================] - ETA: 0s - loss: 0.4307 - accuracy: 0.8540
# Epoch 3: val_accuracy improved from 0.90101 to 0.94949, saving model to weights_Xception.keras
# 32/32 [==============================] - 14s 454ms/step - loss: 0.4307 - accuracy: 0.8540 - val_loss: 0.3992 - val_accuracy: 0.9495
# Epoch 4/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3044 - accuracy: 0.9050
# Epoch 4: val_accuracy did not improve from 0.94949
# 32/32 [==============================] - 10s 330ms/step - loss: 0.3044 - accuracy: 0.9050 - val_loss: 0.3923 - val_accuracy: 0.9414
# Epoch 5/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2020 - accuracy: 0.9390
# Epoch 5: val_accuracy did not improve from 0.94949
# 32/32 [==============================] - 11s 332ms/step - loss: 0.2020 - accuracy: 0.9390 - val_loss: 0.3912 - val_accuracy: 0.9313
# Epoch 6/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1548 - accuracy: 0.9600
# Epoch 6: val_accuracy improved from 0.94949 to 0.95152, saving model to weights_Xception.keras
# 32/32 [==============================] - 14s 448ms/step - loss: 0.1548 - accuracy: 0.9600 - val_loss: 0.3674 - val_accuracy: 0.9515
# Epoch 7/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9630
# Epoch 7: val_accuracy did not improve from 0.95152
# 32/32 [==============================] - 11s 337ms/step - loss: 0.1342 - accuracy: 0.9630 - val_loss: 0.3344 - val_accuracy: 0.9475
# Epoch 8/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1056 - accuracy: 0.9810
# Epoch 8: val_accuracy did not improve from 0.95152
# 32/32 [==============================] - 11s 341ms/step - loss: 0.1056 - accuracy: 0.9810 - val_loss: 0.3494 - val_accuracy: 0.9495
# Epoch 9/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.9800
# Epoch 9: val_accuracy did not improve from 0.95152
# 32/32 [==============================] - 11s 343ms/step - loss: 0.0880 - accuracy: 0.9800 - val_loss: 0.3664 - val_accuracy: 0.9333
# Epoch 10/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0689 - accuracy: 0.9870
# Epoch 10: val_accuracy did not improve from 0.95152
# 32/32 [==============================] - 11s 346ms/step - loss: 0.0689 - accuracy: 0.9870 - val_loss: 0.3345 - val_accuracy: 0.9333
# Epoch 11/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9940
# Epoch 11: val_accuracy improved from 0.95152 to 0.96162, saving model to weights_Xception.keras
# 32/32 [==============================] - 14s 446ms/step - loss: 0.0554 - accuracy: 0.9940 - val_loss: 0.2871 - val_accuracy: 0.9616
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9790
# Epoch 12: val_accuracy did not improve from 0.96162
# 32/32 [==============================] - 11s 341ms/step - loss: 0.0730 - accuracy: 0.9790 - val_loss: 0.3174 - val_accuracy: 0.9192
# Epoch 13/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9900
# Epoch 13: val_accuracy did not improve from 0.96162
# 32/32 [==============================] - 11s 344ms/step - loss: 0.0569 - accuracy: 0.9900 - val_loss: 0.3267 - val_accuracy: 0.9010
# Epoch 14/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.9880
# Epoch 14: val_accuracy did not improve from 0.96162
# 32/32 [==============================] - 11s 344ms/step - loss: 0.0533 - accuracy: 0.9880 - val_loss: 0.3391 - val_accuracy: 0.8869
# Epoch 15/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9930
# Epoch 15: val_accuracy did not improve from 0.96162
# 32/32 [==============================] - 11s 345ms/step - loss: 0.0437 - accuracy: 0.9930 - val_loss: 0.3469 - val_accuracy: 0.8828
# Epoch 16/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9970
# Epoch 16: val_accuracy did not improve from 0.96162
# 32/32 [==============================] - 11s 345ms/step - loss: 0.0374 - accuracy: 0.9970 - val_loss: 0.3233 - val_accuracy: 0.8990
# Epoch 17/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9940
# Epoch 17: val_accuracy did not improve from 0.96162
# 32/32 [==============================] - 11s 345ms/step - loss: 0.0341 - accuracy: 0.9940 - val_loss: 0.3272 - val_accuracy: 0.8949
# Epoch 18/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9930
# Epoch 18: val_accuracy did not improve from 0.96162
# 32/32 [==============================] - 11s 345ms/step - loss: 0.0369 - accuracy: 0.9930 - val_loss: 0.3118 - val_accuracy: 0.9010
# Epoch 19/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9950
# Epoch 19: val_accuracy did not improve from 0.96162
# 32/32 [==============================] - 11s 345ms/step - loss: 0.0306 - accuracy: 0.9950 - val_loss: 0.2968 - val_accuracy: 0.9010
# Epoch 20/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9990
# Epoch 20: val_accuracy did not improve from 0.96162
# 32/32 [==============================] - 11s 344ms/step - loss: 0.0247 - accuracy: 0.9990 - val_loss: 0.2947 - val_accuracy: 0.8990
# Epoch 21/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9980
# Epoch 21: val_accuracy did not improve from 0.96162
# 32/32 [==============================] - 11s 344ms/step - loss: 0.0239 - accuracy: 0.9980 - val_loss: 0.2993 - val_accuracy: 0.8929

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of Xception with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_Xception.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of Xception with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_Xception.png')
plt.show()

# %%
model = tf.keras.models.load_model("weights_Xception.keras")
model.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 5s 209ms/step - loss: 0.2871 - accuracy: 0.9616
# [0.28710392117500305, 0.9616161584854126]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of Xception with {dataset_name}')
plt.savefig('Confusion_Matrix_Xception.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 16/16 [==============================] - 3s 213ms/step
#               precision    recall  f1-score   support
#
#        chair       1.00      0.90      0.95        84
#        cobra       0.94      0.99      0.97       116
#          dog       0.96      0.91      0.94        90
#         tree       1.00      0.98      0.99        96
#      warrior       0.92      1.00      0.96       109
#
#     accuracy                           0.96       495
#    macro avg       0.97      0.96      0.96       495
# weighted avg       0.96      0.96      0.96       495

# %%
import zipfile
import os
import pickle

with open('history_for_Xception.pkl', 'wb') as f:
    pickle.dump(history, f)

def create_zip(files_to_zip, zip_filename):
    with zipfile.ZipFile(zip_filename, 'w') as zipf:
        for file in files_to_zip:
            # Add the file to the zip archive
            zipf.write(file, os.path.basename(file))

# Example: List of files to be included in the zip
files_to_zip = ['Accuracy_Graph_Xception.png', 'Loss_Graph_Xception.png', 'history_for_Xception.pkl', 'weights_Xception.keras', 'Confusion_Matrix_Xception.png']

# Specify the name of the zip file
zip_filename = 'results_Xception.zip'

# Create the zip file
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # EfficientNetB0 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)
        img = tf.image.resize(img, (224, 224))
        img = tf.keras.applications.efficientnet.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df

def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1000, 224, 224, 3)
# (495, 224, 224, 3)
# (1000, 5)
# (495, 5)

# %%
efficient_net_model = tf.keras.applications.EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
efficient_net_model.trainable = False

model = tf.keras.Sequential([
    efficient_net_model,
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer= keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 7, 7, 1280)        4049571
#  )
#
#  flatten_1 (Flatten)         (None, 62720)             0
#
#  dense_3 (Dense)             (None, 256)               16056576
#
#  batch_normalization_6 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 64)                16448
#
#  batch_normalization_7 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 20124200 (76.77 MB)
# Trainable params: 16073989 (61.32 MB)
# Non-trainable params: 4050211 (15.45 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_EfficientNetB0.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 0.8538 - accuracy: 0.7130
# Epoch 1: val_accuracy improved from -inf to 0.58586, saving model to weights_EfficientNetB0.keras
# 32/32 [==============================] - 18s 294ms/step - loss: 0.8538 - accuracy: 0.7130 - val_loss: 1.0741 - val_accuracy: 0.5859
# Epoch 2/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.2508 - accuracy: 0.9284
# Epoch 2: val_accuracy improved from 0.58586 to 0.73535, saving model to weights_EfficientNetB0.keras
# 32/32 [==============================] - 5s 144ms/step - loss: 0.2568 - accuracy: 0.9250 - val_loss: 0.6048 - val_accuracy: 0.7354
# Epoch 3/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.1469 - accuracy: 0.9617
# Epoch 3: val_accuracy improved from 0.73535 to 0.74747, saving model to weights_EfficientNetB0.keras
# 32/32 [==============================] - 5s 144ms/step - loss: 0.1464 - accuracy: 0.9620 - val_loss: 0.5414 - val_accuracy: 0.7475
# Epoch 4/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0803 - accuracy: 0.9859
# Epoch 4: val_accuracy improved from 0.74747 to 0.75758, saving model to weights_EfficientNetB0.keras
# 32/32 [==============================] - 4s 138ms/step - loss: 0.0806 - accuracy: 0.9850 - val_loss: 0.5081 - val_accuracy: 0.7576
# Epoch 5/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0599 - accuracy: 0.9899
# Epoch 5: val_accuracy did not improve from 0.75758
# 32/32 [==============================] - 3s 92ms/step - loss: 0.0684 - accuracy: 0.9860 - val_loss: 0.5359 - val_accuracy: 0.7455
# Epoch 6/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0653 - accuracy: 0.9899
# Epoch 6: val_accuracy did not improve from 0.75758
# 32/32 [==============================] - 3s 92ms/step - loss: 0.0657 - accuracy: 0.9900 - val_loss: 0.5853 - val_accuracy: 0.7010
# Epoch 7/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.
50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.80202
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.7048 - val_accuracy: 0.7838
# Epoch 25/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.80202
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0120 - accuracy: 0.9980 - val_loss: 0.7499 - val_accuracy: 0.7737
# Epoch 26/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0272 - accuracy: 0.9929
# Epoch 26: val_accuracy did not improve from 0.80202
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0270 - accuracy: 0.9930 - val_loss: 1.0611 - val_accuracy: 0.7152
# Epoch 27/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0199 - accuracy: 0.9960
# Epoch 27: val_accuracy did not improve from 0.80202
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0198 - accuracy: 0.9960 - val_loss: 0.9978 - val_accuracy: 0.7455
# Epoch 28/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0184 - accuracy: 0.9950
# Epoch 28: val_accuracy did not improve from 0.80202
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0186 - accuracy: 0.9950 - val_loss: 1.0982 - val_accuracy: 0.7495
# Epoch 29/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0102 - accuracy: 0.9990
# Epoch 29: val_accuracy did not improve from 0.80202
# 32/32 [==============================] - 3s 95ms/step - loss: 0.0103 - accuracy: 0.9990 - val_loss: 1.1647 - val_accuracy: 0.7475
# Epoch 30/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 0.9970
# Epoch 30: val_accuracy did not improve from 0.80202
# 32/32 [==============================] - 3s 94ms/step - loss: 0.0126 - accuracy: 0.9970 - val_loss: 1.2075 - val_accuracy: 0.7253
# Epoch 31/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 0.9980
# Epoch 31: val_accuracy did not improve from 0.80202
# 32/32 [==============================] - 3s 94ms/step - loss: 0.0103 - accuracy: 0.9980 - val_loss: 1.1699 - val_accuracy: 0.7414
# Epoch 32/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9990
# Epoch 32: val_accuracy did not improve from 0.80202
# 32/32 [==============================] - 3s 95ms/step - loss: 0.0100 - accuracy: 0.9990 - val_loss: 1.2574 - val_accuracy: 0.7556
# Epoch 33/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0121 - accuracy: 0.9970
# Epoch 33: val_accuracy did not improve from 0.80202
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0120 - accuracy: 0.9970 - val_loss: 1.2946 - val_accuracy: 0.7677

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of EfficientNetB0 with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_EfficientNetB0.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of EfficientNetB0 with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_EfficientNetB0.png')
plt.show()

# %%
model = tf.keras.models.load_model('weights_EfficientNetB0.keras')
model.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 3s 60ms/step - loss: 0.6408 - accuracy: 0.8020
# [0.6408493518829346, 0.8020201921463013]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of EfficientNetB0 with {dataset_name}')
plt.savefig('Confusion_Matrix_EfficientNetB0.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 16/16 [==============================] - 2s 58ms/step
#               precision    recall  f1-score   support
#
#        chair       0.81      1.00      0.89        84
#        cobra       1.00      0.22      0.37       116
#          dog       0.63      1.00      0.77        90
#         tree       1.00      0.93      0.96        96
#      warrior       0.81      0.99      0.89       109
#
#     accuracy                           0.80       495
#    macro avg       0.85      0.83      0.78       495
# weighted avg       0.86      0.80      0.76       495

# %%
with open('history_for_EfficientNetB0.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_EfficientNetB0.keras', 'history_for_EfficientNetB0.pkl', 'Confusion_Matrix_EfficientNetB0.png', 'Loss_Graph_EfficientNetB0.png', 'Accuracy_Graph_EfficientNetB0.png']
zip_filename = 'results_EfficientNetB0.zip'

create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # Inception V3

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)
        img = tf.image.resize(img, (224, 224))
        img = tf.keras.applications.inception_v3.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df


def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1000, 224, 224, 3)
# (495, 224, 224, 3)
# (1000, 5)
# (495, 5)

# %%
inception_model = tf.keras.applications.InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
inception_model.trainable = False

model = tf.keras.Sequential([
    inception_model,
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer= keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 5s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten_2 (Flatten)         (None, 51200)             0
#
#  dense_6 (Dense)             (None, 256)               13107456
#
#  batch_normalization_102 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 64)                16448
#
#  batch_normalization_103 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 34928293 (133.24 MB)
# Trainable params: 13124869 (50.07 MB)
# Non-trainable params: 21803424 (83.17 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_InceptionV3.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 0.9637 - accuracy: 0.6530
# Epoch 1: val_accuracy improved from -inf to 0.65051, saving model to weights_InceptionV3.keras
# 32/32 [==============================] - 21s 370ms/step - loss: 0.9637 - accuracy: 0.6530 - val_loss: 0.9931 - val_accuracy: 0.6505
# Epoch 2/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.2917 - accuracy: 0.9103
# Epoch 2: val_accuracy improved from 0.65051 to 0.83434, saving model to weights_InceptionV3.keras
# 32/32 [==============================] - 5s 165ms/step - loss: 0.2903 - accuracy: 0.9110 - val_loss: 0.4125 - val_accuracy: 0.8343
# Epoch 3/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.1448 - accuracy: 0.9657
# Epoch 3: val_accuracy improved from 0.83434 to 0.89091, saving model to weights_InceptionV3.keras
# 32/32 [==============================] - 5s 164ms/step - loss: 0.1446 - accuracy: 0.9650 - val_loss: 0.3627 - val_accuracy: 0.8909
# Epoch 4/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.1043 - accuracy: 0.9808
# Epoch 4: val_accuracy improved from 0.89091 to 0.93131, saving model to weights_InceptionV3.keras
# 32/32 [==============================] - 5s 172ms/step - loss: 0.1041 - accuracy: 0.9810 - val_loss: 0.3032 - val_accuracy: 0.9313
# Epoch 5/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0655 - accuracy: 0.9899
# Epoch 5: val_accuracy did not improve from 0.93131
# 32/32 [==============================] - 3s 104ms/step - loss: 0.0664 - accuracy: 0.9900 - val_loss: 0.3435 - val_accuracy: 0.8949
# Epoch 6/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0599 - accuracy: 0.9879
# Epoch 6: val_accuracy did not improve from 0.93131
# 32/32 [==============================] - 3s 101ms/step - loss: 0.0637 - accuracy: 0.9870 - val_loss: 0.2949 - val_accuracy: 0.9152
# Epoch 7/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0640 - accuracy: 0.9829
# Epoch 7: val_accuracy did not improve from 0.93131
# 32/32 [==============================] - 3s 102ms/step - loss: 0.0684 - accuracy: 0.9820 - val_loss: 0.3956 - val_accuracy: 0.8525
# Epoch 8/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0463 - accuracy: 0.9950
# Epoch 8: val_accuracy did not improve from 0.93131
# 32/32 [==============================] - 3s 103ms/step - loss: 0.0462 - accuracy: 0.9950 - val_loss: 0.4066 - val_accuracy: 0.8444
# Epoch 9/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0426 - accuracy: 0.9919
# Epoch 9: val_accuracy did not improve from 0.93131
# 32/32 [==============================] - 3s 103ms/step - loss: 0.0432 - accuracy: 0.9910 - val_loss: 0.4201 - val_accuracy: 0.8465
# Epoch 10/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0382 - accuracy: 0.9950
# Epoch 10: val_accuracy did not improve from 0.93131
# 32/32 [==============================] - 3s 103ms/step - loss: 0.0382 - accuracy: 0.9950 - val_loss: 0.4583 - val_accuracy: 0.8202
# Epoch 11/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9929
# Epoch 11: val_accuracy did not improve from 0.93131
# 32/32 [==============================] - 3s 103ms/step - loss: 0.0322 - accuracy: 0.9930 - val_loss: 0.3294 - val_accuracy: 0.8747
# Epoch 12/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9970
# Epoch 12: val_accuracy did not improve from 0.93131
# 32/32 [==============================] - 3s 103ms/step - loss: 0.0209 - accuracy: 0.9970 - val_loss: 0.3092 - val_accuracy: 0.8970
# Epoch 13/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0198 - accuracy: 0.9980
# Epoch 13: val_accuracy did not improve from 0.93131
# 32/32 [==============================] - 3s 104ms/step - loss: 0.0196 - accuracy: 0.9980 - val_loss: 0.3020 - val_accuracy: 0.9010
# Epoch 14/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0157 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.93131
# 32/32 [==============================] - 3s 104ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.2947 - val_accuracy: 0.9091

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of InceptionV3 with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_InceptionV3.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of InceptionV3 with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_InceptionV3.png')
plt.show()

# %%
model = tf.keras.models.load_model('weights_InceptionV3.keras')
model.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 3s 65ms/step - loss: 0.3032 - accuracy: 0.9313
# [0.3032160699367523, 0.931313157081604]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of Inception-V3 with {dataset_name}')
plt.savefig('Confusion_Matrix_InceptionV3.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 16/16 [==============================] - 1s 67ms/step
#               precision    recall  f1-score   support
#
#        chair       0.92      1.00      0.96        84
#        cobra       0.98      0.89      0.93       116
#          dog       0.87      0.92      0.90        90
#         tree       0.98      0.97      0.97        96
#      warrior       0.90      0.90      0.90       109
#
#     accuracy                           0.93       495
#    macro avg       0.93      0.94      0.93       495
# weighted avg       0.93      0.93      0.93       495

# %%
with open('history_InceptionV3.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['Accuracy_Graph_InceptionV3.png', 'Loss_Graph_InceptionV3.png', 'Confusion_Matrix_InceptionV3.png', 'history_InceptionV3.pkl', 'weights_InceptionV3.keras']
zip_filename = "results_InceptionV3.zip"
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # MobileNet V2 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)
        img = tf.image.resize(img, (224, 224))
        img = tf.keras.applications.mobilenet_v2.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df


def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1000, 224, 224, 3)
# (495, 224, 224, 3)
# (1000, 5)
# (495, 5)

# %%
mobile_net = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
mobile_net.trainable = False

model = tf.keras.Sequential([
    mobile_net,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 2s 0us/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  flatten_3 (Flatten)         (None, 62720)             0
#
#  dense_9 (Dense)             (None, 256)               16056576
#
#  batch_normalization_104 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 64)                16448
#
#  batch_normalization_105 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 18332613 (69.93 MB)
# Trainable params: 16073989 (61.32 MB)
# Non-trainable params: 2258624 (8.62 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_MobileNetV2.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 0.8257 - accuracy: 0.7090
# Epoch 1: val_accuracy improved from -inf to 0.51515, saving model to weights_MobileNetV2.keras
# 32/32 [==============================] - 10s 188ms/step - loss: 0.8257 - accuracy: 0.7090 - val_loss: 1.4617 - val_accuracy: 0.5152
# Epoch 2/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.2497 - accuracy: 0.9234
# Epoch 2: val_accuracy improved from 0.51515 to 0.70707, saving model to weights_MobileNetV2.keras
# 32/32 [==============================] - 3s 107ms/step - loss: 0.2487 - accuracy: 0.9240 - val_loss: 0.7214 - val_accuracy: 0.7071
# Epoch 3/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.1164 - accuracy: 0.9778
# Epoch 3: val_accuracy improved from 0.70707 to 0.78182, saving model to weights_MobileNetV2.keras
# 32/32 [==============================] - 3s 106ms/step - loss: 0.1163 - accuracy: 0.9780 - val_loss: 0.5808 - val_accuracy: 0.7818
# Epoch 4/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0817 - accuracy: 0.9859
# Epoch 4: val_accuracy improved from 0.78182 to 0.81212, saving model to weights_MobileNetV2.keras
# 32/32 [==============================] - 3s 107ms/step - loss: 0.0814 - accuracy: 0.9860 - val_loss: 0.5153 - val_accuracy: 0.8121
# Epoch 5/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0497 - accuracy: 0.9980
# Epoch 5: val_accuracy improved from 0.81212 to 0.82424, saving model to weights_MobileNetV2.keras
# 32/32 [==============================] - 3s 106ms/step - loss: 0.0499 - accuracy: 0.9980 - val_loss: 0.4932 - val_accuracy: 0.8242
# Epoch 6/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0506 - accuracy: 0.9929
# Epoch 6: val_accuracy improved from 0.82424 to 0.83636, saving model to weights_MobileNetV2.keras
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0508 - accuracy: 0.9930 - val_loss: 0.4766 - val_accuracy: 0.8364
# Epoch 7/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9929
# Epoch 7: val_accuracy did not improve from 0.83636
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0455 - accuracy: 0.9930 - val_loss: 0.5203 - val_accuracy: 0.8061
# Epoch 8/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0302 - accuracy: 0.9940
# Epoch 8: val_accuracy did not improve from 0.83636
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0322 - accuracy: 0.9930 - val_loss: 0.5736 - val_accuracy: 0.7919
# Epoch 9/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 0.9970
# Epoch 9: val_accuracy did not improve from 0.83636
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0248 - accuracy: 0.9970 - val_loss: 0.5525 - val_accuracy: 0.8020
# Epoch 10/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0191 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.83636
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.4924 - val_accuracy: 0.8162
# Epoch 11/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0254 - accuracy: 0.9960
# Epoch 11: val_accuracy improved from 0.83636 to 0.84040, saving model to weights_MobileNetV2.keras
# 32/32 [==============================] - 4s 128ms/step - loss: 0.0252 - accuracy: 0.9960 - val_loss: 0.4671 - val_accuracy: 0.8404
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9970
# Epoch 12: val_accuracy improved from 0.84040 to 0.84848, saving model to weights_MobileNetV2.keras
# 32/32 [==============================] - 3s 106ms/step - loss: 0.0198 - accuracy: 0.9970 - val_loss: 0.4357 - val_accuracy: 0.8485
# Epoch 13/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9990
# Epoch 13: val_accuracy improved from 0.84848 to 0.85859, saving model to weights_MobileNetV2.keras
# 32/32 [==============================] - 3s 109ms/step - loss: 0.0186 - accuracy: 0.9980 - val_loss: 0.4311 - val_accuracy: 0.8586
# Epoch 14/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0199 - accuracy: 0.9980
# Epoch 14: val_accuracy did not improve from 0.85859
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0212 - accuracy: 0.9980 - val_loss: 0.4516 - val_accuracy: 0.8404
# Epoch 15/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0192 - accuracy: 0.9980
# Epoch 15: val_accuracy did not improve from 0.85859
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0190 - accuracy: 0.9980 - val_loss: 0.4613 - val_accuracy: 0.8323
# Epoch 16/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0175 - accuracy: 0.9970
# Epoch 16: val_accuracy did not improve from 0.85859
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0176 - accuracy: 0.9970 - val_loss: 0.4290 - val_accuracy: 0.8525
# Epoch 17/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0121 - accuracy: 0.9990
# Epoch 17: val_accuracy did not improve from 0.85859
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0121 - accuracy: 0.9990 - val_loss: 0.4341 - val_accuracy: 0.8465
# Epoch 18/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0144 - accuracy: 0.9980
# Epoch 18: val_accuracy did not improve from 0.85859
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0160 - accuracy: 0.9970 - val_loss: 0.4054 - val_accuracy: 0.8545
# Epoch 19/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9960
# Epoch 19: val_accuracy did not improve from 0.85859
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0198 - accuracy: 0.9960 - val_loss: 0.4991 - val_accuracy: 0.7980
# Epoch 20/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 0.9950
# Epoch 20: val_accuracy did not improve from 0.85859
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0224 - accuracy: 0.9950 - val_loss: 0.4551 - val_accuracy: 0.8242
# Epoch 21/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9990
# Epoch 21: val_accuracy did not improve from 0.85859
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0106 - accuracy: 0.9990 - val_loss: 0.4915 - val_accuracy: 0.8323
# Epoch 22/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0124 - accuracy: 0.9980
# Epoch 22: val_accuracy did not improve from 0.85859
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0126 - accuracy: 0.9980 - val_loss: 0.4825 - val_accuracy: 0.8283
# Epoch 23/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.85859
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.4725 - val_accuracy: 0.8465

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of MobileNetV2 with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_MobileNetV2.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of MobileNetV2 with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_MobileNetV2.png')
plt.show()

# %%
model = tf.keras.models.load_model("weights_MobileNetV2.keras")
model.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 2s 42ms/step - loss: 0.4311 - accuracy: 0.8586
# [0.43106234073638916, 0.8585858345031738]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of MobileNetV2 with {dataset_name}')
plt.savefig('Confusion_Matrix_MobileNetV2.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 16/16 [==============================] - 1s 41ms/step
#               precision    recall  f1-score   support
#
#        chair       1.00      0.77      0.87        84
#        cobra       0.88      0.87      0.87       116
#          dog       0.72      0.98      0.83        90
#         tree       0.82      1.00      0.90        96
#      warrior       1.00      0.69      0.82       109
#
#     accuracy                           0.86       495
#    macro avg       0.88      0.86      0.86       495
# weighted avg       0.88      0.86      0.86       495

# %%
with open('history_for_MoblieNetV2.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_MobileNetV2.keras', 'history_for_MoblieNetV2.pkl', 'Loss_Graph_MobileNetV2.png', 'Accuracy_Graph_MobileNetV2.png', 'Confusion_Matrix_MobileNetV2.png']
zip_filename = 'results_MobileNetV2.zip'
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # ResNet50 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)
        img = tf.image.resize(img, (224, 224))
        img = tf.keras.applications.resnet50.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df


def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1000, 224, 224, 3)
# (495, 224, 224, 3)
# (1000, 5)
# (495, 5)

# %%
resnet_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
resnet_model.trainable = False

model = tf.keras.Sequential([
    resnet_model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_4 (Flatten)         (None, 100352)            0
#
#  dense_12 (Dense)            (None, 256)               25690368
#
#  batch_normalization_106 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 64)                16448
#
#  batch_normalization_107 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 49296133 (188.05 MB)
# Trainable params: 25707781 (98.07 MB)
# Non-trainable params: 23588352 (89.98 MB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = "weights_ResNet50.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 0.8834 - accuracy: 0.7080
# Epoch 1: val_accuracy improved from -inf to 0.45051, saving model to weights_ResNet50.keras
# 32/32 [==============================] - 17s 328ms/step - loss: 0.8834 - accuracy: 0.7080 - val_loss: 2.1504 - val_accuracy: 0.4505
# Epoch 2/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.2604 - accuracy: 0.9244
# Epoch 2: val_accuracy improved from 0.45051 to 0.61212, saving model to weights_ResNet50.keras
# 32/32 [==============================] - 6s 206ms/step - loss: 0.2594 - accuracy: 0.9250 - val_loss: 0.8065 - val_accuracy: 0.6121
# Epoch 3/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.1408 - accuracy: 0.9637
# Epoch 3: val_accuracy improved from 0.61212 to 0.86465, saving model to weights_ResNet50.keras
# 32/32 [==============================] - 6s 205ms/step - loss: 0.1400 - accuracy: 0.9640 - val_loss: 0.4917 - val_accuracy: 0.8646
# Epoch 4/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0967 - accuracy: 0.9778
# Epoch 4: val_accuracy improved from 0.86465 to 0.90303, saving model to weights_ResNet50.keras
# 32/32 [==============================] - 7s 208ms/step - loss: 0.0966 - accuracy: 0.9780 - val_loss: 0.4236 - val_accuracy: 0.9030
# Epoch 5/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0702 - accuracy: 0.9849
# Epoch 5: val_accuracy improved from 0.90303 to 0.91919, saving model to weights_ResNet50.keras
# 32/32 [==============================] - 7s 235ms/step - loss: 0.0698 - accuracy: 0.9850 - val_loss: 0.3861 - val_accuracy: 0.9192
# Epoch 6/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0488 - accuracy: 0.9919
# Epoch 6: val_accuracy did not improve from 0.91919
# 32/32 [==============================] - 5s 144ms/step - loss: 0.0485 - accuracy: 0.9920 - val_loss: 0.3907 - val_accuracy: 0.9010
# Epoch 7/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9960
# Epoch 7: val_accuracy did not improve from 0.91919
# 32/32 [==============================] - 5s 143ms/step - loss: 0.0415 - accuracy: 0.9960 - val_loss: 0.3911 - val_accuracy: 0.8949
# Epoch 8/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.
50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.95354
# 32/32 [==============================] - 5s 145ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.2591 - val_accuracy: 0.9374
# Epoch 30/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.95354
# 32/32 [==============================] - 5s 146ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2732 - val_accuracy: 0.9333
# Epoch 31/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0130 - accuracy: 0.9980
# Epoch 31: val_accuracy did not improve from 0.95354
# 32/32 [==============================] - 5s 146ms/step - loss: 0.0129 - accuracy: 0.9980 - val_loss: 0.3008 - val_accuracy: 0.9131
# Epoch 32/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.95354
# 32/32 [==============================] - 5s 146ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.3115 - val_accuracy: 0.9051
# Epoch 33/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 0.9990
# Epoch 33: val_accuracy did not improve from 0.95354
# 32/32 [==============================] - 5s 146ms/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.3423 - val_accuracy: 0.8990
# Epoch 34/50
# 31/32 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.95354
# 32/32 [==============================] - 5s 145ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.3454 - val_accuracy: 0.8970

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of ResNet50 with {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_ResNet50.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of ResNet50 with {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_ResNet50.png')
plt.show()

# %%
model = keras.models.load_model('weights_ResNet50.keras')
model.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 3s 92ms/step - loss: 0.2935 - accuracy: 0.9535
# [0.2934780716896057, 0.9535353779792786]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of ResNet50 with {dataset_name}')
plt.savefig('Confusion_Matrix_ResNet50.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 16/16 [==============================] - 1s 92ms/step
#               precision    recall  f1-score   support
#
#        chair       1.00      0.76      0.86        84
#        cobra       0.99      1.00      1.00       116
#          dog       1.00      0.97      0.98        90
#         tree       0.83      1.00      0.91        96
#      warrior       0.98      1.00      0.99       109
#
#     accuracy                           0.95       495
#    macro avg       0.96      0.95      0.95       495
# weighted avg       0.96      0.95      0.95       495

# %%
with open('history_for_ResNet50.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['history_for_ResNet50.pkl', 'weights_ResNet50.keras', 'Loss_Graph_ResNet50.png', 'Accuracy_Graph_ResNet50.png', 'Confusion_Matrix_ResNet50.png']
zip_filename = 'results_ResNet50.zip'

create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # Vgg16 Model

# %%
def load_and_preprocess_image(file_path):
    try:
        img = tf.io.read_file(file_path)
        img = tf.image.decode_image(img, channels=3)
        img = tf.image.resize(img, (224, 224))
        img = tf.keras.applications.vgg16.preprocess_input(img)
        return img
    except Exception as e:
        print(f"Error loading image {file_path}: {str(e)}")
        return None


def create_df(dir):
    df = pd.DataFrame(columns=['image_path', 'class_name', 'class_no', 'image'])
    class_names = sorted(os.listdir(dir))
    for class_name in class_names:
        class_path = os.path.join(dir, class_name)
        class_no = class_names.index(class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            img = load_and_preprocess_image(image_path)
            if img is not None:
                df.loc[len(df)] = [image_path, class_name, class_no, img]
            else:
                continue
    return df


def load_data(df):
    df.drop(columns=['image_path'], inplace=True)
    classes = df.pop('class_name').unique()
    x_images = df.pop('image')
    y = df.pop('class_no')
    y = keras.utils.to_categorical(y)
    return x_images, y, classes, df


train_df = create_df(train_dir)
test_df = create_df(test_dir)

X_train, y_train, classes, _ = load_data(train_df)
X_test, y_test, _, _ = load_data(test_df)

X_train = np.stack(X_train.values)
X_test = np.stack(X_test.values)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1000, 224, 224, 3)
# (495, 224, 224, 3)
# (1000, 5)
# (495, 5)

# %%
vgg_model = keras.applications.vgg16.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
vgg_model.trainable = False

model = tf.keras.Sequential([
    vgg_model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(classes), activation='softmax')
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_5 (Flatten)         (None, 25088)             0
#
#  dense_15 (Dense)            (None, 256)               6422784
#
#  batch_normalization_108 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 64)                16448
#
#  batch_normalization_109 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 21155525 (80.70 MB)
# Trainable params: 6440197 (24.57 MB)
# Non-trainable params: 14715328 (56.13 MB)
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = 'weights_Vgg16.keras'
checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 0.8121 - accuracy: 0.7150
# Epoch 1: val_accuracy improved from -inf to 0.87071, saving model to weights_Vgg16.keras
# 32/32 [==============================] - 26s 471ms/step - loss: 0.8121 - accuracy: 0.7150 - val_loss: 0.5223 - val_accuracy: 0.8707
# Epoch 2/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.9400
# Epoch 2: val_accuracy improved from 0.87071 to 0.88485, saving model to weights_Vgg16.keras
# 32/32 [==============================] - 6s 203ms/step - loss: 0.2337 - accuracy: 0.9400 - val_loss: 0.4035 - val_accuracy: 0.8848
# Epoch 3/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9770
# Epoch 3: val_accuracy improved from 0.88485 to 0.90707, saving model to weights_Vgg16.keras
# 32/32 [==============================] - 6s 204ms/step - loss: 0.1148 - accuracy: 0.9770 - val_loss: 0.3305 - val_accuracy: 0.9071
# Epoch 4/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.9780
# Epoch 4: val_accuracy improved from 0.90707 to 0.94949, saving model to weights_Vgg16.keras
# 32/32 [==============================] - 6s 204ms/step - loss: 0.0905 - accuracy: 0.9780 - val_loss: 0.2688 - val_accuracy: 0.9495
# Epoch 5/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9920
# Epoch 5: val_accuracy improved from 0.94949 to 0.96364, saving model to weights_Vgg16.keras
# 32/32 [==============================] - 6s 206ms/step - loss: 0.0561 - accuracy: 0.9920 - val_loss: 0.2498 - val_accuracy: 0.9636
# Epoch 6/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0450 - accuracy: 0.9930
# Epoch 6: val_accuracy did not improve from 0.96364
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0450 - accuracy: 0.9930 - val_loss: 0.2597 - val_accuracy: 0.9596
# Epoch 7/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9960
# Epoch 7: val_accuracy did not improve from 0.96364
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0400 - accuracy: 0.9960 - val_loss: 0.2605 - val_accuracy: 0.9636
# Epoch 8/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9950
# Epoch 8: val_accuracy did not improve from 0.96364
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0309 - accuracy: 0.9950 - val_loss: 0.2470 - val_accuracy: 0.9576
# Epoch 9/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9980
# Epoch 9: val_accuracy did not improve from 0.96364
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0260 - accuracy: 0.9980 - val_loss: 0.2341 - val_accuracy: 0.9535
# Epoch 10/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9990
# Epoch 10: val_accuracy did not improve from 0.96364
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0228 - accuracy: 0.9990 - val_loss: 0.2127 - val_accuracy: 0.9556
# Epoch 11/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9950
# Epoch 11: val_accuracy did not improve from 0.96364
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0245 - accuracy: 0.9950 - val_loss: 0.1900 - val_accuracy: 0.9616
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9990
# Epoch 12: val_accuracy did not improve from 0.96364
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0192 - accuracy: 0.9990 - val_loss: 0.1905 - val_accuracy: 0.9616
# Epoch 13/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.96364
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9576
# Epoch 14/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9980
# Epoch 14: val_accuracy did not improve from 0.96364
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0182 - accuracy: 0.9980 - val_loss: 0.2487 - val_accuracy: 0.9576
# Epoch 15/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.96364
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9515

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of Vgg16 with {dataset_name}')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.savefig('Accuracy_Graph_Vgg16.png')
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of Vgg16 with {dataset_name}')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.savefig('Loss_Graph_Vgg16.png')
plt.show()

# %%
model = keras.models.load_model('weights_Vgg16.keras')
model.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 2s 118ms/step - loss: 0.2498 - accuracy: 0.9636
# [0.24984626471996307, 0.9636363387107849]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(16,16))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of Vgg16 with {dataset_name}')
plt.savefig('Confusion_Matrix_Vgg16.png')
plt.show()

class_report = classification_report(y_true, y_pred, target_names=classes)
print(class_report)
# Out:
# 16/16 [==============================] - 2s 122ms/step
#               precision    recall  f1-score   support
#
#        chair       0.86      1.00      0.92        84
#        cobra       0.98      0.98      0.98       116
#          dog       0.98      1.00      0.99        90
#         tree       1.00      0.89      0.94        96
#      warrior       1.00      0.95      0.98       109
#
#     accuracy                           0.96       495
#    macro avg       0.96      0.96      0.96       495
# weighted avg       0.97      0.96      0.96       495

# %%
with open('history_for_Vgg16.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_Vgg16.keras', 'history_for_Vgg16.pkl', 'Confusion_Matrix_Vgg16.png', 'Accuracy_Graph_Vgg16.png', 'Loss_Graph_Vgg16.png']
zip_filename = 'results_Vgg16.zip'

create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # MoveNet Model

# %% [markdown]
# # Downloading the MoveNet model

# %%
# Download model from TF Hub and check out inference code from GitHub
# !wget -q -O movenet_thunder.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# !git clone https://github.com/tensorflow/examples.git
pose_sample_rpi_path = os.path.join(os.getcwd(), 'examples/lite/examples/pose_estimation/raspberry_pi')
sys.path.append(pose_sample_rpi_path)

# Load MoveNet Thunder model
import utils
from data import BodyPart
from ml import Movenet
movenet = Movenet('movenet_thunder')

# Define function to run pose estimation using MoveNet Thunder.
# You'll apply MoveNet's cropping algorithm and run inference multiple times on
# the input image to improve pose estimation accuracy.
def detect(input_tensor, inference_count=5):
  """Runs detection on an input image.

  Args:
    input_tensor: A [height, width, 3] Tensor of type tf.float32.
      Note that height and width can be anything since the image will be
      immediately resized according to the needs of the model within this
      function.
    inference_count: Number of times the model should run repeatly on the
      same input image to improve detection accuracy.

  Returns:
    A Person entity detected by the MoveNet.SinglePose.
  """

  image_height, image_width, channel = input_tensor.shape

  # Detect pose using the full input image
  movenet.detect(input_tensor.numpy(), reset_crop_region=True)

  # Repeatedly using previous detection result to identify the region of
  # interest and only croping that region to improve detection accuracy
  for _ in range(inference_count - 1):
    person = movenet.detect(input_tensor.numpy(),
                            reset_crop_region=False)

  return person
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 23737, done.
# remote: Counting objects: 100% (701/701), done.
# remote: Compressing objects: 100% (419/419), done.
# remote: Total 23737 (delta 231), reused 564 (delta 194), pack-reused 23036
# Receiving objects: 100% (23737/23737), 44.18 MiB | 13.71 MiB/s, done.
# Resolving deltas: 100% (12880/12880), done.

# %%
def draw_prediction_on_image(
    image, person, crop_region=None, close_figure=True,
    keep_input_size=False):
  """Draws the keypoint predictions on image.

  Args:
    image: An numpy array with shape [height, width, channel] representing the
      pixel values of the input image.
    person: A person entity returned from the MoveNet.SinglePose model.
    close_figure: Whether to close the plt figure after the function returns.
    keep_input_size: Whether to keep the size of the input image.

  Returns:
    An numpy array with shape [out_height, out_width, channel] representing the
    image overlaid with keypoint predictions.
  """
  # Draw the detection result on top of the image.
  image_np = utils.visualize(image, [person])

  # Plot the image with detection results.
  height, width, channel = image.shape
  aspect_ratio = float(width) / height
  fig, ax = plt.subplots(figsize=(12 * aspect_ratio, 12))
  im = ax.imshow(image_np)

  if close_figure:
    plt.close(fig)

  if not keep_input_size:
    image_np = utils.keep_aspect_ratio_resizer(image_np, (512, 512))

  return image_np

# %%
class MoveNetPreprocessor(object):
  """Helper class to preprocess pose sample images for classification."""

  def __init__(self,
               images_in_folder,
               images_out_folder,
               csvs_out_path):
    """Creates a preprocessor to detection pose from images and save as CSV.

    Args:
      images_in_folder: Path to the folder with the input images. It should
        follow this structure:
        yoga_poses
        |__ downdog
            |______ 00000128.jpg
            |______ 00000181.bmp
            |______ ...
        |__ goddess
            |______ 00000243.jpg
            |______ 00000306.jpg
            |______ ...
        ...
      images_out_folder: Path to write the images overlay with detected
        landmarks. These images are useful when you need to debug accuracy
        issues.
      csvs_out_path: Path to write the CSV containing the detected landmark
        coordinates and label of each image that can be used to train a pose
        classification model.
    """
    self._images_in_folder = images_in_folder
    self._images_out_folder = images_out_folder
    self._csvs_out_path = csvs_out_path
    self._messages = []

    # Create a temp dir to store the pose CSVs per class
    self._csvs_out_folder_per_class = tempfile.mkdtemp()

    # Get list of pose classes and print image statistics
    self._pose_class_names = sorted(
        [n for n in os.listdir(self._images_in_folder) if not n.startswith('.')]
        )

  def process(self, per_pose_class_limit=None, detection_threshold=0.1):
    """Preprocesses images in the given folder.
    Args:
      per_pose_class_limit: Number of images to load. As preprocessing usually
        takes time, this parameter can be specified to make the reduce of the
        dataset for testing.
      detection_threshold: Only keep images with all landmark confidence score
        above this threshold.
    """
    # Loop through the classes and preprocess its images
    for pose_class_name in self._pose_class_names:
      print('Preprocessing', pose_class_name, file=sys.stderr)

      # Paths for the pose class.
      images_in_folder = os.path.join(self._images_in_folder, pose_class_name)
      images_out_folder = os.path.join(self._images_out_folder, pose_class_name)
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  pose_class_name + '.csv')
      if not os.path.exists(images_out_folder):
        os.makedirs(images_out_folder)

      # Detect landmarks in each image and write it to a CSV file
      with open(csv_out_path, 'w') as csv_out_file:
        csv_out_writer = csv.writer(csv_out_file,
                                    delimiter=',',
                                    quoting=csv.QUOTE_MINIMAL)
        # Get list of images
        image_names = sorted(
            [n for n in os.listdir(images_in_folder) if not n.startswith('.')])
        if per_pose_class_limit is not None:
          image_names = image_names[:per_pose_class_limit]

        valid_image_count = 0

        # Detect pose landmarks from each image
        for image_name in tqdm.tqdm(image_names):
          image_path = os.path.join(images_in_folder, image_name)

          try:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image,channels = 3)
          except:
            self._messages.append('Skipped ' + image_path + '. Invalid image.')
            continue
          else:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image,channels = 3)
            image_height, image_width, channel = image.shape

          # Skip images that isn't RGB because Movenet requires RGB images
          if channel != 3:
            self._messages.append('Skipped ' + image_path +
                                  '. Image isn\'t in RGB format.')
            continue
          person = detect(image)

          # Save landmarks if all landmarks were detected
          min_landmark_score = min(
              [keypoint.score for keypoint in person.keypoints])
          should_keep_image = min_landmark_score >= detection_threshold
          if not should_keep_image:
            self._messages.append('Skipped ' + image_path +
                                  '. No pose was confidentlly detected.')
            continue

          valid_image_count += 1

          # Draw the prediction result on top of the image for debugging later
          output_overlay = draw_prediction_on_image(
              image.numpy().astype(np.uint8), person,
              close_figure=True, keep_input_size=True)

          # Write detection result into an image file
          output_frame = cv2.cvtColor(output_overlay, cv2.COLOR_RGB2BGR)
          cv2.imwrite(os.path.join(images_out_folder, image_name), output_frame)

          # Get landmarks and scale it to the same size as the input image
          pose_landmarks = np.array(
              [[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score]
                for keypoint in person.keypoints],
              dtype=np.float32)

          # Write the landmark coordinates to its per-class CSV file
          coordinates = pose_landmarks.flatten().astype(str).tolist()
          csv_out_writer.writerow([image_name] + coordinates)

        if not valid_image_count:
          raise RuntimeError(
              'No valid images found for the "{}" class.'
              .format(pose_class_name))

    # Print the error message collected during preprocessing.
    print('\n'.join(self._messages))

    # Combine all per-class CSVs into a single output file
    all_landmarks_df = self._all_landmarks_as_dataframe()
    all_landmarks_df.to_csv(self._csvs_out_path, index=False)

  def class_names(self):
    """List of classes found in the training dataset."""
    return self._pose_class_names

  def _all_landmarks_as_dataframe(self):
    """Merge all per-class CSVs into a single dataframe."""
    total_df = None
    for class_index, class_name in enumerate(self._pose_class_names):
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  class_name + '.csv')
      per_class_df = pd.read_csv(csv_out_path, header=None)

      # Add the labels
      per_class_df['class_no'] = [class_index]*len(per_class_df)
      per_class_df['class_name'] = [class_name]*len(per_class_df)

      # Append the folder name to the filename column (first column)
      per_class_df[per_class_df.columns[0]] = (os.path.join(class_name, '')
        + per_class_df[per_class_df.columns[0]].astype(str))

      if total_df is None:
        # For the first class, assign its data to the total dataframe
        total_df = per_class_df
      else:
        # Concatenate each class's data into the total dataframe
        total_df = pd.concat([total_df, per_class_df], axis=0)

    list_name = [[bodypart.name + '_x', bodypart.name + '_y',
                  bodypart.name + '_score'] for bodypart in BodyPart]
    header_name = []
    for columns_name in list_name:
      header_name += columns_name
    header_name = ['file_name'] + header_name
    header_map = {total_df.columns[i]: header_name[i]
                  for i in range(len(header_name))}

    total_df.rename(header_map, axis=1, inplace=True)

    return total_df

# %% [markdown]
# # Testing the MoveNet Model

# %%
image = tf.io.read_file('/content/dataset/test/chair/guy3_chair070.jpg')
image = tf.io.decode_jpeg(image, channels=3)
person = detect(image)
_ = draw_prediction_on_image(image.numpy(), person, crop_region=None,
                            close_figure=False, keep_input_size=True)

# %%
dataset_in = '/content/dataset/'

# %%
images_in_train_folder = os.path.join(dataset_in, 'train')
images_out_train_folder = 'poses_images_out_train'
csvs_out_train_path = 'train_data_MoveNet.csv'

preprocessor = MoveNetPreprocessor(
    images_in_folder=images_in_train_folder,
    images_out_folder=images_out_train_folder,
    csvs_out_path=csvs_out_train_path,
)

preprocessor.process(per_pose_class_limit=None)
# Out:
# Preprocessing chair
# 100%|██████████| 200/200 [00:20<00:00,  9.59it/s]
# Preprocessing cobra
# 100%|██████████| 200/200 [00:16<00:00, 11.77it/s]
# Preprocessing dog
# 100%|██████████| 200/200 [00:18<00:00, 10.71it/s]
# Preprocessing tree
# 100%|██████████| 200/200 [00:19<00:00, 10.05it/s]
# Preprocessing warrior
# 100%|██████████| 200/200 [00:16<00:00, 11.83it/s]
# Skipped /content/dataset/train/chair/girl3_chair088.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair089.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair091.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair092.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair095.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair096.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair099.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair108.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair110.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair114.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair118.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair122.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair123.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair124.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair125.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair131.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair132.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair133.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair134.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair136.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair138.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/girl3_chair142.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair/guy2_chair136.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/train/chair
processor.process(per_pose_class_limit=None)
# Out:
# Preprocessing chair
# 100%|██████████| 84/84 [00:08<00:00, 10.33it/s]
# Preprocessing cobra
# 100%|██████████| 116/116 [00:12<00:00,  9.52it/s]
# Preprocessing dog
# 100%|██████████| 90/90 [00:08<00:00, 10.66it/s]
# Preprocessing tree
# 100%|██████████| 96/96 [00:10<00:00,  9.34it/s]
# Preprocessing warrior
# 100%|██████████| 109/109 [00:10<00:00, 10.28it/s]
# Skipped /content/dataset/test/cobra/guy3_cobra047.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra048.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra050.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra051.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra052.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra053.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra054.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra055.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra056.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra057.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra058.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra059.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra060.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra062.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra063.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra066.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra068.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra069.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra070.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra074.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra076.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra077.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra079.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra081.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra083.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra087.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra124.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra125.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra131.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra132.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra134.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra135.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/cobra/guy3_cobra136.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/dog/guy3_dog025.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/dog/guy3_dog026.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/dog/guy3_dog104.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/dog/guy3_dog106.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/dog/guy3_dog107.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/dog/guy3_dog108.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior043.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior044.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior045.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior046.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior047.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior048.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior050.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior051.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior052.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior053.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior055.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior060.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior061.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior063.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior065.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior066.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior067.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior068.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior070.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior071.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior072.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior073.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior075.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior076.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior077.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior079.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior080.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior084.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior086.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior087.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior088.jpg. No pose was confidentlly detected.
# Skipped /content/dataset/test/warrior/guy3_warrior131.jpg. No pose was confidentlly detected.

# %%
# !cp {csvs_out_train_path} {path_to_save}
# !cp {csvs_out_test_path} {path_to_save}

# %%
def load_pose_landmarks(csv_path):
  """Loads a CSV created by MoveNetPreprocessor.

  Returns:
    X: Detected landmark coordinates and scores of shape (N, 17 * 3)
    y: Ground truth labels of shape (N, label_count)
    classes: The list of all class names found in the dataset
    dataframe: The CSV loaded as a Pandas dataframe features (X) and ground
      truth labels (y) to use later to train a pose classification model.
  """

  # Load the CSV file
  dataframe = pd.read_csv(csv_path)
  df_to_process = dataframe.copy()

  # Drop the file_name columns as you don't need it during training.
  df_to_process.drop(columns=['file_name'], inplace=True)

  # Extract the list of class names
  classes = df_to_process.pop('class_name').unique()

  # Extract the labels
  y = df_to_process.pop('class_no')

  # Convert the input features and labels into the correct format for training.
  X = df_to_process.astype('float64')
  y = keras.utils.to_categorical(y)

  return X, y, classes, dataframe

# %%
# Load the train data
X, y, class_names, _ = load_pose_landmarks(csvs_out_train_path)

X_train = X
y_train = y
# Load the test data
X_test, y_test, _, df_test = load_pose_landmarks(csvs_out_test_path)

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
  """Calculates the center point of the two given landmarks."""

  left = tf.gather(landmarks, left_bodypart.value, axis=1)
  right = tf.gather(landmarks, right_bodypart.value, axis=1)
  center = left * 0.5 + right * 0.5
  return center


def get_pose_size(landmarks, torso_size_multiplier=2.5):
  """Calculates pose size.

  It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
  """
  # Hips center
  hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)

  # Shoulders center
  shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

  # Torso size as the minimum body size
  torso_size = tf.linalg.norm(shoulders_center - hips_center)

  # Pose center
  pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                     BodyPart.RIGHT_HIP)
  pose_center_new = tf.expand_dims(pose_center_new, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to
  # perform substraction
  pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

  # Dist to pose center
  d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
  # Max dist to pose center
  max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

  # Normalize scale
  pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)

  return pose_size


def normalize_pose_landmarks(landmarks):
  """Normalizes the landmarks translation by moving the pose center to (0,0) and
  scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
  pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)
  pose_center = tf.expand_dims(pose_center, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to perform
  # substraction
  pose_center = tf.broadcast_to(pose_center,
                                [tf.size(landmarks) // (17*2), 17, 2])
  landmarks = landmarks - pose_center

  # Scale the landmarks to a constant pose size
  pose_size = get_pose_size(landmarks)
  landmarks /= pose_size

  return landmarks


def landmarks_to_embedding(landmarks_and_scores):
  """Converts the input landmarks into a pose embedding."""
  # Reshape the flat input into a matrix with shape=(17, 3)
  reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

  # Normalize landmarks 2D
  landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])

  # Flatten the normalized landmark coordinates into a vector
  embedding = keras.layers.Flatten()(landmarks)

  return embedding

# %%
# Define the model
inputs = tf.keras.Input(shape=(51))
embedding = landmarks_to_embedding(inputs)

layer = keras.layers.Dense(256, activation=tf.nn.relu6)(embedding)
layer = keras.layers.Dropout(0.3)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.3)(layer)
outputs = keras.layers.Dense(len(class_names), activation="softmax")(layer)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_8 (InputLayer)        [(None, 51)]                 0         []
#
#  reshape_1 (Reshape)         (None, 17, 3)                0         ['input_8[0][0]']
#
#  tf.__operators__.getitem_1  (None, 17, 2)                0         ['reshape_1[0][0]']
#   (SlicingOpLambda)
#
#  tf.compat.v1.gather_9 (TFO  (None, 2)                    0         ['tf.__operators__.getitem_1[0
#  pLambda)                                                           ][0]']
#
#  tf.compat.v1.gather_10 (TF  (None, 2)                    0         ['tf.__operators__.getitem_1[0
#  OpLambda)                                                          ][0]']
#
#  tf.math.multiply_9 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_9[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_10 (TFOpL  (None, 2)                    0         ['tf.compat.v1.gather_10[0][0]
#  ambda)                                                             ']
#
#  tf.__operators__.add_4 (TF  (None, 2)                    0         ['tf.math.multiply_9[0][0]',
#  OpLambda)                                                           'tf.math.multiply_10[0][0]']
#
#  tf.compat.v1.size_2 (TFOpL  ()                           0         ['tf.__operators__.getitem_1[0
#  ambda)                                                             ][0]']
#
#  tf.expand_dims_2 (TFOpLamb  (None, 1, 2)                 0         ['tf.__operators__.add_4[0][0]
#  da)                                                                ']
#
#  tf.compat.v1.floor_div_2 (  ()                           0         ['tf.compat.v1.size_2[0][0]']
#  TFOpLambda)
#
#  tf.broadcast_to_2 (TFOpLam  (None, 17, 2)                0         ['tf.expand_dims_2[0][0]',
#  bda)                                                                'tf.compat.v1.floor_div_2[0][
#                                                                     0]']
#
#  tf.math.subtract_3 (TFOpLa  (None, 17, 2)                0         ['tf.__operators__.getitem_1[0
#  mbda)                                                              ][0]',
#                                                                      'tf.broadcast_to_2[0][0]']
#
#  tf.compat.v1.gather_15 (TF  (None, 2)                    0         ['tf.math.subtract_3[0][0]']
#  OpLambda)
#
#  tf.compat.v1.gather_16 (TF  (None, 2)                    0         ['tf.math.subtract_3[0][0]']
#  OpLambda)
#
#  tf.math.multiply_15 (TFOpL  (None, 2)                    0         ['tf.compat.v1.gather_15[0][0]
#  ambda)                                                             ']
#
#  tf.math.multiply_16 (TFOpL  (None, 2)                    0         ['tf.compat.v1.gather_16[0][0]
#  ambda)                                                             ']
#
#  tf.__operators__.add_7 (TF  (None, 2)                    0         ['tf.math.multiply_15[0][0]',
#  OpLambda)                                                           'tf.math.multiply_16[0][0]']
#
#  tf.compat.v1.size_3 (TFOpL  ()                           0         ['tf.math.subtract_3[0][0]']
#  ambda)
#
#  tf.compat.v1.gather_13 (TF  (None, 2)                    0         ['tf.math.subtract_3[0][0]']
#  OpLambda)
#
#  tf.compat.v1.gather_14 (TF  (None, 2)                    0         ['tf.math.subtract_3[0][0]']
#  OpLambda)
#
#  tf.compat.v1.gather_11 (TF  (None, 2)                    0         ['tf.math.subtract_3[0][0]']
#  OpLambda)
#
#  tf.compat.v1.gather_12 (TF  (None, 2)                    0         ['tf.math.subtract_3[0][0]']
#  OpLambda)
#
#  tf.expand_dims_3 (TFOpLamb  (None, 1, 2)                 0         ['tf.__operators__.add_7[0][0]
#  da)                                                                ']
#
#  tf.compat.v1.floor_div_3 (  ()                           0         ['tf.compat.v1.size_3[0][0]']
#  TFOpLambda)
#
#  tf.math.multiply_13 (TFOpL  (None, 2)                    0         ['tf.compat.v1.gather_13[0][0]
#  ambda)                                                             ']
#
#  tf.math.multiply_14 (TFOpL  (None, 2)                    0         ['tf.compat.v1.gather_14[0][0]
#  ambda)                                                             ']
#
#  tf.math.multiply_11 (TFOpL  (None, 2)                    0         ['tf.compat.v1.gather_11[0][0]
#  ambda)                                                             ']
#
#  tf.math.multiply_12 (TFOpL  (None, 2)                    0         ['tf.compat.v1.gather_12[0][0]
#  ambda)                                                             ']
#
#  tf.broadcast_to_3 (TFOpLam  (None, 17, 2)                0         ['tf.expand_dims_3[0][0]',
#  bda)                                                                'tf.compat.v1.floor_div_3[0][
#                                                                     0]']
#
#  tf.__operators__.add_6 (TF  (None, 2)                    0         ['tf.math.multiply_13[0][0]',
#  OpLambda)                                                           'tf.math.multiply_14[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 2)                    0         ['tf.math.multiply_11[0][0]',
#  OpLambda)                                                           'tf.math.multiply_12[0][0]']
#
#  tf.math.subtract_5 (TFOpLa  (None, 17, 2)                0         ['tf.math.subtract_3[0][0]',
#  mbda)                                                               'tf.broadcast_to_3[0][0]']
#
#  tf.math.subtract_4 (TFOpLa  (None, 2)                    0         ['tf.__operators__.add_6[0][0]
#  mbda)                                                              ',
#                                                                      'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  tf.compat.v1.gather_17 (TF  (17, 2)                      0         ['tf.math.subtract_5[0][0]']
#  OpLambda)
#
#  tf.compat.v1.norm_2 (TFOpL  ()                           0         ['tf.math.subtract_4[0][0]']
#  ambda)
#
#  tf.compat.v1.norm_3 (TFOpL  (2,)                         0         ['tf.compat.v1.gather_17[0][0]
#  ambda)                                                             ']
#
#  tf.math.multiply_17 (TFOpL  ()                           0         ['tf.compat.v1.norm_2[0][0]']
#  ambda)
#
#  tf.math.reduce_max_1 (TFOp  ()                           0         ['tf.compat.v1.norm_3[0][0]']
#  Lambda)
#
#  tf.math.maximum_1 (TFOpLam  ()                           0         ['tf.math.multiply_17[0][0]',
#  bda)                                                                'tf.math.reduce_max_1[0][0]']
#
#  tf.math.truediv_1 (TFOpLam  (None, 17, 2)                0         ['tf.math.subtract_3[0][0]',
#  bda)                                                                'tf.math.maximum_1[0][0]']
#
#  flatten_7 (Flatten)         (None, 34)                   0         ['tf.math.truediv_1[0][0]']
#
#  dense_21 (Dense)            (None, 256)                  8960      ['flatten_7[0][0]']
#
#  dropout_14 (Dropout)        (None, 256)                  0         ['dense_21[0][0]']
#
#  dense_22 (Dense)            (None, 64)                   16448     ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)        (None, 64)                   0         ['dense_22[0][0]']
#
#  dense_23 (Dense)            (None, 5)                    325       ['dropout_15[0][0]']
#
# ==================================================================================================
# Total params: 25733 (100.52 KB)
# Trainable params: 25733 (100.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Add a checkpoint callback to store the checkpoint that has the highest
# validation accuracy.
checkpoint_path = "weights_MoveNet.keras"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='max')
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                              patience=20)

# Start training
history = model.fit(X_train, y_train,
                    epochs=200,
                    batch_size=16,
                    validation_data=(X_test,y_test),
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/200
# 35/44 [======================>.......] - ETA: 0s - loss: 1.4164 - accuracy: 0.5018
# Epoch 1: val_accuracy improved from -inf to 0.42925, saving model to weights_MoveNet.keras
# 44/44 [==============================] - 2s 12ms/step - loss: 1.3518 - accuracy: 0.5159 - val_loss: 1.0866 - val_accuracy: 0.4292
# Epoch 2/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.8988 - accuracy: 0.6143
# Epoch 2: val_accuracy improved from 0.42925 to 0.83019, saving model to weights_MoveNet.keras
# 44/44 [==============================] - 0s 6ms/step - loss: 0.8698 - accuracy: 0.6420 - val_loss: 0.6541 - val_accuracy: 0.8302
# Epoch 3/200
# 33/44 [=====================>........] - ETA: 0s - loss: 0.6413 - accuracy: 0.7803
# Epoch 3: val_accuracy improved from 0.83019 to 0.84670, saving model to weights_MoveNet.keras
# 44/44 [==============================] - 0s 6ms/step - loss: 0.6358 - accuracy: 0.7739 - val_loss: 0.4275 - val_accuracy: 0.8467
# Epoch 4/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.4737 - accuracy: 0.8446
# Epoch 4: val_accuracy improved from 0.84670 to 0.97170, saving model to weights_MoveNet.keras
# 44/44 [==============================] - 0s 6ms/step - loss: 0.4803 - accuracy: 0.8290 - val_loss: 0.2885 - val_accuracy: 0.9717
# Epoch 5/200
# 33/44 [=====================>........] - ETA: 0s - loss: 0.4172 - accuracy: 0.8485
# Epoch 5: val_accuracy improved from 0.97170 to 0.97642, saving model to weights_MoveNet.keras
# 44/44 [==============================] - 0s 7ms/step - loss: 0.3995 - accuracy: 0.8623 - val_loss: 0.2024 - val_accuracy: 0.9764
# Epoch 6/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.3340 - accuracy: 0.8982
# Epoch 6: val_accuracy improved from 0.97642 to 0.98349, saving model to weights_MoveNet.keras
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3373 - accuracy: 0.8971 - val_loss: 0.1509 - val_accuracy: 0.9835
# Epoch 7/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.2812 - accuracy: 0.9179
# Epoch 7: val_accuracy improved from 0.98349 to 0.98585, saving model to weights_MoveNet.keras
# 44/44 [==============================] - 0s 6ms/step - loss: 0.2772 - accuracy: 0.9246 - val_loss: 0.1174 - val_accuracy: 0.9858
# Epoch 8/200
# 33/44 [=====================>........] - ETA: 0s - loss: 0.2454 - accuracy: 0.9129
# Epoch 8: val_accuracy improved from 0.98585 to 0.98821, saving model to weights_MoveNet.keras
# 44/44 [==============================] - 0s 7ms/step - loss: 0.2470 - accuracy: 0.9130 - val_loss: 0.0876 - val_accuracy: 0.9882
# Epoch 9/200
# 33/44 [=====================>........] - ETA: 0s - loss: 0.1847 - accuracy: 0.9527
# Epoch 9: val_accuracy did not improve from 0.98821
# 44/44 [==============================] - 0s 5ms/step - loss: 0.1918 - accuracy: 0.9478 - val_loss: 0.0735 - val_accuracy: 0.9858
# Epoch 10/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.2036 - accuracy: 0.9429
# Epoch 10: val_accuracy did not improve from 0.98821
# 44/44 [==============================] - 0s 5ms/step - loss: 0.1938 - accuracy: 0.9435 - val_loss: 0.0800 - val_accuracy: 0.9764
# Epoch 11/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.1634 - accuracy: 0.9500
# Epoch 11: val_accuracy improved from 0.98821 to 0.99057, saving model to weights_MoveNet.keras
# 44/44 [==============================] - 0s 6ms/step - loss: 0.1609 - accuracy: 0.9493 - val_loss: 0.0583 - val_accuracy: 0.9906
# Epoch 12/200
# 36/44 [=======================>......] - ETA: 0s - loss: 0.1398 - accuracy: 0.9601
# Epoch 12: val_accuracy improved from 0.99057 to 0.99292, saving model to weights_MoveNet.keras
# 44/44 [==============================] - 0s 6ms/step - loss: 0.1467 - accuracy: 0.9609 - val_loss: 0.0423 - val_accuracy: 0.9929
# Epoch 13/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0
200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.0455 - accuracy: 0.9839
# Epoch 30: val_accuracy did not improve from 0.99764
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0499 - accuracy: 0.9826 - val_loss: 0.0131 - val_accuracy: 0.9953
# Epoch 31/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.0367 - accuracy: 0.9929
# Epoch 31: val_accuracy did not improve from 0.99764
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0367 - accuracy: 0.9928 - val_loss: 0.0119 - val_accuracy: 0.9976
# Epoch 32/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.0479 - accuracy: 0.9875
# Epoch 32: val_accuracy did not improve from 0.99764
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0447 - accuracy: 0.9884 - val_loss: 0.0106 - val_accuracy: 0.9976
# Epoch 33/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.0425 - accuracy: 0.9839
# Epoch 33: val_accuracy did not improve from 0.99764
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0381 - accuracy: 0.9870 - val_loss: 0.0099 - val_accuracy: 0.9976
# Epoch 34/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.0416 - accuracy: 0.9893
# Epoch 34: val_accuracy did not improve from 0.99764
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0429 - accuracy: 0.9884 - val_loss: 0.0110 - val_accuracy: 0.9976
# Epoch 35/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.0297 - accuracy: 0.9946
# Epoch 35: val_accuracy did not improve from 0.99764
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.9928 - val_loss: 0.0160 - val_accuracy: 0.9953
# Epoch 36/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.0353 - accuracy: 0.9911
# Epoch 36: val_accuracy did not improve from 0.99764
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0356 - accuracy: 0.9913 - val_loss: 0.0085 - val_accuracy: 0.9976
# Epoch 37/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.0336 - accuracy: 0.9929
# Epoch 37: val_accuracy did not improve from 0.99764
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0348 - accuracy: 0.9928 - val_loss: 0.0079 - val_accuracy: 0.9976
# Epoch 38/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.0317 - accuracy: 0.9911
# Epoch 38: val_accuracy did not improve from 0.99764
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0387 - accuracy: 0.9884 - val_loss: 0.0080 - val_accuracy: 0.9976
# Epoch 39/200
# 35/44 [======================>.......] - ETA: 0s - loss: 0.0289 - accuracy: 0.9946
# Epoch 39: val_accuracy did not improve from 0.99764
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0338 - accuracy: 0.9913 - val_loss: 0.0095 - val_accuracy: 0.9976

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of MoveNet for {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.savefig("Accuracy_Graph_MoveNet.png")
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of MoveNet for {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.savefig("Loss_Graph_MoveNet.png")
plt.show()

# %%
# Evaluate the model using the TEST dataset
#model = keras.models.load_model('weights_MoveNet.keras')
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.9976

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of MoveNet for {dataset_name}')
plt.savefig("Confusion_Matrix_MoveNet.png")
plt.show()

class_report = classification_report(y_true, y_pred, target_names=class_names)
print(class_report)
# Out:
# 14/14 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#        chair       1.00      1.00      1.00        84
#        cobra       0.99      1.00      0.99        83
#          dog       1.00      1.00      1.00        84
#         tree       1.00      1.00      1.00        96
#      warrior       1.00      0.99      0.99        77
#
#     accuracy                           1.00       424
#    macro avg       1.00      1.00      1.00       424
# weighted avg       1.00      1.00      1.00       424

# %%
with open('history_for_MoveNet.pkl', 'wb') as f:
    pickle.dump(history, f)

files_to_zip = ['weights_MoveNet.keras', 'history_for_MoveNet.pkl', 'Confusion_Matrix_MoveNet.png','Accuracy_Graph_MoveNet.png','Loss_Graph_MoveNet.png' ]
zip_filename = 'results_MoveNet.zip'
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # MediaPipe

# %%
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.3, model_complexity=2)
mp_drawing = mp.solutions.drawing_utils
# Out:
# Downloading model to /usr/local/lib/python3.10/dist-packages/mediapipe/modules/pose_landmark/pose_landmark_heavy.tflite

# %%
# Read an image from the specified path.
sample_img = cv2.imread('/content/dataset/test/chair/guy3_chair070.jpg')
sample_img = cv2.cvtColor(sample_img, cv2.COLOR_BGR2RGB)
# Specify a size of the figure.
plt.figure(figsize = [10, 10])
results = pose.process(sample_img)
img_copy = sample_img.copy()

# Check if any landmarks are found.
if results.pose_landmarks:

    # Draw Pose landmarks on the sample image.
    mp_drawing.draw_landmarks(image=img_copy, landmark_list=results.pose_landmarks, connections=mp_pose.POSE_CONNECTIONS)

    # Specify a size of the figure.
    fig = plt.figure(figsize = [10, 10])

    # Display the output image with the landmarks drawn, also convert BGR to RGB for display.
    plt.title("Output");plt.axis('off');plt.imshow(img_copy);plt.show()

# %%
def detectPose(image, pose, display=True):
    '''
    This function performs pose detection on an image.
    Args:
        image: The input image with a prominent person whose pose landmarks needs to be detected.
        pose: The pose setup function required to perform the pose detection.
        display: A boolean value that is if set to true the function displays the original input image, the resultant image,
                 and the pose landmarks in 3D plot and returns nothing.
    Returns:
        output_image: The input image with the detected pose landmarks drawn.
        landmarks: A list of dictionaries representing the detected landmarks with name, x, y, and score.
    '''

    # Create a copy of the input image.
    output_image = image.copy()

    # Convert the image from BGR into RGB format.
    imageRGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Perform the Pose Detection.
    results = pose.process(imageRGB)

    # Retrieve the height and width of the input image.
    height, width, _ = image.shape

    # Initialize a list to store the detected landmarks.
    landmarks = []

    # Check if any landmarks are detected.
    if results.pose_landmarks:
        # Draw Pose landmarks on the output image.
        mp_drawing.draw_landmarks(image=output_image, landmark_list=results.pose_landmarks, connections=mp_pose.POSE_CONNECTIONS)

        # Iterate over the detected landmarks.
        for idx, landmark in enumerate(results.pose_landmarks.landmark):
            # Append the landmark into the list as a dictionary with name, x, y, and score.
            landmarks.append({
                'name': mp_pose.PoseLandmark(idx).name,
                'x': landmark.x * width,
                'y': landmark.y * height,
                'score': landmark.visibility
            })

    # Check if the original input image and the resultant image are specified to be displayed.
    if display:
        # Display the original input image and the resultant image.
        plt.figure(figsize=[22, 22])
        plt.subplot(121);plt.imshow(image[:,:,::-1]);plt.title("Original Image");plt.axis('off');
        plt.subplot(122);plt.imshow(output_image[:,:,::-1]);plt.title("Output Image");plt.axis('off');

        # Also Plot the Pose landmarks in 3D.
        mp_drawing.plot_landmarks(results.pose_world_landmarks, mp_pose.POSE_CONNECTIONS)

    # Otherwise
    else:
        # Return the output image and the found landmarks.
        return output_image, landmarks

def landmarks_list_to_df(landmarks):
    # Convert the list of dictionaries to a DataFrame
    landmarks_df = pd.DataFrame(landmarks)

    # Initialize an empty list to store the transformed data
    transformed_data = []

    # Loop through each row of the DataFrame
    for index, row in landmarks_df.iterrows():
        transformed_row = dict()
        for landmark in row:
            if landmark is not None:
                name_x = landmark['name']+"_x"
                name_y = landmark['name']+'_y'
                name_score = landmark['name']+'_score'
                transformed_row[name_x] = landmark['x']
                transformed_row[name_y] = landmark['y']
                transformed_row[name_score] = landmark['score']
        transformed_data.append(transformed_row)

        # print()
    # Convert the transformed data list to a DataFrame
    landmarks_df_transformed = pd.DataFrame(transformed_data)
    return landmarks_df_transformed

def create_landmarks_dataframe(dataset_dir, pose):
    image_paths_train = []
    image_paths_test = []
    landmarks_train = []
    landmarks_test = []
    pose_name_train = []
    pose_name_test = []
    class_labels = {}
    class_label_counter = 0
    for root, _, files in os.walk(dataset_dir):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
                image_path = os.path.join(root, file)
                img = cv2.imread(image_path)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                istrain = root.split(os.path.sep)[-2]
                o_img, landmark = detectPose(img, pose, display=False)
                if len(landmark)==0:
                    print(image_path)
                    print(landmark)
                    print()

                if landmark:
                    if istrain == 'train':
                        image_paths_train.append(image_path)
                        landmarks_train.append(landmark)
                        folder_name = root.split(os.path.sep)[-1]
                        pose_name_train.append(folder_name)
                        if folder_name not in class_labels:
                            class_labels[folder_name] = class_label_counter
                            class_label_counter += 1
                    else:
                        image_paths_test.append(image_path)
                        landmarks_test.append(landmark)
                        folder_name = root.split(os.path.sep)[-1]
                        pose_name_test.append(folder_name)
                        if folder_name not in class_labels:
                            class_labels[folder_name] = class_label_counter
                            class_label_counter += 1

    landmarks_train_df = landmarks_list_to_df(landmarks_train)
    landmarks_test_df = landmarks_list_to_df(landmarks_test)

    train_df = pd.DataFrame({'path': image_paths_train, 'pose_name': pose_name_train})
    test_df = pd.DataFrame({'path': image_paths_test, 'pose_name': pose_name_test})

    train_df['label'] = train_df['pose_name'].map(class_labels)
    test_df['label'] = test_df['pose_name'].map(class_labels)

    # # Combine the DataFrames horizontally
    train_combined_df = pd.concat([train_df, landmarks_train_df], axis=1)
    test_combined_df = pd.concat([test_df, landmarks_test_df], axis=1)

    return train_combined_df, test_combined_df

# %%
train_df, test_df = create_landmarks_dataframe('/content/dataset', pose)
# Out:
# /content/dataset/test/warrior/guy3_warrior150.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior052.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior051.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior065.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior108.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior081.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior044.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior069.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior056.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior106.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior080.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior119.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior125.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior140.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior079.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior053.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior047.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior118.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior116.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior082.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior043.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior046.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior142.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior141.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior117.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior133.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior077.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior058.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior107.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior078.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior055.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior109.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior124.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior143.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior045.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior054.jpg
# []
#
# /content/dataset/test/warrior/guy3_warrior123.jpg
# []
#
# /content/dataset/test/chair/guy3_chair119.jpg
# []
#
# /content/dataset/test/chair/guy3_chair118.jpg
# []
#
# /content/dataset/test/chair/guy3_chair145.jpg
# []
#
# /content/dataset/test/dog/guy3_dog046.jpg
# []
#
# /content/dataset/test/dog/guy3_dog032.jpg
# []
#
# /content/dataset/test/dog/guy3_dog048.jpg
# []
#
# /content/dataset/test/dog/guy3_dog049.jpg
# []
#
# /content/dataset/test/dog/guy3_dog043.jpg
# []
#
# /content/dataset/test/dog/guy3_dog038.jpg
# []
#
# /content/dataset/test/dog/guy3_dog039.jpg
# []
#
# /content/dataset/test/dog/guy3_dog031.jpg
# []
#
# /content/dataset/test/cobra/guy3_cobra034.jpg
# []
#
# /content/dataset/test/cobra/guy3_cobra042.jpg
# []
#
# /content/dataset/test/cobra/guy3_cobra044.jpg
# []
#
# /content/dataset/test/cobra/guy3_cobra043.jpg
# []
#
# /content/dataset/test/cobra/guy3_cobra083.jpg
# []
#
# /content/dataset/test/cobra/guy3_cobra040.jpg
# []
#
# /content/dataset/test/cobra/guy3_cobra039.jpg
# []
#
# /content/dataset/test/cobra/guy3_cobra060.jpg
# []
#
# /content/dataset/test/cobra/guy3_cobra036.jpg
# []
#
# /content/dataset/test/tree/guy3_tree175.jpg
# []
#
# /content/dataset/test/tree/guy3_tree165.jpg
# []
#
# /content/dataset/test/tree/guy3_tree162.jpg
# []
#
# /content/dataset/test/tree/guy3_tree177.jpg
# []
#
# /content/dataset/test/tree/guy3_tree174.jpg
# []
#
# /content/dataset/test/tree/guy3_tree163.jpg
# []
#
# /content/dataset/test/tree/guy3_tree170.jpg
# []
#
# /content/dataset/test/tree/guy3_tree176.jpg
# []
#
# /content/dataset/test/tree/guy3_tree168.jpg
# []
#
# /content/dataset/train/warrior/girl2_warrior078.jpg
# []
#
# /content/dataset/train/warrior/guy2_warrior150.jpg
# []
#
# /content/dataset/train/warrior/girl2_warrior079.jpg
# []
#
# /content/dataset/train/warrior/girl2_warrior063.jpg
# []
#
# /content/dataset/train/warrior/guy2_warrior148.jpg
# []
#
# /content/dataset/train/chair/girl3_chair139.jpg
# []
#
# /content/dataset/train/chair/girl3_chair093.jpg
# []
#
# /content/dataset/train/chair/girl3_chair095.jpg
# []
#
# /content/dataset/train/chair/girl3_chair142.jpg
# []
#
# /content/dataset/train/chair/girl1_chair131.jpg
# []
#
# /content/dataset/train/dog/girl2_dog059.jpg
# []
#
# /content/dataset/train/dog/girl2_dog030.jpg
# []
#
# /content/dataset/train/dog/girl2_dog099.jpg
# []
#
# /content/dataset/train/dog/girl2_dog068.jpg
# []
#
# /content/dataset/train/dog/girl2_dog104.jpg
# []
#
# /content/dataset/train/dog/girl2_dog067.jpg
# []
#
# /content/dataset/train/dog/girl2_dog058.jpg
# []
#
# /content/dataset/train/dog/girl2_dog105.jpg
# []
#
# /content/dataset/train/cobra/guy2_cobra122.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra052.jpg
# []
#
# /content/dataset/train/cobra/guy2_cobra124.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra126.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra082.jpg
# []
#
# /content/dataset/train/cobra/girl2_cobra089.jpg
# []
#
# /content/dataset/train/cobra/guy2_cobra119.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra076.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra094.jpg
# []
#
# /content/dataset/train/cobra/guy2_cobra110.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra072.jpg
# []
#
# /content/dataset/train/cobra/guy2_cobra102.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra096.jpg
# []
#
# /content/dataset/train/cobra/guy2_cobra123.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra107.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra097.jpg
# []
#
# /content/dataset/train/cobra/guy2_cobra105.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra062.jpg
# []
#
# /content/dataset/train/cobra/girl2_cobra078.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra098.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra051.jpg
# []
#
# /content/dataset/train/cobra/girl3_cobra125.jpg
# []
#
# /content/dataset/train/cobra/guy2_cobra108.jpg
# []
#
# /content/dataset/train/cobra/girl1_cobra136.jpg
# []
#
# /content/dataset/train/tree/girl3_tree143.jpg
# []
#
# /content/dataset/train/tree/girl3_tree130.jpg
# []
#
# /content/dataset/train/tree/girl3_tree138.jpg
# []

# %%
train_df.to_csv('train_data_MediaPipe.csv', index=False)
test_df.to_csv('test_data_MediaPipe.csv', index=False)

# %%
# !cp train_data_MediaPipe.csv {path_to_save}
# !cp test_data_MediaPipe.csv {path_to_save}

# %%
def load_pose_landmarks(dataframe):
  """Loads a CSV created by MoveNetPreprocessor.

  Returns:
    X: Detected landmark coordinates and scores of shape (N, 17 * 3)
    y: Ground truth labels of shape (N, label_count)
    classes: The list of all class names found in the dataset
    dataframe: The CSV loaded as a Pandas dataframe features (X) and ground
      truth labels (y) to use later to train a pose classification model.
  """

  df_to_process = dataframe.copy()

  # Drop the file_name columns as you don't need it during training.
  df_to_process.drop(columns=['path'], inplace=True)

  # Extract the list of class names
  classes = df_to_process.pop('pose_name').unique()

  # Extract the labels
  y = df_to_process.pop('label')

  # Convert the input features and labels into the correct format for training.
  X = df_to_process.astype('float64')
  y = keras.utils.to_categorical(y)

  return X, y, classes, dataframe

# %%
X_train, y_train, class_names_train, _ = load_pose_landmarks(train_df)
X_test, y_test, class_names_test, _ = load_pose_landmarks(test_df)
# Combine the train and test class names to ensure consistency
class_names = np.unique(np.concatenate((class_names_train, class_names_test), axis=0))

# Build the neural network model
input_shape = X_train.shape[1:]
num_classes = len(class_names)

# %%
model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=input_shape),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(num_classes, activation='softmax')
])

# Compile the model with learning rate
learning_rate = 0.001
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 256)               25600
#
#  batch_normalization_110 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_16 (Dropout)        (None, 256)               0
#
#  dense_25 (Dense)            (None, 128)               32896
#
#  batch_normalization_111 (B  (None, 128)               512
#  atchNormalization)
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_26 (Dense)            (None, 64)                8256
#
#  batch_normalization_112 (B  (None, 64)                256
#  atchNormalization)
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  dense_27 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 68869 (269.02 KB)
# Trainable params: 67973 (265.52 KB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)
checkpoint_pth = 'weights_MediaPipe.keras'
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', save_best_only=True, verbose = 1)
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/100
# 23/30 [======================>.......] - ETA: 0s - loss: 0.8502 - accuracy: 0.6957
# Epoch 1: val_accuracy improved from -inf to 0.52448, saving model to weights_MediaPipe.keras
# 30/30 [==============================] - 3s 17ms/step - loss: 0.7377 - accuracy: 0.7372 - val_loss: 1.9442 - val_accuracy: 0.5245
# Epoch 2/100
# 23/30 [======================>.......] - ETA: 0s - loss: 0.2694 - accuracy: 0.9321
# Epoch 2: val_accuracy improved from 0.52448 to 0.55944, saving model to weights_MediaPipe.keras
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2721 - accuracy: 0.9267 - val_loss: 1.3655 - val_accuracy: 0.5594
# Epoch 3/100
# 23/30 [======================>.......] - ETA: 0s - loss: 0.1981 - accuracy: 0.9524
# Epoch 3: val_accuracy improved from 0.55944 to 0.78322, saving model to weights_MediaPipe.keras
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1990 - accuracy: 0.9476 - val_loss: 0.7010 - val_accuracy: 0.7832
# Epoch 4/100
# 26/30 [=========================>....] - ETA: 0s - loss: 0.1782 - accuracy: 0.9459
# Epoch 4: val_accuracy improved from 0.78322 to 0.86480, saving model to weights_MediaPipe.keras
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1732 - accuracy: 0.9466 - val_loss: 0.5020 - val_accuracy: 0.8648
# Epoch 5/100
# 20/30 [===================>..........] - ETA: 0s - loss: 0.1368 - accuracy: 0.9656
# Epoch 5: val_accuracy improved from 0.86480 to 0.90443, saving model to weights_MediaPipe.keras
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1340 - accuracy: 0.9665 - val_loss: 0.4103 - val_accuracy: 0.9044
# Epoch 6/100
# 23/30 [======================>.......] - ETA: 0s - loss: 0.1136 - accuracy: 0.9674
# Epoch 6: val_accuracy did not improve from 0.90443
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1242 - accuracy: 0.9623 - val_loss: 0.5122 - val_accuracy: 0.8811
# Epoch 7/100
# 30/30 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9759
# Epoch 7: val_accuracy improved from 0.90443 to 0.91142, saving model to weights_MediaPipe.keras
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1064 - accuracy: 0.9759 - val_loss: 0.4153 - val_accuracy: 0.9114
# Epoch 8/100
# 23/30 [======================>.......] - ETA: 0s - loss: 0.1064 - accuracy: 0.9755
# Epoch 8: val_accuracy did not improve from 0.91142
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0978 - accuracy: 0.9780 - val_loss: 0.6752 - val_accuracy: 0.9091
# Epoch 9/100
# 22/30 [=====================>........] - ETA: 0s - loss: 0.1194 - accuracy: 0.9616
# Epoch 9: val_accuracy improved from 0.91142 to 0.92308, saving model to weights_MediaPipe.keras
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1277 - accuracy: 0.9592 - val_loss: 0.8222 - val_accuracy: 0.9231
# Epoch 10/100
# 22/30 [=====================>........] - ETA: 0s - loss: 0.0747 - accuracy: 0.9830
# Epoch 10: val_accuracy did not improve from 0.92308
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0996 - accuracy: 0.9696 - val_loss: 0.8301 - val_accuracy: 0.8695
# Epoch 11/100
# 23/30 [======================>.......] - ETA: 0s - loss: 0.0966 - accuracy: 0.9728
# Epoch 11: val_accuracy improved from 0.92308 to 0.94172, saving model to weights_MediaPipe.keras
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0925 - accuracy: 0.9749 - val_loss: 0.7253 - val_accuracy: 0.9417
# Epoch 12/100
# 22/30 [=====================>........] - ETA: 0s - loss: 0.0894 - accuracy: 0.9688
# Epoch 12: val_accuracy did not improve from 0.94172
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0894 - accuracy: 0.9686 - val_loss: 0.9190 - val_accuracy: 0.9324
# Epoch 13/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9895
# Epoch 13: val_accuracy did not improve from 0.94172
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0621 - accuracy: 0.9895 - val_loss: 1.0209 - val_accuracy: 0.8718
# Epoch 14/100
# 21/30 [====================>.........] - ETA: 0s - loss: 0.0759 - accuracy: 0.9762
# Epoch 14: val_accuracy did not improve from 0.94172
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0876 - accuracy: 0.9738 - val_loss: 1.0390 - val_accuracy: 0.9184
# Epoch 15/100
# 30/30 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9592
# Epoch 15: val_accuracy did not improve from 0.94172
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1208 - accuracy: 0.9592 - val_loss: 1.0955 - val_accuracy: 0.7972
# Epoch 16/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9686
# Epoch 16: val_accuracy did not improve from 0.94172
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0841 - accuracy: 0.9686 - val_loss: 2.0678 - val_accuracy: 0.9091
# Epoch 17/100
# 23/30 [======================>.......] - ETA: 0s - loss: 0.0796 - accuracy: 0.9728
# Epoch 17: val_accuracy did not improve from 0.94172
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0756 - accuracy: 0.9749 - val_loss: 2.2276 - val_accuracy: 0.8228
# Epoch 18/100
# 24/30 [=======================>......] - ETA: 0s - loss: 0.0679 - accuracy: 0.9857
# Epoch 18: val_accuracy did not improve from 0.94172
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0655 - accuracy: 0.9864 - val_loss: 2.0404 - val_accuracy: 0.9417
# Epoch 19/100
# 23/30 [======================>.......] - ETA: 0s - loss: 0.0575 - accuracy: 0.9864
# Epoch 19: val_accuracy did not improve from 0.94172
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0620 - accuracy: 0.9843 - val_loss: 1.5957 - val_accuracy: 0.9254
# Epoch 20/100
# 23/30 [======================>.......] - ETA: 0s - loss: 0.0558 - accuracy: 0.9810
# Epoch 20: val_accuracy did not improve from 0.94172
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0492 - accuracy: 0.9843 - val_loss: 1.6227 - val_accuracy: 0.9161
# Epoch 21/100
# 23/30 [======================>.......] - ETA: 0s - loss: 0.0757 - accuracy: 0.9728
# Epoch 21: val_accuracy did not improve from 0.94172
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0631 - accuracy: 0.9791 - val_loss: 1.1787 - val_accuracy: 0.9114

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f'Training and Validation Accuracy of MediaPipe for {dataset_name}')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.savefig("Accuracy_Graph_MediaPipe.png")
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f'Training and Validation Loss of MediaPipe for {dataset_name}')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.savefig("Loss_Graph_MediaPipe.png")
plt.show()

# %%
model = keras.models.load_model('weights_MediaPipe.keras')
model.evaluate(X_test, y_test)
# Out:
# 14/14 [==============================] - 0s 3ms/step - loss: 0.7253 - accuracy: 0.9417
# [0.7253044247627258, 0.941724956035614]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize = (8,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix of MediaPipe for {dataset_name}')
plt.savefig("Confusion_Matrix_MediaPipe.png")
plt.show()

class_report = classification_report(y_true, y_pred, target_names=class_names)
print(class_report)
# Out:
# 14/14 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#        chair       0.98      0.79      0.88        72
#        cobra       0.99      0.96      0.97        81
#          dog       0.82      0.98      0.89        82
#         tree       0.96      0.96      0.96       107
#      warrior       0.98      0.99      0.98        87
#
#     accuracy                           0.94       429
#    macro avg       0.95      0.94      0.94       429
# weighted avg       0.95      0.94      0.94       429

# %%
with open('history_MediaPipe.pkl', 'wb') as f:
    pickle.dump(history.history, f)

files_to_zip = ['weights_MediaPipe.keras', 'history_MediaPipe.pkl', 'Confusion_Matrix_MediaPipe.png', 'Accuracy_Graph_MediaPipe.png', 'Loss_Graph_MediaPipe.png']
zip_filename = 'results_MediaPipe.zip'
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}

# %% [markdown]
# # Yolo Model

# %%
model = YOLO(model='yolov8x-pose-p6.pt')
image = cv2.imread('/content/dataset/test/chair/guy3_chair070.jpg')
result = model.predict(image, save=False)[0]
result_keypoint = result.keypoints.xyn.cpu().numpy()[0]
Image.fromarray(cv2.cvtColor(result.plot(), cv2.COLOR_BGR2RGB))
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8x-pose-p6.pt to 'yolov8x-pose-p6.pt'...
# 100%|██████████| 190M/190M [00:00<00:00, 388MB/s]
# 0: 1280x1280 1 person, 30.3ms
# Speed: 20.7ms preprocess, 30.3ms inference, 767.2ms postprocess per image at shape (1, 3, 1280, 1280)
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
class GetKeypoint(BaseModel):
    NOSE:           int = 0
    LEFT_EYE:       int = 1
    RIGHT_EYE:      int = 2
    LEFT_EAR:       int = 3
    RIGHT_EAR:      int = 4
    LEFT_SHOULDER:  int = 5
    RIGHT_SHOULDER: int = 6
    LEFT_ELBOW:     int = 7
    RIGHT_ELBOW:    int = 8
    LEFT_WRIST:     int = 9
    RIGHT_WRIST:    int = 10
    LEFT_HIP:       int = 11
    RIGHT_HIP:      int = 12
    LEFT_KNEE:      int = 13
    RIGHT_KNEE:     int = 14
    LEFT_ANKLE:     int = 15
    RIGHT_ANKLE:    int = 16

get_keypoint = GetKeypoint()

# %%
dataset_root_train = '/content/dataset/train'
dataset_root_test = '/content/dataset/test'
pose_list = sorted(os.listdir(dataset_root_train))
pose_list
# Out:
# ['chair', 'cobra', 'dog', 'tree', 'warrior']

# %%
def extract_keypoint(keypoint):
    # nose
    nose_x, nose_y = keypoint[get_keypoint.NOSE]
    # eye
    left_eye_x, left_eye_y = keypoint[get_keypoint.LEFT_EYE]
    right_eye_x, right_eye_y = keypoint[get_keypoint.RIGHT_EYE]
    # ear
    left_ear_x, left_ear_y = keypoint[get_keypoint.LEFT_EAR]
    right_ear_x, right_ear_y = keypoint[get_keypoint.RIGHT_EAR]
    # shoulder
    left_shoulder_x, left_shoulder_y = keypoint[get_keypoint.LEFT_SHOULDER]
    right_shoulder_x, right_shoulder_y = keypoint[get_keypoint.RIGHT_SHOULDER]
    # elbow
    left_elbow_x, left_elbow_y = keypoint[get_keypoint.LEFT_ELBOW]
    right_elbow_x, right_elbow_y = keypoint[get_keypoint.RIGHT_ELBOW]
    # wrist
    left_wrist_x, left_wrist_y = keypoint[get_keypoint.LEFT_WRIST]
    right_wrist_x, right_wrist_y = keypoint[get_keypoint.RIGHT_WRIST]
    # hip
    left_hip_x, left_hip_y = keypoint[get_keypoint.LEFT_HIP]
    right_hip_x, right_hip_y = keypoint[get_keypoint.RIGHT_HIP]
    # knee
    left_knee_x, left_knee_y = keypoint[get_keypoint.LEFT_KNEE]
    right_knee_x, right_knee_y = keypoint[get_keypoint.RIGHT_KNEE]
    # ankle
    left_ankle_x, left_ankle_y = keypoint[get_keypoint.LEFT_ANKLE]
    right_ankle_x, right_ankle_y = keypoint[get_keypoint.RIGHT_ANKLE]

    return [
        nose_x, nose_y,
        left_eye_x, left_eye_y,
        right_eye_x, right_eye_y,
        left_ear_x, left_ear_y,
        right_ear_x, right_ear_y,
        left_shoulder_x, left_shoulder_y,
        right_shoulder_x, right_shoulder_y,
        left_elbow_x, left_elbow_y,
        right_elbow_x, right_elbow_y,
        left_wrist_x, left_wrist_y,
        right_wrist_x, right_wrist_y,
        left_hip_x, left_hip_y,
        right_hip_x, right_hip_y,
        left_knee_x, left_knee_y,
        right_knee_x, right_knee_y,
        left_ankle_x, left_ankle_y,
        right_ankle_x, right_ankle_y
    ]

# %%
dataset_csv_train = []
for pose in pose_list:
    # Using a set to store valid image extensions
    valid_extensions = {'jpg', 'jpeg', 'png', 'bmp'}

    # List all files in the directory
    image_path_list = []
    for ext in valid_extensions:
        image_path_list.extend(glob.glob(f'{dataset_root_train}/{pose}/*.{ext}'))

    for image_path in image_path_list:
        # get image_name
        image_name = image_path.split('/')[-1]
        # read numpy image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip to the next image if reading fails

        # get height width image
        height, width = image.shape[:2]

        # detect pose using yolov8-pose
        results = model.predict(image, save=False)[0]
        results_keypoint = results.keypoints.xyn.cpu().numpy()

        # Check if only one person is detected
        if len(results_keypoint) == 1:
            result_keypoint = results_keypoint[0]
            if len(result_keypoint) == 17:
                keypoint_list = extract_keypoint(result_keypoint)

                # insert image_name, label at index 0, 1
                keypoint_list.insert(0, image_path)
                keypoint_list.insert(1, pose)
                dataset_csv_train.append(keypoint_list)
        else:
            print("------------------------------------------------------------------------")
            print(f"More than one person detected in image: {image_path}. Ignoring pose landmarks.")
            print("------------------------------------------------------------------------")
# Out:
# 0: 1280x1280 1 person, 30.8ms
# Speed: 10.9ms preprocess, 30.8ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 30.3ms
# Speed: 8.3ms preprocess, 30.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 30.3ms
# Speed: 8.1ms preprocess, 30.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 27.0ms
# Speed: 7.6ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 27.0ms
# Speed: 7.7ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 27.0ms
# Speed: 7.6ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 27.0ms
# Speed: 7.5ms preprocess, 27.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 27.1ms
# Speed: 7.3ms preprocess, 27.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.6ms
# Speed: 7.1ms preprocess, 24.6ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 9.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.2ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.1ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.6ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 8.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 8.1ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.9ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.8ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.0ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.0ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.8ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.9ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.0ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.9ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 8.0ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.7ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 28.8ms
# Speed: 8.1ms preprocess, 28.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 8.0ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.1ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 8.1ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.8ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.6ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.8ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 9.7ms preprocess, 24.9ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 28.7ms
# Speed: 9.7ms preprocess, 28.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.7ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 8.0ms preprocess, 25.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 29.5ms
# Speed: 9.5ms preprocess, 29.5ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.4ms preprocess, 25.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.6ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.7ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.9ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.9ms preprocess, 24.8ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 9.8ms preprocess, 24.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.8ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.8ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 8.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 9.6ms preprocess, 24.9ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.2ms preprocess, 24.8ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 9.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 9.6ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.2ms
# Speed: 9.8ms preprocess, 25.2ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 26.9ms
# Speed: 9.5ms preprocess, 26.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.1ms preprocess, 25.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.2ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.7ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.9ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 9.0ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 8.0ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 8.6ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 9.4ms preprocess, 25.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 9.2ms preprocess, 24.8ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 9.5ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.3ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.9ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.3ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.7ms preprocess, 25.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.3ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 7.4ms preprocess, 25.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 10.0ms preprocess, 24.8ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.9ms preprocess, 25.0ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.1ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.5ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.9ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 8.1ms preprocess, 25.0ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.6ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.8ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.9ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.2ms
# Speed: 7.8ms preprocess, 25.2ms inference, 3.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.2ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.2ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 9.5ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 3.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.2ms
# Speed: 7.4ms preprocess, 25.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.2ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/cobra/girl3_cobra052.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 7.7ms preprocess, 25.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 8.0ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 8.5ms preprocess, 24.7ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.2ms preprocess, 24.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.9ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 8.4ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.9ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.9ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 8.0ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.0ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.9ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.0ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/cobra/girl3_cobra039.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.7ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 7.6ms preprocess, 25.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.6ms preprocess, 24.8ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 8.2ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.8ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 31.0ms
# Speed: 7.2ms preprocess, 31.0ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.1ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.2ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/cobra/girl3_cobra078.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.2ms preprocess, 25.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 7.3ms preprocess, 25.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.5ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.6ms preprocess, 25.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 32.0ms
# Speed: 7.5ms preprocess, 32.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.2ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.2ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.2ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 26.7ms
# Speed: 6.8ms preprocess, 26.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 6.8ms preprocess, 24.9ms inference, 2.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.1ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.0ms preprocess, 24.9ms inference, 2.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.1ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# ...
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.5ms preprocess, 25.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 8.5ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.0ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.8ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.7ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 7.7ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.6ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.5ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 11.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.1ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.7ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.2ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.6ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.2ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.3ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 7.3ms preprocess, 25.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.9ms
# Speed: 7.2ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior/girl3_warrior075.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 7.3ms preprocess, 25.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 26.4ms
# Speed: 7.2ms preprocess, 26.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.1ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior/girl3_warrior056.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior/girl3_warrior047.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.1ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.6ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.6ms preprocess, 24.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.8ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.7ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.8ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior/girl3_warrior067.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.2ms preprocess, 25.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 25.1ms
# Speed: 7.3ms preprocess, 25.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior/girl3_warrior061.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.7ms
# Speed: 8.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior/girl3_warrior050.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 3 persons, 25.0ms
# Speed: 7.4ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior/girl3_warrior073.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.7ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.9ms preprocess, 24.8ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.8ms preprocess, 24.8ms inference, 2.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.8ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.1ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 8.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.5ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.4ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.4ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 8.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 8.6ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.8ms
# Speed: 8.8ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/train/warrior/girl3_warrior043.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.9ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)

# %%
dataset_csv_test = []
for pose in pose_list:
    # Using a set to store valid image extensions
    valid_extensions = {'jpg', 'jpeg', 'png', 'bmp'}

    # List all files in the directory
    image_path_list = []
    for ext in valid_extensions:
        image_path_list.extend(glob.glob(f'{dataset_root_test}/{pose}/*.{ext}'))

    for image_path in image_path_list:
        # get image_name
        image_name = image_path.split('/')[-1]
        # read numpy image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            continue  # Skip to the next image if reading fails

        # get height width image
        height, width = image.shape[:2]

        # detect pose using yolov8-pose
        results = model.predict(image, save=False)[0]
        results_keypoint = results.keypoints.xyn.cpu().numpy()

        # Check if only one person is detected
        if len(results_keypoint) == 1:
            result_keypoint = results_keypoint[0]
            if len(result_keypoint) == 17:
                keypoint_list = extract_keypoint(result_keypoint)

                # insert image_name, label at index 0, 1
                keypoint_list.insert(0, image_path)
                keypoint_list.insert(1, pose)
                dataset_csv_test.append(keypoint_list)
        else:
            print("------------------------------------------------------------------------")
            print(f"More than one person detected in image: {image_path}. Ignoring pose landmarks.")
            print("------------------------------------------------------------------------")
# Out:
# 0: 1280x1280 1 person, 24.8ms
# Speed: 9.4ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 28.6ms
# Speed: 9.6ms preprocess, 28.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.7ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.0ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 8.0ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 9.5ms preprocess, 24.9ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.2ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 7.2ms preprocess, 25.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.3ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.2ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.0ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.2ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 3.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.2ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 6.9ms preprocess, 25.1ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.1ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.2ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.2ms preprocess, 24.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 7.1ms preprocess, 25.1ms inference, 2.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.8ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.2ms preprocess, 24.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 3.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.1ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 26.1ms
# Speed: 7.1ms preprocess, 26.1ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.1ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 3.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.0ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.1ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.0ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.8ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.8ms preprocess, 24.7ms inference, 3.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.8ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.8ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.7ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 13.1ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.2ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.1ms preprocess, 25.0ms inference, 2.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 27.8ms
# Speed: 6.9ms preprocess, 27.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.8ms
# Speed: 7.1ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/dog/guy3_dog035.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.1ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.7ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.7ms
# Speed: 6.8ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/dog/guy3_dog036.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.8ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.1ms preprocess, 24.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.8ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.7ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.8ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.7ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/dog/guy3_dog093.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 2 persons, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
# ------------------------------------------------------------------------
# More than one person detected in image: /content/dataset/test/dog/guy3_dog034.jpg. Ignoring pose landmarks.
# ------------------------------------------------------------------------
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.1ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.8ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.3ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.6ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 8.0ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.8ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.2ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.3ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.2ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.6ms preprocess, 24.8ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.6ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.6ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.7ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.1ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 9.0ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.1ms preprocess, 24.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 8.3ms preprocess, 25.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.1ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.9ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.2ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 9.6ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# ...
#
# 0: 1280x1280 1 person, 25.2ms
# Speed: 7.7ms preprocess, 25.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.6ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.9ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.6ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.9ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.9ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.7ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.6ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.6ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.9ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.8ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.9ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.4ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.9ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.9ms preprocess, 24.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.6ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.8ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.0ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.4ms
# Speed: 7.1ms preprocess, 25.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.4ms preprocess, 24.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 3.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.0ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.7ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.1ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 6.9ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 7.9ms preprocess, 25.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 29.4ms
# Speed: 7.7ms preprocess, 29.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.9ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 8.1ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.6ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 8.2ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.3ms preprocess, 24.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.6ms preprocess, 24.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.1ms
# Speed: 7.7ms preprocess, 25.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.6ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.3ms
# Speed: 12.6ms preprocess, 25.3ms inference, 2.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.6ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.5ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 8.4ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.8ms
# Speed: 7.6ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 25.0ms
# Speed: 7.8ms preprocess, 25.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.7ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.4ms preprocess, 24.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.4ms preprocess, 24.9ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.7ms
# Speed: 7.5ms preprocess, 24.7ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 1 person, 24.9ms
# Speed: 7.5ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)

# %%
# Create a list of column headings
column_headings = ['image_path', 'label',
                   'nose_x', 'nose_y',
                   'left_eye_x', 'left_eye_y',
                   'right_eye_x', 'right_eye_y',
                   'left_ear_x', 'left_ear_y',
                   'right_ear_x', 'right_ear_y',
                   'left_shoulder_x', 'left_shoulder_y',
                   'right_shoulder_x', 'right_shoulder_y',
                   'left_elbow_x', 'left_elbow_y',
                   'right_elbow_x', 'right_elbow_y',
                   'left_wrist_x', 'left_wrist_y',
                   'right_wrist_x', 'right_wrist_y',
                   'left_hip_x', 'left_hip_y',
                   'right_hip_x', 'right_hip_y',
                   'left_knee_x', 'left_knee_y',
                   'right_knee_x', 'right_knee_y',
                   'left_ankle_x', 'left_ankle_y',
                   'right_ankle_x', 'right_ankle_y']

with open('train_data_yolo.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)

    # Write the column headings as the first row
    writer.writerow(column_headings)

    # Write the list data to the CSV file
    writer.writerows(dataset_csv_train)



# Create a list of column headings
column_headings = ['image_path', 'label',
                   'nose_x', 'nose_y',
                   'left_eye_x', 'left_eye_y',
                   'right_eye_x', 'right_eye_y',
                   'left_ear_x', 'left_ear_y',
                   'right_ear_x', 'right_ear_y',
                   'left_shoulder_x', 'left_shoulder_y',
                   'right_shoulder_x', 'right_shoulder_y',
                   'left_elbow_x', 'left_elbow_y',
                   'right_elbow_x', 'right_elbow_y',
                   'left_wrist_x', 'left_wrist_y',
                   'right_wrist_x', 'right_wrist_y',
                   'left_hip_x', 'left_hip_y',
                   'right_hip_x', 'right_hip_y',
                   'left_knee_x', 'left_knee_y',
                   'right_knee_x', 'right_knee_y',
                   'left_ankle_x', 'left_ankle_y',
                   'right_ankle_x', 'right_ankle_y']

with open('test_data_yolo.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)

    # Write the column headings as the first row
    writer.writerow(column_headings)

    # Write the list data to the CSV file
    writer.writerows(dataset_csv_test)

# %%
train_df = pd.read_csv('train_data_yolo.csv')
test_df = pd.read_csv('test_data_yolo.csv')

train_df.to_csv('train_data_yolo.csv', index=False)
test_df.to_csv('test_data_yolo.csv', index=False)

# %%
# !cp train_data_yolo.csv {path_to_save}
# !cp test_data_yolo.csv {path_to_save}

# %%
train_df = train_df.drop('image_path', axis=1)
test_df = test_df.drop('image_path', axis=1)
encoder = LabelEncoder()
y_label_train = train_df['label']
y_train = encoder.fit_transform(y_label_train)
y_label_test = test_df['label']
y_test = encoder.fit_transform(y_label_test)
train_df = train_df.drop('label',axis=1)
X_train = train_df
test_df = test_df.drop('label',axis=1)
X_test = test_df
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
y_train = y_train.astype('int64')
y_test = y_test.astype('int64')

# %%
model = tf.keras.models.Sequential()
model.add(layers.Input(shape=(X_train.shape[1],)))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(len(pose_list), activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               8960
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 50437 (197.02 KB)
# Trainable params: 50437 (197.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10)
checkpoint_pth = 'weights_yolo.keras'
checkpoint = ModelCheckpoint(checkpoint_pth, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/100
# 31/31 [==============================] - ETA: 0s - loss: 1.3045 - accuracy: 0.5036
# Epoch 1: val_accuracy improved from -inf to 0.62322, saving model to weights_yolo.keras
# 31/31 [==============================] - 3s 13ms/step - loss: 1.3045 - accuracy: 0.5036 - val_loss: 0.9777 - val_accuracy: 0.6232
# Epoch 2/100
# 20/31 [==================>...........] - ETA: 0s - loss: 0.8738 - accuracy: 0.7109
# Epoch 2: val_accuracy improved from 0.62322 to 0.93483, saving model to weights_yolo.keras
# 31/31 [==============================] - 0s 5ms/step - loss: 0.8179 - accuracy: 0.7323 - val_loss: 0.5000 - val_accuracy: 0.9348
# Epoch 3/100
# 19/31 [=================>............] - ETA: 0s - loss: 0.5743 - accuracy: 0.8273
# Epoch 3: val_accuracy did not improve from 0.93483
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5498 - accuracy: 0.8318 - val_loss: 0.5380 - val_accuracy: 0.6884
# Epoch 4/100
# 19/31 [=================>............] - ETA: 0s - loss: 0.4161 - accuracy: 0.8849
# Epoch 4: val_accuracy did not improve from 0.93483
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3974 - accuracy: 0.8800 - val_loss: 0.4472 - val_accuracy: 0.7984
# Epoch 5/100
# 20/31 [==================>...........] - ETA: 0s - loss: 0.3203 - accuracy: 0.9031
# Epoch 5: val_accuracy did not improve from 0.93483
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2978 - accuracy: 0.9149 - val_loss: 0.3614 - val_accuracy: 0.8473
# Epoch 6/100
# 19/31 [=================>............] - ETA: 0s - loss: 0.2267 - accuracy: 0.9474
# Epoch 6: val_accuracy improved from 0.93483 to 0.98778, saving model to weights_yolo.keras
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2111 - accuracy: 0.9497 - val_loss: 0.1542 - val_accuracy: 0.9878
# Epoch 7/100
# 20/31 [==================>...........] - ETA: 0s - loss: 0.1601 - accuracy: 0.9594
# Epoch 7: val_accuracy improved from 0.98778 to 0.99593, saving model to weights_yolo.keras
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1570 - accuracy: 0.9621 - val_loss: 0.1140 - val_accuracy: 0.9959
# Epoch 8/100
# 20/31 [==================>...........] - ETA: 0s - loss: 0.1370 - accuracy: 0.9656
# Epoch 8: val_accuracy did not improve from 0.99593
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1352 - accuracy: 0.9662 - val_loss: 0.2493 - val_accuracy: 0.8880
# Epoch 9/100
# 19/31 [=================>............] - ETA: 0s - loss: 0.1168 - accuracy: 0.9737
# Epoch 9: val_accuracy did not improve from 0.99593
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1141 - accuracy: 0.9744 - val_loss: 0.1414 - val_accuracy: 0.9226
# Epoch 10/100
# 19/31 [=================>............] - ETA: 0s - loss: 0.0968 - accuracy: 0.9803
# Epoch 10: val_accuracy did not improve from 0.99593
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0850 - accuracy: 0.9846 - val_loss: 0.1860 - val_accuracy: 0.9084
# Epoch 11/100
# 19/31 [=================>............] - ETA: 0s - loss: 0.0758 - accuracy: 0.9819
# Epoch 11: val_accuracy did not improve from 0.99593
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0733 - accuracy: 0.9826 - val_loss: 0.0512 - val_accuracy: 0.9959
# Epoch 12/100
# 19/31 [=================>............] - ETA: 0s - loss: 0.0901 - accuracy: 0.9770
# Epoch 12: val_accuracy did not improve from 0.99593
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0896 - accuracy: 0.9764 - val_loss: 0.2372 - val_accuracy: 0.8371
# Epoch 13/100
# 20/31 [==================>...........] - ETA: 0s - loss: 0.0565 - accuracy: 0.9891
# Epoch 13: val_accuracy did not improve from 0.99593
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0602 - accuracy: 0.9856 - val_loss: 0.2204 - val_accuracy: 0.8961
# Epoch 14/100
# 18/31 [================>.............] - ETA: 0s - loss: 0.0581 - accuracy: 0.9844
# Epoch 14: val_accuracy did not improve from 0.99593
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0555 - accuracy: 0.9856 - val_loss: 0.1403 - val_accuracy: 0.9226
# Epoch 15/100
# 17/31 [===============>..............] - ETA: 0s - loss: 0.0558 - accuracy: 0.9853
# Epoch 15: val_accuracy did not improve from 0.99593
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9887 - val_loss: 0.0751 - val_accuracy: 0.9695
# Epoch 16/100
# 18/31 [================>.............] - ETA: 0s - loss: 0.0375 - accuracy: 0.9931
# Epoch 16: val_accuracy did not improve from 0.99593
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9887 - val_loss: 0.2478 - val_accuracy: 0.8859
# Epoch 17/100
# 17/31 [===============>..............] - ETA: 0s - loss: 0.0394 - accuracy: 0.9890
# Epoch 17: val_accuracy did not improve from 0.99593
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0396 - accuracy: 0.9918 - val_loss: 0.1269 - val_accuracy: 0.9267

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(f"Training and Validation Accuracy of YoloV8 model for {dataset_name}")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.savefig("Accuracy_Graph_Yolo.png")
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f"Training and Validation Loss of YoloV8 model for {dataset_name}")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.savefig("Loss_Graph_Yolo.png")
plt.show()

# %%
model = tf.keras.models.load_model('weights_yolo.keras')
model.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1140 - accuracy: 0.9959
# [0.11396552622318268, 0.9959266781806946]

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
class_names = encoder.classes_

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f"Confusion Matrix of YoloV8 model for {dataset_name}")
plt.savefig("Confusion_Matrix_Yolo.png")
plt.show()

class_report = classification_report(y_test, y_pred, target_names=class_names)
print(class_report)
# Out:
# 16/16 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#        chair       1.00      0.98      0.99        84
#        cobra       1.00      1.00      1.00       116
#          dog       1.00      1.00      1.00        86
#         tree       0.98      1.00      0.99        96
#      warrior       1.00      1.00      1.00       109
#
#     accuracy                           1.00       491
#    macro avg       1.00      1.00      1.00       491
# weighted avg       1.00      1.00      1.00       491

# %%
with open('history_for_yolo.pkl', 'wb') as f:
    pickle.dump(history.history, f)

def create_zip(files_to_zip, zip_filename):
    with zipfile.ZipFile(zip_filename, 'w') as zipf:
        for file in files_to_zip:
            # Add the file to the zip archive
            zipf.write(file, os.path.basename(file))

files_to_zip = ['weights_yolo.keras', 'history_for_yolo.pkl', 'Accuracy_Graph_Yolo.png', 'Loss_Graph_Yolo.png', 'Confusion_Matrix_Yolo.png']
zip_filename = 'results_yolo.zip'
create_zip(files_to_zip, zip_filename)

# %%
# !cp {zip_filename} {path_to_save}
